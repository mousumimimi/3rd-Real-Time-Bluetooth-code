# %%
#XGB-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-XGB-Dataset-A-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-XGB-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys() if feature not in [feature]]).reshape(1, -1)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    
                    
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")           
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.8051251748487359
# Predicted Label: TiSpy
# Accuracy: 0.8054406983061214
# Precision: 0.8048098985009587
# Recall: 0.8054406983061214
# F1-Score: 0.7963647455743421
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7935957243764599
# Precision: 0.7991531578179832
# Recall: 0.7935957243764599
# F1-Score: 0.7975410484527139
# Predicted Label: Normal-Traffic
# Accuracy: 0.801102251022592
# Precision: 0.794011367542449
# Recall: 0.801102251022592
# F1-Score: 0.7830416029865102
# Predicted Label: TiSpy
# Accuracy: 0.7877535533925185
# Precision: 0.7783856865063251
# Recall: 0.7877535533925185
# F1-Score: 0.7602986607192705
# Predicted Label: Air-Droid
# Accuracy: 0.7579786652313826
# Precision: 0.762632901736997
# Recall: 0.7579786652313826
# F1-Score: 0.7916330792390353
# Predicted Label: Qustodio
# Accuracy: 0.7903354023458399
# Precision: 0.7929350245347795
# Recall: 0.7903354023458399
# F1-Score: 0.7978793603297744
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.802273245372374
# Precision: 0.7935333419351134
# Recall: 0.802273245372374
# F1-Score: 0.7588145213316844
# Predicted Label: Qustodio
# Accuracy: 0.7559192553940252
# Precision: 0.7617320510085261
# Recall: 0.7559192553940252
# F1-Score: 0.7624783880319993
# Predicted Label: Normal-Traffic
# Accuracy: 0.7674568276793026
# Precision: 0.7575641216879362
# Recall: 0.7674568276793026
# F1-Score: 0.772241226735292
# Predicted Label: Eyezy
# Accuracy: 0.7679395018994718
# Precision: 0.7765914165295492
# Recall: 0.7679395018994718
# F1-Score: 0.7831230729485743
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7859095553276824
# Precision: 0.7803562799901754
# Recall: 0.7859095553276824
# F1-Score: 0.794046007719388
# Predicted Label: Air-Droid
# Accuracy: 0.7988904902638112
# Precision: 0.7892599250503397
# Recall: 0.7988904902638112
# F1-Score: 0.7982986451895928
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7954958651882558
# Precision: 0.8011212451587906
# Recall: 0.7954958651882558
# F1-Score: 0.7912383978478166
# Predicted Label: Normal-Traffic
# Accuracy: 0.7866257174373166
# Precision: 0.795905493772028
# Recall: 0.7866257174373166
# F1-Score: 0.8136678335564926
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8106294435801312
# Precision: 0.8167290861279934
# Recall: 0.8106294435801312
# F1-Score: 0.7876581816699637
# Predicted Label: Eyezy
# Accuracy: 0.7827540143543624
# Precision: 0.7926241883165126
# Recall: 0.7827540143543624
# F1-Score: 0.7628813575636613
# Predicted Label: Air-Droid
# Accuracy: 0.7631018107025508
# Precision: 0.7626610317617792
# Recall: 0.7631018107025508
# F1-Score: 0.8030573048942424
# Predicted Label: FamiSafe
# Accuracy: 0.8062376210726726
# Precision: 0.7999019805291371
# Recall: 0.8062376210726726
# F1-Score: 0.808820812745852
# Predicted Label: TiSpy
# Accuracy: 0.8044472006963612
# Precision: 0.8132422416027741
# Recall: 0.8044472006963612
# F1-Score: 0.7618524406110548
# Predicted Label: Normal-Traffic
# Accuracy: 0.7645563748358879
# Precision: 0.7591675644821663
# Recall: 0.7645563748358879
# F1-Score: 0.7895941686734574
# Predicted Label: Normal-Traffic
# Accuracy: 0.7849203060818515
# Precision: 0.7943240263720134
# Recall: 0.7849203060818515
# F1-Score: 0.7955445369018737
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8000881482100634
# Precision: 0.7910522395108284
# Recall: 0.8000881482100634
# F1-Score: 0.7748253209635774
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7702116032797457
# Precision: 0.7794946458826603
# Recall: 0.7702116032797457
# F1-Score: 0.7901385838545537
# Predicted Label: Air-Droid
# Accuracy: 0.7857252226252673
# Precision: 0.7946018041946574
# Recall: 0.7857252226252673
# F1-Score: 0.7941103155485446
# Predicted Label: Qustodio
# Accuracy: 0.7921278757762216
# Precision: 0.7961027030273831
# Recall: 0.7921278757762216
# F1-Score: 0.7561263040202569
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.760210397974381
# Precision: 0.7520858577009185
# Recall: 0.760210397974381
# F1-Score: 0.7699547355723949
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7743267904682947
# Precision: 0.765631775044945
# Recall: 0.7743267904682947
# F1-Score: 0.7748423580159232
# Predicted Label: FamiSafe
# Accuracy: 0.772023568151303
# Precision: 0.7776818070769633
# Recall: 0.772023568151303
# F1-Score: 0.7741704282272168
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.777873816487929
# Precision: 0.7705021358841602
# Recall: 0.777873816487929
# F1-Score: 0.8076518267690158
# Predicted Label: FamiSafe
# Accuracy: 0.8069805569434524
# Precision: 0.8083242142877174
# Recall: 0.8069805569434524
# F1-Score: 0.7609845095869223
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7577925415465089
# Precision: 0.7642034817413764
# Recall: 0.7577925415465089
# F1-Score: 0.7940772672978605
# Predicted Label: Qustodio
# Accuracy: 0.7900507830194103
# Precision: 0.7981450036741672
# Recall: 0.7900507830194103
# F1-Score: 0.764752155502658
# Predicted Label: Normal-Traffic
# Accuracy: 0.7664935956257839
# Precision: 0.7630186103948888
# Recall: 0.7664935956257839
# F1-Score: 0.8096110289098962
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8084451565433871
# Precision: 0.8107802687810637
# Recall: 0.8084451565433871
# F1-Score: 0.7612133670902137
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7597968334092383
# Precision: 0.762635192490054
# Recall: 0.7597968334092383
# F1-Score: 0.7734265854959973
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7734957813459636
# Precision: 0.7733574020252514
# Recall: 0.7734957813459636
# F1-Score: 0.798367121930177
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8028059833516842
# Precision: 0.793977077149239
# Recall: 0.8028059833516842
# F1-Score: 0.8021491988933429
# Predicted Label: FamiSafe
# Accuracy: 0.8063939214601369
# Precision: 0.797948929350845
# Recall: 0.8063939214601369
# F1-Score: 0.7830524982644858
# Predicted Label: TiSpy
# Accuracy: 0.783425374211233
# Precision: 0.7826799770939111
# Recall: 0.783425374211233
# F1-Score: 0.7565910717059611
# Predicted Label: Eyezy
# Accuracy: 0.7558082440819001
# Precision: 0.7573755226372002
# Recall: 0.7558082440819001
# F1-Score: 0.8068321379852904
# Predicted Label: FamiSafe
# Accuracy: 0.8027836356127429
# Precision: 0.8109216811754468
# Recall: 0.8027836356127429
# F1-Score: 0.7537916648447648
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7504301764227963
# Precision: 0.7571834037767401
# Recall: 0.7504301764227963
# F1-Score: 0.7730557245716647
# Predicted Label: Qustodio
# Accuracy: 0.77153904523546
# Precision: 0.7745783785816208
# Recall: 0.77153904523546
# F1-Score: 0.7982008175086375
# Predicted Label: kids-360
# Accuracy: 0.7935640607558705
# Precision: 0.8028920774154348
# Recall: 0.7935640607558705
# F1-Score: 0.8135163378793717
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8102832383337
# Precision: 0.8167753414728093
# Recall: 0.8102832383337
# F1-Score: 0.7659309058935412
# Predicted Label: Eyezy
# Accuracy: 0.7708210961461823
# Precision: 0.761102372499905
# Recall: 0.7708210961461823
# F1-Score: 0.7668922481255949
# Predicted Label: Qustodio
# Accuracy: 0.7646594492217292
# Precision: 0.769138124722752
# Recall: 0.7646594492217292
# F1-Score: 0.8066492346117834
# Predicted Label: Air-Droid
# Accuracy: 0.808308623072288
# Precision: 0.8049966453582194
# Recall: 0.808308623072288
# F1-Score: 0.8012302244440422
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7977489998656957
# Precision: 0.8047419649892754
# Recall: 0.7977489998656957
# F1-Score: 0.7959600096463264
# Predicted Label: FamiSafe
# Accuracy: 0.7998528100647508
# Precision: 0.792104917415418
# Recall: 0.7998528100647508
# F1-Score: 0.812088859872074
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8079363729946019
# Precision: 0.8162842516834851
# Recall: 0.8079363729946019
# F1-Score: 0.749995359497724
# Predicted Label: TiSpy
# Accuracy: 0.7517637360568749
# Precision: 0.7482352829316395
# Recall: 0.7517637360568749
# F1-Score: 0.8057442270348333
# Predicted Label: Normal-Traffic
# Accuracy: 0.803299588077891
# Precision: 0.8082037906910269
# Recall: 0.803299588077891
# F1-Score: 0.7807642834707067
# Predicted Label: Normal-Traffic
# Accuracy: 0.7793945490871801
# Precision: 0.7821388407653951
# Recall: 0.7793945490871801
# F1-Score: 0.7718939957183681
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7721012265798928
# Precision: 0.7716868760679262
# Recall: 0.7721012265798928
# F1-Score: 0.7933636702666109
# Predicted Label: Qustodio
# Accuracy: 0.795583293684221
# Precision: 0.79115639758879
# Recall: 0.795583293684221
# F1-Score: 0.803601017860214
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8059120876407606
# Precision: 0.8013031648341776
# Recall: 0.8059120876407606
# F1-Score: 0.7506757877191877
# Predicted Label: mLite
# Accuracy: 0.7545628894894412
# Precision: 0.7468285292091266
# Recall: 0.7545628894894412
# F1-Score: 0.7946450438716642
# Predicted Label: kids-360
# Accuracy: 0.7950598638873474
# Precision: 0.7942306564923651
# Recall: 0.7950598638873474
# F1-Score: 0.7924116948516289
# Predicted Label: Eyezy
# Accuracy: 0.7956743113562933
# Precision: 0.7891757254228104
# Recall: 0.7956743113562933
# F1-Score: 0.8045367367532339
# Predicted Label: Eyezy
# Accuracy: 0.8033064665600538
# Precision: 0.8057707810635242
# Recall: 0.8033064665600538
# F1-Score: 0.7868605257309358
# Predicted Label: mLite
# Accuracy: 0.7847646829725969
# Precision: 0.7889675930497578
# Recall: 0.7847646829725969
# F1-Score: 0.7939979887759931
# Predicted Label: Normal-Traffic
# Accuracy: 0.7978237683386541
# Precision: 0.7902087253925041
# Recall: 0.7978237683386541
# F1-Score: 0.7763058335031587
# Predicted Label: Air-Droid
# Accuracy: 0.7770217472525015
# Precision: 0.7755912377625024
# Recall: 0.7770217472525015
# F1-Score: 0.7928954437764388
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7923963032875954
# Precision: 0.7933952134914983
# Recall: 0.7923963032875954
# F1-Score: 0.7932174222715901
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7916762771900233
# Precision: 0.7947645793074821
# Recall: 0.7916762771900233
# F1-Score: 0.8012254202753101
# Predicted Label: kids-360
# Accuracy: 0.8005500176945706
# Precision: 0.8019019634564324
# Recall: 0.8005500176945706
# F1-Score: 0.7907225251068766
# Predicted Label: Qustodio
# Accuracy: 0.791151023251164
# Precision: 0.790294490872164
# Recall: 0.791151023251164
# F1-Score: 0.7612986452518256
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7622984434829494
# Precision: 0.7603014661712468
# Recall: 0.7622984434829494
# F1-Score: 0.7978400884257948
# Predicted Label: mLite
# Accuracy: 0.7975084364036475
# Precision: 0.7981720164044575
# Recall: 0.7975084364036475
# F1-Score: 0.7794943214338891
# Predicted Label: TiSpy
# Accuracy: 0.7835108710368145
# Precision: 0.7755187422665064
# Recall: 0.7835108710368145
# F1-Score: 0.7529462423191959
# Predicted Label: FamiSafe
# Accuracy: 0.7529722222606182
# Precision: 0.7529202641704933
# Recall: 0.7529722222606182
# F1-Score: 0.7484973705698472
# Predicted Label: Air-Droid
# Accuracy: 0.7528530789627798
# Precision: 0.74419177304705
# Recall: 0.7528530789627798
# F1-Score: 0.8076047868978081
# Predicted Label: Qustodio
# Accuracy: 0.8062333871793356
# Precision: 0.8089808600564907
# Recall: 0.8062333871793356
# F1-Score: 0.8151076330923863
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8118186928260891
# Precision: 0.8184233308850233
# Recall: 0.8118186928260891
# F1-Score: 0.7703436361640229
# Predicted Label: Air-Droid
# Accuracy: 0.7664090708791972
# Precision: 0.7743188081940369
# Recall: 0.7664090708791972
# F1-Score: 0.8002851589886301
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8025555261594418
# Precision: 0.7980276009660651
# Recall: 0.8025555261594418
# F1-Score: 0.8041644808904528
# Predicted Label: Qustodio
# Accuracy: 0.8002783712649928
# Precision: 0.8080885161682542
# Recall: 0.8002783712649928
# F1-Score: 0.8099032685912135
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8115592721086118
# Precision: 0.8082540095306199
# Recall: 0.8115592721086118
# F1-Score: 0.7583293351194952
# Predicted Label: kids-360
# Accuracy: 0.7533731168120784
# Precision: 0.7633511962523475
# Recall: 0.7533731168120784
# F1-Score: 0.786479864706379
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7905632202715485
# Precision: 0.7824384744454809
# Recall: 0.7905632202715485
# F1-Score: 0.7960126669176498
# Predicted Label: kids-360
# Accuracy: 0.7921759009000752
# Precision: 0.799886779231564
# Recall: 0.7921759009000752
# F1-Score: 0.8005979409444918
# Predicted Label: Eyezy
# Accuracy: 0.7991462371609888
# Precision: 0.8020549285648193
# Recall: 0.7991462371609888
# F1-Score: 0.8008888016969302
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8047738962000474
# Precision: 0.7970410380328237
# Recall: 0.8047738962000474
# F1-Score: 0.8042129844059485
# Predicted Label: mLite
# Accuracy: 0.8066279523888128
# Precision: 0.8018124336318906
# Recall: 0.8066279523888128
# F1-Score: 0.7639103755742362
# Predicted Label: Eyezy
# Accuracy: 0.7604316384029586
# Precision: 0.7674210872905276
# Recall: 0.7604316384029586
# F1-Score: 0.7597416370416108
# Predicted Label: mLite
# Accuracy: 0.7633089033218989
# Precision: 0.7562075583585355
# Recall: 0.7633089033218989
# F1-Score: 0.7887758759780004
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7868807857282765
# Precision: 0.7906801163742183
# Recall: 0.7868807857282765
# F1-Score: 0.8066256131039828
# Predicted Label: mLite
# Accuracy: 0.810959546833212
# Precision: 0.802337755988923
# Recall: 0.810959546833212
# F1-Score: 0.756535969070584
# Predicted Label: Normal-Traffic
# Accuracy: 0.7571892724742334
# Precision: 0.7558837920363174
# Recall: 0.7571892724742334
# F1-Score: 0.8062062137042865
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8043688568307402
# Precision: 0.8080519836563996
# Recall: 0.8043688568307402
# F1-Score: 0.7509100003662714
# Predicted Label: mLite
# Accuracy: 0.7512114185530424
# Precision: 0.7506088239662507
# Recall: 0.7512114185530424
# F1-Score: 0.7975521069493489
# Predicted Label: Normal-Traffic
# Accuracy: 0.7941149350594375
# Precision: 0.8010191624433051
# Recall: 0.7941149350594375
# F1-Score: 0.7780857837685106
# Predicted Label: Air-Droid
# Accuracy: 0.7783267255638509
# Precision: 0.7778449911007318
# Recall: 0.7783267255638509
# F1-Score: 0.7909204609908427
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7949607411779959
# Precision: 0.7869210414873536
# Recall: 0.7949607411779959
# F1-Score: 0.8095094785604543
# Predicted Label: Air-Droid
# Accuracy: 0.8090206718513299
# Precision: 0.8099988762963746
# Recall: 0.8090206718513299
# F1-Score: 0.8080410656146906
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8110186594055928
# Precision: 0.8050852558670166
# Recall: 0.8110186594055928
# F1-Score: 0.7673695989802292
# Predicted Label: kids-360
# Accuracy: 0.7678242875636604
# Precision: 0.7669154485911631
# Recall: 0.7678242875636604
# F1-Score: 0.7658907323945842
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7649205348265872
# Precision: 0.7668633942152298
# Recall: 0.7649205348265872
# F1-Score: 0.7986177212886878
# Predicted Label: FamiSafe
# Accuracy: 0.8025967795235707
# Precision: 0.794677922609312
# Recall: 0.8025967795235707
# F1-Score: 0.7651667075589961
# Predicted Label: FamiSafe
# Accuracy: 0.7609047760796215
# Precision: 0.7694766512810409
# Recall: 0.7609047760796215
# F1-Score: 0.7721945347993238
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7705678551764122
# Precision: 0.7738280968384194
# Recall: 0.7705678551764122
# F1-Score: 0.8108070087816392
# Predicted Label: mLite
# Accuracy: 0.8080423731795875
# Precision: 0.813590627175976
# Recall: 0.8080423731795875
# F1-Score: 0.7691775878543836
# Predicted Label: Qustodio
# Accuracy: 0.7660956493363815
# Precision: 0.7722844232907348
# Recall: 0.7660956493363815
# F1-Score: 0.7747394512792706
# Predicted Label: mLite
# Accuracy: 0.7791195503206437
# Precision: 0.7704083255019644
# Recall: 0.7791195503206437
# F1-Score: 0.7611250116801817
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7601088560425836
# Precision: 0.762143887861079
# Recall: 0.7601088560425836
# F1-Score: 0.8051923405972388
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8066491843314119
# Precision: 0.8037407496234512
# Recall: 0.8066491843314119
# F1-Score: 0.7840628540955843
# Predicted Label: mLite
# Accuracy: 0.7843745679738879
# Precision: 0.7837513878717745
# Recall: 0.7843745679738879
# F1-Score: 0.7614785532462649
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7567492774379219
# Precision: 0.766267311647153
# Recall: 0.7567492774379219
# F1-Score: 0.8071484190515028
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8078623779728079
# Precision: 0.8064357209569575
# Recall: 0.8078623779728079
# F1-Score: 0.7811858156368959
# Predicted Label: Normal-Traffic
# Accuracy: 0.7800772981688856
# Precision: 0.782297488073391
# Recall: 0.7800772981688856
# F1-Score: 0.789181540938326
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7861111277146692
# Precision: 0.7922760332096994
# Recall: 0.7861111277146692
# F1-Score: 0.7775476971686575
# Predicted Label: Air-Droid
# Accuracy: 0.7811280376905737
# Precision: 0.774000028244519
# Recall: 0.7811280376905737
# F1-Score: 0.7507070635604692
# Predicted Label: Qustodio
# Accuracy: 0.7536829222502662
# Precision: 0.7477546123435376
# Recall: 0.7536829222502662
# F1-Score: 0.7742727356569521
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7748145027081946
# Precision: 0.7737317257067979
# Recall: 0.7748145027081946
# F1-Score: 0.7602320344572842
# Predicted Label: Air-Droid
# Accuracy: 0.7641786729142865
# Precision: 0.7563259517660654
# Recall: 0.7641786729142865
# F1-Score: 0.7705739616402529
# Predicted Label: TiSpy
# Accuracy: 0.7727724591251984
# Precision: 0.7683879378903554
# Recall: 0.7727724591251984
# F1-Score: 0.7786814151654473
# Predicted Label: Air-Droid
# Accuracy: 0.7777567421408198
# Precision: 0.7796082894900379
# Recall: 0.7777567421408198
# F1-Score: 0.8002327114980089
# Predicted Label: kids-360
# Accuracy: 0.7958515134141204
# Precision: 0.804662413982577
# Recall: 0.7958515134141204
# F1-Score: 0.8038138494297579
# Predicted Label: Normal-Traffic
# Accuracy: 0.8001211002557297
# Precision: 0.8075408424788159
# Recall: 0.8001211002557297

# %%
#XGB-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-XGB-Dataset-B-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-XGB-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7767071239360941
# Predicted Label: Air-Droid
# Accuracy: 0.7767051605532385
# Precision: 0.7767090873288758
# Recall: 0.7767051605532385
# F1-Score: 0.7332920562643752
# Predicted Label: FamiSafe
# Accuracy: 0.735398068408705
# Precision: 0.7311980719508576
# Recall: 0.735398068408705
# F1-Score: 0.7355093212435
# Predicted Label: Qustodio
# Accuracy: 0.7350450069935315
# Precision: 0.7359742224615847
# Recall: 0.7350450069935315
# F1-Score: 0.7836615700522659
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7798576087023238
# Precision: 0.7875028229528662
# Recall: 0.7798576087023238
# F1-Score: 0.7475025407702343
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7446160208284779
# Precision: 0.7504115271161561
# Recall: 0.7446160208284779
# F1-Score: 0.7896931860281431
# Predicted Label: Air-Droid
# Accuracy: 0.7881134367550273
# Precision: 0.7912792811394745
# Recall: 0.7881134367550273
# F1-Score: 0.7453658421365613
# Predicted Label: kids-360
# Accuracy: 0.7492958024837165
# Precision: 0.7414768909770689
# Recall: 0.7492958024837165
# F1-Score: 0.7827702737219487
# Predicted Label: Air-Droid
# Accuracy: 0.7819711784643848
# Precision: 0.7835710038388336
# Recall: 0.7819711784643848
# F1-Score: 0.7756419355370255
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7778034757312519
# Precision: 0.7734923760237679
# Recall: 0.7778034757312519
# F1-Score: 0.7584467462594066
# Predicted Label: Qustodio
# Accuracy: 0.7589169619279742
# Precision: 0.7579771129097967
# Recall: 0.7589169619279742
# F1-Score: 0.7408839815959231
# Predicted Label: Air-Droid
# Accuracy: 0.7407636034281279
# Precision: 0.7410043988943087
# Recall: 0.7407636034281279
# F1-Score: 0.7316847829728098
# Predicted Label: TiSpy
# Accuracy: 0.7315247226075305
# Precision: 0.7318449133970403
# Recall: 0.7315247226075305
# F1-Score: 0.7851124413103133
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7829696638048088
# Precision: 0.7872669794135092
# Recall: 0.7829696638048088
# F1-Score: 0.75327020393688
# Predicted Label: mLite
# Accuracy: 0.7485365439948112
# Precision: 0.7580641151549994
# Recall: 0.7485365439948112
# F1-Score: 0.7777009663291996
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7786873644057754
# Precision: 0.7767170641200298
# Recall: 0.7786873644057754
# F1-Score: 0.7377436729581128
# Predicted Label: TiSpy
# Accuracy: 0.741876531654753
# Precision: 0.7336566059665833
# Recall: 0.741876531654753
# F1-Score: 0.7522448469928196
# Predicted Label: Air-Droid
# Accuracy: 0.7528182693710829
# Precision: 0.7516722975023981
# Recall: 0.7528182693710829
# F1-Score: 0.7531924970221257
# Predicted Label: Qustodio
# Accuracy: 0.7528408583544857
# Precision: 0.7535444643316899
# Recall: 0.7528408583544857
# F1-Score: 0.7574377096891932
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7562211394088654
# Precision: 0.758658200590157
# Recall: 0.7562211394088654
# F1-Score: 0.7363488286425756
# Predicted Label: Qustodio
# Accuracy: 0.7341857324027559
# Precision: 0.7385247086000333
# Recall: 0.7341857324027559
# F1-Score: 0.777522922421692
# Predicted Label: kids-360
# Accuracy: 0.7732492465499217
# Precision: 0.7818441012471409
# Recall: 0.7732492465499217
# F1-Score: 0.7818687656063847
# Predicted Label: mLite
# Accuracy: 0.7834251564578799
# Precision: 0.7803185464986483
# Recall: 0.7834251564578799
# F1-Score: 0.7684376362746196
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7660542207992473
# Precision: 0.7708359290224727
# Recall: 0.7660542207992473
# F1-Score: 0.7482292171029026
# Predicted Label: FamiSafe
# Accuracy: 0.7505916186545326
# Precision: 0.7458816396731747
# Recall: 0.7505916186545326
# F1-Score: 0.7628734393112772
# Predicted Label: FamiSafe
# Accuracy: 0.7582243886263235
# Precision: 0.7675798529994584
# Recall: 0.7582243886263235
# F1-Score: 0.7826279192130834
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7853190239321801
# Precision: 0.7799551950816108
# Recall: 0.7853190239321801
# F1-Score: 0.7514382213057802
# Predicted Label: Eyezy
# Accuracy: 0.7559369964218197
# Precision: 0.7469926761357855
# Recall: 0.7559369964218197
# F1-Score: 0.7659718534657899
# Predicted Label: Eyezy
# Accuracy: 0.7686977966089428
# Precision: 0.7632651753922396
# Recall: 0.7686977966089428
# F1-Score: 0.7778136522980434
# Predicted Label: kids-360
# Accuracy: 0.7743090144577595
# Precision: 0.7813501594083112
# Recall: 0.7743090144577595
# F1-Score: 0.7623035940963641
# Predicted Label: Normal-Traffic
# Accuracy: 0.7597554121402703
# Precision: 0.7648689265259939
# Recall: 0.7597554121402703
# F1-Score: 0.7720235690266624
# Predicted Label: kids-360
# Accuracy: 0.7737148818076718
# Precision: 0.7703396344145229
# Recall: 0.7737148818076718
# F1-Score: 0.7674881017317545
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7644899186892296
# Precision: 0.7705098939643353
# Recall: 0.7644899186892296
# F1-Score: 0.763769659354091
# Predicted Label: Eyezy
# Accuracy: 0.7653309943522574
# Precision: 0.7622146818767478
# Recall: 0.7653309943522574
# F1-Score: 0.77729746046727
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.776399135245252
# Precision: 0.778197866894605
# Recall: 0.776399135245252
# F1-Score: 0.7678734171565438
# Predicted Label: Air-Droid
# Accuracy: 0.7681275125640701
# Precision: 0.7676194898021709
# Recall: 0.7681275125640701
# F1-Score: 0.761039223669649
# Predicted Label: TiSpy
# Accuracy: 0.7578165284337645
# Precision: 0.7642894456732501
# Recall: 0.7578165284337645
# F1-Score: 0.7492155097070231
# Predicted Label: FamiSafe
# Accuracy: 0.7481296164294685
# Precision: 0.7503045598659588
# Recall: 0.7481296164294685
# F1-Score: 0.7827033711363347
# Predicted Label: TiSpy
# Accuracy: 0.7799602043048317
# Precision: 0.7854659018363653
# Recall: 0.7799602043048317
# F1-Score: 0.7724331201531132
# Predicted Label: TiSpy
# Accuracy: 0.7697428309376346
# Precision: 0.7751422807122593
# Recall: 0.7697428309376346
# F1-Score: 0.7870464317682665
# Predicted Label: Air-Droid
# Accuracy: 0.7855211838435928
# Precision: 0.7885776143697035
# Recall: 0.7855211838435928
# F1-Score: 0.7584892807660673
# Predicted Label: FamiSafe
# Accuracy: 0.7543609223152316
# Precision: 0.7626630740442338
# Recall: 0.7543609223152316
# F1-Score: 0.7573260472043986
# Predicted Label: Normal-Traffic
# Accuracy: 0.7560931352827704
# Precision: 0.7585629865519246
# Recall: 0.7560931352827704
# F1-Score: 0.7784427117446798
# Predicted Label: mLite
# Accuracy: 0.77415569216753
# Precision: 0.7827774759242774
# Recall: 0.77415569216753
# F1-Score: 0.7417663700675229
# Predicted Label: FamiSafe
# Accuracy: 0.7431816094202943
# Precision: 0.7403565105452701
# Recall: 0.7431816094202943
# F1-Score: 0.7757086712127355
# Predicted Label: FamiSafe
# Accuracy: 0.7727151477461152
# Precision: 0.7787254788965652
# Recall: 0.7727151477461152
# F1-Score: 0.7353729291563754
# Predicted Label: kids-360
# Accuracy: 0.735638827463531
# Precision: 0.735107222998848
# Recall: 0.735638827463531
# F1-Score: 0.7817225521567905
# Predicted Label: Normal-Traffic
# Accuracy: 0.7824190030731938
# Precision: 0.781027339994843
# Recall: 0.7824190030731938
# F1-Score: 0.7465250248848564
# Predicted Label: Qustodio
# Accuracy: 0.7431917231902946
# Precision: 0.7498883617857878
# Recall: 0.7431917231902946
# F1-Score: 0.7380808250347584
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7396576518602542
# Precision: 0.736510706971224
# Recall: 0.7396576518602542
# F1-Score: 0.7879476659237581
# Predicted Label: FamiSafe
# Accuracy: 0.7853587329115511
# Precision: 0.7905537242112188
# Recall: 0.7853587329115511
# F1-Score: 0.763907724059915
# Predicted Label: FamiSafe
# Accuracy: 0.7642710729603357
# Precision: 0.7635447204811793
# Recall: 0.7642710729603357
# F1-Score: 0.7625218771691245
# Predicted Label: Eyezy
# Accuracy: 0.7660247373130479
# Precision: 0.7590509067955703
# Recall: 0.7660247373130479
# F1-Score: 0.7311664528302727
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7356564022892463
# Precision: 0.7267309781278023
# Recall: 0.7356564022892463
# F1-Score: 0.7628551176674564
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7630741754561701
# Precision: 0.7626361856136836
# Recall: 0.7630741754561701
# F1-Score: 0.7732552528337949
# Predicted Label: FamiSafe
# Accuracy: 0.7740316381896438
# Precision: 0.7724804234097445
# Recall: 0.7740316381896438
# F1-Score: 0.7839385913950863
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7852040525866679
# Precision: 0.7826772025597735
# Recall: 0.7852040525866679
# F1-Score: 0.7813933997780448
# Predicted Label: Eyezy
# Accuracy: 0.7830842515746177
# Precision: 0.7797098340938516
# Recall: 0.7830842515746177
# F1-Score: 0.7431113696324138
# Predicted Label: Qustodio
# Accuracy: 0.7433610576304501
# Precision: 0.7428618493137626
# Recall: 0.7433610576304501
# F1-Score: 0.7361115863992251
# Predicted Label: TiSpy
# Accuracy: 0.736529653167043
# Precision: 0.735693993965794
# Recall: 0.736529653167043
# F1-Score: 0.790496281581601
# Predicted Label: mLite
# Accuracy: 0.7855551034655556
# Precision: 0.7955000136449479
# Recall: 0.7855551034655556
# F1-Score: 0.7869499256516639
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7835871997571215
# Precision: 0.7903416378849349
# Recall: 0.7835871997571215
# F1-Score: 0.7831562219172005
# Predicted Label: Normal-Traffic
# Accuracy: 0.778199046132733
# Precision: 0.7881769576114465
# Recall: 0.778199046132733
# F1-Score: 0.7508906333804413
# Predicted Label: kids-360
# Accuracy: 0.7503686472742198
# Precision: 0.7514133462205648
# Recall: 0.7503686472742198
# F1-Score: 0.7713395081738658
# Predicted Label: mLite
# Accuracy: 0.7712379112786769
# Precision: 0.7714411318397538
# Recall: 0.7712379112786769
# F1-Score: 0.7614479460388794
# Predicted Label: FamiSafe
# Accuracy: 0.7571984835138448
# Precision: 0.765745374445397
# Recall: 0.7571984835138448
# F1-Score: 0.7680809206840115
# Predicted Label: FamiSafe
# Accuracy: 0.7633658573564928
# Precision: 0.7728545928533255
# Recall: 0.7633658573564928
# F1-Score: 0.7614018173552247
# Predicted Label: Eyezy
# Accuracy: 0.766326695006705
# Precision: 0.7565398359641656
# Recall: 0.766326695006705
# F1-Score: 0.7356905111052465
# Predicted Label: TiSpy
# Accuracy: 0.7338609854531609
# Precision: 0.7375291816214409
# Recall: 0.7338609854531609
# F1-Score: 0.77792745434431
# Predicted Label: Normal-Traffic
# Accuracy: 0.7824020352646509
# Precision: 0.7735037629128695
# Recall: 0.7824020352646509
# F1-Score: 0.7310516577327276
# Predicted Label: Normal-Traffic
# Accuracy: 0.7312658890698704
# Precision: 0.7308375518810616
# Recall: 0.7312658890698704
# F1-Score: 0.7547625848747417
# Predicted Label: kids-360
# Accuracy: 0.7544479319786795
# Precision: 0.7550775003409563
# Recall: 0.7544479319786795
# F1-Score: 0.761869813874851
# Predicted Label: kids-360
# Accuracy: 0.761680032044383
# Precision: 0.7620596903017846
# Recall: 0.761680032044383
# F1-Score: 0.7610184543892211
# Predicted Label: TiSpy
# Accuracy: 0.7608222892486246
# Precision: 0.7612147207116233
# Recall: 0.7608222892486246
# F1-Score: 0.7684185604835534
# Predicted Label: mLite
# Accuracy: 0.7689551445124695
# Precision: 0.7678827247990561
# Recall: 0.7689551445124695
# F1-Score: 0.7762153497862282
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7722875513387243
# Precision: 0.7801833054662943
# Recall: 0.7722875513387243
# F1-Score: 0.753208066098021
# Predicted Label: Normal-Traffic
# Accuracy: 0.7569662907236353
# Precision: 0.749486975157602
# Recall: 0.7569662907236353
# F1-Score: 0.7450993791670466
# Predicted Label: Normal-Traffic
# Accuracy: 0.746035402866458
# Precision: 0.7441657013147043
# Recall: 0.746035402866458
# F1-Score: 0.7753869866994259
# Predicted Label: Qustodio
# Accuracy: 0.772802133795962
# Precision: 0.7779891891604712
# Recall: 0.772802133795962
# F1-Score: 0.7600546365097836
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7553938471135823
# Precision: 0.7647732972294132
# Recall: 0.7553938471135823
# F1-Score: 0.7417700776839682
# Predicted Label: Qustodio
# Accuracy: 0.7403682042880393
# Precision: 0.7431772699934553
# Recall: 0.7403682042880393
# F1-Score: 0.7728866309026714
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7727860487771305
# Precision: 0.7729872392141947
# Recall: 0.7727860487771305
# F1-Score: 0.78467133996069
# Predicted Label: FamiSafe
# Accuracy: 0.7831302668400666
# Precision: 0.7862184902031113
# Recall: 0.7831302668400666
# F1-Score: 0.7657762381501134
# Predicted Label: TiSpy
# Accuracy: 0.7640254424086563
# Precision: 0.7675350763621988
# Recall: 0.7640254424086563
# F1-Score: 0.7507482140722248
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7487628813244422
# Precision: 0.7527441029652128
# Recall: 0.7487628813244422
# F1-Score: 0.7521892312030809
# Predicted Label: Normal-Traffic
# Accuracy: 0.7548607558586353
# Precision: 0.749536549425035
# Recall: 0.7548607558586353
# F1-Score: 0.7491571046817597
# Predicted Label: Air-Droid
# Accuracy: 0.7537847408475328
# Precision: 0.7445859417939337
# Recall: 0.7537847408475328
# F1-Score: 0.7615868952305173
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7566796553781391
# Precision: 0.7665581996920015
# Recall: 0.7566796553781391
# F1-Score: 0.7453887152406727
# Predicted Label: FamiSafe
# Accuracy: 0.7486451800752344
# Precision: 0.7421604577209656
# Recall: 0.7486451800752344
# F1-Score: 0.767229219437761
# Predicted Label: FamiSafe
# Accuracy: 0.7719788515072022
# Precision: 0.7625376746028476
# Recall: 0.7719788515072022
# F1-Score: 0.7740891154409798
# Predicted Label: Eyezy
# Accuracy: 0.7721201010580995
# Precision: 0.7760681980240017
# Recall: 0.7721201010580995
# F1-Score: 0.7439281834925975
# Predicted Label: Qustodio
# Accuracy: 0.7429432730117805
# Precision: 0.7449157088065486
# Recall: 0.7429432730117805
# F1-Score: 0.7620748804100757
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7634600092967664
# Precision: 0.7606947684397174
# Recall: 0.7634600092967664
# F1-Score: 0.7743467119907519
# Predicted Label: Qustodio
# Accuracy: 0.769511596064418
# Precision: 0.7792429736345973
# Recall: 0.769511596064418
# F1-Score: 0.7598370998864924
# Predicted Label: kids-360
# Accuracy: 0.7646900692599612
# Precision: 0.7550453390759173
# Recall: 0.7646900692599612
# F1-Score: 0.788666799705484
# Predicted Label: Normal-Traffic
# Accuracy: 0.7837867103319276
# Precision: 0.7936080395986358
# Recall: 0.7837867103319276
# F1-Score: 0.7740658976306536
# Predicted Label: Normal-Traffic
# Accuracy: 0.7710186143910877
# Precision: 0.7771373638957194
# Recall: 0.7710186143910877
# F1-Score: 0.7760500207951302
# Predicted Label: kids-360
# Accuracy: 0.7758547709987995
# Precision: 0.7762453688884118
# Recall: 0.7758547709987995
# F1-Score: 0.7394498120087161
# Predicted Label: TiSpy
# Accuracy: 0.7370474263448712
# Precision: 0.7418679099051584
# Recall: 0.7370474263448712
# F1-Score: 0.7805625962007356
# Predicted Label: Eyezy
# Accuracy: 0.7810184664194942
# Precision: 0.7801072578424532
# Recall: 0.7810184664194942
# F1-Score: 0.7716401276218159
# Predicted Label: kids-360
# Accuracy: 0.7726042823828283
# Precision: 0.7706783762535958
# Recall: 0.7726042823828283
# F1-Score: 0.7386077997447572
# Predicted Label: Qustodio
# Accuracy: 0.7403576087586458
# Precision: 0.7368662424516083
# Recall: 0.7403576087586458
# F1-Score: 0.7398321873699145
# Predicted Label: mLite
# Accuracy: 0.7370785554820659
# Precision: 0.7426064708476253
# Recall: 0.7370785554820659
# F1-Score: 0.7417440915045068
# Predicted Label: Air-Droid
# Accuracy: 0.7453244672909174
# Precision: 0.7381979499492953
# Recall: 0.7453244672909174
# F1-Score: 0.736462115560409
# Predicted Label: kids-360
# Accuracy: 0.7391031410852389
# Precision: 0.7338398971017801
# Recall: 0.7391031410852389
# F1-Score: 0.7651991459087139
# Predicted Label: Eyezy
# Accuracy: 0.7627374766059757
# Precision: 0.7676767563099265
# Recall: 0.7627374766059757
# F1-Score: 0.7641825027255446
# Predicted Label: Air-Droid
# Accuracy: 0.7624238616947409
# Precision: 0.7659492756340556
# Recall: 0.7624238616947409
# F1-Score: 0.7411535467325875
# Predicted Label: mLite
# Accuracy: 0.7399072012674164
# Precision: 0.7424040981252998
# Recall: 0.7399072012674164
# F1-Score: 0.7488489337978738
# Predicted Label: mLite
# Accuracy: 0.749903799891223
# Precision: 0.7477970312297496
# Recall: 0.749903799891223
# F1-Score: 0.7470260806186887
# Predicted Label: FamiSafe
# Accuracy: 0.748420401377856
# Precision: 0.745636945488243
# Recall: 0.748420401377856
# F1-Score: 0.7387838717267244
# Predicted Label: Qustodio
# Accuracy: 0.7436757971249931
# Precision: 0.7339558842551983
# Recall: 0.7436757971249931
# F1-Score: 0.7623446407883958
# Predicted Label: Qustodio
# Accuracy: 0.7632060835772909
# Precision: 0.7614851404552468
# Recall: 0.7632060835772909
# F1-Score: 0.7550547457333713
# Predicted Label: Air-Droid
# Accuracy: 0.7504930355717648
# Precision: 0.7596722497700692
# Recall: 0.7504930355717648
# F1-Score: 0.7518680995854304
# Predicted Label: Qustodio
# Accuracy: 0.7531428103686819
# Precision: 0.7505976964634815
# Recall: 0.7531428103686819
# F1-Score: 0.7773367021976179
# Predicted Label: TiSpy
# Accuracy: 0.7801041131142737
# Precision: 0.7745888565939067
# Recall: 0.7801041131142737
# F1-Score: 0.7300071937997572
# Predicted Label: kids-360
# Accuracy: 0.7318967214312946
# Precision: 0.7281273973799314
# Recall: 0.7318967214312946
# F1-Score: 0.7311134813386769
# Predicted Label: Normal-Traffic
# Accuracy: 0.7332569109218887
# Precision: 0.7289825464202758
# Recall: 0.7332569109218887
# F1-Score: 0.776847206655233
# Predicted Label: kids-360
# Accuracy: 0.779274150024498
# Precision: 0.7744353331231921
# Recall: 0.779274150024498
# F1-Score: 0.7586380458753904
# Predicted Label: kids-360
# Accuracy: 0.7552181022887954
# Precision: 0.7620891042339493
# Recall: 0.7552181022887954
# F1-Score: 0.7650424907163553
# Predicted Label: Qustodio
# Accuracy: 0.7642291799573976
# Precision: 0.7658575344086126
# Recall: 0.7642291799573976
# F1-Score: 0.7612507939250287
# Predicted Label: FamiSafe
# Accuracy: 0.7631347240204776
# Precision: 0.7593761425382372
# Recall: 0.7631347240204776

# %%
#LGB-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-LightGBM-Dataset-A-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-LightGBM-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv','2-All-Together-Update-Single-26-8-24.csv','3-All-Together-Update-Single-26-8-24.csv',
'4-All-Together-Update-Single-26-8-24.csv','5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7698169139023783
# Predicted Label: FamiSafe
# Accuracy: 0.7676690977868041
# Precision: 0.7719767822343355
# Recall: 0.7676690977868041
# F1-Score: 0.7796173739561597
# Predicted Label: mLite
# Accuracy: 0.7764757335180938
# Precision: 0.7827845399846021
# Recall: 0.7764757335180938
# F1-Score: 0.7862951005647358
# Predicted Label: Eyezy
# Accuracy: 0.785739580412215
# Precision: 0.7868514067817107
# Recall: 0.785739580412215
# F1-Score: 0.748620623531079
# Predicted Label: Qustodio
# Accuracy: 0.7531938510608096
# Precision: 0.7441025961034105
# Recall: 0.7531938510608096
# F1-Score: 0.7609627421133256
# Predicted Label: mLite
# Accuracy: 0.7649480279419355
# Precision: 0.7570187667673056
# Recall: 0.7649480279419355
# F1-Score: 0.7588750912101047
# Predicted Label: TiSpy
# Accuracy: 0.76227379659538
# Precision: 0.755506558511627
# Recall: 0.76227379659538
# F1-Score: 0.7675846408166306
# Predicted Label: Eyezy
# Accuracy: 0.7704031679599663
# Precision: 0.7647866617135476
# Recall: 0.7704031679599663
# F1-Score: 0.7774593801055263
# Predicted Label: FamiSafe
# Accuracy: 0.7735080160656729
# Precision: 0.7814513214771053
# Recall: 0.7735080160656729
# F1-Score: 0.7680480903738659
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7634912521756757
# Precision: 0.7726596494385287
# Recall: 0.7634912521756757
# F1-Score: 0.7570991658061947
# Predicted Label: mLite
# Accuracy: 0.7533485603008958
# Precision: 0.760887303542115
# Recall: 0.7533485603008958
# F1-Score: 0.7786731770051815
# Predicted Label: Qustodio
# Accuracy: 0.7815928823718563
# Precision: 0.7757752040608066
# Recall: 0.7815928823718563
# F1-Score: 0.756596973883274
# Predicted Label: kids-360
# Accuracy: 0.760097942839945
# Precision: 0.753128107601047
# Recall: 0.760097942839945
# F1-Score: 0.7858687256882523
# Predicted Label: kids-360
# Accuracy: 0.788611255907813
# Precision: 0.7831452045949182
# Recall: 0.788611255907813
# F1-Score: 0.7848475758659361
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7819925653739925
# Precision: 0.7877235097105229
# Recall: 0.7819925653739925
# F1-Score: 0.7889806199381576
# Predicted Label: mLite
# Accuracy: 0.7911067450351256
# Precision: 0.7868658922708678
# Recall: 0.7911067450351256
# F1-Score: 0.7622597319465482
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7659975470328741
# Precision: 0.7585582183277318
# Recall: 0.7659975470328741
# F1-Score: 0.7969377565873018
# Predicted Label: mLite
# Accuracy: 0.7929497876684627
# Precision: 0.8009660415156605
# Recall: 0.7929497876684627
# F1-Score: 0.7949858542861379
# Predicted Label: mLite
# Accuracy: 0.7904842857804399
# Precision: 0.7995389865694258
# Recall: 0.7904842857804399
# F1-Score: 0.7803686216145487
# Predicted Label: FamiSafe
# Accuracy: 0.7840249896488499
# Precision: 0.776746198847764
# Recall: 0.7840249896488499
# F1-Score: 0.7900962862836878
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7888818816652015
# Precision: 0.7913144355752003
# Recall: 0.7888818816652015
# F1-Score: 0.7931296996351715
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7929880299974249
# Precision: 0.7932714199013559
# Recall: 0.7929880299974249
# F1-Score: 0.7797994239543059
# Predicted Label: Air-Droid
# Accuracy: 0.7807028703369003
# Precision: 0.7788980661304877
# Recall: 0.7807028703369003
# F1-Score: 0.746749464744571
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7503084859001709
# Precision: 0.7432240479862096
# Recall: 0.7503084859001709
# F1-Score: 0.786113340250383
# Predicted Label: Eyezy
# Accuracy: 0.7855336285933215
# Precision: 0.7866939081758142
# Recall: 0.7855336285933215
# F1-Score: 0.7658921970757715
# Predicted Label: kids-360
# Accuracy: 0.7669555224965644
# Precision: 0.764831816012278
# Recall: 0.7669555224965644
# F1-Score: 0.7783360085061051
# Predicted Label: kids-360
# Accuracy: 0.7743721092037962
# Precision: 0.782340697866144
# Recall: 0.7743721092037962
# F1-Score: 0.7781501500210682
# Predicted Label: Air-Droid
# Accuracy: 0.7826421328312216
# Precision: 0.7737094365160198
# Recall: 0.7826421328312216
# F1-Score: 0.7924422144596769
# Predicted Label: Qustodio
# Accuracy: 0.7920965021584896
# Precision: 0.7927882286664556
# Recall: 0.7920965021584896
# F1-Score: 0.781047088763968
# Predicted Label: FamiSafe
# Accuracy: 0.7839155157461726
# Precision: 0.7781995769858124
# Recall: 0.7839155157461726
# F1-Score: 0.7750267807740574
# Predicted Label: Eyezy
# Accuracy: 0.7748033495141314
# Precision: 0.7752503409336019
# Recall: 0.7748033495141314
# F1-Score: 0.7799478395929346
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.784264509673157
# Precision: 0.775678428161688
# Recall: 0.784264509673157
# F1-Score: 0.7789421933346271
# Predicted Label: Normal-Traffic
# Accuracy: 0.7810115993587178
# Precision: 0.7768837247263671
# Recall: 0.7810115993587178
# F1-Score: 0.7908880705680985
# Predicted Label: Eyezy
# Accuracy: 0.7906925744136809
# Precision: 0.791083663417994
# Recall: 0.7906925744136809
# F1-Score: 0.7680198174937052
# Predicted Label: kids-360
# Accuracy: 0.7666154632990205
# Precision: 0.7694293263723213
# Recall: 0.7666154632990205
# F1-Score: 0.7709482145694077
# Predicted Label: mLite
# Accuracy: 0.7738942684000634
# Precision: 0.7680245056992921
# Recall: 0.7738942684000634
# F1-Score: 0.7508381792535045
# Predicted Label: Qustodio
# Accuracy: 0.755529613686166
# Precision: 0.7462046478665175
# Recall: 0.755529613686166
# F1-Score: 0.7519819757799564
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7561319154911015
# Precision: 0.747877340318777
# Recall: 0.7561319154911015
# F1-Score: 0.7954417512098876
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7930488583136784
# Precision: 0.7978491281210495
# Recall: 0.7930488583136784
# F1-Score: 0.7796896938355677
# Predicted Label: mLite
# Accuracy: 0.778212270149585
# Precision: 0.7811727379227924
# Recall: 0.778212270149585
# F1-Score: 0.7526690843559698
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.756469320339154
# Precision: 0.7489068396178851
# Recall: 0.756469320339154
# F1-Score: 0.7630095124343241
# Predicted Label: kids-360
# Accuracy: 0.7606720261272193
# Precision: 0.7653614088518722
# Recall: 0.7606720261272193
# F1-Score: 0.7905035530561475
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7900456658777659
# Precision: 0.7909619712981392
# Recall: 0.7900456658777659
# F1-Score: 0.778061889795465
# Predicted Label: Qustodio
# Accuracy: 0.7751807656352921
# Precision: 0.78096451047326
# Recall: 0.7751807656352921
# F1-Score: 0.7678472100914382
# Predicted Label: mLite
# Accuracy: 0.7728229396964557
# Precision: 0.7629351419095612
# Recall: 0.7728229396964557
# F1-Score: 0.7594491857797061
# Predicted Label: mLite
# Accuracy: 0.7597150026299222
# Precision: 0.7591835548778616
# Recall: 0.7597150026299222
# F1-Score: 0.7700247833342141
# Predicted Label: Qustodio
# Accuracy: 0.77140109339058
# Precision: 0.7686533756711188
# Recall: 0.77140109339058
# F1-Score: 0.7706034244862402
# Predicted Label: Eyezy
# Accuracy: 0.7697276015233806
# Precision: 0.7714812428034287
# Recall: 0.7697276015233806
# F1-Score: 0.7650658622404582
# Predicted Label: kids-360
# Accuracy: 0.7650217759204593
# Precision: 0.7651099536419221
# Recall: 0.7650217759204593
# F1-Score: 0.7585788615831109
# Predicted Label: Normal-Traffic
# Accuracy: 0.7623057042658399
# Precision: 0.754888281997654
# Recall: 0.7623057042658399
# F1-Score: 0.7587335080948022
# Predicted Label: FamiSafe
# Accuracy: 0.7566794468830733
# Precision: 0.7607987514574146
# Recall: 0.7566794468830733
# F1-Score: 0.7601996638014524
# Predicted Label: kids-360
# Accuracy: 0.7637221647620722
# Precision: 0.7567095071856601
# Recall: 0.7637221647620722
# F1-Score: 0.759092562399925
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7626178350371461
# Precision: 0.7555997316055979
# Recall: 0.7626178350371461
# F1-Score: 0.7841891376136537
# Predicted Label: kids-360
# Accuracy: 0.7795659485890956
# Precision: 0.7888674891040661
# Recall: 0.7795659485890956
# F1-Score: 0.7939235596761544
# Predicted Label: Air-Droid
# Accuracy: 0.7915478747901814
# Precision: 0.7963135478504325
# Recall: 0.7915478747901814
# F1-Score: 0.7956023307967665
# Predicted Label: Air-Droid
# Accuracy: 0.7936993459830471
# Precision: 0.7975144627886716
# Recall: 0.7936993459830471
# F1-Score: 0.7542502743142635
# Predicted Label: mLite
# Accuracy: 0.7580543394068172
# Precision: 0.7504841976750571
# Recall: 0.7580543394068172
# F1-Score: 0.7577725992140155
# Predicted Label: Normal-Traffic
# Accuracy: 0.7543428940006246
# Precision: 0.7612336339553105
# Recall: 0.7543428940006246
# F1-Score: 0.7877962206848584
# Predicted Label: Air-Droid
# Accuracy: 0.7852523342530285
# Precision: 0.7903566429243601
# Recall: 0.7852523342530285
# F1-Score: 0.7840822350582717
# Predicted Label: Qustodio
# Accuracy: 0.7856879283663727
# Precision: 0.7824830914056705
# Recall: 0.7856879283663727
# F1-Score: 0.7890479573095643
# Predicted Label: FamiSafe
# Accuracy: 0.7896204011691109
# Precision: 0.7884763428474857
# Recall: 0.7896204011691109
# F1-Score: 0.755095165908231
# Predicted Label: Eyezy
# Accuracy: 0.7510908712192648
# Precision: 0.7591423856783319
# Recall: 0.7510908712192648
# F1-Score: 0.7821236469607907
# Predicted Label: mLite
# Accuracy: 0.7781539658832525
# Precision: 0.786134037642403
# Recall: 0.7781539658832525
# F1-Score: 0.7703680234024818
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7716376592621385
# Precision: 0.7691025587422079
# Recall: 0.7716376592621385
# F1-Score: 0.7606196248633142
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7633712393479698
# Precision: 0.757887775830725
# Recall: 0.7633712393479698
# F1-Score: 0.7854107239625402
# Predicted Label: Air-Droid
# Accuracy: 0.782691365982965
# Precision: 0.7881490439247129
# Recall: 0.782691365982965
# F1-Score: 0.7633370816930202
# Predicted Label: Qustodio
# Accuracy: 0.7649158497273782
# Precision: 0.7617648173142613
# Recall: 0.7649158497273782
# F1-Score: 0.7472312215009999
# Predicted Label: kids-360
# Accuracy: 0.752030050705832
# Precision: 0.7424932482237053
# Recall: 0.752030050705832
# F1-Score: 0.7569325158813841
# Predicted Label: Air-Droid
# Accuracy: 0.7553031247489375
# Precision: 0.7585689522784965
# Recall: 0.7553031247489375
# F1-Score: 0.7858041504969696
# Predicted Label: Air-Droid
# Accuracy: 0.7903854057619705
# Precision: 0.7812756971941945
# Recall: 0.7903854057619705
# F1-Score: 0.7640927222785115
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7672854526945319
# Precision: 0.7609264521250472
# Recall: 0.7672854526945319
# F1-Score: 0.7732369246381474
# Predicted Label: TiSpy
# Accuracy: 0.7709549096234127
# Precision: 0.7755324892201012
# Recall: 0.7709549096234127
# F1-Score: 0.7638262214142336
# Predicted Label: TiSpy
# Accuracy: 0.7615222553322777
# Precision: 0.7661441709836316
# Recall: 0.7615222553322777
# F1-Score: 0.7791104286671375
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7823076112988764
# Precision: 0.7759392725520021
# Recall: 0.7823076112988764
# F1-Score: 0.777319492784801
# Predicted Label: kids-360
# Accuracy: 0.77754784455911
# Precision: 0.777091275096706
# Recall: 0.77754784455911
# F1-Score: 0.7548392294000484
# Predicted Label: TiSpy
# Accuracy: 0.7554228193465492
# Precision: 0.7542565404438608
# Recall: 0.7554228193465492
# F1-Score: 0.7760963559211956
# Predicted Label: Normal-Traffic
# Accuracy: 0.7752146096456372
# Precision: 0.7769801103163397
# Recall: 0.7752146096456372
# F1-Score: 0.7760108359428917
# Predicted Label: Normal-Traffic
# Accuracy: 0.7779325235706436
# Precision: 0.7740986190169341
# Recall: 0.7779325235706436
# F1-Score: 0.7633812242707644
# Predicted Label: mLite
# Accuracy: 0.7679267278676923
# Precision: 0.7588892154199465
# Recall: 0.7679267278676923
# F1-Score: 0.7518061881957936
# Predicted Label: Eyezy
# Accuracy: 0.7501581054611236
# Precision: 0.7534615284864561
# Recall: 0.7501581054611236
# F1-Score: 0.7798909646463197
# Predicted Label: mLite
# Accuracy: 0.7781539759778164
# Precision: 0.7816357252458442
# Recall: 0.7781539759778164
# F1-Score: 0.7608867929221905
# Predicted Label: Eyezy
# Accuracy: 0.7624760120689011
# Precision: 0.7593041847751514
# Recall: 0.7624760120689011
# F1-Score: 0.7680602578402328
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7721922986554278
# Precision: 0.7639722031798711
# Recall: 0.7721922986554278
# F1-Score: 0.7936879645407177
# Predicted Label: Qustodio
# Accuracy: 0.7923054584737287
# Precision: 0.7950753037536396
# Recall: 0.7923054584737287
# F1-Score: 0.7507142243134077
# Predicted Label: Normal-Traffic
# Accuracy: 0.7500327053768121
# Precision: 0.7513969829039048
# Recall: 0.7500327053768121
# F1-Score: 0.7690558458300667
# Predicted Label: Normal-Traffic
# Accuracy: 0.7694055420426377
# Precision: 0.7687064673482108
# Recall: 0.7694055420426377
# F1-Score: 0.7934956406166186
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7928222654187245
# Precision: 0.7941701606350452
# Recall: 0.7928222654187245
# F1-Score: 0.788166820418508
# Predicted Label: kids-360
# Accuracy: 0.7904148258348584
# Precision: 0.7859315657661715
# Recall: 0.7904148258348584
# F1-Score: 0.7798961532046754
# Predicted Label: kids-360
# Accuracy: 0.7840435207512669
# Precision: 0.7757924315764062
# Recall: 0.7840435207512669
# F1-Score: 0.7814582749129327
# Predicted Label: FamiSafe
# Accuracy: 0.7839298176450888
# Precision: 0.779002267564576
# Recall: 0.7839298176450888
# F1-Score: 0.7699218818432806
# Predicted Label: Qustodio
# Accuracy: 0.7689479834276732
# Precision: 0.7708982503373514
# Recall: 0.7689479834276732
# F1-Score: 0.7503136070118656
# Predicted Label: Normal-Traffic
# Accuracy: 0.7541962663596292
# Precision: 0.7464707193635901
# Recall: 0.7541962663596292
# F1-Score: 0.7596018576041434
# Predicted Label: Qustodio
# Accuracy: 0.7619569978535504
# Precision: 0.7572612315442093
# Recall: 0.7619569978535504
# F1-Score: 0.760679812272444
# Predicted Label: mLite
# Accuracy: 0.7596793372464902
# Precision: 0.761682925964973
# Recall: 0.7596793372464902
# F1-Score: 0.78321001085396
# Predicted Label: Normal-Traffic
# Accuracy: 0.7851011803349801
# Precision: 0.7813279304625776
# Recall: 0.7851011803349801
# F1-Score: 0.7951531268574106
# Predicted Label: FamiSafe
# Accuracy: 0.7909658530418304
# Precision: 0.7993849704222686
# Recall: 0.7909658530418304
# F1-Score: 0.7556647796182137
# Predicted Label: Air-Droid
# Accuracy: 0.7571120656774984
# Precision: 0.754223016230115
# Recall: 0.7571120656774984
# F1-Score: 0.7699899907853944
# Predicted Label: Eyezy
# Accuracy: 0.7655598989430377
# Precision: 0.7744716525795481
# Recall: 0.7655598989430377
# F1-Score: 0.7979965942372137
# Predicted Label: Eyezy
# Accuracy: 0.7945684319086452
# Precision: 0.8014544663338294
# Recall: 0.7945684319086452
# F1-Score: 0.772400830440751
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7761887650909651
# Precision: 0.7686496877842441
# Recall: 0.7761887650909651
# F1-Score: 0.767614422963219
# Predicted Label: Normal-Traffic
# Accuracy: 0.766311893519156
# Precision: 0.7689213878639767
# Recall: 0.766311893519156
# F1-Score: 0.7527731965334112
# Predicted Label: Air-Droid
# Accuracy: 0.75495718148086
# Precision: 0.7506018110600425
# Recall: 0.75495718148086
# F1-Score: 0.7657639382532452
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7631549362277131
# Precision: 0.7683908402931301
# Recall: 0.7631549362277131
# F1-Score: 0.7782000238375854
# Predicted Label: mLite
# Accuracy: 0.7827866831834693
# Precision: 0.7736668015153313
# Recall: 0.7827866831834693
# F1-Score: 0.7643691432398296
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7650775129188219
# Precision: 0.7636620840775591
# Recall: 0.7650775129188219
# F1-Score: 0.770416302731091
# Predicted Label: Normal-Traffic
# Accuracy: 0.7726735026256608
# Precision: 0.7681722522738772
# Recall: 0.7726735026256608
# F1-Score: 0.7452760297625901
# Predicted Label: Qustodio
# Accuracy: 0.7502823210497271
# Precision: 0.7403361050326666
# Recall: 0.7502823210497271
# F1-Score: 0.78324317404291
# Predicted Label: Air-Droid
# Accuracy: 0.7813437737488956
# Precision: 0.7851518314990767
# Recall: 0.7813437737488956
# F1-Score: 0.7830706063521246
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7800379076405407
# Precision: 0.7861269786797139
# Recall: 0.7800379076405407
# F1-Score: 0.7553015403591294
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7549640206856633
# Precision: 0.7556393619555464
# Recall: 0.7549640206856633
# F1-Score: 0.7889155318940727
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7909123552613618
# Precision: 0.7869287659297439
# Recall: 0.7909123552613618
# F1-Score: 0.7828767163575651
# Predicted Label: Eyezy
# Accuracy: 0.7844593771225806
# Precision: 0.7813004288269985
# Recall: 0.7844593771225806
# F1-Score: 0.780214777161917
# Predicted Label: Qustodio
# Accuracy: 0.7756712137024347
# Precision: 0.7848118829082148
# Recall: 0.7756712137024347
# F1-Score: 0.7545992293553859
# Predicted Label: kids-360
# Accuracy: 0.7503826747710134
# Precision: 0.758863439098796
# Recall: 0.7503826747710134
# F1-Score: 0.7820271250446977
# Predicted Label: FamiSafe
# Accuracy: 0.7782040006007982
# Precision: 0.7858879990791763
# Recall: 0.7782040006007982
# F1-Score: 0.7660951798987335
# Predicted Label: kids-360
# Accuracy: 0.7694838997185963
# Precision: 0.7627361762875373
# Recall: 0.7694838997185963
# F1-Score: 0.7467226527492309
# Predicted Label: Normal-Traffic
# Accuracy: 0.7516173400610494
# Precision: 0.7418913033963968
# Recall: 0.7516173400610494
# F1-Score: 0.7649764265834046
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7617866972146693
# Precision: 0.7681929801390982
# Recall: 0.7617866972146693
# F1-Score: 0.7676067749607823
# Predicted Label: Eyezy
# Accuracy: 0.764678247475652
# Precision: 0.7705578197452461
# Recall: 0.764678247475652
# F1-Score: 0.7628505914373647
# Predicted Label: kids-360
# Accuracy: 0.7653018707901087
# Precision: 0.7604149649555052
# Recall: 0.7653018707901087
# F1-Score: 0.790592436421878
# Predicted Label: Eyezy
# Accuracy: 0.7901915983070313
# Precision: 0.7909936814070058
# Recall: 0.7901915983070313

# %%
#LGB-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-LGB-Dataset-B-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-LGB-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
               
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7479587104287724
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7455867510181927
# Precision: 0.7503458099886304
# Recall: 0.7455867510181927
# F1-Score: 0.764782464872472
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7672936398781104
# Precision: 0.7622876732403513
# Recall: 0.7672936398781104
# F1-Score: 0.7724128891495807
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7718791736102723
# Precision: 0.7729473432743671
# Recall: 0.7718791736102723
# F1-Score: 0.7372543131256595
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7408601867602074
# Precision: 0.733683370095366
# Recall: 0.7408601867602074
# F1-Score: 0.7679886383537531
# Predicted Label: Eyezy
# Accuracy: 0.7648155452516185
# Precision: 0.7711881704229026
# Recall: 0.7648155452516185
# F1-Score: 0.7742238497587202
# Predicted Label: Normal-Traffic
# Accuracy: 0.7766181372495222
# Precision: 0.7718442799088866
# Recall: 0.7766181372495222
# F1-Score: 0.7790193212663056
# Predicted Label: Eyezy
# Accuracy: 0.7764999144470573
# Precision: 0.7815551300767105
# Recall: 0.7764999144470573
# F1-Score: 0.7452536408751034
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7497132713454139
# Precision: 0.7408467524322081
# Recall: 0.7497132713454139
# F1-Score: 0.7722538179300404
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7678539242056723
# Precision: 0.7767044260760053
# Recall: 0.7678539242056723
# F1-Score: 0.771931343285303
# Predicted Label: Qustodio
# Accuracy: 0.7767971489857093
# Precision: 0.7671261162907753
# Recall: 0.7767971489857093
# F1-Score: 0.7456800128983864
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.749491061758471
# Precision: 0.7419075251765468
# Recall: 0.749491061758471
# F1-Score: 0.7544338431954799
# Predicted Label: mLite
# Accuracy: 0.7499223180577731
# Precision: 0.7589999794530188
# Recall: 0.7499223180577731
# F1-Score: 0.7790870957326284
# Predicted Label: TiSpy
# Accuracy: 0.7749631803718146
# Precision: 0.7832551361884528
# Recall: 0.7749631803718146
# F1-Score: 0.7366759962477254
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7368221035372465
# Precision: 0.7365299468910695
# Recall: 0.7368221035372465
# F1-Score: 0.7378633484794296
# Predicted Label: Air-Droid
# Accuracy: 0.7383046516196933
# Precision: 0.7374225725798507
# Recall: 0.7383046516196933
# F1-Score: 0.7477825706113973
# Predicted Label: kids-360
# Accuracy: 0.7483354803279456
# Precision: 0.7472304773293371
# Recall: 0.7483354803279456
# F1-Score: 0.7393729925745336
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7353585313699337
# Precision: 0.7434315257814116
# Recall: 0.7353585313699337
# F1-Score: 0.7509183491198538
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7554858819422648
# Precision: 0.7464057133761967
# Recall: 0.7554858819422648
# F1-Score: 0.7685019198702667
# Predicted Label: Normal-Traffic
# Accuracy: 0.7646222080585101
# Precision: 0.7724212039783431
# Recall: 0.7646222080585101
# F1-Score: 0.7565798218472306
# Predicted Label: TiSpy
# Accuracy: 0.7519538316638055
# Precision: 0.7612630821709859
# Recall: 0.7519538316638055
# F1-Score: 0.761500259120002
# Predicted Label: kids-360
# Accuracy: 0.7565739323159686
# Precision: 0.7664911605880194
# Recall: 0.7565739323159686
# F1-Score: 0.7334251281810158
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7307827242659511
# Precision: 0.7360867105380793
# Recall: 0.7307827242659511
# F1-Score: 0.7707059403996573
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7736171205323411
# Precision: 0.7678165881121601
# Recall: 0.7736171205323411
# F1-Score: 0.7660754766829698
# Predicted Label: mLite
# Accuracy: 0.7664762190551504
# Precision: 0.7656751531379465
# Recall: 0.7664762190551504
# F1-Score: 0.7382392105846148
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7389507604472252
# Precision: 0.7375290297337819
# Recall: 0.7389507604472252
# F1-Score: 0.7567304181990835
# Predicted Label: Air-Droid
# Accuracy: 0.7542038212443027
# Precision: 0.7592740003490133
# Recall: 0.7542038212443027
# F1-Score: 0.7401909844172164
# Predicted Label: FamiSafe
# Accuracy: 0.7416406368759046
# Precision: 0.7387469880471116
# Recall: 0.7416406368759046
# F1-Score: 0.7730881154607312
# Predicted Label: Eyezy
# Accuracy: 0.7691509152672615
# Precision: 0.777065831251499
# Recall: 0.7691509152672615
# F1-Score: 0.7730965273660944
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7772229048820318
# Precision: 0.7690137334094884
# Recall: 0.7772229048820318
# F1-Score: 0.7467033625128616
# Predicted Label: TiSpy
# Accuracy: 0.7457898512276206
# Precision: 0.7476191144461766
# Recall: 0.7457898512276206
# F1-Score: 0.772882981958906
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7737321327987079
# Precision: 0.7720356929176371
# Recall: 0.7737321327987079
# F1-Score: 0.7415027853428161
# Predicted Label: Qustodio
# Accuracy: 0.7381789578808672
# Precision: 0.74485668085094
# Recall: 0.7381789578808672
# F1-Score: 0.7635215744277007
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7635633255356798
# Precision: 0.7634798278853147
# Recall: 0.7635633255356798
# F1-Score: 0.7384368305760268
# Predicted Label: FamiSafe
# Accuracy: 0.7379824238607312
# Precision: 0.7388917972306281
# Recall: 0.7379824238607312
# F1-Score: 0.7729441089362434
# Predicted Label: mLite
# Accuracy: 0.7718627481407142
# Precision: 0.7740285039025225
# Recall: 0.7718627481407142
# F1-Score: 0.760855391432688
# Predicted Label: mLite
# Accuracy: 0.7563278321926419
# Precision: 0.7654374832218953
# Recall: 0.7563278321926419
# F1-Score: 0.7293021804766773
# Predicted Label: Air-Droid
# Accuracy: 0.7301184272064265
# Precision: 0.7284877567791292
# Recall: 0.7301184272064265
# F1-Score: 0.7500535652941974
# Predicted Label: Eyezy
# Accuracy: 0.7540479054927767
# Precision: 0.7461013197248099
# Recall: 0.7540479054927767
# F1-Score: 0.7438417093952837
# Predicted Label: mLite
# Accuracy: 0.740311928767902
# Precision: 0.7474053110138741
# Recall: 0.740311928767902
# F1-Score: 0.7684077766711812
# Predicted Label: FamiSafe
# Accuracy: 0.7706333060818642
# Precision: 0.7661950645588985
# Recall: 0.7706333060818642
# F1-Score: 0.7524941275256328
# Predicted Label: kids-360
# Accuracy: 0.7481465647745397
# Precision: 0.7568925139584551
# Recall: 0.7481465647745397
# F1-Score: 0.781512463382247
# Predicted Label: Qustodio
# Accuracy: 0.7779513200192429
# Precision: 0.7851063595937096
# Recall: 0.7779513200192429
# F1-Score: 0.7383071874909278
# Predicted Label: Eyezy
# Accuracy: 0.7396951658282316
# Precision: 0.7369244082568016
# Recall: 0.7396951658282316
# F1-Score: 0.771564507815288
# Predicted Label: Eyezy
# Accuracy: 0.7681364518895506
# Precision: 0.7750232985086623
# Recall: 0.7681364518895506
# F1-Score: 0.7330608556484093
# Predicted Label: Air-Droid
# Accuracy: 0.7340094084094139
# Precision: 0.7321147513331334
# Recall: 0.7340094084094139
# F1-Score: 0.7546080854228085
# Predicted Label: TiSpy
# Accuracy: 0.7581572463727303
# Precision: 0.751091999010077
# Recall: 0.7581572463727303
# F1-Score: 0.7734923685596476
# Predicted Label: Qustodio
# Accuracy: 0.7694139825736274
# Precision: 0.7776142210519303
# Recall: 0.7694139825736274
# F1-Score: 0.7325171680418401
# Predicted Label: mLite
# Accuracy: 0.7354589755141915
# Precision: 0.7295988010408526
# Recall: 0.7354589755141915
# F1-Score: 0.7359026584518543
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.731303484280351
# Precision: 0.7405600472307723
# Recall: 0.731303484280351
# F1-Score: 0.7737838377873325
# Predicted Label: Air-Droid
# Accuracy: 0.7711117947106919
# Precision: 0.7764744634898411
# Recall: 0.7711117947106919
# F1-Score: 0.7584552957180285
# Predicted Label: Air-Droid
# Accuracy: 0.7563163808354003
# Precision: 0.7606063429092492
# Recall: 0.7563163808354003
# F1-Score: 0.7510215967622728
# Predicted Label: FamiSafe
# Accuracy: 0.7544989374615183
# Precision: 0.7475761618064837
# Recall: 0.7544989374615183
# F1-Score: 0.7400498293229872
# Predicted Label: Normal-Traffic
# Accuracy: 0.7395669243361445
# Precision: 0.7405333653537173
# Recall: 0.7395669243361445
# F1-Score: 0.7541101147733106
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7524833522314686
# Precision: 0.7557439262147798
# Recall: 0.7524833522314686
# F1-Score: 0.7594150156393865
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7562415217705002
# Precision: 0.7626152562641111
# Recall: 0.7562415217705002
# F1-Score: 0.7785007456196087
# Predicted Label: mLite
# Accuracy: 0.7757140658439188
# Precision: 0.7813075193505966
# Recall: 0.7757140658439188
# F1-Score: 0.759569573311889
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.761462529763246
# Precision: 0.7576860051054362
# Recall: 0.761462529763246
# F1-Score: 0.7514566879331929
# Predicted Label: mLite
# Accuracy: 0.7490400367168286
# Precision: 0.7538889834575575
# Recall: 0.7490400367168286
# F1-Score: 0.7277312189782393
# Predicted Label: Air-Droid
# Accuracy: 0.7300811062897067
# Precision: 0.7253964101394875
# Recall: 0.7300811062897067
# F1-Score: 0.7405039541594555
# Predicted Label: mLite
# Accuracy: 0.7364086706143818
# Precision: 0.7446450414481467
# Recall: 0.7364086706143818
# F1-Score: 0.7722412230471464
# Predicted Label: kids-360
# Accuracy: 0.7677535006473989
# Precision: 0.7767817177652949
# Recall: 0.7677535006473989
# F1-Score: 0.7775520017019936
# Predicted Label: Normal-Traffic
# Accuracy: 0.7740532898752852
# Precision: 0.7810824854103962
# Recall: 0.7740532898752852
# F1-Score: 0.74273474605125
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7414696568971497
# Precision: 0.7440041595519904
# Recall: 0.7414696568971497
# F1-Score: 0.725875806945987
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7303936537963255
# Precision: 0.721413506757104
# Recall: 0.7303936537963255
# F1-Score: 0.7620889976871966
# Predicted Label: mLite
# Accuracy: 0.7584805697182064
# Precision: 0.7657319235577182
# Recall: 0.7584805697182064
# F1-Score: 0.7500766031449041
# Predicted Label: TiSpy
# Accuracy: 0.7529103635464249
# Precision: 0.7472640938461275
# Recall: 0.7529103635464249
# F1-Score: 0.7340135315765962
# Predicted Label: TiSpy
# Accuracy: 0.7315680959876546
# Precision: 0.7364753708669849
# Recall: 0.7315680959876546
# F1-Score: 0.7638034350575892
# Predicted Label: Normal-Traffic
# Accuracy: 0.7641516730488461
# Precision: 0.7634555143186871
# Recall: 0.7641516730488461
# F1-Score: 0.7619806605334516
# Predicted Label: Eyezy
# Accuracy: 0.7666004607032717
# Precision: 0.7574162078556306
# Recall: 0.7666004607032717
# F1-Score: 0.775558317330401
# Predicted Label: kids-360
# Accuracy: 0.7778620389463824
# Precision: 0.7732682008572037
# Recall: 0.7778620389463824
# F1-Score: 0.7511693199135178
# Predicted Label: Eyezy
# Accuracy: 0.7525311298864794
# Precision: 0.7498124298073022
# Recall: 0.7525311298864794
# F1-Score: 0.7600428992443409
# Predicted Label: mLite
# Accuracy: 0.7638359693328726
# Precision: 0.7562873143992216
# Recall: 0.7638359693328726
# F1-Score: 0.7729117807782847
# Predicted Label: mLite
# Accuracy: 0.7740790939439537
# Precision: 0.7717479829337172
# Recall: 0.7740790939439537
# F1-Score: 0.7456642863188768
# Predicted Label: kids-360
# Accuracy: 0.7486136210044538
# Precision: 0.7427380995945496
# Recall: 0.7486136210044538
# F1-Score: 0.7639087970408662
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7669381888043705
# Precision: 0.7609032432016809
# Recall: 0.7669381888043705
# F1-Score: 0.7628618303463308
# Predicted Label: Qustodio
# Accuracy: 0.7644244201121295
# Precision: 0.761305615849942
# Recall: 0.7644244201121295
# F1-Score: 0.7420818009354008
# Predicted Label: mLite
# Accuracy: 0.7424804042250068
# Precision: 0.741683625399388
# Recall: 0.7424804042250068
# F1-Score: 0.7595200474203668
# Predicted Label: kids-360
# Accuracy: 0.7582973892454804
# Precision: 0.760746654724583
# Recall: 0.7582973892454804
# F1-Score: 0.7529821479742854
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7515886410765688
# Precision: 0.7543808318223328
# Recall: 0.7515886410765688
# F1-Score: 0.7505451618725729
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7529311376927534
# Precision: 0.7481742601994299
# Recall: 0.7529311376927534
# F1-Score: 0.7380528589275199
# Predicted Label: kids-360
# Accuracy: 0.7391192808470788
# Precision: 0.7369895099009021
# Recall: 0.7391192808470788
# F1-Score: 0.7727020089162653
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7713144259231471
# Precision: 0.774094593388629
# Recall: 0.7713144259231471
# F1-Score: 0.7503808160838008
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7483980886813423
# Precision: 0.7523740770528403
# Recall: 0.7483980886813423
# F1-Score: 0.7496480103337883
# Predicted Label: TiSpy
# Accuracy: 0.7535985991160297
# Precision: 0.7457386258772216
# Recall: 0.7535985991160297
# F1-Score: 0.7695385572836663
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7646218942069257
# Precision: 0.7745188597163558
# Recall: 0.7646218942069257
# F1-Score: 0.7754371917507463
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7712315767621545
# Precision: 0.7796889256409496
# Recall: 0.7712315767621545
# F1-Score: 0.7604472237759831
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7587921021903314
# Precision: 0.7621095816412866
# Recall: 0.7587921021903314
# F1-Score: 0.7510162729849682
# Predicted Label: Air-Droid
# Accuracy: 0.7478442178371734
# Precision: 0.7542153519275678
# Recall: 0.7478442178371734
# F1-Score: 0.7706751461151286
# Predicted Label: Air-Droid
# Accuracy: 0.7664982709016314
# Precision: 0.7748977928015185
# Recall: 0.7664982709016314
# F1-Score: 0.7595255477277532
# Predicted Label: TiSpy
# Accuracy: 0.7621873818685103
# Precision: 0.7568822410584101
# Recall: 0.7621873818685103
# F1-Score: 0.7567475786778378
# Predicted Label: Eyezy
# Accuracy: 0.7527062446497228
# Precision: 0.7608325433890396
# Recall: 0.7527062446497228
# F1-Score: 0.7400443010324531
# Predicted Label: Air-Droid
# Accuracy: 0.7449969622564593
# Precision: 0.7351570544774642
# Recall: 0.7449969622564593
# F1-Score: 0.7712351494305443
# Predicted Label: kids-360
# Accuracy: 0.7737059139455351
# Precision: 0.7687801150384959
# Recall: 0.7737059139455351
# F1-Score: 0.7396577644805766
# Predicted Label: FamiSafe
# Accuracy: 0.7352905438903464
# Precision: 0.7440771728039813
# Recall: 0.7352905438903464
# F1-Score: 0.7611794552395144
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7589362401316091
# Precision: 0.7634359703617027
# Recall: 0.7589362401316091
# F1-Score: 0.7512346329350629
# Predicted Label: FamiSafe
# Accuracy: 0.752297389872153
# Precision: 0.7501748744371978
# Recall: 0.752297389872153
# F1-Score: 0.780872253634657
# Predicted Label: Qustodio
# Accuracy: 0.7771260489593257
# Precision: 0.7846547510827393
# Recall: 0.7771260489593257
# F1-Score: 0.728743880335105
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7306373008535075
# Precision: 0.7268602479147437
# Recall: 0.7306373008535075
# F1-Score: 0.7629690840677615
# Predicted Label: mLite
# Accuracy: 0.7599010354856042
# Precision: 0.7660620071526567
# Recall: 0.7599010354856042
# F1-Score: 0.7492574514978997
# Predicted Label: Qustodio
# Accuracy: 0.7536354386920372
# Precision: 0.744930035365481
# Recall: 0.7536354386920372
# F1-Score: 0.7344934259803159
# Predicted Label: FamiSafe
# Accuracy: 0.7322566657898376
# Precision: 0.7367438929097785
# Recall: 0.7322566657898376
# F1-Score: 0.7657356300527804
# Predicted Label: Eyezy
# Accuracy: 0.7659845087893423
# Precision: 0.7654869129918296
# Recall: 0.7659845087893423
# F1-Score: 0.7377272331495337
# Predicted Label: Qustodio
# Accuracy: 0.7403065766853058
# Precision: 0.7351658008781817
# Recall: 0.7403065766853058
# F1-Score: 0.7795696963980592
# Predicted Label: Air-Droid
# Accuracy: 0.7757033280682668
# Precision: 0.7834748003801758
# Recall: 0.7757033280682668
# F1-Score: 0.7459531229322517
# Predicted Label: Air-Droid
# Accuracy: 0.7416584279807538
# Precision: 0.7502978458520376
# Recall: 0.7416584279807538
# F1-Score: 0.7493660105789569
# Predicted Label: Air-Droid
# Accuracy: 0.752628711187826
# Precision: 0.7461314759608558
# Recall: 0.752628711187826
# F1-Score: 0.7459422968125561
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7468545209818497
# Precision: 0.7450322983451687
# Recall: 0.7468545209818497
# F1-Score: 0.7657556616692682
# Predicted Label: Eyezy
# Accuracy: 0.7611654893785739
# Precision: 0.770401531472642
# Recall: 0.7611654893785739
# F1-Score: 0.7638809270601957
# Predicted Label: Qustodio
# Accuracy: 0.759527695599912
# Precision: 0.7682843472518169
# Recall: 0.759527695599912
# F1-Score: 0.7765048871506736
# Predicted Label: Normal-Traffic
# Accuracy: 0.7720647552496088
# Precision: 0.7809963847080736
# Recall: 0.7720647552496088
# F1-Score: 0.7554166898775011
# Predicted Label: Air-Droid
# Accuracy: 0.7598435423583574
# Precision: 0.7510411203536184
# Recall: 0.7598435423583574
# F1-Score: 0.7590496009267104
# Predicted Label: Air-Droid
# Accuracy: 0.763075734137582
# Precision: 0.7550657300262873
# Recall: 0.763075734137582
# F1-Score: 0.7552635983582421
# Predicted Label: kids-360
# Accuracy: 0.7535027246958229
# Precision: 0.7570327213313807
# Recall: 0.7535027246958229
# F1-Score: 0.7326262271087748
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7366159367210057
# Precision: 0.7286795033497271
# Recall: 0.7366159367210057
# F1-Score: 0.7338481957471709
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.738763915498874
# Precision: 0.7289974617757202
# Recall: 0.738763915498874
# F1-Score: 0.7392127893770802
# Predicted Label: Qustodio
# Accuracy: 0.7362998647009834
# Precision: 0.7421488536257697
# Recall: 0.7362998647009834
# F1-Score: 0.7412416916609441
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7390657631008883
# Precision: 0.7434304706224479
# Recall: 0.7390657631008883
# F1-Score: 0.7732877801955659
# Predicted Label: Eyezy
# Accuracy: 0.7688624105618188
# Precision: 0.7777643872637823
# Recall: 0.7688624105618188
# F1-Score: 0.739223705913717
# Predicted Label: kids-360
# Accuracy: 0.7349164993727992
# Precision: 0.7435816975414606
# Recall: 0.7349164993727992
# F1-Score: 0.7431848566620852
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7444336708549099
# Precision: 0.74194022531362
# Recall: 0.7444336708549099

# %%
#CatBoost-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-CatBoost-Dataset-A-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-CatBoost-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv','2-All-Together-Update-Single-26-8-24.csv','3-All-Together-Update-Single-26-8-24.csv',
'4-All-Together-Update-Single-26-8-24.csv','5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
               
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7626248394796831
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.76453455965641
# Precision: 0.7607246360577924
# Recall: 0.76453455965641
# F1-Score: 0.7732530313903097
# Predicted Label: Qustodio
# Accuracy: 0.7706721829561068
# Precision: 0.7758512235396177
# Recall: 0.7706721829561068
# F1-Score: 0.7993804838104772
# Predicted Label: TiSpy
# Accuracy: 0.7977675228135119
# Precision: 0.8009999803303235
# Recall: 0.7977675228135119
# F1-Score: 0.7787177230681155
# Predicted Label: Eyezy
# Accuracy: 0.7755640729518272
# Precision: 0.7818971250612867
# Recall: 0.7755640729518272
# F1-Score: 0.8110428897176166
# Predicted Label: FamiSafe
# Accuracy: 0.8069511436718854
# Precision: 0.8151763426568646
# Recall: 0.8069511436718854
# F1-Score: 0.7782003573293621
# Predicted Label: Eyezy
# Accuracy: 0.7745631500057414
# Precision: 0.7818718851405486
# Recall: 0.7745631500057414
# F1-Score: 0.7707397898891796
# Predicted Label: Eyezy
# Accuracy: 0.772553916682152
# Precision: 0.7689341630751221
# Recall: 0.772553916682152
# F1-Score: 0.7901427487499324
# Predicted Label: kids-360
# Accuracy: 0.7922236562767269
# Precision: 0.7880727442855964
# Recall: 0.7922236562767269
# F1-Score: 0.7931008848675801
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7884041619732923
# Precision: 0.7978539022535259
# Recall: 0.7884041619732923
# F1-Score: 0.7934011580512811
# Predicted Label: kids-360
# Accuracy: 0.7969882873204017
# Precision: 0.7898461744017404
# Recall: 0.7969882873204017
# F1-Score: 0.7708774972624847
# Predicted Label: kids-360
# Accuracy: 0.7727341646853473
# Precision: 0.7690297305747616
# Recall: 0.7727341646853473
# F1-Score: 0.7879790863910762
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.79125471576947
# Precision: 0.7847304660448488
# Recall: 0.79125471576947
# F1-Score: 0.7657124274706163
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7627920021075402
# Precision: 0.7686553010593199
# Recall: 0.7627920021075402
# F1-Score: 0.8053646102809701
# Predicted Label: kids-360
# Accuracy: 0.8086815971412614
# Precision: 0.8020747229798358
# Recall: 0.8086815971412614
# F1-Score: 0.776873666501153
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7726416196119061
# Precision: 0.781152329730197
# Recall: 0.7726416196119061
# F1-Score: 0.7971397854358254
# Predicted Label: Normal-Traffic
# Accuracy: 0.7982627443482877
# Precision: 0.7960199815378048
# Recall: 0.7982627443482877
# F1-Score: 0.7853539411836097
# Predicted Label: TiSpy
# Accuracy: 0.7878340942506524
# Precision: 0.7828893544795847
# Recall: 0.7878340942506524
# F1-Score: 0.8000031169973362
# Predicted Label: Air-Droid
# Accuracy: 0.8004352220239722
# Precision: 0.7995714782520621
# Recall: 0.8004352220239722
# F1-Score: 0.7919533014511094
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7898167691376784
# Precision: 0.7941014241793126
# Recall: 0.7898167691376784
# F1-Score: 0.77477979700776
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7761215971230616
# Precision: 0.7734426284353858
# Recall: 0.7761215971230616
# F1-Score: 0.8076592617748496
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8038012641272652
# Precision: 0.8115544724260867
# Recall: 0.8038012641272652
# F1-Score: 0.7624461167245651
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7626002210285787
# Precision: 0.762292074689976
# Recall: 0.7626002210285787
# F1-Score: 0.7605281982900269
# Predicted Label: TiSpy
# Accuracy: 0.7611803361998982
# Precision: 0.7598771768561998
# Recall: 0.7611803361998982
# F1-Score: 0.8062490325275739
# Predicted Label: Normal-Traffic
# Accuracy: 0.8057731301021386
# Precision: 0.8067254974363027
# Recall: 0.8057731301021386
# F1-Score: 0.7678558957159719
# Predicted Label: Air-Droid
# Accuracy: 0.7721661697409734
# Precision: 0.7635934749447807
# Recall: 0.7721661697409734
# F1-Score: 0.8045720948979003
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8077903376078837
# Precision: 0.801379393437151
# Recall: 0.8077903376078837
# F1-Score: 0.7887638321255414
# Predicted Label: Eyezy
# Accuracy: 0.7901949441016674
# Precision: 0.7873378945154496
# Recall: 0.7901949441016674
# F1-Score: 0.7842076170370212
# Predicted Label: kids-360
# Accuracy: 0.7806418124010815
# Precision: 0.7878061468184413
# Recall: 0.7806418124010815
# F1-Score: 0.8006118438463183
# Predicted Label: Qustodio
# Accuracy: 0.8034315184157497
# Precision: 0.7978118915786873
# Recall: 0.8034315184157497
# F1-Score: 0.7859940237180546
# Predicted Label: kids-360
# Accuracy: 0.7820723375387327
# Precision: 0.7899552385476762
# Recall: 0.7820723375387327
# F1-Score: 0.7659319788714526
# Predicted Label: mLite
# Accuracy: 0.7648508851933944
# Precision: 0.7670161330621255
# Recall: 0.7648508851933944
# F1-Score: 0.8016885556812079
# Predicted Label: mLite
# Accuracy: 0.8039512539275774
# Precision: 0.7994385582900899
# Recall: 0.8039512539275774
# F1-Score: 0.7795725971450507
# Predicted Label: Eyezy
# Accuracy: 0.7830620334655801
# Precision: 0.7761141217121499
# Recall: 0.7830620334655801
# F1-Score: 0.7897790970872434
# Predicted Label: Eyezy
# Accuracy: 0.7888594989514012
# Precision: 0.7907008417338295
# Recall: 0.7888594989514012
# F1-Score: 0.7734267599113278
# Predicted Label: kids-360
# Accuracy: 0.7728808425576411
# Precision: 0.7739734490176501
# Recall: 0.7728808425576411
# F1-Score: 0.7735946110152494
# Predicted Label: kids-360
# Accuracy: 0.7779647624137002
# Precision: 0.769273283267407
# Recall: 0.7779647624137002
# F1-Score: 0.7990758236312832
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7961273047128129
# Precision: 0.8020462638718268
# Recall: 0.7961273047128129
# F1-Score: 0.784439802981103
# Predicted Label: mLite
# Accuracy: 0.789253942713371
# Precision: 0.7796840359296521
# Recall: 0.789253942713371
# F1-Score: 0.797600686370959
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7971411161974196
# Precision: 0.7980607867557113
# Recall: 0.7971411161974196
# F1-Score: 0.8080656653451515
# Predicted Label: Qustodio
# Accuracy: 0.8059033688619314
# Precision: 0.8102395962371185
# Recall: 0.8059033688619314
# F1-Score: 0.7791772568358114
# Predicted Label: TiSpy
# Accuracy: 0.7791030953178705
# Precision: 0.7792514324737174
# Recall: 0.7791030953178705
# F1-Score: 0.7699145195004045
# Predicted Label: Eyezy
# Accuracy: 0.7717210810092532
# Precision: 0.7681163963829094
# Recall: 0.7717210810092532
# F1-Score: 0.8057077128529769
# Predicted Label: Qustodio
# Accuracy: 0.8095180769248019
# Precision: 0.801933051145973
# Recall: 0.8095180769248019
# F1-Score: 0.7850154933282297
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7883899732338241
# Precision: 0.7816697773172206
# Recall: 0.7883899732338241
# F1-Score: 0.793860394785872
# Predicted Label: Air-Droid
# Accuracy: 0.7904395287310396
# Precision: 0.7973109992068196
# Recall: 0.7904395287310396
# F1-Score: 0.7859769858650415
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7810339980065182
# Precision: 0.7909829383208865
# Recall: 0.7810339980065182
# F1-Score: 0.7868147052225068
# Predicted Label: mLite
# Accuracy: 0.7915585741588986
# Precision: 0.7821273582588423
# Recall: 0.7915585741588986
# F1-Score: 0.7669651718837649
# Predicted Label: Qustodio
# Accuracy: 0.7678096057695202
# Precision: 0.7661225933673971
# Recall: 0.7678096057695202
# F1-Score: 0.7909580859741734
# Predicted Label: Normal-Traffic
# Accuracy: 0.7889550330759596
# Precision: 0.792971335735764
# Recall: 0.7889550330759596
# F1-Score: 0.8101453373082311
# Predicted Label: FamiSafe
# Accuracy: 0.8062231722373885
# Precision: 0.8141058505269773
# Recall: 0.8062231722373885
# F1-Score: 0.8050074970234916
# Predicted Label: Normal-Traffic
# Accuracy: 0.8020002903937354
# Precision: 0.8080373403741351
# Recall: 0.8020002903937354
# F1-Score: 0.7846065899442536
# Predicted Label: kids-360
# Accuracy: 0.7808788062273873
# Precision: 0.7883701360059852
# Recall: 0.7808788062273873
# F1-Score: 0.7716806233410378
# Predicted Label: TiSpy
# Accuracy: 0.7765295737410054
# Precision: 0.7668918545796868
# Recall: 0.7765295737410054
# F1-Score: 0.7665777666228671
# Predicted Label: FamiSafe
# Accuracy: 0.7628571550418288
# Precision: 0.770334848455947
# Recall: 0.7628571550418288
# F1-Score: 0.7669709578389662
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.765613228711174
# Precision: 0.7683335110822158
# Recall: 0.765613228711174
# F1-Score: 0.7813230131651301
# Predicted Label: Eyezy
# Accuracy: 0.7785467728640516
# Precision: 0.7841191240590858
# Recall: 0.7785467728640516
# F1-Score: 0.7659745362953659
# Predicted Label: Air-Droid
# Accuracy: 0.7633298561653872
# Precision: 0.7686376059857313
# Recall: 0.7633298561653872
# F1-Score: 0.7646586172528137
# Predicted Label: kids-360
# Accuracy: 0.7696415372746586
# Precision: 0.7597398044037034
# Recall: 0.7696415372746586
# F1-Score: 0.8038426705895712
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.802220161062859
# Precision: 0.805471756546177
# Recall: 0.802220161062859
# F1-Score: 0.7647322362147749
# Predicted Label: Air-Droid
# Accuracy: 0.7684106887057571
# Precision: 0.7610888341137192
# Recall: 0.7684106887057571
# F1-Score: 0.7824649090523379
# Predicted Label: Normal-Traffic
# Accuracy: 0.783142902058667
# Precision: 0.7817880889530328
# Recall: 0.783142902058667
# F1-Score: 0.7731650792866965
# Predicted Label: TiSpy
# Accuracy: 0.7776465214798667
# Precision: 0.7687349926902153
# Recall: 0.7776465214798667
# F1-Score: 0.7905781754416213
# Predicted Label: Air-Droid
# Accuracy: 0.7910346837804818
# Precision: 0.7901221937033484
# Recall: 0.7910346837804818
# F1-Score: 0.7767497737098822
# Predicted Label: Air-Droid
# Accuracy: 0.7728448597471947
# Precision: 0.7806943483850598
# Recall: 0.7728448597471947
# F1-Score: 0.8137968401736082
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8103932148061194
# Precision: 0.8172291763591641
# Recall: 0.8103932148061194
# F1-Score: 0.8000574116293888
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7978822023923775
# Precision: 0.8022445135235352
# Recall: 0.7978822023923775
# F1-Score: 0.7750493249469155
# Predicted Label: Eyezy
# Accuracy: 0.7703951252885073
# Precision: 0.779760101376227
# Recall: 0.7703951252885073
# F1-Score: 0.8033246700789607
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8036041311813248
# Precision: 0.8030454032796237
# Recall: 0.8036041311813248
# F1-Score: 0.8039284109833665
# Predicted Label: TiSpy
# Accuracy: 0.8004856704282581
# Precision: 0.8074008926279085
# Recall: 0.8004856704282581
# F1-Score: 0.7687156416675013
# Predicted Label: FamiSafe
# Accuracy: 0.7706855132746558
# Precision: 0.7667558143678729
# Recall: 0.7706855132746558
# F1-Score: 0.7924761978760849
# Predicted Label: Qustodio
# Accuracy: 0.7934882758496795
# Precision: 0.7914666983829647
# Recall: 0.7934882758496795
# F1-Score: 0.7910605241525236
# Predicted Label: mLite
# Accuracy: 0.7879440808734873
# Precision: 0.7942017173721743
# Recall: 0.7879440808734873
# F1-Score: 0.8024895460514558
# Predicted Label: Normal-Traffic
# Accuracy: 0.7993540164403283
# Precision: 0.8056497712608515
# Recall: 0.7993540164403283
# F1-Score: 0.8122825140395226
# Predicted Label: mLite
# Accuracy: 0.8123411754585459
# Precision: 0.8122238610920964
# Recall: 0.8123411754585459
# F1-Score: 0.8123974802085535
# Predicted Label: FamiSafe
# Accuracy: 0.8105687081889271
# Precision: 0.8142345228896131
# Recall: 0.8105687081889271
# F1-Score: 0.7819307502877345
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7853424425794693
# Precision: 0.7785485719947959
# Recall: 0.7853424425794693
# F1-Score: 0.795106318870961
# Predicted Label: mLite
# Accuracy: 0.7938557044242671
# Precision: 0.7963608798895706
# Recall: 0.7938557044242671
# F1-Score: 0.8063971087420405
# Predicted Label: Air-Droid
# Accuracy: 0.8064421564236316
# Precision: 0.8063520660928756
# Recall: 0.8064421564236316
# F1-Score: 0.7938595909364463
# Predicted Label: TiSpy
# Accuracy: 0.7974902678943808
# Precision: 0.790261822405779
# Recall: 0.7974902678943808
# F1-Score: 0.8019549552432945
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8050130337022494
# Precision: 0.798920022875619
# Recall: 0.8050130337022494
# F1-Score: 0.786576865870684
# Predicted Label: mLite
# Accuracy: 0.7823631342707095
# Precision: 0.7908362327533837
# Recall: 0.7823631342707095
# F1-Score: 0.7655510482950734
# Predicted Label: mLite
# Accuracy: 0.7617159506987351
# Precision: 0.7694249593104688
# Recall: 0.7617159506987351
# F1-Score: 0.7657878475616875
# Predicted Label: kids-360
# Accuracy: 0.7630993300800537
# Precision: 0.7684953761518676
# Recall: 0.7630993300800537
# F1-Score: 0.8150894218011306
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.81016683347374
# Precision: 0.8200721952859741
# Recall: 0.81016683347374
# F1-Score: 0.7635277152490828
# Predicted Label: FamiSafe
# Accuracy: 0.7616277944984088
# Precision: 0.7654371386097926
# Recall: 0.7616277944984088
# F1-Score: 0.7936225891885609
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.792748918943071
# Precision: 0.7944981872622008
# Recall: 0.792748918943071
# F1-Score: 0.8059791380123241
# Predicted Label: Qustodio
# Accuracy: 0.8084011912853573
# Precision: 0.803571554827801
# Recall: 0.8084011912853573
# F1-Score: 0.8009056841406332
# Predicted Label: Normal-Traffic
# Accuracy: 0.8032494455136789
# Precision: 0.7985755604629574
# Recall: 0.8032494455136789
# F1-Score: 0.7777866360012013
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7739000160464748
# Precision: 0.7817124911555985
# Recall: 0.7739000160464748
# F1-Score: 0.7585009738234023
# Predicted Label: mLite
# Accuracy: 0.7634597685524565
# Precision: 0.7536061797480021
# Recall: 0.7634597685524565
# F1-Score: 0.8093183917981803
# Predicted Label: Qustodio
# Accuracy: 0.8076719029377533
# Precision: 0.810971607308959
# Recall: 0.8076719029377533
# F1-Score: 0.7685443358813453
# Predicted Label: FamiSafe
# Accuracy: 0.7662174370999947
# Precision: 0.7708854106674167
# Recall: 0.7662174370999947
# F1-Score: 0.8003595129961077
# Predicted Label: FamiSafe
# Accuracy: 0.7956711740950551
# Precision: 0.8051034296434102
# Recall: 0.7956711740950551
# F1-Score: 0.7666590738771754
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.766690251514729
# Precision: 0.7666278987752104
# Recall: 0.766690251514729
# F1-Score: 0.7989879817095329
# Predicted Label: Air-Droid
# Accuracy: 0.7969721034068622
# Precision: 0.8010140838841676
# Recall: 0.7969721034068622
# F1-Score: 0.7998729275189843
# Predicted Label: TiSpy
# Accuracy: 0.7993249982858369
# Precision: 0.8004216084673629
# Recall: 0.7993249982858369
# F1-Score: 0.7838912317536022
# Predicted Label: Normal-Traffic
# Accuracy: 0.7817594495032015
# Precision: 0.7860346721217274
# Recall: 0.7817594495032015
# F1-Score: 0.7859196820401707
# Predicted Label: Air-Droid
# Accuracy: 0.7902714526874351
# Precision: 0.7816155765182391
# Recall: 0.7902714526874351
# F1-Score: 0.7654166923227523
# Predicted Label: kids-360
# Accuracy: 0.7659926227619775
# Precision: 0.7648416272878523
# Recall: 0.7659926227619775
# F1-Score: 0.7764933030781165
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7793120946944504
# Precision: 0.7736948292533833
# Recall: 0.7793120946944504
# F1-Score: 0.7789031194022735
# Predicted Label: Eyezy
# Accuracy: 0.7834719120708005
# Precision: 0.7743873033536659
# Recall: 0.7834719120708005
# F1-Score: 0.809584197914932
# Predicted Label: Normal-Traffic
# Accuracy: 0.8114260961405935
# Precision: 0.8077506427916603
# Recall: 0.8114260961405935
# F1-Score: 0.7692240145715556
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7703341023065307
# Precision: 0.768117121610215
# Recall: 0.7703341023065307
# F1-Score: 0.7964235338976408
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7989623925309797
# Precision: 0.793900759588938
# Recall: 0.7989623925309797
# F1-Score: 0.7859768187194829
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7872325093697493
# Precision: 0.7847251275178045
# Recall: 0.7872325093697493
# F1-Score: 0.8035832597179277
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8077940108183042
# Precision: 0.7994161793585636
# Recall: 0.8077940108183042
# F1-Score: 0.7785559837475723
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.777018615534998
# Precision: 0.7800994475324875
# Recall: 0.777018615534998
# F1-Score: 0.7659578171127943
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7630644629267608
# Precision: 0.7688731965990518
# Recall: 0.7630644629267608
# F1-Score: 0.7891600271794209
# Predicted Label: Normal-Traffic
# Accuracy: 0.7920598977177533
# Precision: 0.7862813130554756
# Recall: 0.7920598977177533
# F1-Score: 0.776568924646215
# Predicted Label: Eyezy
# Accuracy: 0.7778035161402864
# Precision: 0.7753382462242829
# Recall: 0.7778035161402864
# F1-Score: 0.7950498536985066
# Predicted Label: TiSpy
# Accuracy: 0.7930406002163646
# Precision: 0.7970693143603566
# Recall: 0.7930406002163646
# F1-Score: 0.7617134687073942
# Predicted Label: Normal-Traffic
# Accuracy: 0.7637293129520246
# Precision: 0.7597082379886356
# Recall: 0.7637293129520246
# F1-Score: 0.780772359234224
# Predicted Label: TiSpy
# Accuracy: 0.7848715323469894
# Precision: 0.7767157814170561
# Recall: 0.7848715323469894
# F1-Score: 0.7935350421826558
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7960116284185431
# Precision: 0.7910738186766653
# Recall: 0.7960116284185431
# F1-Score: 0.7810343395558313
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7855273503830795
# Precision: 0.7765924341108872
# Recall: 0.7855273503830795
# F1-Score: 0.8052553616199221
# Predicted Label: Eyezy
# Accuracy: 0.8010098104678184
# Precision: 0.8095461575338845
# Recall: 0.8010098104678184
# F1-Score: 0.7857366415163605
# Predicted Label: mLite
# Accuracy: 0.790721864592867
# Precision: 0.7808138847657359
# Recall: 0.790721864592867
# F1-Score: 0.7880868108468613
# Predicted Label: Qustodio
# Accuracy: 0.7847189884921248
# Precision: 0.7914836655442998
# Recall: 0.7847189884921248
# F1-Score: 0.7644778615656984
# Predicted Label: Normal-Traffic
# Accuracy: 0.7629322405103106
# Precision: 0.7660297578678157
# Recall: 0.7629322405103106
# F1-Score: 0.7885479003107179
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7915005113781192
# Precision: 0.7856172361949215
# Recall: 0.7915005113781192

# %%
#CatBoost-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-CatBoost-Dataset-B-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-CatBoost-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection" 
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7588071542977008
# Predicted Label: TiSpy
# Accuracy: 0.7609735382932493
# Precision: 0.75921017986806
# Recall: 0.7584045563913401
# F1-Score: 0.792184730366724
# Predicted Label: Air-Droid
# Accuracy: 0.7920857320555862
# Precision: 0.7976480336480289
# Recall: 0.786795757209702
# F1-Score: 0.7746134470651505
# Predicted Label: mLite
# Accuracy: 0.7767274076100978
# Precision: 0.7756235612148336
# Recall: 0.7736059604878422
# F1-Score: 0.7781866934689426
# Predicted Label: FamiSafe
# Accuracy: 0.7733748193541534
# Precision: 0.7744753482635981
# Recall: 0.7819337800508397
# F1-Score: 0.7876720300160183
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.789857960891046
# Precision: 0.7956600724739318
# Recall: 0.7798427854725747
# F1-Score: 0.7587881101858542
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7656419076603967
# Precision: 0.7625017355504887
# Recall: 0.7551104825682041
# F1-Score: 0.7996304284666558
# Predicted Label: Eyezy
# Accuracy: 0.7979597683955756
# Precision: 0.7961779474253716
# Recall: 0.8031129820257179
# F1-Score: 0.7923465409362268
# Predicted Label: mLite
# Accuracy: 0.7908018004583478
# Precision: 0.7907488618453916
# Recall: 0.7939506892018743
# F1-Score: 0.7917568100079073
# Predicted Label: kids-360
# Accuracy: 0.7956824966849528
# Precision: 0.790544059970589
# Recall: 0.7929732866493385
# F1-Score: 0.7637309392655148
# Predicted Label: Normal-Traffic
# Accuracy: 0.7627479089761081
# Precision: 0.7646052166175921
# Recall: 0.7628586589908103
# F1-Score: 0.7789410696522224
# Predicted Label: Eyezy
# Accuracy: 0.7750583587067698
# Precision: 0.7760644850514025
# Recall: 0.7818390584652937
# F1-Score: 0.7814392495966022
# Predicted Label: Normal-Traffic
# Accuracy: 0.7824645987456285
# Precision: 0.788395257344974
# Recall: 0.7746049139846033
# F1-Score: 0.7956437124853286
# Predicted Label: FamiSafe
# Accuracy: 0.7910103201453801
# Precision: 0.797369865903485
# Recall: 0.7939250165079579
# F1-Score: 0.7677144043616017
# Predicted Label: kids-360
# Accuracy: 0.771260771917335
# Precision: 0.7725950119387844
# Recall: 0.7628950728674869
# F1-Score: 0.7603385360919919
# Predicted Label: Normal-Traffic
# Accuracy: 0.762816829609789
# Precision: 0.7553862213289847
# Recall: 0.7653562141636059
# F1-Score: 0.764294948522142
# Predicted Label: kids-360
# Accuracy: 0.7714165638052711
# Precision: 0.7638547085887623
# Recall: 0.7647356962038206
# F1-Score: 0.7661786138677521
# Predicted Label: Air-Droid
# Accuracy: 0.7673211254948658
# Precision: 0.7702925993431828
# Recall: 0.7621083389619985
# F1-Score: 0.7795330931890889
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7789842418957091
# Precision: 0.775237400935625
# Recall: 0.7838766566933327
# F1-Score: 0.7651724969878503
# Predicted Label: TiSpy
# Accuracy: 0.7624120459576447
# Precision: 0.7684895406789453
# Recall: 0.7618839650484596
# F1-Score: 0.7777204396150755
# Predicted Label: Qustodio
# Accuracy: 0.7749403171682614
# Precision: 0.7760874667272001
# Recall: 0.7793602988996953
# F1-Score: 0.7765492213137495
# Predicted Label: mLite
# Accuracy: 0.77105377048087
# Precision: 0.77024666258155
# Recall: 0.7829557725929762
# F1-Score: 0.7882263517631419
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7922233303432495
# Precision: 0.7916532222987666
# Recall: 0.7848290215009409
# F1-Score: 0.7855319051383449
# Predicted Label: mLite
# Accuracy: 0.7897822228949462
# Precision: 0.7891148519438149
# Recall: 0.7819813477449084
# F1-Score: 0.7873828146899918
# Predicted Label: Eyezy
# Accuracy: 0.7856802720568726
# Precision: 0.7822251930247158
# Recall: 0.7926089016013356
# F1-Score: 0.7626018922766146
# Predicted Label: TiSpy
# Accuracy: 0.7646263670212385
# Precision: 0.7554137172193425
# Recall: 0.7699281803967063
# F1-Score: 0.7992362721848373
# Predicted Label: kids-360
# Accuracy: 0.7937753404908907
# Precision: 0.7988965422607283
# Recall: 0.799576291171464
# F1-Score: 0.7829388864424736
# Predicted Label: FamiSafe
# Accuracy: 0.778810369149728
# Precision: 0.7886315532399645
# Recall: 0.7773278146774637
# F1-Score: 0.7702249088022648
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7708385306622985
# Precision: 0.7640235489718783
# Recall: 0.7765277617382821
# F1-Score: 0.7681974464742384
# Predicted Label: Eyezy
# Accuracy: 0.7691769992054837
# Precision: 0.7778541553944479
# Recall: 0.758777564831963
# F1-Score: 0.7906932986722124
# Predicted Label: mLite
# Accuracy: 0.7903822780091034
# Precision: 0.8002073070629293
# Recall: 0.7814028643777459
# F1-Score: 0.7601661897586699
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7608497559475901
# Precision: 0.7672291088987447
# Recall: 0.7532321233640005
# F1-Score: 0.7699837772348729
# Predicted Label: Air-Droid
# Accuracy: 0.7759246988053383
# Precision: 0.7744260200437926
# Recall: 0.7655922067209088
# F1-Score: 0.7920817819991783
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7890745331436507
# Precision: 0.797268733707384
# Recall: 0.7869618856275157
# F1-Score: 0.7870589437539717
# Predicted Label: Normal-Traffic
# Accuracy: 0.7861367177509946
# Precision: 0.7837234902845043
# Recall: 0.7904229093208115
# F1-Score: 0.772113050508704
# Predicted Label: TiSpy
# Accuracy: 0.7643955078022474
# Precision: 0.7699968250998257
# Recall: 0.7742409402570197
# F1-Score: 0.7633401760310791
# Predicted Label: Eyezy
# Accuracy: 0.7646532107359869
# Precision: 0.7601004420762292
# Recall: 0.7666076452772068
# F1-Score: 0.7737125601848965
# Predicted Label: Normal-Traffic
# Accuracy: 0.7698879245674888
# Precision: 0.776883713793582
# Recall: 0.7705671899297418
# F1-Score: 0.7718273390462769
# Predicted Label: Air-Droid
# Accuracy: 0.7695932409264763
# Precision: 0.779156336063062
# Recall: 0.7646349350338689
# F1-Score: 0.7893871132729599
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7909093709296654
# Precision: 0.7918087619517269
# Recall: 0.786980232052716
# F1-Score: 0.7873084023075665
# Predicted Label: FamiSafe
# Accuracy: 0.7835757910172201
# Precision: 0.7916839889519718
# Recall: 0.7829809169838905
# F1-Score: 0.7809350678437693
# Predicted Label: TiSpy
# Accuracy: 0.7759366384806554
# Precision: 0.7817797510604102
# Recall: 0.7800922079531205
# F1-Score: 0.7805964606870386
# Predicted Label: FamiSafe
# Accuracy: 0.7822972568622861
# Precision: 0.783593437288332
# Recall: 0.7776223215589465
# F1-Score: 0.7596820115950962
# Predicted Label: Eyezy
# Accuracy: 0.7673833615038015
# Precision: 0.7608631815705975
# Recall: 0.7585045032503336
# F1-Score: 0.7861316414787342
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7820706533339281
# Precision: 0.7810522141591686
# Recall: 0.7912775674753982
# F1-Score: 0.7682683813316051
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7757330429837327
# Precision: 0.7708010655007702
# Recall: 0.7657522863494592
# F1-Score: 0.7768031334049579
# Predicted Label: mLite
# Accuracy: 0.7815508200305643
# Precision: 0.7823965790758866
# Recall: 0.7712890964409699
# F1-Score: 0.7590235637545015
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7602664585374544
# Precision: 0.759788460658527
# Recall: 0.7582602053809893
# F1-Score: 0.7816066916755662
# Predicted Label: Qustodio
# Accuracy: 0.7896213438234508
# Precision: 0.7849258834542676
# Recall: 0.7783154532185157
# F1-Score: 0.7816422267005743
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7775708029607848
# Precision: 0.7817643444219993
# Recall: 0.7815201471246819
# F1-Score: 0.768343875290186
# Predicted Label: Normal-Traffic
# Accuracy: 0.7655674109212381
# Precision: 0.7735030365660375
# Recall: 0.763253079847796
# F1-Score: 0.7714347025411419
# Predicted Label: TiSpy
# Accuracy: 0.7775390425548261
# Precision: 0.7736134828873711
# Recall: 0.769268160223112
# F1-Score: 0.7891920404975031
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7885966074332524
# Precision: 0.7794375250077086
# Recall: 0.7991938021165846
# F1-Score: 0.7589115945652032
# Predicted Label: Normal-Traffic
# Accuracy: 0.7689038243724158
# Precision: 0.7609674641083243
# Recall: 0.7568668035812608
# F1-Score: 0.7615657044135075
# Predicted Label: Qustodio
# Accuracy: 0.7632477683626918
# Precision: 0.7683086207255185
# Recall: 0.7549401142874804
# F1-Score: 0.7700514629522346
# Predicted Label: Eyezy
# Accuracy: 0.7684574964243155
# Precision: 0.7704174567660855
# Recall: 0.7696858167106405
# F1-Score: 0.7648305880105745
# Predicted Label: Normal-Traffic
# Accuracy: 0.7657549411816247
# Precision: 0.7618689295457254
# Recall: 0.767815362398005
# F1-Score: 0.7988044792948187
# Predicted Label: Qustodio
# Accuracy: 0.7930871728250909
# Precision: 0.7931560811520512
# Recall: 0.8045339036987071
# F1-Score: 0.7820600737906495
# Predicted Label: Eyezy
# Accuracy: 0.7756459486639453
# Precision: 0.779872557113978
# Recall: 0.7842598968097654
# F1-Score: 0.7808445237683621
# Predicted Label: Normal-Traffic
# Accuracy: 0.778941755728018
# Precision: 0.785903875628851
# Recall: 0.7758498956279113
# F1-Score: 0.7718797324596142
# Predicted Label: kids-360
# Accuracy: 0.7732027603393966
# Precision: 0.7643782288638128
# Recall: 0.7795299328096406
# F1-Score: 0.7720617255143378
# Predicted Label: TiSpy
# Accuracy: 0.7823207882919638
# Precision: 0.7737552292731247
# Recall: 0.7703756186468189
# F1-Score: 0.7735280903791638
# Predicted Label: Eyezy
# Accuracy: 0.7785291579780969
# Precision: 0.7780957588321554
# Recall: 0.7690137362739982
# F1-Score: 0.7714865304527386
# Predicted Label: mLite
# Accuracy: 0.7742492972448235
# Precision: 0.7715853067465114
# Recall: 0.7713877794458841
# F1-Score: 0.7870209177759313
# Predicted Label: kids-360
# Accuracy: 0.7850968208634351
# Precision: 0.7942612197564914
# Recall: 0.7799114252108195
# F1-Score: 0.8034063917701739
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7931702152661206
# Precision: 0.8024053436767256
# Recall: 0.8044099407169142
# F1-Score: 0.7749310018981712
# Predicted Label: Qustodio
# Accuracy: 0.7751883083473513
# Precision: 0.7749416198816904
# Recall: 0.7749203842056158
# F1-Score: 0.7710006563105791
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7703754806673452
# Precision: 0.7746208998375181
# Recall: 0.7674140942801946
# F1-Score: 0.8017572168704322
# Predicted Label: TiSpy
# Accuracy: 0.7946245482000841
# Precision: 0.8013666867968867
# Recall: 0.8021481277636492
# F1-Score: 0.7726837214848287
# Predicted Label: FamiSafe
# Accuracy: 0.7706293772593034
# Precision: 0.7716071189816363
# Recall: 0.7737633324943036
# F1-Score: 0.7818086830407824
# Predicted Label: FamiSafe
# Accuracy: 0.7784325932913913
# Precision: 0.7847579909988622
# Recall: 0.7788814604878856
# F1-Score: 0.7783371086068405
# Predicted Label: Eyezy
# Accuracy: 0.7759991001086252
# Precision: 0.7741426284686448
# Recall: 0.7825772896501368
# F1-Score: 0.7743273258137288
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7826615307027319
# Precision: 0.772727263331436
# Recall: 0.7759340284455182
# F1-Score: 0.7874801735710143
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7863273743146756
# Precision: 0.778913964890906
# Recall: 0.7962368934340515
# F1-Score: 0.7904709860920329
# Predicted Label: Air-Droid
# Accuracy: 0.790269153444075
# Precision: 0.7992056393708088
# Recall: 0.7819251937194268
# F1-Score: 0.7728659393414923
# Predicted Label: kids-360
# Accuracy: 0.7708383669521718
# Precision: 0.7714609153118136
# Recall: 0.7742760905120614
# F1-Score: 0.790049941760781
# Predicted Label: TiSpy
# Accuracy: 0.791151670305597
# Precision: 0.7835933459507183
# Recall: 0.7966138227544284
# F1-Score: 0.7823224080624691
# Predicted Label: mLite
# Accuracy: 0.7831226397524365
# Precision: 0.7796278351035429
# Recall: 0.7850356717475743
# F1-Score: 0.7781774580124472
# Predicted Label: Eyezy
# Accuracy: 0.7733658201619458
# Precision: 0.7794293064499647
# Recall: 0.7769296243369122
# F1-Score: 0.7712321409403191
# Predicted Label: Eyezy
# Accuracy: 0.7613462333290155
# Precision: 0.7704924317183166
# Recall: 0.7719732718389644
# F1-Score: 0.7601840301331875
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7624855203778411
# Precision: 0.7563378393890804
# Recall: 0.7640695387441884
# F1-Score: 0.7659319430572213
# Predicted Label: Normal-Traffic
# Accuracy: 0.7606911272751419
# Precision: 0.7653264899329442
# Recall: 0.7665383548931543
# F1-Score: 0.759811291483511
# Predicted Label: mLite
# Accuracy: 0.7615591867114492
# Precision: 0.767274374551403
# Recall: 0.7524919928895216
# F1-Score: 0.7910181346040764
# Predicted Label: mLite
# Accuracy: 0.7951600385761461
# Precision: 0.790032025455099
# Recall: 0.7920067085304101
# F1-Score: 0.7742771972983711
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7768042944410527
# Precision: 0.7720316898605002
# Recall: 0.7765358052666717
# F1-Score: 0.7961027444005482
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7921951005289731
# Precision: 0.7904150265459285
# Recall: 0.8018729116207896
# F1-Score: 0.7824402096911311
# Predicted Label: Eyezy
# Accuracy: 0.7871119218039851
# Precision: 0.785566366774218
# Recall: 0.7793388350367159
# F1-Score: 0.7846172691724503
# Predicted Label: Eyezy
# Accuracy: 0.7918482938686344
# Precision: 0.7852957838504737
# Recall: 0.7839399259886326
# F1-Score: 0.7669007028739254
# Predicted Label: mLite
# Accuracy: 0.7662801514120933
# Precision: 0.7717920399588293
# Recall: 0.7620709743651423
# F1-Score: 0.7723958280608861
# Predicted Label: mLite
# Accuracy: 0.7714194130498143
# Precision: 0.7813145363569822
# Recall: 0.763678435915962
# F1-Score: 0.7725333445051887
# Predicted Label: Qustodio
# Accuracy: 0.7758821596453773
# Precision: 0.7781309028460506
# Recall: 0.7670157441113226
# F1-Score: 0.8051513355495368
# Predicted Label: kids-360
# Accuracy: 0.7964385660364011
# Precision: 0.805768564353566
# Recall: 0.804535051631689
# F1-Score: 0.7835263814231977
# Predicted Label: Eyezy
# Accuracy: 0.7808448053333782
# Precision: 0.7898258591448013
# Recall: 0.7773265950886845
# F1-Score: 0.766318756388073
# Predicted Label: Normal-Traffic
# Accuracy: 0.7750157693116465
# Precision: 0.7674023006713431
# Recall: 0.765238267641145
# F1-Score: 0.7621665403042547
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7634047159789897
# Precision: 0.7698221765324402
# Recall: 0.7546616704776214
# F1-Score: 0.768965591200507
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7686921933869888
# Precision: 0.7620577958939075
# Recall: 0.7759997657323219
# F1-Score: 0.7675333949550219
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7688381945040269
# Precision: 0.7709101339549314
# Recall: 0.7641861085176495
# F1-Score: 0.7811465076832701
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7816085481398453
# Precision: 0.7830237838825316
# Recall: 0.7792782113825142
# F1-Score: 0.786410283115751
# Predicted Label: Normal-Traffic
# Accuracy: 0.7812831363778122
# Precision: 0.7863078657307481
# Recall: 0.7865127271841629
# F1-Score: 0.7951300004228098
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7860213285682983
# Precision: 0.7931853130061383
# Recall: 0.7970842470279917
# F1-Score: 0.7687727831130896
# Predicted Label: Eyezy
# Accuracy: 0.7640548219193949
# Precision: 0.7719934693519709
# Recall: 0.7655788580466522
# F1-Score: 0.7885410217681049
# Predicted Label: Air-Droid
# Accuracy: 0.7912521595564889
# Precision: 0.7830013424115988
# Recall: 0.7941596453319749
# F1-Score: 0.7751694251718673
# Predicted Label: Qustodio
# Accuracy: 0.7708923616432704
# Precision: 0.7741782352681987
# Recall: 0.7761631563944339
# F1-Score: 0.7876465855188933
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.785676504601582
# Precision: 0.7925374942553505
# Recall: 0.7828156721078563
# F1-Score: 0.7932080183222525
# Predicted Label: FamiSafe
# Accuracy: 0.7954334212143713
# Precision: 0.7982187213008273
# Recall: 0.7882598308431865
# F1-Score: 0.7855617813349138
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7775196431565303
# Precision: 0.7825202906037484
# Recall: 0.7886270075823482
# F1-Score: 0.7989877149621658
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7952951192189501
# Precision: 0.8013957055012876
# Recall: 0.7965941518720966
# F1-Score: 0.7638437238052217
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7634025270020381
# Precision: 0.7557538267917139
# Recall: 0.7721086899402494
# F1-Score: 0.7884203921032685
# Predicted Label: TiSpy
# Accuracy: 0.7925409671081552
# Precision: 0.783922222354736
# Recall: 0.7929704810375613
# F1-Score: 0.7937120535621514
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7906179043384334
# Precision: 0.790982448478184
# Recall: 0.7964605630978489
# F1-Score: 0.7826719948740042
# Predicted Label: Qustodio
# Accuracy: 0.7914113978826227
# Precision: 0.7861537585489842
# Recall: 0.7792209356897601
# F1-Score: 0.7725950587148002
# Predicted Label: Normal-Traffic
# Accuracy: 0.779375258768372
# Precision: 0.7716708025552711
# Recall: 0.7735215315549032
# F1-Score: 0.7636988766639735
# Predicted Label: Air-Droid
# Accuracy: 0.7645266500572034
# Precision: 0.7633452401983649
# Recall: 0.7640528409411838
# F1-Score: 0.7897343721508725
# Predicted Label: Normal-Traffic
# Accuracy: 0.7923790936566862
# Precision: 0.7987355681039267
# Recall: 0.7809337898932462
# F1-Score: 0.767761780959302
# Predicted Label: FamiSafe
# Accuracy: 0.7625154750238777
# Precision: 0.7621524749766524
# Recall: 0.7734542661044805
# F1-Score: 0.7785296101858971
# Predicted Label: FamiSafe
# Accuracy: 0.7784526597967927
# Precision: 0.7874562130308385
# Recall: 0.7698031227547063
# F1-Score: 0.7740891390228655
# Predicted Label: kids-360
# Accuracy: 0.7777280399930255
# Precision: 0.7719913986629053
# Recall: 0.7761983108696818
# F1-Score: 0.78425786151012
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7891499875079033
# Precision: 0.7915193776585548
# Recall: 0.7771283705945939
# F1-Score: 0.8023769113934341
# Predicted Label: Normal-Traffic
# Accuracy: 0.7971052394491718
# Precision: 0.8058481046326149
# Recall: 0.7989354942451868
# F1-Score: 0.7902321336524197
# Predicted Label: Qustodio
# Accuracy: 0.7907586594849922
# Precision: 0.7974715290464902
# Recall: 0.7831229933451884
# F1-Score: 0.7653394795291106
# Predicted Label: Normal-Traffic
# Accuracy: 0.7635931531590787
# Precision: 0.7682206879310643
# Recall: 0.7624798022941659

# %%
#RF-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-RF-Dataset-A-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-RF-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv','2-All-Together-Update-Single-26-8-24.csv','3-All-Together-Update-Single-26-8-24.csv',
'4-All-Together-Update-Single-26-8-24.csv','5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.735163741534751
# Predicted Label: Normal-Traffic
# Accuracy: 0.735454597496718
# Precision: 0.7389262490581493
# Recall: 0.7314393562065202
# F1-Score: 0.7257364392833316
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7208789690480943
# Precision: 0.7278540254404706
# Recall: 0.7236311390043326
# F1-Score: 0.7330383750886806
# Predicted Label: kids-360
# Accuracy: 0.74102139590855
# Precision: 0.7347467133029594
# Recall: 0.731337962461845
# F1-Score: 0.7227020439432019
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7241796934417165
# Precision: 0.7252016074852143
# Recall: 0.7202196517845796
# F1-Score: 0.7404524454911755
# Predicted Label: Normal-Traffic
# Accuracy: 0.745020275011835
# Precision: 0.7433015418387083
# Recall: 0.7376251070825417
# F1-Score: 0.7496479703725303
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7448161372711221
# Precision: 0.7442557363249871
# Recall: 0.7551189095880345
# F1-Score: 0.7246685355137097
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7323126038807615
# Precision: 0.7243697112316966
# Recall: 0.7249676064454724
# F1-Score: 0.7409942536968279
# Predicted Label: kids-360
# Accuracy: 0.7408934277469187
# Precision: 0.733209276196221
# Recall: 0.7489463220290872
# F1-Score: 0.7337997015741459
# Predicted Label: Eyezy
# Accuracy: 0.7262158065507578
# Precision: 0.7307129510971231
# Recall: 0.7369126414008628
# F1-Score: 0.7215611958375866
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7306736977664231
# Precision: 0.722486535305125
# Recall: 0.7206382236331801
# F1-Score: 0.7288720386802454
# Predicted Label: TiSpy
# Accuracy: 0.7278862702414535
# Precision: 0.7202977613604258
# Recall: 0.7376529081196334
# F1-Score: 0.7209645325242193
# Predicted Label: Air-Droid
# Accuracy: 0.7169064561711012
# Precision: 0.7179053838531622
# Recall: 0.7240498641424084
# F1-Score: 0.742107362823931
# Predicted Label: FamiSafe
# Accuracy: 0.7383097007625885
# Precision: 0.7425947043429717
# Recall: 0.7416206605391645
# F1-Score: 0.7141899233162816
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7145252403598479
# Precision: 0.7088246383530655
# Recall: 0.7196370503435711
# F1-Score: 0.7338014191059941
# Predicted Label: TiSpy
# Accuracy: 0.7245054685210129
# Precision: 0.7337448093935195
# Recall: 0.7338580375542219
# F1-Score: 0.7363412098133101
# Predicted Label: Qustodio
# Accuracy: 0.7365960158469117
# Precision: 0.7359748015848351
# Recall: 0.7367079830593434
# F1-Score: 0.7316931133716925
# Predicted Label: Normal-Traffic
# Accuracy: 0.7253835749354821
# Precision: 0.7293333055059689
# Recall: 0.734068241446973
# F1-Score: 0.7075873823686704
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7102423423188735
# Precision: 0.7017558804490291
# Recall: 0.7135166144891437
# F1-Score: 0.7108672485195038
# Predicted Label: TiSpy
# Accuracy: 0.7140806254080869
# Precision: 0.7147288590733979
# Recall: 0.7070471415387859
# F1-Score: 0.7065350933990895
# Predicted Label: kids-360
# Accuracy: 0.7110507127337938
# Precision: 0.7084103860346588
# Recall: 0.7046697030396736
# F1-Score: 0.7187296905850156
# Predicted Label: FamiSafe
# Accuracy: 0.7176006238165327
# Precision: 0.7092414675491477
# Recall: 0.7284752225425188
# F1-Score: 0.7154867501366079
# Predicted Label: Normal-Traffic
# Accuracy: 0.7190317969853859
# Precision: 0.7093071084890045
# Recall: 0.7217750149647688
# F1-Score: 0.7409412111546199
# Predicted Label: Qustodio
# Accuracy: 0.7443238354930671
# Precision: 0.7481857515300353
# Recall: 0.7338356203707508
# F1-Score: 0.7293734682933748
# Predicted Label: kids-360
# Accuracy: 0.7317944648050758
# Precision: 0.7224538796199519
# Recall: 0.7364268890081552
# F1-Score: 0.7405188627590884
# Predicted Label: Qustodio
# Accuracy: 0.7435117760131299
# Precision: 0.7389729798765993
# Recall: 0.7420712269707725
# F1-Score: 0.7335146608791858
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7402962145199975
# Precision: 0.7377182208196266
# Recall: 0.7293587337664397
# F1-Score: 0.743820307210678
# Predicted Label: kids-360
# Accuracy: 0.7479825154150589
# Precision: 0.7380840989072692
# Recall: 0.7496463746810816
# F1-Score: 0.7402269756978201
# Predicted Label: FamiSafe
# Accuracy: 0.7384336444689743
# Precision: 0.7471237039330036
# Recall: 0.7334564107821455
# F1-Score: 0.7369363800647417
# Predicted Label: Normal-Traffic
# Accuracy: 0.734525602900359
# Precision: 0.7366471262632807
# Recall: 0.7372258611137539
# F1-Score: 0.7398750788371719
# Predicted Label: TiSpy
# Accuracy: 0.7324072811722112
# Precision: 0.7423843892526477
# Recall: 0.7373826745621667
# F1-Score: 0.7292734033126943
# Predicted Label: TiSpy
# Accuracy: 0.7369081620832688
# Precision: 0.7297932146854729
# Recall: 0.7287543319071728
# F1-Score: 0.7532403173977222
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7451844779646378
# Precision: 0.7515312023017487
# Recall: 0.7549572238737073
# F1-Score: 0.7339147159437102
# Predicted Label: Eyezy
# Accuracy: 0.7313045943962663
# Precision: 0.726174741526598
# Recall: 0.7418214618109809
# F1-Score: 0.7241643498510604
# Predicted Label: Normal-Traffic
# Accuracy: 0.7306105944688434
# Precision: 0.7210552472050719
# Recall: 0.7273003807543743
# F1-Score: 0.7364033157994929
# Predicted Label: FamiSafe
# Accuracy: 0.7357388634527549
# Precision: 0.7415837110398219
# Recall: 0.73129479464797
# F1-Score: 0.7249767744706498
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7259278394168454
# Precision: 0.7336414771149662
# Recall: 0.7165143524322655
# F1-Score: 0.7438927534282145
# Predicted Label: FamiSafe
# Accuracy: 0.7471994860703985
# Precision: 0.7385344599460297
# Recall: 0.7493293672660097
# F1-Score: 0.7199970227490959
# Predicted Label: Air-Droid
# Accuracy: 0.7170700368589137
# Precision: 0.714220437681829
# Recall: 0.72586781128758
# F1-Score: 0.7482494976996946
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7481010972243355
# Precision: 0.756696066649438
# Recall: 0.7399894156184209
# F1-Score: 0.7199667210215432
# Predicted Label: Qustodio
# Accuracy: 0.7172385830990642
# Precision: 0.726734978446984
# Recall: 0.713323369135265
# F1-Score: 0.7261692768313582
# Predicted Label: TiSpy
# Accuracy: 0.7288816883096823
# Precision: 0.7251047849670443
# Recall: 0.7272368987505601
# F1-Score: 0.72660298779496
# Predicted Label: Qustodio
# Accuracy: 0.7257368603632665
# Precision: 0.7183921874579104
# Recall: 0.735003647352196
# F1-Score: 0.743006839892758
# Predicted Label: Normal-Traffic
# Accuracy: 0.7421452095271529
# Precision: 0.7461610044139451
# Recall: 0.7398792296286824
# F1-Score: 0.733729424589632
# Predicted Label: Qustodio
# Accuracy: 0.7308509535815007
# Precision: 0.7319824038090874
# Recall: 0.7354848045422424
# F1-Score: 0.7222860208960941
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.720118135241229
# Precision: 0.7261463414104542
# Recall: 0.7184665276104453
# F1-Score: 0.7221631328961381
# Predicted Label: FamiSafe
# Accuracy: 0.7293583592938866
# Precision: 0.7220637188155776
# Recall: 0.7222625743552251
# F1-Score: 0.7239313119714117
# Predicted Label: Qustodio
# Accuracy: 0.7261189004933815
# Precision: 0.7217865146181163
# Recall: 0.7260888938967418
# F1-Score: 0.7399752454267566
# Predicted Label: Air-Droid
# Accuracy: 0.7437756442230551
# Precision: 0.7340875641994073
# Recall: 0.7459581334539024
# F1-Score: 0.733448550416586
# Predicted Label: TiSpy
# Accuracy: 0.7441107989717818
# Precision: 0.7350265914265462
# Recall: 0.7318772707364342
# F1-Score: 0.7415808360155554
# Predicted Label: FamiSafe
# Accuracy: 0.7450523637323151
# Precision: 0.7373310383696073
# Recall: 0.7458799072727436
# F1-Score: 0.7408223691400725
# Predicted Label: kids-360
# Accuracy: 0.7464797820869151
# Precision: 0.7473184666447666
# Recall: 0.7344382336079839
# F1-Score: 0.7221104846471846
# Predicted Label: mLite
# Accuracy: 0.7183047638443344
# Precision: 0.7247611305139134
# Recall: 0.7194791563767305
# F1-Score: 0.7223517851908206
# Predicted Label: Eyezy
# Accuracy: 0.7273569749093177
# Precision: 0.7175458468628843
# Recall: 0.7272225355011793
# F1-Score: 0.7367649592025044
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7351269079817171
# Precision: 0.7333674722432961
# Recall: 0.7401940718939227
# F1-Score: 0.7364234740685746
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.733901946476542
# Precision: 0.7316690404753465
# Recall: 0.7412401010434693
# F1-Score: 0.7342100979042593
# Predicted Label: mLite
# Accuracy: 0.7374948682769452
# Precision: 0.738876179468424
# Recall: 0.7296025801052078
# F1-Score: 0.7409533066239562
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7418417411250073
# Precision: 0.7328838690713693
# Recall: 0.7492024200206862
# F1-Score: 0.724792150899481
# Predicted Label: Normal-Traffic
# Accuracy: 0.7258738263255627
# Precision: 0.7269517953830098
# Recall: 0.722645300247019
# F1-Score: 0.7106115775875265
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7162629013915538
# Precision: 0.712456896317204
# Recall: 0.7087757932009949
# F1-Score: 0.7398314823736074
# Predicted Label: TiSpy
# Accuracy: 0.7425750459577763
# Precision: 0.7379928470660424
# Recall: 0.7416793021149235
# F1-Score: 0.7373491437541968
# Predicted Label: TiSpy
# Accuracy: 0.7417239959433474
# Precision: 0.7386819525921039
# Recall: 0.7360211358459223
# F1-Score: 0.721492862724513
# Predicted Label: Eyezy
# Accuracy: 0.7154300870716809
# Precision: 0.7243847616151171
# Recall: 0.7186239621773111
# F1-Score: 0.7370093808103136
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7383038840717601
# Precision: 0.7435390836632312
# Recall: 0.7305933662486942
# F1-Score: 0.738922139981914
# Predicted Label: Normal-Traffic
# Accuracy: 0.729373206443281
# Precision: 0.7368363199608757
# Recall: 0.7410198025131937
# F1-Score: 0.7456380554128542
# Predicted Label: mLite
# Accuracy: 0.7458823316529059
# Precision: 0.7529094567134119
# Recall: 0.7385057612111307
# F1-Score: 0.7563319846447193
# Predicted Label: Normal-Traffic
# Accuracy: 0.7494968763180729
# Precision: 0.758517407596527
# Recall: 0.754159118694901
# F1-Score: 0.7536732850640382
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7461944238410482
# Precision: 0.7512732728621447
# Recall: 0.756088680532692
# F1-Score: 0.7290422641256314
# Predicted Label: Qustodio
# Accuracy: 0.7261800268985806
# Precision: 0.731705207372306
# Recall: 0.7263986334450833
# F1-Score: 0.7471695412193522
# Predicted Label: Air-Droid
# Accuracy: 0.745582525683226
# Precision: 0.7441984661582903
# Recall: 0.7501644343074444
# F1-Score: 0.7479690938622899
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7469145204231403
# Precision: 0.7459680721818901
# Recall: 0.7499808796961904
# F1-Score: 0.7163904964674833
# Predicted Label: FamiSafe
# Accuracy: 0.7180333315101363
# Precision: 0.7166993441098329
# Recall: 0.7160819148942449
# F1-Score: 0.7299371456664808
# Predicted Label: TiSpy
# Accuracy: 0.7379125528675111
# Precision: 0.7342789948537363
# Recall: 0.7256463420312619
# F1-Score: 0.703535903021533
# Predicted Label: Air-Droid
# Accuracy: 0.7102022793194652
# Precision: 0.7027337252163383
# Recall: 0.7043399143081649
# F1-Score: 0.7120920823197348
# Predicted Label: Normal-Traffic
# Accuracy: 0.7196164434707973
# Precision: 0.7166512962933982
# Recall: 0.7075905115217092
# F1-Score: 0.7422168953670585
# Predicted Label: kids-360
# Accuracy: 0.7396238823623953
# Precision: 0.7378019346859004
# Recall: 0.7466850118268358
# F1-Score: 0.7149229168802123
# Predicted Label: FamiSafe
# Accuracy: 0.7154431180588895
# Precision: 0.7142484699680889
# Recall: 0.7155986387228196
# F1-Score: 0.7171261242904126
# Predicted Label: FamiSafe
# Accuracy: 0.7184078688691332
# Precision: 0.7135164454702013
# Recall: 0.7207725115399478
# F1-Score: 0.7313226523861597
# Predicted Label: Air-Droid
# Accuracy: 0.7293035405960601
# Precision: 0.7218261157472504
# Recall: 0.7410723982438889
# F1-Score: 0.7467538750021401
# Predicted Label: mLite
# Accuracy: 0.744864441343508
# Precision: 0.7444638851563522
# Recall: 0.7490579964511195
# F1-Score: 0.7369564097226333
# Predicted Label: Eyezy
# Accuracy: 0.7429611725585076
# Precision: 0.7386063926501913
# Recall: 0.7353137822026099
# F1-Score: 0.7353115762262277
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.740120088174749
# Precision: 0.7388745875293791
# Recall: 0.7317827632168223
# F1-Score: 0.716481878286526
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7159014904298874
# Precision: 0.7176226946929796
# Recall: 0.7153446832716794
# F1-Score: 0.7299163289111654
# Predicted Label: FamiSafe
# Accuracy: 0.7278459597574771
# Precision: 0.7300298528975353
# Recall: 0.7298028402266169
# F1-Score: 0.7283742359340121
# Predicted Label: Qustodio
# Accuracy: 0.7362071861822825
# Precision: 0.7311575575862725
# Recall: 0.7256120246453764
# F1-Score: 0.7338050069786788
# Predicted Label: TiSpy
# Accuracy: 0.7286641613275724
# Precision: 0.7368724444959115
# Recall: 0.7307630017246634
# F1-Score: 0.7213749737837186
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7270338445899984
# Precision: 0.7211594992073747
# Recall: 0.7215905771614437
# F1-Score: 0.72879142517322
# Predicted Label: FamiSafe
# Accuracy: 0.7310098692672845
# Precision: 0.7325694544911224
# Recall: 0.7250521642516
# F1-Score: 0.7141689414588133
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.718410662615639
# Precision: 0.7157674984540319
# Recall: 0.7125775088164896
# F1-Score: 0.7429367030237021
# Predicted Label: Air-Droid
# Accuracy: 0.7411660087702217
# Precision: 0.7412205671307432
# Recall: 0.7446608040410841
# F1-Score: 0.7399706533608681
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7388868940036886
# Precision: 0.7473006119429699
# Recall: 0.7327830910582542
# F1-Score: 0.7477407530660537
# Predicted Label: Air-Droid
# Accuracy: 0.7393014551266955
# Precision: 0.7455202371593643
# Recall: 0.7499745360055452
# F1-Score: 0.7443572839211353
# Predicted Label: Eyezy
# Accuracy: 0.7390010065111859
# Precision: 0.7380044126876242
# Recall: 0.7508204780901505
# F1-Score: 0.7377623912229184
# Predicted Label: Qustodio
# Accuracy: 0.7277526035066891
# Precision: 0.7372716860355842
# Recall: 0.7382537500416226
# F1-Score: 0.7298300259156266
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7256802083075556
# Precision: 0.7284305198486749
# Recall: 0.7312349199706955
# F1-Score: 0.7212954354664837
# Predicted Label: Normal-Traffic
# Accuracy: 0.7180050066139184
# Precision: 0.716235678718332
# Recall: 0.7264271888544527
# F1-Score: 0.7351731298217958
# Predicted Label: kids-360
# Accuracy: 0.734657867793215
# Precision: 0.7261234094084452
# Recall: 0.74445127150012
# F1-Score: 0.7190090467895321
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7222542866182569
# Precision: 0.7278953892290456
# Recall: 0.7103370611359108
# F1-Score: 0.7225070997286447
# Predicted Label: Qustodio
# Accuracy: 0.7247199646108853
# Precision: 0.7270639208571976
# Recall: 0.7180070419410033
# F1-Score: 0.7245133960645728
# Predicted Label: mLite
# Accuracy: 0.7181316994950602
# Precision: 0.7190114844525216
# Recall: 0.7301001587635303
# F1-Score: 0.713692113631475
# Predicted Label: TiSpy
# Accuracy: 0.7141069744213313
# Precision: 0.7167694314882275
# Recall: 0.7106411066115779
# F1-Score: 0.7162408709610314
# Predicted Label: Air-Droid
# Accuracy: 0.7152193231711512
# Precision: 0.7140019712091137
# Recall: 0.7184938559396212
# F1-Score: 0.7293788963281439
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7298880168076946
# Precision: 0.7231763138750937
# Recall: 0.7356887966016409
# F1-Score: 0.7183122822370905
# Predicted Label: mLite
# Accuracy: 0.7175832320628799
# Precision: 0.7100966933568018
# Recall: 0.7267201997047124
# F1-Score: 0.7176793931020304
# Predicted Label: TiSpy
# Accuracy: 0.7187307240746217
# Precision: 0.7126454745234928
# Recall: 0.7227849338468326
# F1-Score: 0.7058245361084783
# Predicted Label: Qustodio
# Accuracy: 0.7131176650975773
# Precision: 0.7105200128777746
# Recall: 0.7011907120925412
# F1-Score: 0.7203394651301243
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7157713609871663
# Precision: 0.7238654610103815
# Recall: 0.7168476534482919
# F1-Score: 0.7142434291195562
# Predicted Label: Air-Droid
# Accuracy: 0.713789121622885
# Precision: 0.7180785045308602
# Recall: 0.7104491004231472
# F1-Score: 0.718255566859561
# Predicted Label: FamiSafe
# Accuracy: 0.724601693146138
# Precision: 0.7240506236242805
# Recall: 0.7125525368994351
# F1-Score: 0.7455886838460115
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7456198428408308
# Precision: 0.7551902894525468
# Recall: 0.7362281656014606
# F1-Score: 0.7354426892637963
# Predicted Label: kids-360
# Accuracy: 0.7379940836232446
# Precision: 0.7431691088848291
# Recall: 0.7278752732801377
# F1-Score: 0.7071671969858754
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7111465650469868
# Precision: 0.7064766671077547
# Recall: 0.7078590780707921
# F1-Score: 0.7254413641893204
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7358383595435884
# Precision: 0.7268352678835183
# Recall: 0.7240527966381511
# F1-Score: 0.7294738713960108
# Predicted Label: mLite
# Accuracy: 0.7296036405804777
# Precision: 0.7233458378897558
# Recall: 0.735706622867783
# F1-Score: 0.7150568286007802
# Predicted Label: TiSpy
# Accuracy: 0.7168073121216534
# Precision: 0.7091031849406271
# Recall: 0.7211112925580424
# F1-Score: 0.7317499298795437
# Predicted Label: kids-360
# Accuracy: 0.7365888010499688
# Precision: 0.7342718563363686
# Recall: 0.7292452677189224
# F1-Score: 0.7381246173082425
# Predicted Label: Normal-Traffic
# Accuracy: 0.7441805086221961
# Precision: 0.7358992541970528
# Recall: 0.740363480261901
# F1-Score: 0.7230952572316348
# Predicted Label: kids-360
# Accuracy: 0.7178536006337864
# Precision: 0.7261088332851605
# Recall: 0.7201065923329828
# F1-Score: 0.7179537975767712
# Predicted Label: kids-360
# Accuracy: 0.7207856439636555
# Precision: 0.7190197023640577
# Recall: 0.7168910483948857
# F1-Score: 0.7468231297539661
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7421228126039356
# Precision: 0.7404478817875021
# Recall: 0.7533091127751408
# F1-Score: 0.725893326163781
# Predicted Label: TiSpy
# Accuracy: 0.7326595128846081
# Precision: 0.7263459345705774
# Recall: 0.7254412814740471

# %%
#RF-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-RF-Dataset-B-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-RF-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection" 
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"F1-Score: {f1}")           
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
               
               
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# F1-Score: 0.7034765435530468
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.705957449512774
# Precision: 0.7087334086805193
# Recall: 0.6982970874099322
# F1-Score: 0.7181242907947675
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7195464525706898
# Precision: 0.7200405344704309
# Recall: 0.7162182194450263
# F1-Score: 0.7047175720671832
# Predicted Label: FamiSafe
# Accuracy: 0.7139397410243402
# Precision: 0.7069674091985874
# Recall: 0.702482009171619
# F1-Score: 0.7147943746108351
# Predicted Label: Air-Droid
# Accuracy: 0.7115312941765268
# Precision: 0.7137795264491551
# Recall: 0.7158121126934738
# F1-Score: 0.721353052926753
# Predicted Label: Normal-Traffic
# Accuracy: 0.7260272773903116
# Precision: 0.7226164037610552
# Recall: 0.7200941118174647
# F1-Score: 0.7189300911540425
# Predicted Label: FamiSafe
# Accuracy: 0.722701783423315
# Precision: 0.7236046764878998
# Recall: 0.7143155150753956
# F1-Score: 0.7085674031878532
# Predicted Label: FamiSafe
# Accuracy: 0.7175061744176908
# Precision: 0.709906485309111
# Recall: 0.7072333633220681
# F1-Score: 0.7117736949551455
# Predicted Label: Qustodio
# Accuracy: 0.7128881092597777
# Precision: 0.7041022413440576
# Recall: 0.7196141566041997
# F1-Score: 0.7221198762397111
# Predicted Label: TiSpy
# Accuracy: 0.7208572173951812
# Precision: 0.7237730301270173
# Recall: 0.720474257006751
# F1-Score: 0.7129676852020878
# Predicted Label: TiSpy
# Accuracy: 0.7137281764046496
# Precision: 0.7179997491310856
# Recall: 0.7080056642972782
# F1-Score: 0.7066000968089617
# Predicted Label: Normal-Traffic
# Accuracy: 0.7079039821770863
# Precision: 0.7146412162814952
# Recall: 0.6987379206955574
# F1-Score: 0.7067444476805727
# Predicted Label: Air-Droid
# Accuracy: 0.7071972154399916
# Precision: 0.7161650137311616
# Recall: 0.6975685035386503
# F1-Score: 0.7315164973843878
# Predicted Label: kids-360
# Accuracy: 0.7259941243576333
# Precision: 0.7305743229930151
# Recall: 0.7324611050363715
# F1-Score: 0.7051901803351509
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7050848646697429
# Precision: 0.7104803403241351
# Recall: 0.699978218016221
# F1-Score: 0.706164493768952
# Predicted Label: FamiSafe
# Accuracy: 0.7032258813931377
# Precision: 0.6988297699163833
# Recall: 0.7136548172148933
# F1-Score: 0.718496621188559
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7163281474101731
# Precision: 0.7125750849242677
# Recall: 0.7245173987056416
# F1-Score: 0.7216789291335142
# Predicted Label: Normal-Traffic
# Accuracy: 0.7291372857935652
# Precision: 0.7213663559143586
# Recall: 0.7219917733505332
# F1-Score: 0.716285838085948
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7130993363525636
# Precision: 0.719146982171367
# Recall: 0.7134473700485673
# F1-Score: 0.7331349323408578
# Predicted Label: Eyezy
# Accuracy: 0.7263284846175876
# Precision: 0.7356064964162993
# Recall: 0.7306799210646555
# F1-Score: 0.7201016508014434
# Predicted Label: Eyezy
# Accuracy: 0.716826653737049
# Precision: 0.7137617383471635
# Recall: 0.7265551998116134
# F1-Score: 0.7191320686823003
# Predicted Label: Air-Droid
# Accuracy: 0.7184270400789132
# Precision: 0.7135210369063965
# Recall: 0.7248320487068853
# F1-Score: 0.7111241590289683
# Predicted Label: kids-360
# Accuracy: 0.7105156571739549
# Precision: 0.7163238008257063
# Recall: 0.7059994594259756
# F1-Score: 0.7124431570953688
# Predicted Label: Eyezy
# Accuracy: 0.713430000339228
# Precision: 0.72098016800193
# Recall: 0.7041059510935466
# F1-Score: 0.7112156692382804
# Predicted Label: TiSpy
# Accuracy: 0.7054880636808077
# Precision: 0.7049632546379058
# Recall: 0.7175799833143603
# F1-Score: 0.7093083151874123
# Predicted Label: Normal-Traffic
# Accuracy: 0.7107405538646593
# Precision: 0.7031567094945153
# Recall: 0.7155685061758676
# F1-Score: 0.7027045037553884
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7046552656441593
# Precision: 0.6974102538175777
# Recall: 0.7080797490241749
# F1-Score: 0.7186116149604164
# Predicted Label: kids-360
# Accuracy: 0.7258018251972742
# Precision: 0.7195380342048692
# Recall: 0.7176875782141214
# F1-Score: 0.716785526621046
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7201207293179804
# Precision: 0.7256507679339903
# Recall: 0.7081342833763462
# F1-Score: 0.7200835882108768
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7192305574849678
# Precision: 0.7264036971669074
# Recall: 0.7138725074504155
# F1-Score: 0.7092314629270393
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7042783066515409
# Precision: 0.7100907978213907
# Recall: 0.7083742054117518
# F1-Score: 0.7230406917482712
# Predicted Label: Qustodio
# Accuracy: 0.7254796823231748
# Precision: 0.7233340041165768
# Recall: 0.722747617160225
# F1-Score: 0.7185968859799517
# Predicted Label: kids-360
# Accuracy: 0.7174627057808523
# Precision: 0.7166415133936305
# Recall: 0.7205629583174871
# F1-Score: 0.7147211827433617
# Predicted Label: Normal-Traffic
# Accuracy: 0.7060897335088737
# Precision: 0.7144991446353962
# Recall: 0.7149433588955706
# F1-Score: 0.7135206387834188
# Predicted Label: TiSpy
# Accuracy: 0.7168466040209944
# Precision: 0.7159381905618922
# Recall: 0.7111193590447082
# F1-Score: 0.717092318280598
# Predicted Label: Normal-Traffic
# Accuracy: 0.7131543440491921
# Precision: 0.7112662471082288
# Recall: 0.7230146218663265
# F1-Score: 0.7333435714268751
# Predicted Label: TiSpy
# Accuracy: 0.7293932966074289
# Precision: 0.7314507973899684
# Recall: 0.7352461667348531
# F1-Score: 0.7263903794760398
# Predicted Label: mLite
# Accuracy: 0.7260685648804736
# Precision: 0.7237179092383658
# Recall: 0.7290826601078582
# F1-Score: 0.7102643962503999
# Predicted Label: FamiSafe
# Accuracy: 0.7153111039800206
# Precision: 0.7066983941608261
# Recall: 0.7138665689702741
# F1-Score: 0.7058103535661793
# Predicted Label: Qustodio
# Accuracy: 0.7047995421652596
# Precision: 0.7044823064101797
# Recall: 0.7071434172863974
# F1-Score: 0.711718204891086
# Predicted Label: kids-360
# Accuracy: 0.7048715007303484
# Precision: 0.7086033927414547
# Recall: 0.714860521539002
# F1-Score: 0.7057708206516689
# Predicted Label: Qustodio
# Accuracy: 0.7077335348518705
# Precision: 0.70715906436727
# Recall: 0.7043880168568517
# F1-Score: 0.7052157700900624
# Predicted Label: kids-360
# Accuracy: 0.7088981853591718
# Precision: 0.7088557431710818
# Recall: 0.7016129885422083
# F1-Score: 0.7283122705934476
# Predicted Label: Normal-Traffic
# Accuracy: 0.7230872248241479
# Precision: 0.7283654962464744
# Recall: 0.7282590527188318
# F1-Score: 0.6949179788691711
# Predicted Label: TiSpy
# Accuracy: 0.7028191966704016
# Precision: 0.6986110447599084
# Recall: 0.6912637529495134
# F1-Score: 0.7310676284208121
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7273327243011111
# Precision: 0.7348311536002462
# Recall: 0.7273424574894742
# F1-Score: 0.7036326826755881
# Predicted Label: kids-360
# Accuracy: 0.7032951489638465
# Precision: 0.6982628854584838
# Recall: 0.709085709824242
# F1-Score: 0.7198574024152714
# Predicted Label: mLite
# Accuracy: 0.7230537408666677
# Precision: 0.7280808187448562
# Recall: 0.71181767259164
# F1-Score: 0.7136413432242881
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.714698343135156
# Precision: 0.7192367928979861
# Recall: 0.7081322833528423
# F1-Score: 0.7002602490042855
# Predicted Label: Normal-Traffic
# Accuracy: 0.701260126239222
# Precision: 0.698089921062104
# Recall: 0.7024441139223568
# F1-Score: 0.7130241187152885
# Predicted Label: Qustodio
# Accuracy: 0.7053761188878727
# Precision: 0.7153525268297237
# Recall: 0.7107108189424112
# F1-Score: 0.720088312876173
# Predicted Label: FamiSafe
# Accuracy: 0.7230758552255304
# Precision: 0.7139000296667714
# Recall: 0.7263848176864495
# F1-Score: 0.7105731031688036
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7038356002007272
# Precision: 0.7123275784212135
# Recall: 0.7088272492881129
# F1-Score: 0.7080166419670256
# Predicted Label: Normal-Traffic
# Accuracy: 0.7036186170789349
# Precision: 0.7023134119302429
# Recall: 0.7138132580429387
# F1-Score: 0.7179780695981767
# Predicted Label: Qustodio
# Accuracy: 0.7144850684522486
# Precision: 0.7172531110144876
# Recall: 0.718704495158275
# F1-Score: 0.7049976886789169
# Predicted Label: mLite
# Accuracy: 0.7075291261325236
# Precision: 0.698942002320013
# Recall: 0.7111592259874863
# F1-Score: 0.7148333078970112
# Predicted Label: Qustodio
# Accuracy: 0.715179427379406
# Precision: 0.71519078367973
# Recall: 0.7144761892919766
# F1-Score: 0.7119199561257712
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7100658038046784
# Precision: 0.702235785073385
# Recall: 0.7218749609097471
# F1-Score: 0.7138172938461176
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7194211013676058
# Precision: 0.7185715789963145
# Recall: 0.7091255067439229
# F1-Score: 0.7169447240302821
# Predicted Label: TiSpy
# Accuracy: 0.7126347271698135
# Precision: 0.7204387174036307
# Recall: 0.7134844575199726
# F1-Score: 0.7215986999413413
# Predicted Label: TiSpy
# Accuracy: 0.7270009272412944
# Precision: 0.726437008348482
# Recall: 0.7168244145572843
# F1-Score: 0.7151371588115297
# Predicted Label: FamiSafe
# Accuracy: 0.7073055275577163
# Precision: 0.7162698188938376
# Recall: 0.7140080752957926
# F1-Score: 0.7133743407323767
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7136987801587604
# Precision: 0.7142404374469754
# Recall: 0.7125103419527938
# F1-Score: 0.71900557723173
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7203681701385223
# Precision: 0.7267120794927697
# Recall: 0.7114608088335714
# F1-Score: 0.7279495965121986
# Predicted Label: Normal-Traffic
# Accuracy: 0.7233515946576733
# Precision: 0.7276444411301664
# Recall: 0.7282550079502669
# F1-Score: 0.6982418787626213
# Predicted Label: TiSpy
# Accuracy: 0.7056470152652663
# Precision: 0.6984823237467586
# Recall: 0.6980015992626876
# F1-Score: 0.7142590253256659
# Predicted Label: Air-Droid
# Accuracy: 0.7182434808142938
# Precision: 0.7223452508788285
# Recall: 0.7063518365358585
# F1-Score: 0.7115556508592193
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7048472853472886
# Precision: 0.7091155639370627
# Recall: 0.7140125885831408
# F1-Score: 0.7236412003233776
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7157982249860697
# Precision: 0.7213420870582912
# Recall: 0.7259550162474101
# F1-Score: 0.7354894609781819
# Predicted Label: Air-Droid
# Accuracy: 0.7295865559090904
# Precision: 0.7338553954299382
# Recall: 0.7371308198682253
# F1-Score: 0.7289439275864168
# Predicted Label: kids-360
# Accuracy: 0.7229201960426576
# Precision: 0.7249840639898567
# Recall: 0.7329472863103103
# F1-Score: 0.7011700748014809
# Predicted Label: Eyezy
# Accuracy: 0.7020364493056834
# Precision: 0.7115947651250374
# Recall: 0.6910464128436339
# F1-Score: 0.708477065922405
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7032463093618017
# Precision: 0.7101300657745766
# Recall: 0.7068317437142888
# F1-Score: 0.706456088805469
# Predicted Label: Normal-Traffic
# Accuracy: 0.7117937534104232
# Precision: 0.7051925833171329
# Recall: 0.7077241301090439
# F1-Score: 0.7041589461309754
# Predicted Label: Air-Droid
# Accuracy: 0.707911191586328
# Precision: 0.704144817394729
# Recall: 0.7041730754342224
# F1-Score: 0.7063988056752988
# Predicted Label: Eyezy
# Accuracy: 0.708163048911558
# Precision: 0.7045789883562212
# Recall: 0.7082280479445195
# F1-Score: 0.7006288496994145
# Predicted Label: kids-360
# Accuracy: 0.7085143868778052
# Precision: 0.7040864480897833
# Recall: 0.697205044220423
# F1-Score: 0.6969314400064708
# Predicted Label: mLite
# Accuracy: 0.7012589943765579
# Precision: 0.6945603833077757
# Recall: 0.6993187405553737
# F1-Score: 0.6919659412723675
# Predicted Label: FamiSafe
# Accuracy: 0.7007768982724858
# Precision: 0.6916836244616976
# Recall: 0.6922484886373645
# F1-Score: 0.7256765275367492
# Predicted Label: Normal-Traffic
# Accuracy: 0.7274083169032731
# Precision: 0.7214862813681405
# Recall: 0.7299157302368089
# F1-Score: 0.7233607389081963
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7204427360190676
# Precision: 0.7183788540273299
# Recall: 0.728412204059346
# F1-Score: 0.727164679133984
# Predicted Label: Normal-Traffic
# Accuracy: 0.7275568373021571
# Precision: 0.7267628757330511
# Recall: 0.7275669270685771
# F1-Score: 0.7036080612087677
# Predicted Label: Eyezy
# Accuracy: 0.7036259148124497
# Precision: 0.7046518780500921
# Recall: 0.7025673322525079
# F1-Score: 0.7191140300848581
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7124630121689431
# Precision: 0.7196112837097666
# Recall: 0.7186174631930033
# F1-Score: 0.7090480748091328
# Predicted Label: Eyezy
# Accuracy: 0.7095904482970834
# Precision: 0.7179014999943414
# Recall: 0.7004103568308364
# F1-Score: 0.7017156842738761
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7046320576059545
# Precision: 0.7022528802417832
# Recall: 0.701179309545533
# F1-Score: 0.724628668672674
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7190504754171754
# Precision: 0.7182838446149956
# Recall: 0.7310865832933373
# F1-Score: 0.699690246324903
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7005094473386638
# Precision: 0.6947299821130195
# Recall: 0.7047218509288423
# F1-Score: 0.7020200056327778
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7027301096755455
# Precision: 0.7042985431658024
# Recall: 0.6997561635475144
# F1-Score: 0.7182220303452802
# Predicted Label: Eyezy
# Accuracy: 0.7105978968845954
# Precision: 0.7142336468313036
# Recall: 0.7222552074084041
# F1-Score: 0.7236899510156387
# Predicted Label: Qustodio
# Accuracy: 0.7257772462343952
# Precision: 0.7291622383506529
# Recall: 0.7182991897391745
# F1-Score: 0.7263535775024998
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7213249875752769
# Precision: 0.7236375391376589
# Recall: 0.7290900809648345
# F1-Score: 0.7348244838075872
# Predicted Label: Eyezy
# Accuracy: 0.7282901483069761
# Precision: 0.7369569334417371
# Recall: 0.7327043394278394
# F1-Score: 0.7291155236456354
# Predicted Label: kids-360
# Accuracy: 0.7271724603349927
# Precision: 0.7210318881055785
# Recall: 0.7373824688811976
# F1-Score: 0.7064204962921342
# Predicted Label: Air-Droid
# Accuracy: 0.715760122597039
# Precision: 0.7084112508521039
# Recall: 0.7044408990872618
# F1-Score: 0.7200599922538796
# Predicted Label: TiSpy
# Accuracy: 0.7208857291004465
# Precision: 0.7212827752607702
# Recall: 0.7188413481723296
# F1-Score: 0.7046240415600631
# Predicted Label: Eyezy
# Accuracy: 0.7075982367159416
# Precision: 0.7023151920087505
# Recall: 0.7069481217912348
# F1-Score: 0.7072915412742237
# Predicted Label: TiSpy
# Accuracy: 0.7064896505546635
# Precision: 0.6996155947337774
# Recall: 0.7151377921336828
# F1-Score: 0.7279432470461898
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7279016120893395
# Precision: 0.734184712670518
# Recall: 0.7218070070183672
# F1-Score: 0.7143951086985777
# Predicted Label: FamiSafe
# Accuracy: 0.7105517295135707
# Precision: 0.7148435332415487
# Recall: 0.7139472464003477
# F1-Score: 0.7268922506658446
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7268639410097624
# Precision: 0.7239774023463013
# Recall: 0.7298306651536172
# F1-Score: 0.7044018597925593
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7026627610421556
# Precision: 0.7116125094725407
# Recall: 0.6973358728662621
# F1-Score: 0.6975112688427187
# Predicted Label: mLite
# Accuracy: 0.704599491702948
# Precision: 0.6970382641567944
# Recall: 0.6979849159190863
# F1-Score: 0.6956382612689033
# Predicted Label: Qustodio
# Accuracy: 0.7026265027498398
# Precision: 0.6985295779895394
# Recall: 0.6927707810562528
# F1-Score: 0.7229180183329457
# Predicted Label: mLite
# Accuracy: 0.7217741143768873
# Precision: 0.724664038289593
# Recall: 0.7211803919431395
# F1-Score: 0.7148647226923451
# Predicted Label: Air-Droid
# Accuracy: 0.7145968845434997
# Precision: 0.7243022768229413
# Recall: 0.705669945154243
# F1-Score: 0.7133448624156453
# Predicted Label: Normal-Traffic
# Accuracy: 0.7120469714492357
# Precision: 0.705296152470606
# Recall: 0.7215793937142769
# F1-Score: 0.7080221741196159
# Predicted Label: Qustodio
# Accuracy: 0.7114016865924591
# Precision: 0.7045426086540248
# Recall: 0.7115362796339144
# F1-Score: 0.7273022421271484
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7283443489668435
# Precision: 0.7253204638764966
# Recall: 0.7292948795924745
# F1-Score: 0.7021633072750537
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7102959144137234
# Precision: 0.7054913705825308
# Recall: 0.6988664959475565
# F1-Score: 0.726924893297529
# Predicted Label: kids-360
# Accuracy: 0.7183682287831912
# Precision: 0.7264824742671316
# Recall: 0.7273678515119479
# F1-Score: 0.7052097145143329
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7044588128836327
# Precision: 0.7036740065999026
# Recall: 0.706752140190215
# F1-Score: 0.7118765390079769
# Predicted Label: Qustodio
# Accuracy: 0.7064098294827674
# Precision: 0.7142023664637052
# Recall: 0.7095658106743761
# F1-Score: 0.7323333535771535
# Predicted Label: kids-360
# Accuracy: 0.7297515620376144
# Precision: 0.7376213816349824
# Recall: 0.7271206058708062
# F1-Score: 0.7297712969922137
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7284179703392424
# Precision: 0.7286075774616272
# Recall: 0.730938739815343
# F1-Score: 0.7312803523626196
# Predicted Label: FamiSafe
# Accuracy: 0.7279891657142153
# Precision: 0.7345540360064523
# Recall: 0.7280357188732185
# F1-Score: 0.7215447568075508
# Predicted Label: Normal-Traffic
# Accuracy: 0.7264769164182324
# Precision: 0.7248972929997554
# Recall: 0.7182230877668909
# F1-Score: 0.7080407750303696
# Predicted Label: FamiSafe
# Accuracy: 0.710707911419058
# Precision: 0.7049855976867492
# Recall: 0.7111225479120385
# F1-Score: 0.7072262321404912
# Predicted Label: Air-Droid
# Accuracy: 0.7070571911406209
# Precision: 0.7032783672335512
# Recall: 0.7112186700705485
# F1-Score: 0.7201962970548328
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7146498296173248
# Precision: 0.722723339768944
# Recall: 0.7176868646585736
# F1-Score: 0.700290255439456
# Predicted Label: mLite
# Accuracy: 0.7100531650159329
# Precision: 0.7014231671026244
# Recall: 0.6991609975453613

# %%
#TabNEt-A
import pandas as pd
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import joblib
from concurrent.futures import ThreadPoolExecutor
import scapy.all as scapy
import torch
from sklearn.preprocessing import LabelEncoder
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.model_selection import train_test_split
import pickle
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)
def load_pretrained_model():
    # Load the TabNet model from the zip file
    tabnet_model = TabNetClassifier()
    tabnet_model.load_model('Original-tabnet-Dataset-A-1-80-20.zip')
    
    # Load the LabelEncoder
    with open('Original-Tabnet-label_encoder-Dataset-A-1-80-20.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    
    return tabnet_model, label_encoder
def predict_with_model(tabnet_model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    tabnet_output = tabnet_model.predict_proba(features_df.values)
    predicted_label = label_encoder.inverse_transform(tabnet_output.argmax(axis=1))[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = [
        '1-All-Together-Update-Single-26-8-24.csv',
        '2-All-Together-Update-Single-26-8-24.csv',
        '3-All-Together-Update-Single-26-8-24.csv',
        '4-All-Together-Update-Single-26-8-24.csv',
        '5-All-Together-Update-Single-26-8-24.csv'
    ]
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    # Load pretrained models and label encoder
    tabnet_model, label_encoder = load_pretrained_model()
    
    # Load previous samples for evaluation
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1
        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(tabnet_model, label_encoder, features)
                              
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
               
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == "__main__":
    main()
# Out:
# Predicted Label: Normal-Traffic
# Accuracy: 0.6081095610567089
# Precision: 0.6118133312980122
# Recall: 0.6037910498490562
# F1-Score: 0.6077757193791865
# Predicted Label: Qustodio
# Accuracy: 0.6018950845333884
# Precision: 0.6089595706245473
# Recall: 0.6083497849722399
# F1-Score: 0.6086545250687114
# Predicted Label: Normal-Traffic
# Accuracy: 0.5937291512081532
# Precision: 0.5967297829585247
# Recall: 0.584884829033814
# F1-Score: 0.5907479368363543
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.593197224832855
# Precision: 0.5960960163498012
# Recall: 0.6052520774562544
# F1-Score: 0.6006391554941941
# Predicted Label: Air-Droid
# Accuracy: 0.5910940828413918
# Precision: 0.5946692323606726
# Recall: 0.5822731943957552
# F1-Score: 0.5884059333127941
# Predicted Label: TiSpy
# Accuracy: 0.5938666608832471
# Precision: 0.6007612781654513
# Recall: 0.5819430481159117
# F1-Score: 0.5912024529492464
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5994380947855229
# Precision: 0.6012961394689235
# Recall: 0.5903265636226753
# F1-Score: 0.59576086090227
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5901185415240895
# Precision: 0.5972858856995512
# Recall: 0.5877921905852971
# F1-Score: 0.5925010110078724
# Predicted Label: kids-360
# Accuracy: 0.6082963568908057
# Precision: 0.6060295469358432
# Recall: 0.6153655387464657
# F1-Score: 0.6106618620266049
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5826815404074234
# Precision: 0.5736218066673409
# Recall: 0.5797789537997545
# F1-Score: 0.5766839460234666
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5995829122007525
# Precision: 0.6031810984971852
# Recall: 0.5943125240685075
# F1-Score: 0.5987139711862834
# Predicted Label: FamiSafe
# Accuracy: 0.6150071349147133
# Precision: 0.6111167153870856
# Recall: 0.6187278149067611
# F1-Score: 0.6148987138628093
# Predicted Label: TiSpy
# Accuracy: 0.5884841767672825
# Precision: 0.5870522069690538
# Recall: 0.5912445677441904
# F1-Score: 0.5891409291808696
# Predicted Label: mLite
# Accuracy: 0.5861762564270814
# Precision: 0.5859087583472393
# Recall: 0.5954197707329097
# F1-Score: 0.5906259774106377
# Predicted Label: Qustodio
# Accuracy: 0.5823198287915962
# Precision: 0.5747049056384396
# Recall: 0.5847177358216354
# F1-Score: 0.5796680850864109
# Predicted Label: FamiSafe
# Accuracy: 0.5865048651094024
# Precision: 0.5884933287053956
# Recall: 0.5841475210932865
# F1-Score: 0.5863123721166819
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5848632191860568
# Precision: 0.5879556785676342
# Recall: 0.5935951996998874
# F1-Score: 0.5907619804671955
# Predicted Label: Air-Droid
# Accuracy: 0.5975015999623581
# Precision: 0.5970174619675128
# Recall: 0.5869109658653577
# F1-Score: 0.5919210773293487
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5966210423393956
# Precision: 0.5895515791543976
# Recall: 0.6052657739287959
# F1-Score: 0.5973053402798784
# Predicted Label: TiSpy
# Accuracy: 0.6063704228695096
# Precision: 0.6115541072559864
# Recall: 0.6108844108763273
# F1-Score: 0.6112190756241128
# Predicted Label: TiSpy
# Accuracy: 0.5981175400296735
# Precision: 0.5909684656974102
# Recall: 0.6007241178226029
# F1-Score: 0.5958063600067575
# Predicted Label: Normal-Traffic
# Accuracy: 0.6076581545734553
# Precision: 0.6074212416816841
# Recall: 0.614272400024999
# F1-Score: 0.6108276104846196
# Predicted Label: FamiSafe
# Accuracy: 0.6013371972013846
# Precision: 0.5989311423574383
# Recall: 0.5958779632559643
# F1-Score: 0.5974006518058711
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6105218276573485
# Precision: 0.6202595130853171
# Recall: 0.6154897578092476
# F1-Score: 0.6178654302768124
# Predicted Label: Air-Droid
# Accuracy: 0.590210947204483
# Precision: 0.5854241889670886
# Recall: 0.5910378726531229
# F1-Score: 0.5882176374991123
# Predicted Label: kids-360
# Accuracy: 0.5994692495534
# Precision: 0.6088988533356128
# Recall: 0.6109788404432706
# F1-Score: 0.6099370736188958
# Predicted Label: Qustodio
# Accuracy: 0.6154597472012716
# Precision: 0.6242417987126403
# Recall: 0.6159835610506754
# F1-Score: 0.6200851854876976
# Predicted Label: kids-360
# Accuracy: 0.5934848501719544
# Precision: 0.5851149394142717
# Recall: 0.5992739916342918
# F1-Score: 0.5921098316871555
# Predicted Label: mLite
# Accuracy: 0.5943736728736457
# Precision: 0.5922903641950491
# Recall: 0.6053893581626159
# F1-Score: 0.5987682294897593
# Predicted Label: Qustodio
# Accuracy: 0.5831944641502034
# Precision: 0.5925435253212378
# Recall: 0.5897509481648775
# F1-Score: 0.5911439387122585
# Predicted Label: Normal-Traffic
# Accuracy: 0.6178456423921388
# Precision: 0.6194935749758659
# Recall: 0.6120102473998821
# F1-Score: 0.6157291746804463
# Predicted Label: FamiSafe
# Accuracy: 0.5895134555424495
# Precision: 0.591525473845991
# Recall: 0.5992585074082757
# F1-Score: 0.5953668811996399
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6134508703080807
# Precision: 0.6116504370616604
# Recall: 0.6219971516131466
# F1-Score: 0.6167804049193102
# Predicted Label: FamiSafe
# Accuracy: 0.6026415398140721
# Precision: 0.6120805337972619
# Recall: 0.6068006064236866
# F1-Score: 0.6094291343633164
# Predicted Label: FamiSafe
# Accuracy: 0.6106209948839136
# Precision: 0.601169610497934
# Recall: 0.6200414882659343
# F1-Score: 0.610459731934463
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.596959950082116
# Precision: 0.606081045201816
# Recall: 0.5860266635464333
# F1-Score: 0.5958851706970423
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5827542086820671
# Precision: 0.5847565804957547
# Recall: 0.5795348379706171
# F1-Score: 0.58213399970988
# Predicted Label: FamiSafe
# Accuracy: 0.5837177534955643
# Precision: 0.5867302313722738
# Recall: 0.5840373913705675
# F1-Score: 0.5853807145197765
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6021276694901676
# Precision: 0.592503457741587
# Recall: 0.6096983414981517
# F1-Score: 0.6009779319003115
# Predicted Label: Eyezy
# Accuracy: 0.599574346691876
# Precision: 0.6034689016389106
# Recall: 0.610550451327951
# F1-Score: 0.6069890226339366
# Predicted Label: Air-Droid
# Accuracy: 0.5927066196554249
# Precision: 0.5982391331028505
# Recall: 0.5891754850767459
# F1-Score: 0.5936727172487162
# Predicted Label: mLite
# Accuracy: 0.5805783344527615
# Precision: 0.5901510705235276
# Recall: 0.5759087288558246
# F1-Score: 0.5829429211761008
# Predicted Label: Air-Droid
# Accuracy: 0.5812742953914787
# Precision: 0.578308959435675
# Recall: 0.5851391391852779
# F1-Score: 0.5817040005625059
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6055197228012196
# Precision: 0.6005197500330886
# Recall: 0.6168604529823013
# F1-Score: 0.608580432165195
# Predicted Label: Air-Droid
# Accuracy: 0.5804873986664811
# Precision: 0.5729129891384072
# Recall: 0.5694542519803296
# F1-Score: 0.5711783845624411
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5935709000829136
# Precision: 0.602614100485938
# Recall: 0.6035317886753417
# F1-Score: 0.6030725954721197
# Predicted Label: Qustodio
# Accuracy: 0.5886926285413959
# Precision: 0.587212004734866
# Recall: 0.5951878197677122
# F1-Score: 0.5911730120335624
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6055978520019492
# Precision: 0.5972167214975291
# Recall: 0.5938145105538224
# F1-Score: 0.59551075677472
# Predicted Label: TiSpy
# Accuracy: 0.602075979290563
# Precision: 0.6034971005088121
# Recall: 0.5944334798464419
# F1-Score: 0.5989310022059955
# Predicted Label: FamiSafe
# Accuracy: 0.6141337532122022
# Precision: 0.6151763084768122
# Recall: 0.6126804917709997
# F1-Score: 0.6139258635491898
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5983695497157139
# Precision: 0.5897330585451286
# Recall: 0.6063674163915884
# F1-Score: 0.597934569150035
# Predicted Label: Eyezy
# Accuracy: 0.5872989604470039
# Precision: 0.5873364118830547
# Recall: 0.5869648780827443
# F1-Score: 0.5871505862086454
# Predicted Label: TiSpy
# Accuracy: 0.5975641676983481
# Precision: 0.5934568345785897
# Recall: 0.6009443350659881
# F1-Score: 0.5971771158802895
# Predicted Label: Qustodio
# Accuracy: 0.5904791504519856
# Precision: 0.6002116848535642
# Recall: 0.5955852767750324
# F1-Score: 0.5978895312800563
# Predicted Label: mLite
# Accuracy: 0.5832041943891141
# Precision: 0.5893067747720819
# Recall: 0.5726455799327789
# F1-Score: 0.5808567252026287
# Predicted Label: Normal-Traffic
# Accuracy: 0.597125361481882
# Precision: 0.6048996579857665
# Recall: 0.5882611157714573
# F1-Score: 0.5964643752341184
# Predicted Label: Qustodio
# Accuracy: 0.5911678538288077
# Precision: 0.5960657637572659
# Recall: 0.5857169811344157
# F1-Score: 0.5908460606902589
# Predicted Label: mLite
# Accuracy: 0.5852861492585149
# Precision: 0.5842776490104707
# Recall: 0.5785246279851168
# F1-Score: 0.5813869068216212
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6014402914907073
# Precision: 0.5988705460532038
# Recall: 0.5906907490859131
# F1-Score: 0.5947525241434267
# Predicted Label: Air-Droid
# Accuracy: 0.5901742206307546
# Precision: 0.5891596995577913
# Recall: 0.5970912292718813
# F1-Score: 0.5930989484551534
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.617496823173462
# Precision: 0.6259420759392326
# Recall: 0.6249082323271627
# F1-Score: 0.6254247268907822
# Predicted Label: Air-Droid
# Accuracy: 0.6067379094297582
# Precision: 0.6075789051193062
# Recall: 0.6122248017101992
# F1-Score: 0.609893005944044
# Predicted Label: Qustodio
# Accuracy: 0.5870505216740101
# Precision: 0.5806287676228643
# Recall: 0.5804523171372965
# F1-Score: 0.5805405289724148
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5831770554865384
# Precision: 0.5886311831633517
# Recall: 0.5815901150941124
# F1-Score: 0.5850894665371874
# Predicted Label: TiSpy
# Accuracy: 0.5881812150352717
# Precision: 0.5950801583116301
# Recall: 0.5850874684316464
# F1-Score: 0.5900415084275037
# Predicted Label: TiSpy
# Accuracy: 0.6017176634331707
# Precision: 0.6036001894358534
# Recall: 0.607922895718458
# F1-Score: 0.6057538308835716
# Predicted Label: kids-360
# Accuracy: 0.5983303112891225
# Precision: 0.5942910854603116
# Recall: 0.606199781422827
# F1-Score: 0.6001863671698301
# Predicted Label: FamiSafe
# Accuracy: 0.5937090839415027
# Precision: 0.596622261296134
# Recall: 0.5961309461281369
# F1-Score: 0.5963765025216324
# Predicted Label: Eyezy
# Accuracy: 0.5808518305998843
# Precision: 0.5729237184946413
# Recall: 0.5769115859575094
# F1-Score: 0.5749107368500908
# Predicted Label: mLite
# Accuracy: 0.5983211214092586
# Precision: 0.591396086786691
# Recall: 0.592965508533843
# F1-Score: 0.5921797578238563
# Predicted Label: Air-Droid
# Accuracy: 0.5858965977184968
# Precision: 0.5922415056433842
# Recall: 0.5748311633133844
# F1-Score: 0.5834064710910775
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5947535965244128
# Precision: 0.6029757258627437
# Recall: 0.6063693268692475
# F1-Score: 0.60466776489293
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.589764885357853
# Precision: 0.595193213767929
# Recall: 0.6001930855803304
# F1-Score: 0.5976826933395731
# Predicted Label: mLite
# Accuracy: 0.5806349694696139
# Precision: 0.5762751084580342
# Recall: 0.581318575949563
# F1-Score: 0.5787858553762613
# Predicted Label: FamiSafe
# Accuracy: 0.5818994174676899
# Precision: 0.5896168652229531
# Recall: 0.5933765784225262
# F1-Score: 0.5914907473841581
# Predicted Label: FamiSafe
# Accuracy: 0.5809235132191962
# Precision: 0.5789078151733629
# Recall: 0.5916431682474198
# F1-Score: 0.5852062127040867
# Predicted Label: Air-Droid
# Accuracy: 0.5859706820773917
# Precision: 0.5914381852349743
# Recall: 0.5876499263720446
# F1-Score: 0.589537970208603
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6107374580742597
# Precision: 0.6055882326102194
# Recall: 0.620211615928519
# F1-Score: 0.6128126982267454
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.583408053608345
# Precision: 0.5823258634829891
# Recall: 0.5930978510823742
# F1-Score: 0.5876624981811921
# Predicted Label: kids-360
# Accuracy: 0.6017375592972682
# Precision: 0.5925274515834739
# Recall: 0.5984592547433946
# F1-Score: 0.5954785812568542
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6045881592578529
# Precision: 0.6141021680395218
# Recall: 0.6057073912897238
# F1-Score: 0.6098758930748515
# Predicted Label: FamiSafe
# Accuracy: 0.5947195239148177
# Precision: 0.5990491642979388
# Recall: 0.5924142202488626
# F1-Score: 0.5957132181502739
# Predicted Label: kids-360
# Accuracy: 0.5857064203378773
# Precision: 0.585204512749951
# Recall: 0.5854216804838949
# F1-Score: 0.5853130764730782
# Predicted Label: Normal-Traffic
# Accuracy: 0.6192978566853905
# Precision: 0.6097154977141808
# Recall: 0.6313137862969486
# F1-Score: 0.6203266987895122
# Predicted Label: kids-360
# Accuracy: 0.6141488482725788
# Precision: 0.60867332037152
# Recall: 0.6212464534069931
# F1-Score: 0.6148956210413135
# Predicted Label: Normal-Traffic
# Accuracy: 0.6057217969193511
# Precision: 0.6018432128153238
# Recall: 0.616927815116877
# F1-Score: 0.6092921636889027
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5805621852966617
# Precision: 0.5745068179781221
# Recall: 0.5700192276947311
# F1-Score: 0.5722542251045498
# Predicted Label: Air-Droid
# Accuracy: 0.5829022046753168
# Precision: 0.5839682613802215
# Recall: 0.5927253201335603
# F1-Score: 0.5883142053501146
# Predicted Label: Eyezy
# Accuracy: 0.5876437319944112
# Precision: 0.5850758980583128
# Recall: 0.581834614181135
# F1-Score: 0.5834507545229595
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5947850227255647
# Precision: 0.6005984345539822
# Recall: 0.5872706139479466
# F1-Score: 0.5938597555707253
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6076830023170962
# Precision: 0.6028636438833224
# Recall: 0.604404164533088
# F1-Score: 0.6036329213260908
# Predicted Label: kids-360
# Accuracy: 0.6179705163176512
# Precision: 0.6101861523378501
# Recall: 0.6095993366662846
# F1-Score: 0.6098926033491205
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5864117613161683
# Precision: 0.5907295318385116
# Recall: 0.586269918611417
# F1-Score: 0.5884912765591099
# Predicted Label: Qustodio
# Accuracy: 0.5973654127331656
# Precision: 0.605381906262124
# Recall: 0.5900920787420069
# F1-Score: 0.5976392158760043
# Predicted Label: Normal-Traffic
# Accuracy: 0.5904569314738491
# Precision: 0.586022300152218
# Recall: 0.5927723008496646
# F1-Score: 0.5893779746110124
# Predicted Label: FamiSafe
# Accuracy: 0.5913913223788286
# Precision: 0.5899539911469521
# Recall: 0.589632118270965
# F1-Score: 0.5897930107943399
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5818324426310479
# Precision: 0.5838507952042173
# Recall: 0.571831265285717
# F1-Score: 0.5777785264195635
# Predicted Label: FamiSafe
# Accuracy: 0.6195478188560158
# Precision: 0.619919278945139
# Recall: 0.621793428411889
# F1-Score: 0.6208549393271093
# Predicted Label: Air-Droid
# Accuracy: 0.612487711431574
# Precision: 0.6114032549551722
# Recall: 0.6108820433820666
# F1-Score: 0.611142538040103
# Predicted Label: Qustodio
# Accuracy: 0.6031192843788852
# Precision: 0.6082330643610675
# Recall: 0.6058405531816594
# F1-Score: 0.6070344513732366
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6028885240479176
# Precision: 0.5958673257170002
# Recall: 0.6021688091096031
# F1-Score: 0.599001495002924
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6137585359205934
# Precision: 0.6161186267199273
# Recall: 0.6169835543466713
# F1-Score: 0.6165507871927445
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.59577968497097
# Precision: 0.598484201448679
# Recall: 0.5991538023504932
# F1-Score: 0.5988188147122364
# Predicted Label: Eyezy
# Accuracy: 0.6010000777477077
# Precision: 0.595880700974869
# Recall: 0.6111509643381133
# F1-Score: 0.6034192399365635
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5817705255944579
# Precision: 0.5787412137081877
# Recall: 0.5721234918965804
# F1-Score: 0.5754133261341048
# Predicted Label: FamiSafe
# Accuracy: 0.6039749978875641
# Precision: 0.6122160519075114
# Recall: 0.601350439170887
# F1-Score: 0.6067346031528899
# Predicted Label: Eyezy
# Accuracy: 0.5894109409046291
# Precision: 0.5807890336435021
# Recall: 0.5929505842413434
# F1-Score: 0.5868068037789734
# Predicted Label: mLite
# Accuracy: 0.6062218359512338
# Precision: 0.6060951389505549
# Recall: 0.5993486684822691
# F1-Score: 0.6027030248340042
# Predicted Label: mLite
# Accuracy: 0.5894983548163201
# Precision: 0.5879157346758905
# Recall: 0.5921194615064221
# F1-Score: 0.5900101104673452
# Predicted Label: Qustodio
# Accuracy: 0.6110947484735144
# Precision: 0.601178386059599
# Recall: 0.6108976367589511
# F1-Score: 0.6059990436249206
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6017723694174804
# Precision: 0.6059422658934663
# Recall: 0.6111649339311421
# F1-Score: 0.6085423945470597
# Predicted Label: Air-Droid
# Accuracy: 0.5805373022352402
# Precision: 0.5897170917651178
# Recall: 0.5816708851855427
# F1-Score: 0.5856663539760886
# Predicted Label: kids-360
# Accuracy: 0.6046648235182717
# Precision: 0.6122286105167769
# Recall: 0.6044294464585706
# F1-Score: 0.6083040309299549
# Predicted Label: TiSpy
# Accuracy: 0.5946867879059549
# Precision: 0.5931781786506549
# Recall: 0.5997901201128769
# F1-Score: 0.5964658262754667
# Predicted Label: FamiSafe
# Accuracy: 0.6173289592558708
# Precision: 0.6207575136925615
# Recall: 0.6061733338569613
# F1-Score: 0.6133787447651406
# Predicted Label: Qustodio
# Accuracy: 0.5815075690106398
# Precision: 0.5830547595220918
# Recall: 0.5917946713645319
# F1-Score: 0.5873922065715341
# Predicted Label: TiSpy
# Accuracy: 0.610656792973225
# Precision: 0.6064344974456719
# Recall: 0.6121269234140624
# F1-Score: 0.6092674145414322
# Predicted Label: kids-360
# Accuracy: 0.6172362542153051
# Precision: 0.6142882684234335
# Recall: 0.6243523634218672
# F1-Score: 0.619279429968511
# Predicted Label: mLite
# Accuracy: 0.6193396021387173
# Precision: 0.622997157093976
# Recall: 0.6276231374577285
# F1-Score: 0.6253015916437314
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.598542200576014
# Precision: 0.5992398736451257
# Recall: 0.6060862122102322
# F1-Score: 0.6026435990807821

# %%
#TabNEt-B
import pandas as pd
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import joblib
from concurrent.futures import ThreadPoolExecutor
import scapy.all as scapy
import torch
from sklearn.preprocessing import LabelEncoder
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.model_selection import train_test_split
import pickle
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)
def load_pretrained_model():
    # Load the TabNet model from the zip file
    tabnet_model = TabNetClassifier()
    tabnet_model.load_model('Original-tabnet-Dataset-B-1-80-20.zip')
    
    # Load the LabelEncoder
    with open('Original-Tabnet-label_encoder-Dataset-B-1-80-20.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    
    return tabnet_model, label_encoder
def predict_with_model(tabnet_model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    tabnet_output = tabnet_model.predict_proba(features_df.values)
    predicted_label = label_encoder.inverse_transform(tabnet_output.argmax(axis=1))[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = [  '1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv' ]
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    # Load pretrained models and label encoder
    tabnet_model, label_encoder = load_pretrained_model()
    
    # Load previous samples for evaluation
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1
        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(tabnet_model, label_encoder, features)
                              
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
               
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == "__main__":
    main()
# Out:
# Predicted Label: kids-360
# Accuracy: 0.5683060066684383
# Precision: 0.5757351707174524
# Recall: 0.5732169493876162
# F1-Score: 0.5744733003906847
# Predicted Label: Normal-Traffic
# Accuracy: 0.5780872277207763
# Precision: 0.5681634982146612
# Recall: 0.5681613717789329
# F1-Score: 0.5681624349948073
# Predicted Label: TiSpy
# Accuracy: 0.566216795984501
# Precision: 0.5649261896940021
# Recall: 0.563280325120526
# F1-Score: 0.5641020568867217
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5631220142791972
# Precision: 0.5656837272756641
# Recall: 0.5563149159586142
# F1-Score: 0.5609602063178364
# Predicted Label: FamiSafe
# Accuracy: 0.595802270426994
# Precision: 0.6021798611497843
# Recall: 0.6012812770151532
# F1-Score: 0.6017302336111263
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5976013873228753
# Precision: 0.6025083798761892
# Recall: 0.5981684731589235
# F1-Score: 0.6003305831122857
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5907713250729374
# Precision: 0.5950347282686458
# Recall: 0.5804158566242188
# F1-Score: 0.5876343862820632
# Predicted Label: Normal-Traffic
# Accuracy: 0.5713910021220748
# Precision: 0.57304402435543
# Recall: 0.5691435210019474
# F1-Score: 0.5710871126838077
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5542895702815585
# Precision: 0.5521148962332989
# Recall: 0.5526263839895997
# F1-Score: 0.5523705217037599
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5977178643451616
# Precision: 0.5928269902359387
# Recall: 0.6091425612029261
# F1-Score: 0.6008740416930753
# Predicted Label: kids-360
# Accuracy: 0.5689043219450842
# Precision: 0.5609018196600135
# Recall: 0.5673301675965601
# F1-Score: 0.5640976801707444
# Predicted Label: TiSpy
# Accuracy: 0.5807872960999676
# Precision: 0.5803419470350227
# Recall: 0.5847442521665781
# F1-Score: 0.5825347824949568
# Predicted Label: TiSpy
# Accuracy: 0.5614452580299977
# Precision: 0.5539781956375991
# Recall: 0.5731740251959102
# F1-Score: 0.5634126542900572
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5996892655351099
# Precision: 0.5968867844224888
# Recall: 0.603555917513311
# F1-Score: 0.600202825578845
# Predicted Label: FamiSafe
# Accuracy: 0.5511788157134216
# Precision: 0.5461363641364751
# Recall: 0.5406393264394316
# F1-Score: 0.5433739429603136
# Predicted Label: Qustodio
# Accuracy: 0.5547972145813992
# Precision: 0.5620969426286146
# Recall: 0.5628115480971706
# F1-Score: 0.5624540183839961
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5863228932297686
# Precision: 0.5813140990239531
# Recall: 0.5766760204246887
# F1-Score: 0.5789857713147172
# Predicted Label: kids-360
# Accuracy: 0.5614272660279155
# Precision: 0.5527329999151538
# Recall: 0.569163352154354
# F1-Score: 0.5608278634612233
# Predicted Label: Qustodio
# Accuracy: 0.5943759406272731
# Precision: 0.5846261878053186
# Recall: 0.6034847473144991
# F1-Score: 0.593905799184571
# Predicted Label: Air-Droid
# Accuracy: 0.5668335831724521
# Precision: 0.56944085782546
# Recall: 0.5636864947983734
# F1-Score: 0.5665490651149623
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5645535992887332
# Precision: 0.5584682278929186
# Recall: 0.56274510404698
# F1-Score: 0.5605985088828382
# Predicted Label: TiSpy
# Accuracy: 0.5943796100481943
# Precision: 0.5865090733364802
# Recall: 0.599194429567514
# F1-Score: 0.592783893736171
# Predicted Label: Qustodio
# Accuracy: 0.5771195087439982
# Precision: 0.5795577756584707
# Recall: 0.5656522658915397
# F1-Score: 0.5725205981822656
# Predicted Label: Air-Droid
# Accuracy: 0.597124584767404
# Precision: 0.6024043884820303
# Recall: 0.5848733108340768
# F1-Score: 0.5935094196672115
# Predicted Label: FamiSafe
# Accuracy: 0.5789215836255106
# Precision: 0.5748456600029753
# Recall: 0.572003697119307
# F1-Score: 0.5734211572821771
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5502503047850834
# Precision: 0.5521199908181769
# Recall: 0.5550925402682406
# F1-Score: 0.5536022753200198
# Predicted Label: kids-360
# Accuracy: 0.5726085917489271
# Precision: 0.5765359062119424
# Recall: 0.5646785581379796
# F1-Score: 0.5705456325774536
# Predicted Label: TiSpy
# Accuracy: 0.5664768698994443
# Precision: 0.5652697978984318
# Recall: 0.5741171326561635
# F1-Score: 0.5696591155185738
# Predicted Label: kids-360
# Accuracy: 0.5682165653889524
# Precision: 0.5590808338231086
# Recall: 0.5795196249607685
# F1-Score: 0.5691167830478123
# Predicted Label: kids-360
# Accuracy: 0.5988145503254673
# Precision: 0.5909029550609108
# Recall: 0.5895445947414691
# F1-Score: 0.590222993357462
# Predicted Label: FamiSafe
# Accuracy: 0.5752680906118927
# Precision: 0.5798420128291997
# Recall: 0.5654683262106582
# F1-Score: 0.5725649743737028
# Predicted Label: TiSpy
# Accuracy: 0.564344565174086
# Precision: 0.5711947534797148
# Recall: 0.5742966892093928
# F1-Score: 0.572741521398176
# Predicted Label: kids-360
# Accuracy: 0.5873042476129607
# Precision: 0.580583582286188
# Recall: 0.5818918163494894
# F1-Score: 0.5812369631833938
# Predicted Label: Normal-Traffic
# Accuracy: 0.594159394208908
# Precision: 0.5955344669626484
# Recall: 0.5863760594427448
# F1-Score: 0.5909197797940855
# Predicted Label: Qustodio
# Accuracy: 0.5906809401782137
# Precision: 0.5911664904287556
# Recall: 0.5833303816582458
# F1-Score: 0.5872222952328598
# Predicted Label: TiSpy
# Accuracy: 0.572371635791494
# Precision: 0.5674918775313809
# Recall: 0.5793562760846356
# F1-Score: 0.5733627068905581
# Predicted Label: mLite
# Accuracy: 0.5951630791455461
# Precision: 0.5996899866786908
# Recall: 0.584753219288286
# F1-Score: 0.5921274207470794
# Predicted Label: Qustodio
# Accuracy: 0.5808539059610055
# Precision: 0.5716074731909669
# Recall: 0.5753852791539114
# F1-Score: 0.5734901547652573
# Predicted Label: TiSpy
# Accuracy: 0.5864329306946154
# Precision: 0.5837930098630892
# Recall: 0.5898109458050186
# F1-Score: 0.5867865486286451
# Predicted Label: Air-Droid
# Accuracy: 0.5773649864136341
# Precision: 0.5809141112490405
# Recall: 0.5842196340089763
# F1-Score: 0.5825621836906093
# Predicted Label: mLite
# Accuracy: 0.5905138506209895
# Precision: 0.595727449640547
# Recall: 0.58703314740728
# F1-Score: 0.5913483432442432
# Predicted Label: Qustodio
# Accuracy: 0.5638505410762116
# Precision: 0.5594972099944582
# Recall: 0.560980750345956
# F1-Score: 0.5602379980482679
# Predicted Label: Normal-Traffic
# Accuracy: 0.5681590624333592
# Precision: 0.5756030523074991
# Recall: 0.579737304775333
# F1-Score: 0.5776627815681507
# Predicted Label: Eyezy
# Accuracy: 0.5618514034742412
# Precision: 0.5645960417530037
# Recall: 0.5597653770287979
# F1-Score: 0.5621703322464666
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5531503687435358
# Precision: 0.5515704663050567
# Recall: 0.5474056304252211
# F1-Score: 0.5494801565383932
# Predicted Label: FamiSafe
# Accuracy: 0.5856015681829491
# Precision: 0.5820715258169958
# Recall: 0.578371177082482
# F1-Score: 0.5802154517268474
# Predicted Label: Air-Droid
# Accuracy: 0.5934421336914417
# Precision: 0.6031015999758982
# Recall: 0.5822380525929804
# F1-Score: 0.5924862132548507
# Predicted Label: mLite
# Accuracy: 0.5883841703977851
# Precision: 0.5927466918058318
# Recall: 0.5949612536063399
# F1-Score: 0.5938519081059511
# Predicted Label: Qustodio
# Accuracy: 0.5577550555311673
# Precision: 0.5524844396707258
# Recall: 0.5502382068728483
# F1-Score: 0.5513590354971601
# Predicted Label: mLite
# Accuracy: 0.5990163572749301
# Precision: 0.5984358250202595
# Recall: 0.6007588810928929
# F1-Score: 0.5995951029676252
# Predicted Label: TiSpy
# Accuracy: 0.5538843255581835
# Precision: 0.5626883355888262
# Recall: 0.5508572914462757
# F1-Score: 0.5567099631043733
# Predicted Label: Qustodio
# Accuracy: 0.5504385721303964
# Precision: 0.5454963008402506
# Recall: 0.5601426791455549
# F1-Score: 0.5527224798470299
# Predicted Label: FamiSafe
# Accuracy: 0.578860203610391
# Precision: 0.5713196067933621
# Recall: 0.5847139631911318
# F1-Score: 0.577939188290919
# Predicted Label: Air-Droid
# Accuracy: 0.5990070537440658
# Precision: 0.5998695550829773
# Recall: 0.6014663972880048
# F1-Score: 0.6006669149065779
# Predicted Label: FamiSafe
# Accuracy: 0.5702451462670268
# Precision: 0.5748429251122804
# Recall: 0.5591008636846416
# F1-Score: 0.5668626242122138
# Predicted Label: kids-360
# Accuracy: 0.586900545328297
# Precision: 0.5826875911580324
# Recall: 0.5768606793036843
# F1-Score: 0.5797594946580494
# Predicted Label: Air-Droid
# Accuracy: 0.5929269795244494
# Precision: 0.5923571000375337
# Recall: 0.5858966389953237
# F1-Score: 0.5891091578998664
# Predicted Label: Qustodio
# Accuracy: 0.560902464131644
# Precision: 0.5685589960292114
# Recall: 0.5678803000266808
# F1-Score: 0.5682194453650034
# Predicted Label: TiSpy
# Accuracy: 0.5770486501589692
# Precision: 0.5689004554494779
# Recall: 0.5653646755102292
# F1-Score: 0.5671270545373773
# Predicted Label: kids-360
# Accuracy: 0.5946117647093309
# Precision: 0.5952001708848537
# Recall: 0.588692361850545
# F1-Score: 0.5919283797870951
# Predicted Label: Normal-Traffic
# Accuracy: 0.5545132105419582
# Precision: 0.5475745265667388
# Recall: 0.5647947405051658
# F1-Score: 0.5560513433701489
# Predicted Label: Normal-Traffic
# Accuracy: 0.5555547649452011
# Precision: 0.564832436056814
# Recall: 0.5549206687457184
# F1-Score: 0.5598326841901364
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5744606985412227
# Precision: 0.5839151738317824
# Recall: 0.5738816217984143
# F1-Score: 0.5788549220658191
# Predicted Label: Air-Droid
# Accuracy: 0.5985896521343079
# Precision: 0.5948137868724357
# Recall: 0.5950871187952177
# F1-Score: 0.5949504214403133
# Predicted Label: mLite
# Accuracy: 0.5670743851983386
# Precision: 0.5572840148943979
# Recall: 0.5572916464501217
# F1-Score: 0.557287830646133
# Predicted Label: kids-360
# Accuracy: 0.5637256550142715
# Precision: 0.572503628150661
# Recall: 0.5690091570548262
# F1-Score: 0.5707510438548373
# Predicted Label: kids-360
# Accuracy: 0.5990672342516281
# Precision: 0.6047993181192455
# Recall: 0.5998722284148322
# F1-Score: 0.6023256974031964
# Predicted Label: kids-360
# Accuracy: 0.5561906171212897
# Precision: 0.559278037325591
# Recall: 0.5503985350335624
# F1-Score: 0.5548027598095884
# Predicted Label: Normal-Traffic
# Accuracy: 0.5744731316474984
# Precision: 0.5712356014153406
# Recall: 0.5646637556765622
# F1-Score: 0.5679306675498871
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5625722741532954
# Precision: 0.5579052358836231
# Recall: 0.5530001831661686
# F1-Score: 0.5554418807262653
# Predicted Label: TiSpy
# Accuracy: 0.5515121383532045
# Precision: 0.5557325552591115
# Recall: 0.5411062116892118
# F1-Score: 0.5483218623376596
# Predicted Label: Eyezy
# Accuracy: 0.5511133738738859
# Precision: 0.5412224903550861
# Recall: 0.5461831880205206
# F1-Score: 0.5436915239437241
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5980643682338291
# Precision: 0.6029812916258204
# Recall: 0.5946285685352561
# F1-Score: 0.5987758020709298
# Predicted Label: FamiSafe
# Accuracy: 0.5753495618479672
# Precision: 0.5689062156120397
# Recall: 0.5738369903448746
# F1-Score: 0.5713609651819078
# Predicted Label: FamiSafe
# Accuracy: 0.5786784298185907
# Precision: 0.5803318138285464
# Recall: 0.5865923716320876
# F1-Score: 0.583445298758395
# Predicted Label: Qustodio
# Accuracy: 0.550629961897223
# Precision: 0.5564492412466928
# Recall: 0.5613211204398771
# F1-Score: 0.5588745636325919
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5774847680227259
# Precision: 0.5763062502424553
# Recall: 0.5764204662914292
# F1-Score: 0.5763633526084866
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5868772847653853
# Precision: 0.5790663132379392
# Recall: 0.5859596165314649
# F1-Score: 0.5824925715058585
# Predicted Label: Eyezy
# Accuracy: 0.584639735823122
# Precision: 0.5891307643723327
# Recall: 0.5846439617706333
# F1-Score: 0.5868787875769105
# Predicted Label: Air-Droid
# Accuracy: 0.582800896234472
# Precision: 0.5883911433408974
# Recall: 0.5815498926231367
# F1-Score: 0.5849505158152648
# Predicted Label: Normal-Traffic
# Accuracy: 0.5653016027957922
# Precision: 0.5684383802195474
# Recall: 0.5543562371101929
# F1-Score: 0.5613089992129492
# Predicted Label: Qustodio
# Accuracy: 0.5626445482535444
# Precision: 0.5676107209806981
# Recall: 0.5538369772724249
# F1-Score: 0.5606392638106181
# Predicted Label: FamiSafe
# Accuracy: 0.567306086423814
# Precision: 0.5575642829285657
# Recall: 0.5693288919411654
# F1-Score: 0.5633851769887356
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5697338142160032
# Precision: 0.5601256278023169
# Recall: 0.5642267427147172
# F1-Score: 0.5621687057778998
# Predicted Label: mLite
# Accuracy: 0.5681015131216205
# Precision: 0.5604753880019663
# Recall: 0.5591924825869317
# F1-Score: 0.5598332003236834
# Predicted Label: Eyezy
# Accuracy: 0.5639657271971498
# Precision: 0.561670886359553
# Recall: 0.5638558667046806
# F1-Score: 0.5627612556855462
# Predicted Label: Air-Droid
# Accuracy: 0.5875813838876285
# Precision: 0.5784652692232128
# Recall: 0.5782385131023792
# F1-Score: 0.5783518689365618
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5623491203914497
# Precision: 0.5677309605267203
# Recall: 0.5708129345566232
# F1-Score: 0.5692677761768425
# Predicted Label: Qustodio
# Accuracy: 0.5710773575982641
# Precision: 0.562071017330463
# Recall: 0.571255449587147
# F1-Score: 0.5666260183233872
# Predicted Label: FamiSafe
# Accuracy: 0.569920700211381
# Precision: 0.5618487193419818
# Recall: 0.5714109693470332
# F1-Score: 0.5665895020354711
# Predicted Label: Normal-Traffic
# Accuracy: 0.5520900628628155
# Precision: 0.5606262485975689
# Recall: 0.5535998484124333
# F1-Score: 0.5570908939801277
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5746630329177299
# Precision: 0.5672861884951754
# Recall: 0.5647466183281744
# F1-Score: 0.5660135548119726
# Predicted Label: kids-360
# Accuracy: 0.5629594444999365
# Precision: 0.5655077951494689
# Recall: 0.5582418288454956
# F1-Score: 0.5618513217710105
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.584523498759754
# Precision: 0.5872161298692921
# Recall: 0.5932983066283528
# F1-Score: 0.5902415501328788
# Predicted Label: Eyezy
# Accuracy: 0.5520213140256205
# Precision: 0.5543849270766633
# Recall: 0.5592079149798226
# F1-Score: 0.5567859768104663
# Predicted Label: Eyezy
# Accuracy: 0.5656042949771192
# Precision: 0.5675148860807647
# Recall: 0.5732503067501774
# F1-Score: 0.5703681784395099
# Predicted Label: Qustodio
# Accuracy: 0.5787248456382441
# Precision: 0.5722748774324049
# Recall: 0.574052401829427
# F1-Score: 0.5731622614935205
# Predicted Label: Qustodio
# Accuracy: 0.5574693074903337
# Precision: 0.5520293190173424
# Recall: 0.5574295043770354
# F1-Score: 0.5547162692527358
# Predicted Label: FamiSafe
# Accuracy: 0.5903015690554154
# Precision: 0.58825533820448
# Recall: 0.5905254645011936
# F1-Score: 0.5893882154191198
# Predicted Label: mLite
# Accuracy: 0.5972605655654669
# Precision: 0.6012181697519566
# Recall: 0.6030813207379048
# F1-Score: 0.602148304020541
# Predicted Label: mLite
# Accuracy: 0.5742494243189936
# Precision: 0.5676171897251994
# Recall: 0.5625771624148941
# F1-Score: 0.5650859382350493
# Predicted Label: Eyezy
# Accuracy: 0.5726048880463827
# Precision: 0.575129203781464
# Recall: 0.5776863872863819
# F1-Score: 0.5764049593528683
# Predicted Label: mLite
# Accuracy: 0.5751985491742665
# Precision: 0.5654883418806007
# Recall: 0.5852590535304795
# F1-Score: 0.5752038598068399
# Predicted Label: Eyezy
# Accuracy: 0.589118095276727
# Precision: 0.5878327534498614
# Recall: 0.5803705077975413
# F1-Score: 0.5840777969673409
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5793006678777425
# Precision: 0.585983008859972
# Recall: 0.5889261352888918
# F1-Score: 0.5874508858348534
# Predicted Label: Eyezy
# Accuracy: 0.5685856216294564
# Precision: 0.562727109212458
# Recall: 0.5567840284882221
# F1-Score: 0.5597397940146527
# Predicted Label: Normal-Traffic
# Accuracy: 0.597654269129479
# Precision: 0.5929405095362289
# Recall: 0.5859943725815003
# F1-Score: 0.5894469781735409
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5719225158805323
# Precision: 0.5732044221983963
# Recall: 0.5804116336579261
# F1-Score: 0.5767855144165129
# Predicted Label: kids-360
# Accuracy: 0.5863388921949408
# Precision: 0.5930018613375829
# Recall: 0.5763423145746422
# F1-Score: 0.5845534143850358
# Predicted Label: FamiSafe
# Accuracy: 0.560188664761605
# Precision: 0.5583297138271327
# Recall: 0.5516013968217445
# F1-Score: 0.554945162054401
# Predicted Label: Normal-Traffic
# Accuracy: 0.5933856184124631
# Precision: 0.5921884069849781
# Recall: 0.5811235603946758
# F1-Score: 0.5866038105110516
# Predicted Label: TiSpy
# Accuracy: 0.5803082647214679
# Precision: 0.5790234064555473
# Recall: 0.5788601117237878
# F1-Score: 0.578941747575051
# Predicted Label: kids-360
# Accuracy: 0.5739868232479085
# Precision: 0.5809967007647097
# Recall: 0.5793688387975986
# F1-Score: 0.5801816279277925
# Predicted Label: TiSpy
# Accuracy: 0.5808911134876001
# Precision: 0.587897361081281
# Recall: 0.5790017074452154
# F1-Score: 0.583415627023219
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.592447345469831
# Precision: 0.599529214081131
# Recall: 0.5846663006477152
# F1-Score: 0.592004484677193
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5590901613307044
# Precision: 0.5566743907114091
# Recall: 0.5571582035851
# F1-Score: 0.5569161920719181
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5519449869528749
# Precision: 0.5451046912306127
# Recall: 0.5599026398941054
# F1-Score: 0.552404580570577
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5763124587210373
# Precision: 0.5721101228153767
# Recall: 0.5726223986615664
# F1-Score: 0.5723661461149513
# Predicted Label: TiSpy
# Accuracy: 0.5921902359575076
# Precision: 0.5832766911739263
# Recall: 0.6010278846952092
# F1-Score: 0.5920192542210069
# Predicted Label: Eyezy
# Accuracy: 0.5827469790389415
# Precision: 0.5927114035777366
# Recall: 0.5705775571794206
# F1-Score: 0.5814339105318291

# %%
#TabNet-XGB-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torch
import joblib
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    tabnet_model = torch.load('Original-TabNet-XGB-model-Dataset-A-1-80-20-Tabnet.h5')
    xgb_model = joblib.load('Original-TabNet-XGB-model-Dataset-A-1-80-20-XGB.pkl')
    label_encoder = joblib.load('Original-TabNet-XGB-Dataset-A-1-80-20-label_encoder.pkl')
    return tabnet_model, xgb_model, label_encoder

def predict_with_model(tabnet_model, xgb_model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')

    tabnet_output = tabnet_model.predict_proba(features_df.values)
    prediction = xgb_model.predict(tabnet_output)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    tabnet_model, xgb_model, label_encoder = load_pretrained_model()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(tabnet_model, xgb_model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)  
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# Predicted Label: kids-360
# Accuracy: 0.8062957272203791
# Precision: 0.8032572216973848
# Recall: 0.8094285651212723
# F1-Score: 0.8063310853187609
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7817270644092539
# Precision: 0.7769406314681978
# Recall: 0.7884295254624065
# F1-Score: 0.7826429176113261
# Predicted Label: TiSpy
# Accuracy: 0.8168330302421749
# Precision: 0.8133782877130592
# Recall: 0.8283990903646754
# F1-Score: 0.8208199755472235
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.82352644500503
# Precision: 0.8298316837777123
# Recall: 0.8155542576363273
# F1-Score: 0.8226310263047697
# Predicted Label: TiSpy
# Accuracy: 0.8011745452295174
# Precision: 0.7966873490467773
# Recall: 0.7942140439266957
# F1-Score: 0.7954487739168512
# Predicted Label: kids-360
# Accuracy: 0.7812284656715778
# Precision: 0.7726191903934616
# Recall: 0.7843792999302618
# F1-Score: 0.7784548327307717
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.821069936491112
# Precision: 0.8210940833165287
# Recall: 0.8176285212977896
# F1-Score: 0.8193576378309165
# Predicted Label: mLite
# Accuracy: 0.7843544528193385
# Precision: 0.7927188115434531
# Recall: 0.7761827136303581
# F1-Score: 0.7843636180052336
# Predicted Label: kids-360
# Accuracy: 0.7863735557207546
# Precision: 0.7912674370339657
# Recall: 0.7924103152778804
# F1-Score: 0.7918384637706767
# Predicted Label: Qustodio
# Accuracy: 0.8015617388027203
# Precision: 0.8106459095180744
# Recall: 0.8086629522099729
# F1-Score: 0.8096532167288518
# Predicted Label: TiSpy
# Accuracy: 0.8123518372918896
# Precision: 0.8159632024084468
# Recall: 0.8023649289218727
# F1-Score: 0.8091069347785874
# Predicted Label: Eyezy
# Accuracy: 0.8172505753789472
# Precision: 0.8089987017558364
# Recall: 0.8153757078023943
# F1-Score: 0.8121746872813393
# Predicted Label: Eyezy
# Accuracy: 0.7995572885133095
# Precision: 0.804103690400061
# Recall: 0.7966158400226068
# F1-Score: 0.8003422518674252
# Predicted Label: mLite
# Accuracy: 0.8101033403452759
# Precision: 0.8029533652108888
# Recall: 0.8192616772136674
# F1-Score: 0.8110255465561985
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.787079209192348
# Precision: 0.7875799292102778
# Recall: 0.7928273050725296
# F1-Score: 0.7901949057938338
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8071464812764845
# Precision: 0.8138570175995199
# Recall: 0.796791461302276
# F1-Score: 0.8052338307690691
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7836632038161135
# Precision: 0.7913385897851175
# Recall: 0.7732960642516125
# F1-Score: 0.7822132986668302
# Predicted Label: Qustodio
# Accuracy: 0.7968164367235465
# Precision: 0.790667043099575
# Recall: 0.8023043708547907
# F1-Score: 0.796443199184483
# Predicted Label: FamiSafe
# Accuracy: 0.8174827820108006
# Precision: 0.822729149831488
# Recall: 0.8193131901692308
# F1-Score: 0.8210176168701722
# Predicted Label: mLite
# Accuracy: 0.8110640271965495
# Precision: 0.8016455164296217
# Recall: 0.8159023061780144
# F1-Score: 0.8087110828510549
# Predicted Label: TiSpy
# Accuracy: 0.7815929542604787
# Precision: 0.78132620432587
# Recall: 0.77823329897871
# F1-Score: 0.7797766847402977
# Predicted Label: FamiSafe
# Accuracy: 0.7919446422970382
# Precision: 0.7982101005401702
# Recall: 0.7801933985817829
# F1-Score: 0.7890989236518734
# Predicted Label: kids-360
# Accuracy: 0.8057090198011913
# Precision: 0.8020104559072997
# Recall: 0.7965677450038811
# F1-Score: 0.7992798350027144
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.811121014439261
# Precision: 0.8019064883292937
# Recall: 0.8014968740564477
# F1-Score: 0.8017016288717093
# Predicted Label: kids-360
# Accuracy: 0.7984505411373818
# Precision: 0.8008606565802092
# Recall: 0.8074339917514584
# F1-Score: 0.8041338910752871
# Predicted Label: TiSpy
# Accuracy: 0.8128580569606114
# Precision: 0.8050791369013975
# Recall: 0.808259450090684
# F1-Score: 0.8066661588806341
# Predicted Label: mLite
# Accuracy: 0.8200038651980709
# Precision: 0.8259662254870176
# Recall: 0.822631743877989
# F1-Score: 0.8242956124935865
# Predicted Label: Air-Droid
# Accuracy: 0.7875156977419722
# Precision: 0.797494517329712
# Recall: 0.7839738808558528
# F1-Score: 0.7906764022974535
# Predicted Label: FamiSafe
# Accuracy: 0.7986437844389512
# Precision: 0.7983656247112075
# Recall: 0.7944142075533911
# F1-Score: 0.7963850147337385
# Predicted Label: mLite
# Accuracy: 0.8094523487719814
# Precision: 0.8065646435702524
# Recall: 0.8211029124870979
# F1-Score: 0.8137688503773522
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7849699924986488
# Precision: 0.7825858369476115
# Recall: 0.7806061812728649
# F1-Score: 0.7815947555737102
# Predicted Label: Normal-Traffic
# Accuracy: 0.800814552779844
# Precision: 0.797965030305632
# Recall: 0.8046312428707709
# F1-Score: 0.8012842720888552
# Predicted Label: Qustodio
# Accuracy: 0.7861036737100924
# Precision: 0.7789222082610525
# Recall: 0.7922739062055069
# F1-Score: 0.7855413272565572
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8093529853769803
# Precision: 0.8077843461961074
# Recall: 0.8155698379095354
# F1-Score: 0.8116584227193472
# Predicted Label: Normal-Traffic
# Accuracy: 0.8074868259488811
# Precision: 0.806070351700369
# Recall: 0.8104470466509752
# F1-Score: 0.8082527742599519
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8185683063861059
# Precision: 0.825776630368767
# Recall: 0.8228525031014354
# F1-Score: 0.8243119735138297
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.820566189836405
# Precision: 0.8284923208164812
# Recall: 0.8247955702828987
# F1-Score: 0.8266398125839248
# Predicted Label: kids-360
# Accuracy: 0.7843659880071883
# Precision: 0.7816066828019907
# Recall: 0.7757623920345497
# F1-Score: 0.7786735715736524
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.822311065856724
# Precision: 0.8192759717464325
# Recall: 0.8256778630200169
# F1-Score: 0.8224644598263582
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8201738241000132
# Precision: 0.8234192160557259
# Recall: 0.8240771289739875
# F1-Score: 0.8237480411490393
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8216965552840805
# Precision: 0.8160143790469758
# Recall: 0.8123151796498393
# F1-Score: 0.8141605774729007
# Predicted Label: Eyezy
# Accuracy: 0.7852134758273978
# Precision: 0.7896629045031766
# Recall: 0.7962011942157103
# F1-Score: 0.7929185711451376
# Predicted Label: Air-Droid
# Accuracy: 0.8238329125374941
# Precision: 0.8236691487701742
# Recall: 0.8296576704870818
# F1-Score: 0.8266525641043384
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8162568762047292
# Precision: 0.8085085796581877
# Recall: 0.8152206667159284
# F1-Score: 0.8118507501497979
# Predicted Label: FamiSafe
# Accuracy: 0.7888607444211584
# Precision: 0.7819998203157293
# Recall: 0.7976085508792505
# F1-Score: 0.7897270675996851
# Predicted Label: Eyezy
# Accuracy: 0.7900117193597251
# Precision: 0.7932755517029237
# Recall: 0.7952791196897193
# F1-Score: 0.794276072194111
# Predicted Label: FamiSafe
# Accuracy: 0.8138878503066257
# Precision: 0.8054965298167558
# Recall: 0.8166261275367881
# F1-Score: 0.8110231478570762
# Predicted Label: kids-360
# Accuracy: 0.8046908119618985
# Precision: 0.8066209522320414
# Recall: 0.8069061590802202
# F1-Score: 0.8067635304495677
# Predicted Label: Eyezy
# Accuracy: 0.8222270819579359
# Precision: 0.8258064875701314
# Recall: 0.8135423470726988
# F1-Score: 0.8196285426610127
# Predicted Label: Air-Droid
# Accuracy: 0.82425181688532
# Precision: 0.8163466269280572
# Recall: 0.82440782293436
# F1-Score: 0.8203574221870937
# Predicted Label: Air-Droid
# Accuracy: 0.8023023020352291
# Precision: 0.796357382091741
# Recall: 0.796345780555957
# F1-Score: 0.7963515812815951
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8061178907394961
# Precision: 0.7982704282308287
# Recall: 0.802365144997223
# F1-Score: 0.8003125490991045
# Predicted Label: TiSpy
# Accuracy: 0.8176403266390515
# Precision: 0.8202125953549156
# Recall: 0.8186783178199938
# F1-Score: 0.8194447384165456
# Predicted Label: Qustodio
# Accuracy: 0.8021766907289049
# Precision: 0.8019938127028775
# Recall: 0.7992102052689306
# F1-Score: 0.8005995894096791
# Predicted Label: Eyezy
# Accuracy: 0.8153631303288428
# Precision: 0.8201089875271771
# Recall: 0.813595196848248
# F1-Score: 0.8168391065231673
# Predicted Label: Eyezy
# Accuracy: 0.7857877300992483
# Precision: 0.7760419731676348
# Recall: 0.789010006199541
# F1-Score: 0.78247226307165
# Predicted Label: mLite
# Accuracy: 0.8223571317041323
# Precision: 0.8286075324406493
# Recall: 0.8197021340804024
# F1-Score: 0.8241307764581041
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8098573710795612
# Precision: 0.8072537621331455
# Recall: 0.8074349804570874
# F1-Score: 0.8073443611259488
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7983931015873902
# Precision: 0.7996317613996015
# Recall: 0.8050284094063571
# F1-Score: 0.8023210106436505
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7947200852891397
# Precision: 0.7859527974195187
# Recall: 0.7946690191547485
# F1-Score: 0.7902868758080989
# Predicted Label: TiSpy
# Accuracy: 0.8138358970745897
# Precision: 0.8101607382969812
# Recall: 0.8141216808380064
# F1-Score: 0.8121363800299612
# Predicted Label: kids-360
# Accuracy: 0.8096067580744032
# Precision: 0.8085705560580504
# Recall: 0.8199701462470826
# F1-Score: 0.8142304532684382
# Predicted Label: TiSpy
# Accuracy: 0.7941469037505047
# Precision: 0.7957497201320668
# Recall: 0.7954258642266173
# F1-Score: 0.7955877592217451
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7952279027063575
# Precision: 0.7863365461252757
# Recall: 0.7976913255389109
# F1-Score: 0.7919732386266215
# Predicted Label: Eyezy
# Accuracy: 0.7947243962946977
# Precision: 0.8015439543473267
# Recall: 0.8059589579356266
# F1-Score: 0.8037453932421388
# Predicted Label: kids-360
# Accuracy: 0.8000645864159742
# Precision: 0.7907430504756225
# Recall: 0.7915932994580342
# F1-Score: 0.79116794653141
# Predicted Label: FamiSafe
# Accuracy: 0.7893547830693424
# Precision: 0.7910225106861852
# Recall: 0.8011685071387092
# F1-Score: 0.7960631819985083
# Predicted Label: kids-360
# Accuracy: 0.7861537973914801
# Precision: 0.7789301851891218
# Recall: 0.7772874007315533
# F1-Score: 0.7781079258769688
# Predicted Label: Normal-Traffic
# Accuracy: 0.8087717541293177
# Precision: 0.8180274262597031
# Recall: 0.8185251172546473
# F1-Score: 0.8182761960809228
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.802595052687298
# Precision: 0.8058746826701438
# Recall: 0.801304287921985
# F1-Score: 0.8035829867951084
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8185312663595119
# Precision: 0.8270600100021224
# Recall: 0.828588187527953
# F1-Score: 0.8278233935045379
# Predicted Label: TiSpy
# Accuracy: 0.7903326518319668
# Precision: 0.7813393731100765
# Recall: 0.7812288579546346
# F1-Score: 0.7812841116241743
# Predicted Label: FamiSafe
# Accuracy: 0.8087676157307071
# Precision: 0.8003062226448487
# Recall: 0.8081214469687992
# F1-Score: 0.8041948480247674
# Predicted Label: FamiSafe
# Accuracy: 0.7854398941158489
# Precision: 0.7804202550936366
# Recall: 0.7796926938487312
# F1-Score: 0.7800563048214911
# Predicted Label: mLite
# Accuracy: 0.8241677286394056
# Precision: 0.8224655795239749
# Recall: 0.8143532777682212
# F1-Score: 0.8183893257985888
# Predicted Label: kids-360
# Accuracy: 0.7989964657185697
# Precision: 0.7932776541570135
# Recall: 0.7974520631365007
# F1-Score: 0.7953593813836688
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8103211696735072
# Precision: 0.8180864109230493
# Recall: 0.8178174564065501
# F1-Score: 0.8179519115557585
# Predicted Label: mLite
# Accuracy: 0.8128549688790883
# Precision: 0.8077161264865366
# Recall: 0.8217832462445573
# F1-Score: 0.8146889671466266
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7987120506349741
# Precision: 0.8035354829682411
# Recall: 0.7898314319446653
# F1-Score: 0.7966245253257873
# Predicted Label: Eyezy
# Accuracy: 0.7845106265182804
# Precision: 0.7924295297843811
# Recall: 0.7894440619359316
# F1-Score: 0.7909339786254795
# Predicted Label: FamiSafe
# Accuracy: 0.8039039216593452
# Precision: 0.7977005479837154
# Recall: 0.7942591483896654
# F1-Score: 0.7959761284847428
# Predicted Label: mLite
# Accuracy: 0.8139067169962956
# Precision: 0.8144695998244097
# Recall: 0.821723517517461
# F1-Score: 0.8180804788691871
# Predicted Label: Normal-Traffic
# Accuracy: 0.7928149933979258
# Precision: 0.7842666977939623
# Recall: 0.7875380478861023
# F1-Score: 0.7858989685585989
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8197984547126176
# Precision: 0.8131664769824932
# Recall: 0.8113388936952644
# F1-Score: 0.8122516573149856
# Predicted Label: FamiSafe
# Accuracy: 0.8223952213069042
# Precision: 0.8249284359366948
# Recall: 0.8192039400817954
# F1-Score: 0.8220562223114489
# Predicted Label: Qustodio
# Accuracy: 0.8167384007096525
# Precision: 0.8146734344170492
# Recall: 0.8057003788244802
# F1-Score: 0.8101620618207532
# Predicted Label: kids-360
# Accuracy: 0.7928806597182859
# Precision: 0.7949976853193399
# Recall: 0.7940179048032135
# F1-Score: 0.7945074929969466
# Predicted Label: TiSpy
# Accuracy: 0.7849611051658267
# Precision: 0.7767471809302656
# Recall: 0.7768565565501638
# F1-Score: 0.7768018648901255
# Predicted Label: FamiSafe
# Accuracy: 0.8086488061912516
# Precision: 0.8153898198933325
# Recall: 0.801183788010089
# F1-Score: 0.8082243844797853
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8224240850391702
# Precision: 0.8144452774095987
# Recall: 0.8193825254934357
# F1-Score: 0.8169064415409324
# Predicted Label: Eyezy
# Accuracy: 0.8222094943245513
# Precision: 0.8248991941838059
# Recall: 0.811615764038101
# F1-Score: 0.8182035689662435
# Predicted Label: FamiSafe
# Accuracy: 0.8226047221927077
# Precision: 0.8246380982579877
# Recall: 0.8228222287325175
# F1-Score: 0.8237291627482
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.801318191537506
# Precision: 0.8063673353823572
# Recall: 0.8038966885802007
# F1-Score: 0.8051301166102309
# Predicted Label: Normal-Traffic
# Accuracy: 0.7916775112621663
# Precision: 0.7870180108355777
# Recall: 0.8037154828777293
# F1-Score: 0.7952791125754555
# Predicted Label: Air-Droid
# Accuracy: 0.7863752406509521
# Precision: 0.7942293349984452
# Recall: 0.7843513048954464
# F1-Score: 0.789259413867063
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8144311171863371
# Precision: 0.8066262983931276
# Recall: 0.8172187111112261
# F1-Score: 0.8118879573641767
# Predicted Label: Air-Droid
# Accuracy: 0.8204578516799798
# Precision: 0.8293330336598428
# Recall: 0.8099385117752018
# F1-Score: 0.8195210426472721
# Predicted Label: FamiSafe
# Accuracy: 0.7983944719597599
# Precision: 0.8004772308083111
# Recall: 0.7918016516259442
# F1-Score: 0.796115806640616
# Predicted Label: Air-Droid
# Accuracy: 0.8215904307383175
# Precision: 0.8261580433510268
# Recall: 0.8335442445964187
# F1-Score: 0.8298347085053759
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8118984732809571
# Precision: 0.8085760676952904
# Recall: 0.8171550281179016
# F1-Score: 0.8128429123790718
# Predicted Label: TiSpy
# Accuracy: 0.7913293725950422
# Precision: 0.7885618424028126
# Recall: 0.7796508354002741
# F1-Score: 0.7840810215300786
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7944685880477742
# Precision: 0.8018553325786759
# Recall: 0.7970681356347052
# F1-Score: 0.7994545676428053
# Predicted Label: Eyezy
# Accuracy: 0.7863436009584106
# Precision: 0.7784960410376114
# Recall: 0.7898738998416148
# F1-Score: 0.7841436996693728
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7965004287698333
# Precision: 0.7961084398037146
# Recall: 0.8012004732905117
# F1-Score: 0.7986463401443252
# Predicted Label: kids-360
# Accuracy: 0.8135575616942262
# Precision: 0.8139718565539904
# Recall: 0.8043259152687051
# F1-Score: 0.8091201383641103
# Predicted Label: Qustodio
# Accuracy: 0.7950270457922691
# Precision: 0.7895477303538854
# Recall: 0.8005855591925062
# F1-Score: 0.795028335511239
# Predicted Label: TiSpy
# Accuracy: 0.8100966995085589
# Precision: 0.8098635454686559
# Recall: 0.804675862131538
# F1-Score: 0.8072613695165609
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7985393864335808
# Precision: 0.7967485372440528
# Recall: 0.7882119418695367
# F1-Score: 0.792457250510207
# Predicted Label: Eyezy
# Accuracy: 0.7918098698227582
# Precision: 0.793918503437334
# Recall: 0.7832481258577094
# F1-Score: 0.7885472192357951
# Predicted Label: Air-Droid
# Accuracy: 0.8152435824613439
# Precision: 0.8233134566560416
# Recall: 0.8162942845633661
# F1-Score: 0.8197888460475393
# Predicted Label: Normal-Traffic
# Accuracy: 0.780740195144746
# Precision: 0.7751191022446432
# Recall: 0.7926691832582712
# F1-Score: 0.7837959134986834
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8242415233634176
# Precision: 0.8327348515098216
# Recall: 0.8206228756821696
# F1-Score: 0.8266344993437722
# Predicted Label: Air-Droid
# Accuracy: 0.8191507916215328
# Precision: 0.8138357518681714
# Recall: 0.8130476790118117
# F1-Score: 0.8134415245661972
# Predicted Label: TiSpy
# Accuracy: 0.8053527254309729
# Precision: 0.7996679588033758
# Recall: 0.7950811840301806
# F1-Score: 0.7973679752373997
# Predicted Label: Eyezy
# Accuracy: 0.8145528685254086
# Precision: 0.8093724611137761
# Recall: 0.8032032916042888
# F1-Score: 0.8062760757808666
# Predicted Label: Qustodio
# Accuracy: 0.8238140190162785
# Precision: 0.8241491277296226
# Recall: 0.8135847636802014
# F1-Score: 0.8188328724686084
# Predicted Label: FamiSafe
# Accuracy: 0.8134967461737512
# Precision: 0.804409714265614
# Recall: 0.8255163681171738
# F1-Score: 0.8148263813631892
# Predicted Label: TiSpy
# Accuracy: 0.7862952586747719
# Precision: 0.7826679879746036
# Recall: 0.7745944249236413
# F1-Score: 0.7786102779210214
# Predicted Label: FamiSafe
# Accuracy: 0.8147642351790383
# Precision: 0.823047893854273
# Recall: 0.8245922363513425
# F1-Score: 0.8238193413422896
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7835821651685531
# Precision: 0.776397928141755
# Recall: 0.7917050665873271
# F1-Score: 0.7839767865553086

# %%
#TabNet-XGB-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torch
import joblib
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    tabnet_model = torch.load('Original-TabNet-XGB-model-Dataset-B-1-80-20-Tabnet.h5')
    xgb_model = joblib.load('Original-TabNet-XGB-model-Dataset-B-1-80-20-XGB.pkl')
    label_encoder = joblib.load('Original-TabNet-XGB-Dataset-B-1-80-20-label_encoder.pkl')
    return tabnet_model, xgb_model, label_encoder

def predict_with_model(tabnet_model, xgb_model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')

    tabnet_output = tabnet_model.predict_proba(features_df.values)
    prediction = xgb_model.predict(tabnet_output)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    tabnet_model, xgb_model, label_encoder = load_pretrained_model()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(tabnet_model, xgb_model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)  
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7559851232319842
# Precision: 0.7471130255418845
# Recall: 0.7679613389521831
# F1-Score: 0.757393739726244
# Predicted Label: FamiSafe
# Accuracy: 0.7483415057632383
# Precision: 0.7411520606660766
# Recall: 0.7522598254221373
# F1-Score: 0.74666463413294
# Predicted Label: FamiSafe
# Accuracy: 0.7420824247107837
# Precision: 0.7360981729792523
# Recall: 0.7329745228761986
# F1-Score: 0.7345330270607616
# Predicted Label: Qustodio
# Accuracy: 0.7561083398370498
# Precision: 0.7498193872141683
# Recall: 0.7642765082423
# F1-Score: 0.7569789268858129
# Predicted Label: Air-Droid
# Accuracy: 0.7636792357650382
# Precision: 0.7542309577107689
# Recall: 0.7660665943145486
# F1-Score: 0.760102705329446
# Predicted Label: FamiSafe
# Accuracy: 0.7511239132493557
# Precision: 0.7578315436533987
# Recall: 0.7552137316474902
# F1-Score: 0.7565203730322568
# Predicted Label: TiSpy
# Accuracy: 0.7490826196768064
# Precision: 0.741695364314648
# Recall: 0.7534999096519001
# F1-Score: 0.7475510386248371
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7678329151840381
# Precision: 0.7672868304054249
# Recall: 0.7710665092177804
# F1-Score: 0.7691720265441696
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7653355744860084
# Precision: 0.7562976149638673
# Recall: 0.7540372724376913
# F1-Score: 0.7551657523049246
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7797292237943696
# Precision: 0.7769365856599229
# Recall: 0.7694878117836953
# F1-Score: 0.7731942591987548
# Predicted Label: mLite
# Accuracy: 0.7655831180119956
# Precision: 0.7738905247073656
# Recall: 0.762714008746504
# F1-Score: 0.7682616204492805
# Predicted Label: Air-Droid
# Accuracy: 0.7492860842906217
# Precision: 0.7485988592972208
# Recall: 0.7566603873920587
# F1-Score: 0.7526080362873383
# Predicted Label: mLite
# Accuracy: 0.7465200602302026
# Precision: 0.7386339636576008
# Recall: 0.7346441368112927
# F1-Score: 0.7366336477519628
# Predicted Label: FamiSafe
# Accuracy: 0.7421613363250977
# Precision: 0.7377560044244018
# Recall: 0.7446413081901195
# F1-Score: 0.7411826661919445
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7463878596414116
# Precision: 0.7480691511361076
# Recall: 0.7396429432713831
# F1-Score: 0.7438321847308763
# Predicted Label: TiSpy
# Accuracy: 0.763301474118212
# Precision: 0.7636016205070538
# Recall: 0.7623773625423824
# F1-Score: 0.7629890004276648
# Predicted Label: mLite
# Accuracy: 0.7604478290593779
# Precision: 0.7569943732865434
# Recall: 0.759106074866776
# F1-Score: 0.7580487534341408
# Predicted Label: Normal-Traffic
# Accuracy: 0.7552958823051666
# Precision: 0.74982783709336
# Recall: 0.7535176288142207
# F1-Score: 0.7516682048651866
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7748397253244521
# Precision: 0.7734145492035736
# Recall: 0.7730217069807561
# F1-Score: 0.7732180781951803
# Predicted Label: FamiSafe
# Accuracy: 0.7489723866988793
# Precision: 0.7437474147841432
# Recall: 0.7381745981128754
# F1-Score: 0.7409505280679396
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7649511236117228
# Precision: 0.7628181210551718
# Recall: 0.7748385829938788
# F1-Score: 0.7687813677058412
# Predicted Label: FamiSafe
# Accuracy: 0.7642464943865497
# Precision: 0.7630522087200147
# Recall: 0.7719726293092773
# F1-Score: 0.7674864995957812
# Predicted Label: TiSpy
# Accuracy: 0.7481054504491768
# Precision: 0.7541170897769941
# Recall: 0.7463023810447161
# F1-Score: 0.7501893845443948
# Predicted Label: kids-360
# Accuracy: 0.763073460100966
# Precision: 0.7592084426656497
# Recall: 0.7728491361020462
# F1-Score: 0.7659680643432213
# Predicted Label: kids-360
# Accuracy: 0.7798270148357951
# Precision: 0.7712965127335725
# Recall: 0.7754142413081381
# F1-Score: 0.7733498958122422
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7457822464693964
# Precision: 0.7463501339668075
# Recall: 0.7460233688009902
# F1-Score: 0.7461867156101889
# Predicted Label: Air-Droid
# Accuracy: 0.7656786481205816
# Precision: 0.7646768694853845
# Recall: 0.7765542014624089
# F1-Score: 0.7705697697812788
# Predicted Label: TiSpy
# Accuracy: 0.7510112216042063
# Precision: 0.7482445176814623
# Recall: 0.7622416694052568
# F1-Score: 0.7551782401676538
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7729223678156291
# Precision: 0.7689686899704549
# Recall: 0.7840595162156101
# F1-Score: 0.7764407840651313
# Predicted Label: FamiSafe
# Accuracy: 0.7546762612646032
# Precision: 0.7568638012042603
# Recall: 0.7535710616737591
# F1-Score: 0.7552138423621545
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7689316287879681
# Precision: 0.7635927720927866
# Recall: 0.7636192635391967
# F1-Score: 0.7636060175862276
# Predicted Label: Qustodio
# Accuracy: 0.7520289548488837
# Precision: 0.7522662050435198
# Recall: 0.7629664726317982
# F1-Score: 0.7575785572717821
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7751047644375193
# Precision: 0.7761632073640905
# Recall: 0.7827177160239517
# F1-Score: 0.779426682070726
# Predicted Label: kids-360
# Accuracy: 0.7660135684352202
# Precision: 0.7604945788604066
# Recall: 0.7647292748806139
# F1-Score: 0.7626060481759371
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7521514901741033
# Precision: 0.7499951426052724
# Recall: 0.7620334089317037
# F1-Score: 0.7559663534405668
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7701867692904276
# Precision: 0.7700306560006329
# Recall: 0.7654797295839885
# F1-Score: 0.7677484488030012
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.752149212969011
# Precision: 0.7609130474094561
# Recall: 0.7407281577711117
# F1-Score: 0.7506849410992743
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7728185550838529
# Precision: 0.7629373082941255
# Recall: 0.7611653515906103
# F1-Score: 0.7620502998836186
# Predicted Label: Eyezy
# Accuracy: 0.747774776326209
# Precision: 0.7459999885499499
# Recall: 0.7573852302268415
# F1-Score: 0.7516494987716281
# Predicted Label: FamiSafe
# Accuracy: 0.748755762854429
# Precision: 0.7462547251697599
# Recall: 0.753425872318186
# F1-Score: 0.7498231533093016
# Predicted Label: mLite
# Accuracy: 0.7503077943165886
# Precision: 0.7594993128829416
# Recall: 0.756993393646141
# F1-Score: 0.7582442828189684
# Predicted Label: TiSpy
# Accuracy: 0.7515426403626789
# Precision: 0.7487198203331936
# Recall: 0.7453327329255909
# F1-Score: 0.7470224372861638
# Predicted Label: Air-Droid
# Accuracy: 0.778286954777318
# Precision: 0.7753020961664175
# Recall: 0.787940354650547
# F1-Score: 0.781570137499045
# Predicted Label: FamiSafe
# Accuracy: 0.7734325532755981
# Precision: 0.7820310209491769
# Recall: 0.7791454201797647
# F1-Score: 0.7805855537641077
# Predicted Label: Normal-Traffic
# Accuracy: 0.7619619021488819
# Precision: 0.7645565284157809
# Recall: 0.752872802888618
# F1-Score: 0.7586696851580907
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7526979207201382
# Precision: 0.7577505180493458
# Recall: 0.7523823552322813
# F1-Score: 0.755056895370459
# Predicted Label: Eyezy
# Accuracy: 0.7664665344093092
# Precision: 0.7693932447027424
# Recall: 0.7743626787674307
# F1-Score: 0.7718699632961662
# Predicted Label: Eyezy
# Accuracy: 0.7786504390226272
# Precision: 0.785776245286538
# Recall: 0.7867514028352253
# F1-Score: 0.7862635217030038
# Predicted Label: kids-360
# Accuracy: 0.7434645082324878
# Precision: 0.7457192325637803
# Recall: 0.73633895715998
# F1-Score: 0.7409994099388247
# Predicted Label: TiSpy
# Accuracy: 0.7536880904781982
# Precision: 0.7555427137350595
# Recall: 0.7576589554832256
# F1-Score: 0.7565993548066722
# Predicted Label: FamiSafe
# Accuracy: 0.7419656111922256
# Precision: 0.7514992304273662
# Recall: 0.753337344690342
# F1-Score: 0.7524171649572043
# Predicted Label: TiSpy
# Accuracy: 0.7557120405155547
# Precision: 0.7634215403861746
# Recall: 0.7660902760925539
# F1-Score: 0.7647535799963936
# Predicted Label: Eyezy
# Accuracy: 0.7418383770119626
# Precision: 0.7505345226735097
# Recall: 0.7449273791641668
# F1-Score: 0.7477204390969403
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7511351780921858
# Precision: 0.7540858181371423
# Recall: 0.7481727162292586
# F1-Score: 0.7511176297807917
# Predicted Label: TiSpy
# Accuracy: 0.7695500365223428
# Precision: 0.7617697160477289
# Recall: 0.7599754435016668
# F1-Score: 0.7608715219714418
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7605414719323769
# Precision: 0.7658681250742027
# Recall: 0.7536395705547118
# F1-Score: 0.7597046418953078
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7718908441880056
# Precision: 0.7708175013385759
# Recall: 0.7700286119676529
# F1-Score: 0.770422854703538
# Predicted Label: kids-360
# Accuracy: 0.7572538229372278
# Precision: 0.759021479053645
# Recall: 0.761815469822541
# F1-Score: 0.7604159079616464
# Predicted Label: Air-Droid
# Accuracy: 0.7618699547465978
# Precision: 0.7605536440364509
# Recall: 0.7707985949914624
# F1-Score: 0.7656418494690266
# Predicted Label: mLite
# Accuracy: 0.7791704549826153
# Precision: 0.7826064554353692
# Recall: 0.7901734658059288
# F1-Score: 0.7863717572963395
# Predicted Label: Qustodio
# Accuracy: 0.7553402258031617
# Precision: 0.7518696154875788
# Recall: 0.7505771385313931
# F1-Score: 0.751222821084067
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7644445079143465
# Precision: 0.7645342472483426
# Recall: 0.7682354441365318
# F1-Score: 0.7663803770307452
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7464720612669834
# Precision: 0.7403435236399242
# Recall: 0.7483697508739799
# F1-Score: 0.7443350010141928
# Predicted Label: mLite
# Accuracy: 0.7703419073407598
# Precision: 0.7634606162507802
# Recall: 0.7720652762774657
# F1-Score: 0.7677388372033331
# Predicted Label: Qustodio
# Accuracy: 0.7756873132773695
# Precision: 0.7693726426762637
# Recall: 0.7638778866156108
# F1-Score: 0.7666154187846155
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7712958182545793
# Precision: 0.7652264445183475
# Recall: 0.767815855615169
# F1-Score: 0.7665189632223941
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7658929811681496
# Precision: 0.769994798396273
# Recall: 0.777387175175331
# F1-Score: 0.7736733288204849
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7647111287862594
# Precision: 0.7581918178695067
# Recall: 0.7575596035122372
# F1-Score: 0.7578755788437274
# Predicted Label: kids-360
# Accuracy: 0.7408588241573765
# Precision: 0.7390699880811358
# Recall: 0.7430673566715871
# F1-Score: 0.7410632818652511
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7477366590621505
# Precision: 0.7518604477591609
# Recall: 0.7492061478931413
# F1-Score: 0.7505309510589259
# Predicted Label: Normal-Traffic
# Accuracy: 0.7728239259624999
# Precision: 0.7687117625840318
# Recall: 0.7632751658702519
# F1-Score: 0.7659838177401911
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7531816575839314
# Precision: 0.7518272394232715
# Recall: 0.7529959940328811
# F1-Score: 0.7524111628583767
# Predicted Label: kids-360
# Accuracy: 0.7676125659041744
# Precision: 0.7759045276313477
# Recall: 0.7630836776479855
# F1-Score: 0.7694406993082661
# Predicted Label: mLite
# Accuracy: 0.7520966167288031
# Precision: 0.7432749052621228
# Recall: 0.7565703418582894
# F1-Score: 0.7498636946024947
# Predicted Label: mLite
# Accuracy: 0.7724931911854128
# Precision: 0.7650707022149006
# Recall: 0.7734917592060704
# F1-Score: 0.7692581851069995
# Predicted Label: Eyezy
# Accuracy: 0.7610116461055568
# Precision: 0.7604782953559762
# Recall: 0.7509431553859415
# F1-Score: 0.755680648090329
# Predicted Label: kids-360
# Accuracy: 0.7635058334558616
# Precision: 0.7694220300753565
# Recall: 0.7598658631920558
# F1-Score: 0.7646140894936924
# Predicted Label: Normal-Traffic
# Accuracy: 0.770078057271831
# Precision: 0.7719520458693699
# Recall: 0.7815464521793799
# F1-Score: 0.7767196214989678
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7643738120768617
# Precision: 0.7550538813307549
# Recall: 0.757200067514238
# F1-Score: 0.7561254514920595
# Predicted Label: kids-360
# Accuracy: 0.7672289268478099
# Precision: 0.7649459511978415
# Recall: 0.7780912614509929
# F1-Score: 0.7714626131246956
# Predicted Label: FamiSafe
# Accuracy: 0.7716847829514977
# Precision: 0.7672230998607377
# Recall: 0.7639304426765811
# F1-Score: 0.7655732309341888
# Predicted Label: mLite
# Accuracy: 0.7605774366100294
# Precision: 0.7543039993103213
# Recall: 0.7517197176002908
# F1-Score: 0.7530096411887777
# Predicted Label: Normal-Traffic
# Accuracy: 0.7404504770863747
# Precision: 0.7351793781123023
# Recall: 0.7503661065230025
# F1-Score: 0.742695115371118
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.742729115029703
# Precision: 0.7474579910557827
# Recall: 0.7496171096640346
# F1-Score: 0.7485359933928727
# Predicted Label: kids-360
# Accuracy: 0.740664467213498
# Precision: 0.7454318502062856
# Recall: 0.7304396582981866
# F1-Score: 0.7378596074410422
# Predicted Label: Air-Droid
# Accuracy: 0.7706684932537003
# Precision: 0.7702661225322726
# Recall: 0.7741613258732007
# F1-Score: 0.77220881215294
# Predicted Label: Air-Droid
# Accuracy: 0.7700154634105074
# Precision: 0.7696009706763616
# Recall: 0.7769298602344338
# F1-Score: 0.7732480499360427
# Predicted Label: mLite
# Accuracy: 0.7729296164806881
# Precision: 0.7632926275001707
# Recall: 0.7647466334235645
# F1-Score: 0.764018938682121
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7678999980380702
# Precision: 0.7753569095573688
# Recall: 0.7720694297465066
# F1-Score: 0.773709677555664
# Predicted Label: Air-Droid
# Accuracy: 0.7450299002720852
# Precision: 0.743719866336855
# Recall: 0.7365153626875179
# F1-Score: 0.7401000818687878
# Predicted Label: Eyezy
# Accuracy: 0.7590424265963029
# Precision: 0.7676497905256507
# Recall: 0.7515216309407489
# F1-Score: 0.7595000990872984
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7737504257086953
# Precision: 0.7815150149167822
# Recall: 0.7696828610009602
# F1-Score: 0.7755538115863879
# Predicted Label: kids-360
# Accuracy: 0.765521818907948
# Precision: 0.7681927435484426
# Recall: 0.7638046049490427
# F1-Score: 0.7659923897207745
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7444701621285982
# Precision: 0.753316752017511
# Recall: 0.7480582095670996
# F1-Score: 0.7506782718107349
# Predicted Label: FamiSafe
# Accuracy: 0.7650745614032934
# Precision: 0.7699033920936438
# Recall: 0.7609248325611857
# F1-Score: 0.7653877819625903
# Predicted Label: Qustodio
# Accuracy: 0.758133895428944
# Precision: 0.7599347724962529
# Recall: 0.7504748606255809
# F1-Score: 0.7551751921694146
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7706014685427168
# Precision: 0.7771287432699938
# Recall: 0.7689728646192033
# F1-Score: 0.7730292923064802
# Predicted Label: FamiSafe
# Accuracy: 0.7490462827520419
# Precision: 0.7455526283014366
# Recall: 0.757930009072769
# F1-Score: 0.7516903704583204
# Predicted Label: TiSpy
# Accuracy: 0.7495284331012813
# Precision: 0.7533913180486341
# Recall: 0.7570402266570517
# F1-Score: 0.7552113648263716
# Predicted Label: TiSpy
# Accuracy: 0.7484102236855069
# Precision: 0.7460447795839882
# Recall: 0.7579012574356881
# F1-Score: 0.7519262827681336
# Predicted Label: Normal-Traffic
# Accuracy: 0.7794177634064924
# Precision: 0.7743965920208441
# Recall: 0.7761396625253629
# F1-Score: 0.7752671475169789
# Predicted Label: mLite
# Accuracy: 0.7607989578017736
# Precision: 0.7527630559611712
# Recall: 0.7703975092259824
# F1-Score: 0.7614782007943705
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7462611797841031
# Precision: 0.7386967768537521
# Recall: 0.734969959434093
# F1-Score: 0.736828655691732
# Predicted Label: Normal-Traffic
# Accuracy: 0.7630582938772781
# Precision: 0.7559823705995671
# Recall: 0.7580687893718923
# F1-Score: 0.7570241424044217
# Predicted Label: Normal-Traffic
# Accuracy: 0.7719037953709637
# Precision: 0.7763921532922801
# Recall: 0.7621423967654005
# F1-Score: 0.7692012851032102
# Predicted Label: kids-360
# Accuracy: 0.7438608183564567
# Precision: 0.7356478449582832
# Recall: 0.7357229095152215
# F1-Score: 0.7356853753219774
# Predicted Label: Eyezy
# Accuracy: 0.7537455495539107
# Precision: 0.7460718998850363
# Recall: 0.7419152630627536
# F1-Score: 0.743987775768677
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7429791613171478
# Precision: 0.7510256302635587
# Recall: 0.735822268123075
# F1-Score: 0.7433462202539192
# Predicted Label: Normal-Traffic
# Accuracy: 0.7596569498102175
# Precision: 0.7691622252553673
# Recall: 0.7577880933963698
# F1-Score: 0.7634327968226602
# Predicted Label: TiSpy
# Accuracy: 0.7661975820855172
# Precision: 0.7757293856142131
# Recall: 0.7777989251314656
# F1-Score: 0.7767627768997907
# Predicted Label: Qustodio
# Accuracy: 0.770087741917627
# Precision: 0.7658117679901727
# Recall: 0.7675795181240463
# F1-Score: 0.7666946240932729
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7466644827471448
# Precision: 0.7518141137262229
# Recall: 0.7441225162367476
# F1-Score: 0.7479485411920228
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7493967798108812
# Precision: 0.753461889930121
# Recall: 0.7486798064762614
# F1-Score: 0.7510632362973988
# Predicted Label: FamiSafe
# Accuracy: 0.7448671167603731
# Precision: 0.7442711034751041
# Recall: 0.7488028179429774
# F1-Score: 0.7465300834755282
# Predicted Label: FamiSafe
# Accuracy: 0.7572046790135171
# Precision: 0.7508191949525385
# Recall: 0.7539347720220387
# F1-Score: 0.752373758102711
# Predicted Label: FamiSafe
# Accuracy: 0.7789328497980429
# Precision: 0.7871340493618737
# Recall: 0.7815556663416762
# F1-Score: 0.7843349392691489
# Predicted Label: Eyezy
# Accuracy: 0.7785260838116331
# Precision: 0.7835960143672618
# Recall: 0.7850046894204846
# F1-Score: 0.7842997193666149
# Predicted Label: Qustodio
# Accuracy: 0.7606779737167276
# Precision: 0.7706318447480944
# Recall: 0.7561720934262767
# F1-Score: 0.7633334978175415
# Predicted Label: Normal-Traffic
# Accuracy: 0.7720434035748305
# Precision: 0.7637370565195476
# Recall: 0.7761567479425375
# F1-Score: 0.7698968180191978
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7793230828223189
# Precision: 0.7730350735766345
# Recall: 0.7812450914601734
# F1-Score: 0.7771183990422957
