# %%
#CNN-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-CNN-Dataset-A-80-20.h5')
    with open('Scaler-Original-CNN-Dataset-A-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-CNN-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    prediction = model.predict(features_df)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label


def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection" 
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}") 
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.743120009076779
# Precision: 0.7451720704681213
# Recall: 0.7437459378723289
# F1-Score: 0.7444583211728508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.747381585425477
# Precision: 0.7563153178372957
# Recall: 0.7449498088781196
# F1-Score: 0.7505895413785774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7421074410828917
# Precision: 0.7369817035166785
# Recall: 0.7575688372297401
# F1-Score: 0.7471334785558821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7424159552737025
# Precision: 0.7422344335776432
# Recall: 0.7586652762063517
# F1-Score: 0.7503599179735846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7320580407243356
# Precision: 0.7233697637878516
# Recall: 0.7149296369636045
# F1-Score: 0.7191249364980639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7442396372064751
# Precision: 0.7372574911326671
# Recall: 0.7300342359480857
# F1-Score: 0.7336280840441458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.731246920364302
# Precision: 0.7232564737658342
# Recall: 0.7293553173566192
# F1-Score: 0.7262930924525874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.734543634816237
# Precision: 0.7312644229917894
# Recall: 0.7386188198892377
# F1-Score: 0.7349232229881238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7392934003193254
# Precision: 0.7431975739514343
# Recall: 0.7253984893277216
# F1-Score: 0.7341901710026867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.738344872483199
# Precision: 0.740557188929328
# Recall: 0.735707544058617
# F1-Score: 0.7381244007630143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7418742250822312
# Precision: 0.7493399281492056
# Recall: 0.7489933363435464
# F1-Score: 0.7491665921598738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7333550128298945
# Precision: 0.7300379361190719
# Recall: 0.7369202888890583
# F1-Score: 0.7334629679476479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7305588367708751
# Precision: 0.7239958278785794
# Recall: 0.7173128101026043
# F1-Score: 0.7206388251798226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.731564946053511
# Precision: 0.7286045802021961
# Recall: 0.7132674897729147
# F1-Score: 0.720854465218734
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7484506274576451
# Precision: 0.7541604204995208
# Recall: 0.7676619911994346
# F1-Score: 0.7608513130492524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7385019815271602
# Precision: 0.7382674244427772
# Recall: 0.7258722505683135
# F1-Score: 0.732017369719172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7446901081501511
# Precision: 0.7415944838749068
# Recall: 0.7645428208886217
# F1-Score: 0.7528938256345515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7487223984254506
# Precision: 0.7440825030462431
# Recall: 0.7399124320240866
# F1-Score: 0.7419916085217954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7418230702863936
# Precision: 0.737577396154328
# Recall: 0.7397216671687705
# F1-Score: 0.7386479754775992
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7462293476573343
# Precision: 0.7375211477535839
# Recall: 0.7410344899530579
# F1-Score: 0.7392736446534816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7367544188494928
# Precision: 0.7373485641471489
# Recall: 0.751659016000277
# F1-Score: 0.7444350231194774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7323052236534048
# Precision: 0.7347495759238719
# Recall: 0.7132806279010198
# F1-Score: 0.7238559492483678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7305862147548381
# Precision: 0.7251378409276147
# Recall: 0.7397544501368163
# F1-Score: 0.7323732236982766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7429064093138097
# Precision: 0.7477086060273291
# Recall: 0.7542645162629203
# F1-Score: 0.7509722533128542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7301951086390079
# Precision: 0.7290122186705947
# Recall: 0.7391050464952481
# F1-Score: 0.7340239401316045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7486753435309367
# Precision: 0.7483862988544858
# Recall: 0.7503577253363791
# F1-Score: 0.7493707155023149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7387863698557636
# Precision: 0.7329488207631104
# Recall: 0.7518709337334557
# F1-Score: 0.7422893082842125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7375893435241131
# Precision: 0.7430919738960341
# Recall: 0.7521508272333902
# F1-Score: 0.7475939592609568
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.744591992033292
# Precision: 0.7424531744270324
# Recall: 0.7333262897702258
# F1-Score: 0.7378615097166408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7450537926520276
# Precision: 0.7505187141396528
# Recall: 0.7639150572025399
# F1-Score: 0.7571576351410123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7475354450637356
# Precision: 0.7431143918567976
# Recall: 0.7426131131289846
# F1-Score: 0.7428636679281366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7368675969874932
# Precision: 0.7354290051950356
# Recall: 0.7209927630428511
# F1-Score: 0.7281393371632395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7407903047061445
# Precision: 0.7434829249539053
# Recall: 0.7285378067129095
# F1-Score: 0.7359344985054438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7443018996264881
# Precision: 0.7479212187142743
# Recall: 0.7325023673518158
# F1-Score: 0.7401314981162472
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7431237234389408
# Precision: 0.7420705631959322
# Recall: 0.7577078173488491
# F1-Score: 0.7498076703223051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.730439141378353
# Precision: 0.7362349341849411
# Recall: 0.7162622039239577
# F1-Score: 0.7261112503831723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7347134121653861
# Precision: 0.740042813626679
# Recall: 0.7294044295975984
# F1-Score: 0.7346851121606182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7491854349181095
# Precision: 0.7518427490574157
# Recall: 0.7481522061268466
# F1-Score: 0.7499929375411545
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7482001690548561
# Precision: 0.7413492207452144
# Recall: 0.7635742713186148
# F1-Score: 0.752297633744614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.73183151428507
# Precision: 0.7230220095024428
# Recall: 0.7193184719670027
# F1-Score: 0.721165485896856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7357093049908194
# Precision: 0.7264051399392022
# Recall: 0.7433994782977484
# F1-Score: 0.7348040622043408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7406129153816818
# Precision: 0.7411788451075286
# Recall: 0.7326212528976969
# F1-Score: 0.7368752042544923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7325112985722337
# Precision: 0.7320492082379082
# Recall: 0.7154954359687569
# F1-Score: 0.7236776696249321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7317296968483662
# Precision: 0.7383917086365629
# Recall: 0.7342078019897907
# F1-Score: 0.7362938117165972
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.740915346092244
# Precision: 0.7415047828907546
# Recall: 0.7608813874066271
# F1-Score: 0.7510681329859289
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7328179140465111
# Precision: 0.7376457697752061
# Recall: 0.7257808023501335
# F1-Score: 0.7316651874922737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7350160470154177
# Precision: 0.7439938471386156
# Recall: 0.7407126105575985
# F1-Score: 0.7423496030426676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7397631581022531
# Precision: 0.7343971233603669
# Recall: 0.7572843370280797
# F1-Score: 0.745665148287703
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7356928437010805
# Precision: 0.7444178671058268
# Recall: 0.7313179075986074
# F1-Score: 0.7378097438342404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7308184214813613
# Precision: 0.7286448710397174
# Recall: 0.7259949248737126
# F1-Score: 0.7273174842269716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7363184927756918
# Precision: 0.7449928804405717
# Recall: 0.742091782711955
# F1-Score: 0.7435395017548552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7458538089614842
# Precision: 0.7377237411320761
# Recall: 0.7535610204772956
# F1-Score: 0.7455582857265641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7346168316092244
# Precision: 0.7252383032302423
# Recall: 0.7320811031653809
# F1-Score: 0.7286436381160091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7432276654278368
# Precision: 0.7441525059868921
# Recall: 0.7244065371689631
# F1-Score: 0.7341467712855999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7401873088875933
# Precision: 0.7405311675341819
# Recall: 0.7578041467885773
# F1-Score: 0.7490680947305035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7325317482758511
# Precision: 0.7420735658808654
# Recall: 0.7298843853670861
# F1-Score: 0.7359285067496878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.745071716212531
# Precision: 0.7370290754560842
# Recall: 0.7605879264763863
# F1-Score: 0.7486232000980291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7462183464165593
# Precision: 0.7395340771122372
# Recall: 0.7396946027145145
# F1-Score: 0.7396143312032726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7495111814452993
# Precision: 0.7429924383412249
# Recall: 0.7368814420840986
# F1-Score: 0.739924322828252
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7464561589587259
# Precision: 0.7510543809831115
# Recall: 0.7378491521058003
# F1-Score: 0.7443932073208975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7357715403078273
# Precision: 0.732156380883821
# Recall: 0.7213287559389451
# F1-Score: 0.7267022386347045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7405809957430154
# Precision: 0.7341885616135367
# Recall: 0.7492948034778006
# F1-Score: 0.7416647694677633
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7482567412908654
# Precision: 0.7418714335822157
# Recall: 0.7357072241395687
# F1-Score: 0.7387764708387984
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7406538907531043
# Precision: 0.7435006480098603
# Recall: 0.7594878691077108
# F1-Score: 0.7514092308837498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7453144612550727
# Precision: 0.7359952270608534
# Recall: 0.7476786689207527
# F1-Score: 0.7417909463680532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7481151671756828
# Precision: 0.7553936649003056
# Recall: 0.7325228577995859
# F1-Score: 0.7437824874374116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7474714608383047
# Precision: 0.7425394819432347
# Recall: 0.7506388348542941
# F1-Score: 0.746567191994337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7351629740142923
# Precision: 0.7285729673198493
# Recall: 0.753303748636973
# F1-Score: 0.7407319941365444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7436732808554047
# Precision: 0.7398841115912093
# Recall: 0.755388454742608
# F1-Score: 0.7475559016157558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7470999068705095
# Precision: 0.7487568534895155
# Recall: 0.7492756513776182
# F1-Score: 0.7490161625986508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7452931180138386
# Precision: 0.7444586217071998
# Recall: 0.7649157044119638
# F1-Score: 0.7545485320303045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7381203261401399
# Precision: 0.7349841647196041
# Recall: 0.7244854802132027
# F1-Score: 0.7296970613602551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7495832158198185
# Precision: 0.7569735496257565
# Recall: 0.7491654999242634
# F1-Score: 0.7530492857273074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7313026801175464
# Precision: 0.7375768881201245
# Recall: 0.7211655897183762
# F1-Score: 0.7292789228595883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7341788696348504
# Precision: 0.7427382881675588
# Recall: 0.7392737564694225
# F1-Score: 0.7410019727630466
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7404845610349304
# Precision: 0.7397912847907472
# Recall: 0.7339303026324863
# F1-Score: 0.736849139165686
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7394881355248393
# Precision: 0.7442695471834118
# Recall: 0.745469072967837
# F1-Score: 0.7448688271512751
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7404894355977356
# Precision: 0.7337493939096
# Recall: 0.7557802002982775
# F1-Score: 0.7446018743825565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7358150552799153
# Precision: 0.7412553816781293
# Recall: 0.7304920693619791
# F1-Score: 0.735834367921054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7490348012306648
# Precision: 0.7572792956794404
# Recall: 0.7427108394997785
# F1-Score: 0.7499243204858516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7362774767785507
# Precision: 0.7409694877818653
# Recall: 0.7557685445175361
# F1-Score: 0.7482958530190995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7464433398720803
# Precision: 0.7432206243587024
# Recall: 0.7620958892982349
# F1-Score: 0.7525399177206116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7303604751365683
# Precision: 0.7299359204732794
# Recall: 0.7474553823599092
# F1-Score: 0.7385917752315211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7348319814587562
# Precision: 0.7408318086066658
# Recall: 0.7498607510486434
# F1-Score: 0.7453189362278316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7413565534635546
# Precision: 0.7477820017368875
# Recall: 0.7447951357243227
# F1-Score: 0.7462855801518733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7400270558001327
# Precision: 0.7307364043188355
# Recall: 0.7357319990071988
# F1-Score: 0.7332256927970117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7483227302235436
# Precision: 0.7547536478206148
# Recall: 0.7607822531073692
# F1-Score: 0.7577559599589564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7451387991956143
# Precision: 0.7505163498403001
# Recall: 0.7468260514662144
# F1-Score: 0.74866665316229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7402787112975217
# Precision: 0.7476226227073378
# Recall: 0.7567747511591434
# F1-Score: 0.7521708480601298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7313123349455805
# Precision: 0.7239954425778589
# Recall: 0.7509082901881166
# F1-Score: 0.7372063244705219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7394617570473694
# Precision: 0.737252666756924
# Recall: 0.7381776045645781
# F1-Score: 0.7377148457419509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7300105824714817
# Precision: 0.7278135486721619
# Recall: 0.7360468318720168
# F1-Score: 0.7319070367824703
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7393970691105785
# Precision: 0.7470765162589806
# Recall: 0.7583239298795535
# F1-Score: 0.7526582062379726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7418389479958418
# Precision: 0.7398047182121452
# Recall: 0.7606133819459269
# F1-Score: 0.7500647568029352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.742373287179434
# Precision: 0.7386347698628757
# Recall: 0.7532463349918364
# F1-Score: 0.7458689991933807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7472267363412244
# Precision: 0.7489455626829287
# Recall: 0.7404044464326262
# F1-Score: 0.7446505137845023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7356918134937938
# Precision: 0.7273119065012806
# Recall: 0.725287289164541
# F1-Score: 0.7262981868878365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7360676200518538
# Precision: 0.7357380647538059
# Recall: 0.7261410805465609
# F1-Score: 0.7309080713779441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7313117663158927
# Precision: 0.7255203635939336
# Recall: 0.7277990533849504
# F1-Score: 0.7266579220868442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7430211870747567
# Precision: 0.7332402947812591
# Recall: 0.7411863303344384
# F1-Score: 0.7371919010206665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7476522003250899
# Precision: 0.753370189711545
# Recall: 0.7543429959571953
# F1-Score: 0.7538562789974945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7305662456462657
# Precision: 0.739604025747813
# Recall: 0.7194611913337722
# F1-Score: 0.7293935695953495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.746020932320036
# Precision: 0.7381734938586269
# Recall: 0.740444577985141
# F1-Score: 0.739307291785515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7495043120540422
# Precision: 0.7453564667333905
# Recall: 0.7530206826680698
# F1-Score: 0.7491689734254715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7400345576912041
# Precision: 0.7433626057778913
# Recall: 0.7327075024403001
# F1-Score: 0.7379965968479865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7487567374070134
# Precision: 0.7441970639592244
# Recall: 0.7646602917702843
# F1-Score: 0.7542899160093486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7392836734470967
# Precision: 0.7382613805616679
# Recall: 0.7419196190681282
# F1-Score: 0.7400859791822951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7432875688398787
# Precision: 0.7440556373671453
# Recall: 0.7370408724582379
# F1-Score: 0.7405316432582852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7438590415555237
# Precision: 0.7442286585684609
# Recall: 0.75972131020236
# F1-Score: 0.7518951870983885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7308113129762756
# Precision: 0.7239813756909197
# Recall: 0.7174504098927614
# F1-Score: 0.7207010972549711
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7331587090764814
# Precision: 0.7361993158142742
# Recall: 0.7460056947000588
# F1-Score: 0.7410700653901545
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7398520719616684
# Precision: 0.7496487812670323
# Recall: 0.7239774351481596
# F1-Score: 0.7365895040112895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7343650457277924
# Precision: 0.7249045875627993
# Recall: 0.7411002043246852
# F1-Score: 0.7329129357988132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7334350689898675
# Precision: 0.7286034995246737
# Recall: 0.7239043811026952
# F1-Score: 0.7262463390764594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7441922329568563
# Precision: 0.7390499086538012
# Recall: 0.7583765499643121
# F1-Score: 0.7485885089723099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.742305303484329
# Precision: 0.7420132422168256
# Recall: 0.7286281140769054
# F1-Score: 0.7352597653843639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7367228462084363
# Precision: 0.7318080476411416
# Recall: 0.7466321028860502
# F1-Score: 0.73914575618689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7408938178794177
# Precision: 0.7370992561620959
# Recall: 0.7257160916558412
# F1-Score: 0.731363383823289
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7422430486291571
# Precision: 0.7496237024516181
# Recall: 0.7434850092942543
# F1-Score: 0.746541736713533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7302298032396097
# Precision: 0.7268702151004927
# Recall: 0.7350213660234017
# F1-Score: 0.7309230661471459

# %%
#CNN-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-CNN-Dataset-B-80-20.h5')
    with open('Scaler-Original-CNN-Dataset-B-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-CNN-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    prediction = model.predict(features_df)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label


def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}") 
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7013665868715504
# Precision: 0.6978450864928467
# Recall: 0.7109983135181823
# F1-Score: 0.7043602995045154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.707647491482414
# Precision: 0.7079559584910113
# Recall: 0.7131310250697165
# F1-Score: 0.7105340689531887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7341121326020514
# Precision: 0.7299903058207503
# Recall: 0.7339254227193307
# F1-Score: 0.7319525753231757
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7330931180084095
# Precision: 0.7245284434068658
# Recall: 0.7461227808476768
# F1-Score: 0.7351670716787213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7113806796070772
# Precision: 0.7185765153063143
# Recall: 0.7124732906665519
# F1-Score: 0.7155118882923086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7041172447244186
# Precision: 0.7038015043236693
# Recall: 0.7173501288396311
# F1-Score: 0.7105112333162228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7155813423096262
# Precision: 0.710427779850574
# Recall: 0.695998662278986
# F1-Score: 0.7031392038863276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7056677386309684
# Precision: 0.7148258588381706
# Recall: 0.6893443176388829
# F1-Score: 0.7018538808846146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7145882061722285
# Precision: 0.7228161980020569
# Recall: 0.7233581759471045
# F1-Score: 0.7230870854169476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7272813536033329
# Precision: 0.723087372463399
# Recall: 0.7279949828015655
# F1-Score: 0.7255328787791664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.73235895853414
# Precision: 0.727685854811848
# Recall: 0.7232518314381411
# F1-Score: 0.7254620680017536
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7129427388884769
# Precision: 0.7213285521143983
# Recall: 0.7065900825863708
# F1-Score: 0.713883254723723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7068594160277625
# Precision: 0.7013870178919295
# Recall: 0.7170729639389432
# F1-Score: 0.7091432599161337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7255407725212712
# Precision: 0.7279045825993498
# Recall: 0.7270981214165964
# F1-Score: 0.7275011285102306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7137934635911394
# Precision: 0.7074317406885686
# Recall: 0.7216160686664915
# F1-Score: 0.7144535098457869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7182641548361818
# Precision: 0.7102732513500571
# Recall: 0.6986181798298295
# F1-Score: 0.7043975072294071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7312565167350875
# Precision: 0.7243560554706865
# Recall: 0.7167116538996462
# F1-Score: 0.7205135791370435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7009225462074153
# Precision: 0.7003868629633369
# Recall: 0.6879795756630768
# F1-Score: 0.6941277797787049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.708402562417989
# Precision: 0.6999093004835656
# Recall: 0.6994555462640699
# F1-Score: 0.6996823498072665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7369196803512832
# Precision: 0.7376696294867808
# Recall: 0.7201052772534849
# F1-Score: 0.7287816392050144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7357799119230605
# Precision: 0.7319153835295218
# Recall: 0.7450623386270012
# F1-Score: 0.7384303488794172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7078773661648222
# Precision: 0.7086605293340483
# Recall: 0.7251451987548375
# F1-Score: 0.7168081007440219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7290951696150784
# Precision: 0.7214567315251517
# Recall: 0.7310385674030045
# F1-Score: 0.7262160446875058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7331622162183007
# Precision: 0.7291446305764764
# Recall: 0.7312652923881959
# F1-Score: 0.7302034217754193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.70964847734871
# Precision: 0.7182692091586851
# Recall: 0.7188052914399655
# F1-Score: 0.7185371503100025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7271090990657647
# Precision: 0.7303005462555504
# Recall: 0.7323088998681198
# F1-Score: 0.7313033441960539
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7234404929130724
# Precision: 0.715203069604831
# Recall: 0.7420634020029941
# F1-Score: 0.7283856910100823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7124375091894075
# Precision: 0.707725064813713
# Recall: 0.7183246875504763
# F1-Score: 0.7129854834463308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7111512395858992
# Precision: 0.7050088138128922
# Recall: 0.7134307058154385
# F1-Score: 0.7091947575973203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7317191333506131
# Precision: 0.7327680722700216
# Recall: 0.729966559422534
# F1-Score: 0.7313646330376313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7077769522680523
# Precision: 0.7170786904185501
# Recall: 0.722677936290354
# F1-Score: 0.7198674255579485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7101317710674963
# Precision: 0.7143559162822427
# Recall: 0.7211630924846527
# F1-Score: 0.7177433646989267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.723511785135912
# Precision: 0.7322541621823134
# Recall: 0.7259503011472714
# F1-Score: 0.7290886057759174
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7123046241994786
# Precision: 0.7212270018176776
# Recall: 0.7130387643030334
# F1-Score: 0.7171095096956764
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7312843591862872
# Precision: 0.7390791478411306
# Recall: 0.7335343436552663
# F1-Score: 0.7362963068741704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7145660792336506
# Precision: 0.7166823889687053
# Recall: 0.7224271867197
# F1-Score: 0.7195433214827257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7214017354857881
# Precision: 0.7191643256825068
# Recall: 0.7372874056037687
# F1-Score: 0.7281131100952616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7116962876883428
# Precision: 0.7123603445627168
# Recall: 0.7282696697693254
# F1-Score: 0.7202271613534212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7047891837302516
# Precision: 0.6953239624062537
# Recall: 0.7008380550731551
# F1-Score: 0.698070119882409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7075359543080468
# Precision: 0.6988432567234293
# Recall: 0.690039362907981
# F1-Score: 0.6944134066130808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7278009696880633
# Precision: 0.7245000891304223
# Recall: 0.7163647499713822
# F1-Score: 0.7204094528778888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7303200492447403
# Precision: 0.7269150916097531
# Recall: 0.7242398545409875
# F1-Score: 0.7255750071452526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7180584272639016
# Precision: 0.7242162112109568
# Recall: 0.7157700270148163
# F1-Score: 0.7199683487277324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7329645928543996
# Precision: 0.7313245734384982
# Recall: 0.7280330209012374
# F1-Score: 0.7296750851536534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7027503632495067
# Precision: 0.7054064537237514
# Recall: 0.698393376692905
# F1-Score: 0.7018823973085625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7330887648217259
# Precision: 0.7415968736847341
# Recall: 0.719245466011551
# F1-Score: 0.7302501776023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.736636248756279
# Precision: 0.7396624828050126
# Recall: 0.7305955584692215
# F1-Score: 0.7351010632600433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.711446395721239
# Precision: 0.702522970305343
# Recall: 0.7302441518631212
# F1-Score: 0.7161153863421301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7013561397249811
# Precision: 0.6997309395119399
# Recall: 0.7126913420320558
# F1-Score: 0.706151678373366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7229874680874455
# Precision: 0.7147798869403725
# Recall: 0.7399112878439157
# F1-Score: 0.727128501002152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7371570044663026
# Precision: 0.7351193335584674
# Recall: 0.7453436534243949
# F1-Score: 0.7401961880776383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7184520065919716
# Precision: 0.7245212485787411
# Recall: 0.7015623157968559
# F1-Score: 0.7128569709300114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7225639517162732
# Precision: 0.718001576088128
# Recall: 0.7342777522585188
# F1-Score: 0.726048457920656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.705280348449736
# Precision: 0.7099932063635149
# Recall: 0.7036524002786732
# F1-Score: 0.7068085827053977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.724488301850123
# Precision: 0.7325633226917408
# Recall: 0.7321923772048072
# F1-Score: 0.7323778029777949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7210349660069273
# Precision: 0.7141611681983177
# Recall: 0.7019299995043403
# F1-Score: 0.7079927618681712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7054668801395746
# Precision: 0.7081713755929514
# Recall: 0.7075092496349024
# F1-Score: 0.7078401577729351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7096142560575663
# Precision: 0.7124674205101782
# Recall: 0.7039312569603139
# F1-Score: 0.70817361642651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7232392084536018
# Precision: 0.724602999557608
# Recall: 0.7305589801682805
# F1-Score: 0.727568800943247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7254359751466684
# Precision: 0.7316270939920624
# Recall: 0.7139159166134545
# F1-Score: 0.7226630042751739
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.717394065664098
# Precision: 0.7097424844415525
# Recall: 0.7061692098363208
# F1-Score: 0.7079513382802783
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7062858566724616
# Precision: 0.7104356391136356
# Recall: 0.7181031415727632
# F1-Score: 0.7142488131650523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7054737250735077
# Precision: 0.712116709950438
# Recall: 0.722481703700756
# F1-Score: 0.7172617632126591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7163525979928276
# Precision: 0.7122032519431358
# Recall: 0.697945182010324
# F1-Score: 0.7050021350053167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7326983970882794
# Precision: 0.7228867660941869
# Recall: 0.7456633412270078
# F1-Score: 0.7340984262604854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7000304501435434
# Precision: 0.6933273261166202
# Recall: 0.6857379558694662
# F1-Score: 0.6895117578116954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7319414228910786
# Precision: 0.7344840262577372
# Recall: 0.7246551143441231
# F1-Score: 0.729536466018166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7142105367902621
# Precision: 0.7186093616735227
# Recall: 0.6970824080604983
# F1-Score: 0.7076822158601813
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.714065085429211
# Precision: 0.7042245299243791
# Recall: 0.728139805570711
# F1-Score: 0.7159825186795437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7215883286530298
# Precision: 0.7158680740821488
# Recall: 0.7117213547548488
# F1-Score: 0.7137886919302285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7066797922472821
# Precision: 0.7027589028539245
# Recall: 0.7092567601596327
# F1-Score: 0.7059928804865203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.708149050472139
# Precision: 0.7012711593989315
# Recall: 0.7038107826797093
# F1-Score: 0.7025386759111093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7222765393306989
# Precision: 0.7189103389386552
# Recall: 0.7170215878133078
# F1-Score: 0.7179647211928575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7224595761860485
# Precision: 0.7296602870187968
# Recall: 0.7148727741177319
# F1-Score: 0.7221908415640864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7174509239267889
# Precision: 0.7255908047309986
# Recall: 0.7105769297306275
# F1-Score: 0.7180053887783601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7098174029978873
# Precision: 0.7140986194299624
# Recall: 0.6962673731127915
# F1-Score: 0.7050702761168551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7112202200398453
# Precision: 0.7119920868349677
# Recall: 0.6998846143864256
# F1-Score: 0.7058864371224418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7239847104039094
# Precision: 0.7222741318415469
# Recall: 0.7366363365003501
# F1-Score: 0.729384540003233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7340934814951672
# Precision: 0.7439319352823424
# Recall: 0.7437328823583972
# F1-Score: 0.7438323955035037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7061244961329617
# Precision: 0.7159790124082609
# Recall: 0.7126835130583516
# F1-Score: 0.7143274618650914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7323532723856616
# Precision: 0.7286028389799085
# Recall: 0.7510548479252402
# F1-Score: 0.7396585024642017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7270326715728573
# Precision: 0.7346705714999769
# Recall: 0.7464654061232509
# F1-Score: 0.7405210254922792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7029741844654307
# Precision: 0.7059803776418951
# Recall: 0.7087202670919628
# F1-Score: 0.7073476691574933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7236904556897202
# Precision: 0.7265283832631518
# Recall: 0.7298469879574351
# F1-Score: 0.728183904601175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7318221519434868
# Precision: 0.7408075765200841
# Recall: 0.7416778797861839
# F1-Score: 0.74124247269438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7065818037041596
# Precision: 0.7070971522508236
# Recall: 0.7200148524513962
# F1-Score: 0.7134975391828646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7113087194131351
# Precision: 0.7033152820183707
# Recall: 0.7215774374323154
# F1-Score: 0.7123293311533634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.736757347570767
# Precision: 0.7444264740938503
# Recall: 0.7345465799245439
# F1-Score: 0.7394535269797066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7200172180171404
# Precision: 0.7169504525411646
# Recall: 0.703848842811499
# F1-Score: 0.7103392407708421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7107809805106106
# Precision: 0.7205653879049255
# Recall: 0.6938975837235886
# F1-Score: 0.7069800929555825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7022223535626354
# Precision: 0.7065770655256098
# Recall: 0.7075328181622268
# F1-Score: 0.707054618862263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7038401684879682
# Precision: 0.7044248746005247
# Recall: 0.7182125626844291
# F1-Score: 0.7112519059965712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7231048854856912
# Precision: 0.71601185245666
# Recall: 0.7232655986648502
# F1-Score: 0.7196204466549013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7228619391353511
# Precision: 0.7304102897580218
# Recall: 0.7351256184383239
# F1-Score: 0.7327603683664146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.723292569820726
# Precision: 0.7177225326981708
# Recall: 0.7194542537761505
# F1-Score: 0.7185873499215713
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.711506889448415
# Precision: 0.7179670871724799
# Recall: 0.694820710915035
# F1-Score: 0.7062042899833675
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7283078016180201
# Precision: 0.73464001131685
# Recall: 0.7357537027681424
# F1-Score: 0.7351964352817674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7126119938184047
# Precision: 0.7145007803761602
# Recall: 0.6998116235995244
# F1-Score: 0.7070799206350796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7184749313332853
# Precision: 0.7098095829499308
# Recall: 0.73421794269883
# F1-Score: 0.7218074758890383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7235786461029053
# Precision: 0.7282672508672506
# Recall: 0.7395681313054876
# F1-Score: 0.733874188286181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7125022066619967
# Precision: 0.7047707422743495
# Recall: 0.7286550960853567
# F1-Score: 0.7165139335254498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7026308208992095
# Precision: 0.6959328999959075
# Recall: 0.6862679071884641
# F1-Score: 0.691066612523087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.730712516156048
# Precision: 0.7364424157031871
# Recall: 0.733827682633865
# F1-Score: 0.7351327241436781
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7149026915810867
# Precision: 0.7217673252294703
# Recall: 0.7144286431504965
# F1-Score: 0.7180792345709057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7192200214024027
# Precision: 0.7266866152136234
# Recall: 0.7265706920382607
# F1-Score: 0.7266286490024723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7116494788588827
# Precision: 0.709953600299372
# Recall: 0.7287238214443099
# F1-Score: 0.7192162646596097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7169405973546767
# Precision: 0.7236425825633451
# Recall: 0.7316308816824336
# F1-Score: 0.7276148074041393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7030413301664264
# Precision: 0.710731965791228
# Recall: 0.6856506799396249
# F1-Score: 0.6979660726799229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7346609762643025
# Precision: 0.742277051405499
# Recall: 0.7327575453002185
# F1-Score: 0.7374865800915071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7090137380595014
# Precision: 0.7152998644859646
# Recall: 0.7036556615814241
# F1-Score: 0.7094299858275764
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7167726622206343
# Precision: 0.717387568517747
# Recall: 0.6997726253919537
# F1-Score: 0.7084706223087736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7147358169710635
# Precision: 0.7049612305731157
# Recall: 0.7186389880451659
# F1-Score: 0.7117344022914621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7350850878277567
# Precision: 0.7279867314029274
# Recall: 0.7373800592517649
# F1-Score: 0.7326532886644141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7280812226467384
# Precision: 0.7256115662985729
# Recall: 0.7177514627408556
# F1-Score: 0.7216601126870863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7369286495172085
# Precision: 0.7341075289321853
# Recall: 0.7508050978064427
# F1-Score: 0.7423624328266847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7075076035495326
# Precision: 0.7026364714802855
# Recall: 0.712309861676177
# F1-Score: 0.7074401001375864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7120748793797903
# Precision: 0.7174686554862567
# Recall: 0.7134288627266737
# F1-Score: 0.7154430564180013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7009945115389526
# Precision: 0.6934921347610111
# Recall: 0.6829568578039918
# F1-Score: 0.6881841780211054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7346919502748787
# Precision: 0.7424394655820625
# Recall: 0.7284673012332616
# F1-Score: 0.7353870225134863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7087798525336226
# Precision: 0.6993598702400666
# Recall: 0.714111610633583
# F1-Score: 0.7066587619312156

# %%
#LSTM-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-LSTM-Dataset-A-1-80-20.h5')
    with open('Scaler-Original-LSTM-Dataset-A-1-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-LSTM-Dataset-A-1-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    # Reshape the input to match the expected shape for the LSTM model
    features_reshaped = features_df.values.reshape((features_df.shape[0], 1, features_df.shape[1]))
    
    prediction = model.predict(features_reshaped)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label



def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None   
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len
def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)              
                
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}"  
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7875680706895838
# Precision: 0.7910668318219471
# Recall: 0.7898931638645359
# F1-Score: 0.7904795621913344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7785690861075762
# Precision: 0.7763876319161352
# Recall: 0.7914894542816585
# F1-Score: 0.7838658125765978
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7550947491019625
# Precision: 0.7536378241742371
# Recall: 0.7659250123716588
# F1-Score: 0.759731741158528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7724832262885116
# Precision: 0.7787096565115779
# Recall: 0.7909135813688907
# F1-Score: 0.7847641757773374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7638393943952342
# Precision: 0.7682839586711319
# Recall: 0.7609892626948075
# F1-Score: 0.7646192126835005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7585076862878983
# Precision: 0.7594818326863282
# Recall: 0.7706068911401898
# F1-Score: 0.7650039175508915
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7608555096949148
# Precision: 0.7524717142687933
# Recall: 0.7743955294542129
# F1-Score: 0.7632762232159233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7535572483461572
# Precision: 0.7455668586078376
# Recall: 0.7425471717300524
# F1-Score: 0.7440539513886653
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7695014441288703
# Precision: 0.7640015002169996
# Recall: 0.7761687184173904
# F1-Score: 0.7700370493050793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.771442580000666
# Precision: 0.7775259580662464
# Recall: 0.7785626843433302
# F1-Score: 0.7780439758512704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7765971954569245
# Precision: 0.770342594922138
# Recall: 0.7942241486946365
# F1-Score: 0.7821011077365873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.768157370169555
# Precision: 0.7766952201483777
# Recall: 0.7593003657715922
# F1-Score: 0.767899296271074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7524851045507512
# Precision: 0.7506090689478506
# Recall: 0.7672096122164138
# F1-Score: 0.7588185596343711
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7599881283819753
# Precision: 0.7677381463456553
# Recall: 0.770382415089953
# F1-Score: 0.7690580077629502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7754996992911178
# Precision: 0.7823664857381698
# Recall: 0.7629153688619882
# F1-Score: 0.7725185075788468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7791366651808196
# Precision: 0.7709464586079647
# Recall: 0.780301036714444
# F1-Score: 0.775595541932649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7887309884240836
# Precision: 0.790242335449101
# Recall: 0.7969281428757502
# F1-Score: 0.7935711574927006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7816079390352519
# Precision: 0.7754860082951214
# Recall: 0.7780863661404802
# F1-Score: 0.7767840109880239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7760795716041077
# Precision: 0.7674883284293147
# Recall: 0.7823378674146495
# F1-Score: 0.7748419580713756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7545255219766239
# Precision: 0.7458319195989734
# Recall: 0.7413317971070802
# F1-Score: 0.7435750497205224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.762646957142353
# Precision: 0.7659973837644403
# Recall: 0.7503930234773813
# F1-Score: 0.7581149155701538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7737867888035058
# Precision: 0.7789351567204335
# Recall: 0.7618906513813638
# F1-Score: 0.7703186314988923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7511399257527055
# Precision: 0.7568967482869065
# Recall: 0.7476346971826802
# F1-Score: 0.7522372136627776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7633192652433403
# Precision: 0.7536023266237173
# Recall: 0.7737016834533809
# F1-Score: 0.763519751033354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7537373633610089
# Precision: 0.7475642854351909
# Recall: 0.7610422605945512
# F1-Score: 0.7542430665233658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.763321067944425
# Precision: 0.768117506347877
# Recall: 0.7766643308586665
# F1-Score: 0.7723672750675119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7690067388278614
# Precision: 0.7785173302913796
# Recall: 0.7606350252215832
# F1-Score: 0.7694722969309531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.764436222583539
# Precision: 0.7549184187697987
# Recall: 0.7467210843016371
# F1-Score: 0.7507973772267558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7625976727484433
# Precision: 0.76111164032189
# Recall: 0.771462248028357
# F1-Score: 0.7662519915112724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7836563011368355
# Precision: 0.7878206679538042
# Recall: 0.7709111134327141
# F1-Score: 0.7792741709254594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7569079698733258
# Precision: 0.7566809645041239
# Recall: 0.772698144416253
# F1-Score: 0.7646056805368292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7870184983118749
# Precision: 0.7855722780962491
# Recall: 0.8048388635437486
# F1-Score: 0.7950888710229819
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7502249125940719
# Precision: 0.7436421518247345
# Recall: 0.7408819160840537
# F1-Score: 0.7422594678453263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.777832825995104
# Precision: 0.7691327119668997
# Recall: 0.7925286376730372
# F1-Score: 0.7806554225670477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7591933617132203
# Precision: 0.7684394110886728
# Recall: 0.7420819120636755
# F1-Score: 0.7550307019773904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7711556863962362
# Precision: 0.780567873720964
# Recall: 0.7647357681244303
# F1-Score: 0.7725707185552297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7746458786819173
# Precision: 0.7767087672546759
# Recall: 0.7553363548777902
# F1-Score: 0.7658734858189674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7677240137490752
# Precision: 0.7659233040195114
# Recall: 0.7685273478479054
# F1-Score: 0.7672231163337281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.768572856296682
# Precision: 0.7664998384811947
# Recall: 0.7587800561933615
# F1-Score: 0.762620411565916
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7722465557093553
# Precision: 0.7745911515869266
# Recall: 0.7729692643715789
# F1-Score: 0.773779358087348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.783283957651343
# Precision: 0.7736997841931151
# Recall: 0.7838097077391009
# F1-Score: 0.7787219337891566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7802432436535243
# Precision: 0.771404220885306
# Recall: 0.7947480314662614
# F1-Score: 0.7829021541077356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7508123583257815
# Precision: 0.7419404610443945
# Recall: 0.7607412892295443
# F1-Score: 0.7512232616967371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7667451863278023
# Precision: 0.7576218821730519
# Recall: 0.7861106066391639
# F1-Score: 0.7716033726237271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7760089348686132
# Precision: 0.785912961851612
# Recall: 0.783778306450145
# F1-Score: 0.7848441826700124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7685926714014272
# Precision: 0.7736704813270023
# Recall: 0.7647258390039454
# F1-Score: 0.769172156909606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7520723415228205
# Precision: 0.7573907926626491
# Recall: 0.765939694037978
# F1-Score: 0.761641255215315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7550440274078277
# Precision: 0.7640586002585343
# Recall: 0.7366427444602789
# F1-Score: 0.7501002463996391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7701438306399353
# Precision: 0.7750889262063719
# Recall: 0.7877390976396289
# F1-Score: 0.7813628140832992
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7774746511700348
# Precision: 0.7732807842923491
# Recall: 0.7756406900257201
# F1-Score: 0.7744589394064814
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7694766609681742
# Precision: 0.7702138164696075
# Recall: 0.7741984964759957
# F1-Score: 0.7722010161114421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.765488959774363
# Precision: 0.7649571360584813
# Recall: 0.7806666878500845
# F1-Score: 0.7727320768696796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7594412339278399
# Precision: 0.7629742853713994
# Recall: 0.7706063596002851
# F1-Score: 0.7667713314542242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7574500049122478
# Precision: 0.7602782751224186
# Recall: 0.7752433925461595
# F1-Score: 0.7676879091910808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7766485284174396
# Precision: 0.7850254860121494
# Recall: 0.7906317014519978
# F1-Score: 0.7878186202264761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7620937870896578
# Precision: 0.7715562551233057
# Recall: 0.7712121757797685
# F1-Score: 0.7713841770820087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7696824156158761
# Precision: 0.7681918246758279
# Recall: 0.7784601569584725
# F1-Score: 0.7732919047237308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.780063691150423
# Precision: 0.775357228928474
# Recall: 0.7795551930366175
# F1-Score: 0.777450544135203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7507216676574912
# Precision: 0.75448698554321
# Recall: 0.7421295771921631
# F1-Score: 0.7482572644455981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7721931664228977
# Precision: 0.7818720157984443
# Recall: 0.7697710050553931
# F1-Score: 0.7757743235227677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7865562790271565
# Precision: 0.7922935193714534
# Recall: 0.7887192361758041
# F1-Score: 0.7905023374835305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7767177424370987
# Precision: 0.7709613284814598
# Recall: 0.7605452514057902
# F1-Score: 0.7657178690505413
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7810273219870805
# Precision: 0.7839697435859516
# Recall: 0.7745903534258538
# F1-Score: 0.7792518259946424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7678343637449215
# Precision: 0.7645045631893256
# Recall: 0.7832404020671161
# F1-Score: 0.7737590816266557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7583170911494665
# Precision: 0.7562159745714535
# Recall: 0.7563249035408646
# F1-Score: 0.7562704351337791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7504513626134454
# Precision: 0.744053878366262
# Recall: 0.7468393905465581
# F1-Score: 0.7454440322989423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7560815579423086
# Precision: 0.7608798964039196
# Recall: 0.745622208391436
# F1-Score: 0.7531737883026774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7824734983593512
# Precision: 0.7824879530247039
# Recall: 0.7797357798007755
# F1-Score: 0.7811094421577194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7586949493424997
# Precision: 0.7684958203277075
# Recall: 0.7767413016487045
# F1-Score: 0.772596561787809
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7671295743405476
# Precision: 0.7682009135785055
# Recall: 0.7587675939754762
# F1-Score: 0.7634551151541926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7810510321100541
# Precision: 0.7892160212593375
# Recall: 0.7929511970626106
# F1-Score: 0.7910792001648453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7732970032478597
# Precision: 0.7657186700739379
# Recall: 0.7902262554460451
# F1-Score: 0.7777794540837459
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7594344016653096
# Precision: 0.7562051779237569
# Recall: 0.7654372911065175
# F1-Score: 0.7607932279644678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7525026910415621
# Precision: 0.7565454464256068
# Recall: 0.750045059858964
# F1-Score: 0.7532812297479591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7713456702280189
# Precision: 0.7702332251277167
# Recall: 0.7594765040122802
# F1-Score: 0.7648170446336566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7596059208784707
# Precision: 0.7542465916724027
# Recall: 0.7648029006311323
# F1-Score: 0.7594880667481678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7773096946634492
# Precision: 0.7824065580716513
# Recall: 0.7930743967349978
# F1-Score: 0.7877043605650347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7848119148251458
# Precision: 0.7928736590254027
# Recall: 0.7823923423226259
# F1-Score: 0.7875981310076438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7639137908204298
# Precision: 0.7613550547709118
# Recall: 0.7565067896328449
# F1-Score: 0.7589231791800297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7551658291984301
# Precision: 0.7532003426866024
# Recall: 0.7707675201496098
# F1-Score: 0.7618826806858753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7760824694940629
# Precision: 0.773559017450576
# Recall: 0.7565328693649431
# F1-Score: 0.7649512138947376
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7534614414335888
# Precision: 0.7593121588539999
# Recall: 0.7394776704918054
# F1-Score: 0.7492636731469438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7825074679842058
# Precision: 0.7884529694623699
# Recall: 0.7876967796297475
# F1-Score: 0.7880746931473486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7862658699439946
# Precision: 0.7822036440511642
# Recall: 0.7965390286158088
# F1-Score: 0.7893062518665325
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7511720554038529
# Precision: 0.760764871708075
# Recall: 0.7700401012853312
# F1-Score: 0.7653743869395327
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7774562154254995
# Precision: 0.7824096917569966
# Recall: 0.7643108868773115
# F1-Score: 0.7732543985885383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7688028307467321
# Precision: 0.7647215048087932
# Recall: 0.7495787851864166
# F1-Score: 0.7570744328158544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7682102471554659
# Precision: 0.7748203216491034
# Recall: 0.7520869738849072
# F1-Score: 0.7632844151285604
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7808861148026124
# Precision: 0.7756573854296719
# Recall: 0.7999847630687033
# F1-Score: 0.7876332710403955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7667238696271395
# Precision: 0.7701702611392967
# Recall: 0.7574504509699557
# F1-Score: 0.7637573999872393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7627026700924312
# Precision: 0.7585121526380625
# Recall: 0.7787126358727049
# F1-Score: 0.7684796682136353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.756767104873754
# Precision: 0.7545386240842157
# Recall: 0.7404976052531212
# F1-Score: 0.7474521797414919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7515256203676817
# Precision: 0.7524369981938046
# Recall: 0.7425408258647738
# F1-Score: 0.7474561576214346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.785364403485169
# Precision: 0.781413426259134
# Recall: 0.797064198093146
# F1-Score: 0.7891612226508843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7812895866984357
# Precision: 0.7900652349108754
# Recall: 0.796794407282316
# F1-Score: 0.7934155533694444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7638063813126521
# Precision: 0.7672595279709632
# Recall: 0.7487929115996722
# F1-Score: 0.7579137514064861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7729182459549867
# Precision: 0.7738904488822756
# Recall: 0.7763621780734086
# F1-Score: 0.7751243430102267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7771154654722718
# Precision: 0.7752197194730505
# Recall: 0.7929547112909464
# F1-Score: 0.7839869300028307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7656708573890683
# Precision: 0.763390260030919
# Recall: 0.7664918362066121
# F1-Score: 0.7649379041592417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7542431650725906
# Precision: 0.7625941819393883
# Recall: 0.7741778055795097
# F1-Score: 0.7683423372060612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7823855858335884
# Precision: 0.7727204414575191
# Recall: 0.7685257316527684
# F1-Score: 0.7706173783202579
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7510767825000517
# Precision: 0.7555372704813171
# Recall: 0.7369662485275111
# F1-Score: 0.7461362211314668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7774993411974038
# Precision: 0.7730215673551437
# Recall: 0.7613703719771844
# F1-Score: 0.7671517337867073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7533042763909709
# Precision: 0.7520571520432584
# Recall: 0.7433513816632389
# F1-Score: 0.7476789258055678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7745182394109175
# Precision: 0.7655836617396258
# Recall: 0.7857060432172605
# F1-Score: 0.775514344864347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7657759733551678
# Precision: 0.7742360154858436
# Recall: 0.7518113466689239
# F1-Score: 0.7628589202108408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7630595173318315
# Precision: 0.7615289744681104
# Recall: 0.7625593495488359
# F1-Score: 0.7620438137108088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7809369575694873
# Precision: 0.7887882170792997
# Recall: 0.787070605124916
# F1-Score: 0.7879284750440092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7637071154038731
# Precision: 0.7577325753153549
# Recall: 0.7503232299411462
# F1-Score: 0.7540097009149309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7520004431070516
# Precision: 0.7530726705372265
# Recall: 0.7633233289273916
# F1-Score: 0.7581633531104937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7530438911532784
# Precision: 0.7555280310205172
# Recall: 0.7343879973866247
# F1-Score: 0.7448080389655303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7504669529623724
# Precision: 0.7504070546005824
# Recall: 0.7691745642810426
# F1-Score: 0.7596749158898409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7813865065267147
# Precision: 0.7757875729265827
# Recall: 0.7910649478206678
# F1-Score: 0.7833517804271837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7562705196710463
# Precision: 0.7567012542957979
# Recall: 0.7381773110215593
# F1-Score: 0.747324511973491
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7616929853119726
# Precision: 0.7626331262917201
# Recall: 0.7458805913105866
# F1-Score: 0.7541638376290488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7742251642732438
# Precision: 0.7833441534756779
# Recall: 0.7652264186063457
# F1-Score: 0.7741793004557523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7697263452716105
# Precision: 0.7603627190178269
# Recall: 0.7616335966982882
# F1-Score: 0.760997627262135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7836920011961022
# Precision: 0.7903737960273706
# Recall: 0.7651831020306963
# F1-Score: 0.777574479934484
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7867425473384485
# Precision: 0.7784412306151854
# Recall: 0.8017156759505891
# F1-Score: 0.7899070463158261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7868907746404817
# Precision: 0.7856450853369358
# Recall: 0.796601699417487
# F1-Score: 0.7910854566413746

# %%
#LSTM-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-LSTM-Dataset-B-80-20.h5')
    with open('Scaler-Original-LSTM-Dataset-B-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-LSTM-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    # Reshape the input to match the expected shape for the LSTM model
    features_reshaped = features_df.values.reshape((features_df.shape[0], 1, features_df.shape[1]))
    
    prediction = model.predict(features_reshaped)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label



def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None   
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len
def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)              
                
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}"  
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7788874703380793
# Precision: 0.7711946108586465
# Recall: 0.7868014378382784
# F1-Score: 0.7789198556494547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7687934544015387
# Precision: 0.7728590868978721
# Recall: 0.7597541479952996
# F1-Score: 0.7662505891480791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7865912501788037
# Precision: 0.7840136141135219
# Recall: 0.7972799421380197
# F1-Score: 0.7905911289205495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7687361810965399
# Precision: 0.7623340327021985
# Recall: 0.7823319661399153
# F1-Score: 0.7722035483481133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7872040540623338
# Precision: 0.7893434873673552
# Recall: 0.7781321740563061
# F1-Score: 0.7836977364541489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7543297735008121
# Precision: 0.7564237876712452
# Recall: 0.7453019767446667
# F1-Score: 0.7508216980313182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7712564136107624
# Precision: 0.7623685181752109
# Recall: 0.7900801448973148
# F1-Score: 0.7759770015362919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7680135274971034
# Precision: 0.7680727776319324
# Recall: 0.7810879978995647
# F1-Score: 0.7745257143059985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7598399321897918
# Precision: 0.7562427598153005
# Recall: 0.7629106221055149
# F1-Score: 0.7595620576824087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7790280663388262
# Precision: 0.7727397336455679
# Recall: 0.7936856232072343
# F1-Score: 0.7830726365509266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7531161373431066
# Precision: 0.7540080411046218
# Recall: 0.7483563444090836
# F1-Score: 0.7511715622880243
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7554024058059235
# Precision: 0.754349903671894
# Recall: 0.7709441573838068
# F1-Score: 0.7625567629318222
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7611378837564516
# Precision: 0.7617904736326393
# Recall: 0.7687104283138853
# F1-Score: 0.7652348071494888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7582668265713214
# Precision: 0.7629420329264782
# Recall: 0.7461997504567054
# F1-Score: 0.754478023007753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7632856833501251
# Precision: 0.7680324127312891
# Recall: 0.7567841445025111
# F1-Score: 0.7623667904990191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7746668379772581
# Precision: 0.7692156550151562
# Recall: 0.7809902313335628
# F1-Score: 0.7750582263245853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7545983139208805
# Precision: 0.7596903308138286
# Recall: 0.7432963305726045
# F1-Score: 0.7514039209696262
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7624940590155523
# Precision: 0.7525423866197094
# Recall: 0.7755069321838741
# F1-Score: 0.7638520961387875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7708086436175698
# Precision: 0.7803746483207222
# Recall: 0.7892615033923821
# F1-Score: 0.7847929183724504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7619281003296446
# Precision: 0.7676492006431687
# Recall: 0.7544091520735937
# F1-Score: 0.7609715902330492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7865960342253426
# Precision: 0.7947440284498216
# Recall: 0.7928898517503753
# F1-Score: 0.7938158573658246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7670136363481168
# Precision: 0.774787315753882
# Recall: 0.763562459742864
# F1-Score: 0.7691339356208156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7733287059958507
# Precision: 0.7684181656179679
# Recall: 0.7649235250168519
# F1-Score: 0.7666668629979421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7680279508030402
# Precision: 0.7774694513905598
# Recall: 0.783966374821693
# F1-Score: 0.7807043966959859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7531812288979355
# Precision: 0.7489044106153235
# Recall: 0.75033225246327
# F1-Score: 0.7496176516158419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7598945936516247
# Precision: 0.7660586922711344
# Recall: 0.7606432239712059
# F1-Score: 0.7633413533330332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7648169512943066
# Precision: 0.7736790506657741
# Recall: 0.7779020273205116
# F1-Score: 0.775784792103058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7863216721003425
# Precision: 0.7895925362819609
# Recall: 0.805001614034194
# F1-Score: 0.7972226237131355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7622377573495358
# Precision: 0.7559167411678963
# Recall: 0.7751900659688146
# F1-Score: 0.7654320988209825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7661317195869007
# Precision: 0.7568617321279771
# Recall: 0.7606727570958023
# F1-Score: 0.7587624592474027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.756446404150903
# Precision: 0.766099900277395
# Recall: 0.7519881368306308
# F1-Score: 0.758978428857398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7892037014818082
# Precision: 0.7934452346173354
# Recall: 0.774056030858187
# F1-Score: 0.7836307153792574
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7787125629589716
# Precision: 0.7716754208683964
# Recall: 0.7855816998600417
# F1-Score: 0.7785664689495068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7515523355256041
# Precision: 0.7481548253186227
# Recall: 0.7559448290075297
# F1-Score: 0.7520296542452449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7705303692460671
# Precision: 0.7743593871957863
# Recall: 0.7854985417122178
# F1-Score: 0.779889191356388
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7870475628830855
# Precision: 0.7802868463523572
# Recall: 0.7858891473853999
# F1-Score: 0.7830779769934015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7655273172569685
# Precision: 0.7608556725920081
# Recall: 0.7469509327941424
# F1-Score: 0.7538391891031242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7741776542737734
# Precision: 0.7786428230689949
# Recall: 0.7703880788004505
# F1-Score: 0.7744934562789488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7745386651429563
# Precision: 0.7805401423102738
# Recall: 0.7675528573120443
# F1-Score: 0.7739920232481663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7662656479427951
# Precision: 0.7744275592520292
# Recall: 0.7475949528410467
# F1-Score: 0.7607747323548427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7598511907560604
# Precision: 0.7521293051864645
# Recall: 0.7440800201739666
# F1-Score: 0.7480830109674124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.786928145290357
# Precision: 0.7852839898168417
# Recall: 0.7712145674768446
# F1-Score: 0.7781856908445757
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.751362029734736
# Precision: 0.7555009392069534
# Recall: 0.7519164125732449
# F1-Score: 0.753704414020892
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7602662866373054
# Precision: 0.758246613455483
# Recall: 0.757497496357895
# F1-Score: 0.7578718697908695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7785198844354558
# Precision: 0.7779031672670171
# Recall: 0.7668227960129699
# F1-Score: 0.7723232417022808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.769488202061574
# Precision: 0.7718043321634316
# Recall: 0.7607954090326012
# F1-Score: 0.7662603311196898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7571299724108385
# Precision: 0.7563074788052887
# Recall: 0.7508413353523155
# F1-Score: 0.7535644947450074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7565934935181343
# Precision: 0.7546413918943524
# Recall: 0.7491309341151614
# F1-Score: 0.7518760666808616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.767301045245076
# Precision: 0.7708866819148574
# Recall: 0.7651268099829441
# F1-Score: 0.7679959465240106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7849489597274024
# Precision: 0.7932814400747363
# Recall: 0.802550858190009
# F1-Score: 0.7978892283486885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7790394848485949
# Precision: 0.7841169022725075
# Recall: 0.7894496686112938
# F1-Score: 0.7867742491553685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7785295446471652
# Precision: 0.7714731989040979
# Recall: 0.7883175424725993
# F1-Score: 0.7798044187732208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7880150842478403
# Precision: 0.7950106443209158
# Recall: 0.7757991500551364
# F1-Score: 0.7852874159012257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7803298548483062
# Precision: 0.7812657085438794
# Recall: 0.7908319301251322
# F1-Score: 0.7860197140826783
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7815056095269892
# Precision: 0.7763342167473035
# Recall: 0.771448977049976
# F1-Score: 0.7738838873024263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7518165657916649
# Precision: 0.7463337904670196
# Recall: 0.7474420916087846
# F1-Score: 0.7468875298880652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7523772337705351
# Precision: 0.7462475781640268
# Recall: 0.7655201055070372
# F1-Score: 0.7557609954768623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7598936562240525
# Precision: 0.7524183603025993
# Recall: 0.7622868635474931
# F1-Score: 0.7573204646284103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7666517280924243
# Precision: 0.7614331448749082
# Recall: 0.7842956290080038
# F1-Score: 0.772695310325439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.784275032940338
# Precision: 0.7875383341963818
# Recall: 0.8004117251717137
# F1-Score: 0.7939228478807768
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7714441952106634
# Precision: 0.7674860879548993
# Recall: 0.7814937939061863
# F1-Score: 0.7744266038180614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.75310753436778
# Precision: 0.7620504780786426
# Recall: 0.7413322267385775
# F1-Score: 0.7515485923724547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7810405146763902
# Precision: 0.772698543845111
# Recall: 0.8004701727257649
# F1-Score: 0.7863392277528509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7534375950780443
# Precision: 0.7476118847973291
# Recall: 0.7471076734091389
# F1-Score: 0.7473596940608183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7537674909564936
# Precision: 0.7496689829284892
# Recall: 0.758646012736631
# F1-Score: 0.7541307835638537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7717451341460024
# Precision: 0.7656822567253143
# Recall: 0.7817784641791128
# F1-Score: 0.7736466465682694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7607395848360557
# Precision: 0.7578553403592684
# Recall: 0.7673215625903674
# F1-Score: 0.7625590747634492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7845299213835222
# Precision: 0.7815295416159368
# Recall: 0.7987824530739324
# F1-Score: 0.7900618188046281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7684539577709311
# Precision: 0.7623866370368528
# Recall: 0.777260459982511
# F1-Score: 0.7697517039261254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7701558208829979
# Precision: 0.7619903396386406
# Recall: 0.7626972685159285
# F1-Score: 0.7623436401917664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7694142069178811
# Precision: 0.7766050832973312
# Recall: 0.7794107648241816
# F1-Score: 0.7780053945721142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7542300076872841
# Precision: 0.7554943733086457
# Recall: 0.7361394251454288
# F1-Score: 0.7456913275154049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7541854356575727
# Precision: 0.7557955965530012
# Recall: 0.7629562116861542
# F1-Score: 0.7593590236757793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7829726029651326
# Precision: 0.7863001474456294
# Recall: 0.7749953520600156
# F1-Score: 0.7806068227153875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.761970755271463
# Precision: 0.7646940642753794
# Recall: 0.7611053407924941
# F1-Score: 0.7628954821442205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7780326536205169
# Precision: 0.7807154816341314
# Recall: 0.7772879931328347
# F1-Score: 0.7789979672771846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7879800736670504
# Precision: 0.7826595865612854
# Recall: 0.7912125912073302
# F1-Score: 0.786912848785935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.763877988789249
# Precision: 0.7711846969834489
# Recall: 0.764552092094492
# F1-Score: 0.7678540719519471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7542750584927278
# Precision: 0.7472810923369658
# Recall: 0.7438090710365691
# F1-Score: 0.7455410393651807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7615044176215745
# Precision: 0.7582749091195032
# Recall: 0.7739646905705679
# F1-Score: 0.7660394699664606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7628494295093631
# Precision: 0.7618589997200378
# Recall: 0.7649927758084274
# F1-Score: 0.7634226718159888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7528676132374655
# Precision: 0.7563009561824375
# Recall: 0.7420161391772504
# F1-Score: 0.7490904526158874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7660621143174167
# Precision: 0.7563420703033819
# Recall: 0.7855709460844884
# F1-Score: 0.7706794733773316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7658853715371338
# Precision: 0.7675193136515405
# Recall: 0.7772512917514951
# F1-Score: 0.7723546472121505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7787892197795134
# Precision: 0.7848268056032692
# Recall: 0.7928184745119372
# F1-Score: 0.7888023988878197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7737119933977804
# Precision: 0.7789547153867269
# Recall: 0.7656454698304215
# F1-Score: 0.7722427521981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7646429029710384
# Precision: 0.7600543280907468
# Recall: 0.7757338525816926
# F1-Score: 0.7678140508192615
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7599165733847763
# Precision: 0.7588934896025679
# Recall: 0.7442075985691298
# F1-Score: 0.7514788006092646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7807721740430971
# Precision: 0.770860630356895
# Recall: 0.7666986235808534
# F1-Score: 0.7687739939175432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7827235701423102
# Precision: 0.7789864526604379
# Recall: 0.7970308612689856
# F1-Score: 0.7879053583907828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7500543091604598
# Precision: 0.7505971960596443
# Recall: 0.7645025286874035
# F1-Score: 0.7574860519614663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7778089084604447
# Precision: 0.7830261097186036
# Recall: 0.7729553398965269
# F1-Score: 0.7779581343146534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7773775911261465
# Precision: 0.7711569608817914
# Recall: 0.790307160148165
# F1-Score: 0.7806146290200746
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7661518617392069
# Precision: 0.7657474705678798
# Recall: 0.7510411728011854
# F1-Score: 0.7583230279037715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.7545057597238628
# Precision: 0.7570096844109804
# Recall: 0.7442185220844976
# F1-Score: 0.7505596099225554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7634876360687229
# Precision: 0.762539657210801
# Recall: 0.7451558264112346
# F1-Score: 0.7537475234391546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7719331978309462
# Precision: 0.7644528465483595
# Recall: 0.7610882977279175
# F1-Score: 0.7627668619174055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7893613105496247
# Precision: 0.7923335379873438
# Recall: 0.7968104690184025
# F1-Score: 0.7945656973055214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7718848931478965
# Precision: 0.7806397677358249
# Recall: 0.779176599340538
# F1-Score: 0.7799074972837614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7646459683570485
# Precision: 0.7568841988114402
# Recall: 0.7495823661694979
# F1-Score: 0.7532155865252316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7574749215250584
# Precision: 0.762906482087333
# Recall: 0.7521238667344975
# F1-Score: 0.7574768039604693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7694834325344883
# Precision: 0.7773018089116677
# Recall: 0.7674532513543575
# F1-Score: 0.7723461354839661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7705780857913204
# Precision: 0.7720506138466104
# Recall: 0.7587426069493536
# F1-Score: 0.7653387635754422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7580156773866731
# Precision: 0.7523207947039974
# Recall: 0.7620620999915118
# F1-Score: 0.7571601167546012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7590656701927279
# Precision: 0.7502932111482842
# Recall: 0.748291176210503
# F1-Score: 0.7492908563693543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7659135940032871
# Precision: 0.7600284468558117
# Recall: 0.7558756201093569
# F1-Score: 0.7579463451377999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7757351866764879
# Precision: 0.775518688949974
# Recall: 0.7626508474622384
# F1-Score: 0.7690309440532305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7782477033936304
# Precision: 0.7708273140119972
# Recall: 0.7893168722915295
# F1-Score: 0.7799625315585551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7833063501211079
# Precision: 0.7775355257609632
# Recall: 0.7865325856647339
# F1-Score: 0.7820081786150672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7615223632936925
# Precision: 0.7640282826995035
# Recall: 0.767971009756904
# F1-Score: 0.7659945727608969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7604837885718712
# Precision: 0.7615003846711702
# Recall: 0.7412862409355911
# F1-Score: 0.7512573614979856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7804607427668426
# Precision: 0.77803222519646
# Recall: 0.7772609926445437
# F1-Score: 0.7776464177026523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7621029328340169
# Precision: 0.7694960098258863
# Recall: 0.7602992621327326
# F1-Score: 0.7648699917024308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7531099691200848
# Precision: 0.7475604262434093
# Recall: 0.7661874946332865
# F1-Score: 0.7567593549376515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7783196225695153
# Precision: 0.771150736896041
# Recall: 0.7775624838866524
# F1-Score: 0.7743433379213632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7666447400991326
# Precision: 0.7583381830599677
# Recall: 0.7859809779025064
# F1-Score: 0.7719121821046505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7575731204451016
# Precision: 0.7604384456498405
# Recall: 0.7613631810046418
# F1-Score: 0.7609005323656948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7655229833473376
# Precision: 0.7703813936262899
# Recall: 0.7736570825246043
# F1-Score: 0.7720157633764921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7638227085162451
# Precision: 0.7715455961146058
# Recall: 0.7687797363129504
# F1-Score: 0.7701601829784896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.7539549976386781
# Precision: 0.7571313057537146
# Recall: 0.7617938597407408
# F1-Score: 0.7594554265652854

# %%
#FFNN-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-FFNN-Dataset-A-80-20.h5')
    with open('Scaler-Original-FFNN-Dataset-A-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-FFNN-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    prediction = model.predict(features_df)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label


def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None 
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  # Replace with the correct interface name
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6415811992873168
# Precision: 0.6421537568705952
# Recall: 0.6279586958698702
# F1-Score: 0.6349769027810578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6403677746977555
# Precision: 0.6487960802097485
# Recall: 0.6595613159163396
# F1-Score: 0.6541344095910403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6480995359376771
# Precision: 0.6564659945390713
# Recall: 0.6640178307836505
# F1-Score: 0.6602203182163661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6761284717792568
# Precision: 0.6741841809468471
# Recall: 0.676880692162262
# F1-Score: 0.6755297456501873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6628525517257685
# Precision: 0.6693362462530233
# Recall: 0.6557960304419049
# F1-Score: 0.6624969613122972
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6584641023485953
# Precision: 0.6664934896858831
# Recall: 0.658881745013656
# F1-Score: 0.6626657598955792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6283860761882284
# Precision: 0.6372186803632278
# Recall: 0.6397551175736468
# F1-Score: 0.6384843799215575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6211209965528371
# Precision: 0.6256018264119458
# Recall: 0.6116577209232937
# F1-Score: 0.6185511975603278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.667497259317449
# Precision: 0.6675263903309574
# Recall: 0.6806230399573175
# F1-Score: 0.6740111011902307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.678262514976259
# Precision: 0.6728077468576328
# Recall: 0.6843608704111339
# F1-Score: 0.6785351346916086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6371155154338461
# Precision: 0.6281131628451463
# Recall: 0.6564495836394589
# F1-Score: 0.641968833918852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6773928309893347
# Precision: 0.6690342619864812
# Recall: 0.6905100908519567
# F1-Score: 0.6796025566401745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.659501123490708
# Precision: 0.6526928651592091
# Recall: 0.6528906681951404
# F1-Score: 0.6527917516930546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6667575009444956
# Precision: 0.6738395094349986
# Recall: 0.680050911583182
# F1-Score: 0.6769309621193951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6711466076413303
# Precision: 0.6689516609646569
# Recall: 0.6551795956532637
# F1-Score: 0.6619940078476225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6304857000458326
# Precision: 0.6352679368418321
# Recall: 0.6413812202178589
# F1-Score: 0.6383099416840728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6710642232302417
# Precision: 0.6685393825419064
# Recall: 0.6660811064534237
# F1-Score: 0.667307980512743
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6552543141510437
# Precision: 0.6611512012064232
# Recall: 0.639818588807056
# F1-Score: 0.6503099945765854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6224313111667692
# Precision: 0.621573745313185
# Recall: 0.6383897190304091
# F1-Score: 0.6298695158337598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6481412420900009
# Precision: 0.6412424233960199
# Recall: 0.6563116058542887
# F1-Score: 0.6486895114249631
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.637725609270685
# Precision: 0.6377269761164411
# Recall: 0.641035846273336
# F1-Score: 0.6393771302518069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.665100536187257
# Precision: 0.6599877135170655
# Recall: 0.6664771918733057
# F1-Score: 0.6632165784232147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6586250320051437
# Precision: 0.6620392540142159
# Recall: 0.665454082281906
# F1-Score: 0.6637422760159956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6208155625056295
# Precision: 0.6284259680301608
# Recall: 0.6360079324250041
# F1-Score: 0.6321942182429117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.631369938754857
# Precision: 0.6306646312632797
# Recall: 0.6153999998816712
# F1-Score: 0.62293881762486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6352758823359766
# Precision: 0.6444154066814701
# Recall: 0.6164548711490073
# F1-Score: 0.6301251183044716
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6583819299772603
# Precision: 0.6662571720121598
# Recall: 0.6449735528583509
# F1-Score: 0.6554426268381967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6214998769050802
# Precision: 0.6129771862491425
# Recall: 0.6258639834099458
# F1-Score: 0.619353558666251
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6397569883750339
# Precision: 0.6421821542534134
# Recall: 0.6242348258902289
# F1-Score: 0.6330813176631966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6533132216234262
# Precision: 0.6506797791237424
# Recall: 0.6381614510310304
# F1-Score: 0.6443598207240673
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6506507289908171
# Precision: 0.6467008151116733
# Recall: 0.663523462632782
# F1-Score: 0.6550041415337465
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6491054646827441
# Precision: 0.657345827237468
# Recall: 0.6444149531238385
# F1-Score: 0.6508161665890898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6251646201446864
# Precision: 0.6326345678780818
# Recall: 0.6139459506358617
# F1-Score: 0.623150170265832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.651729011992174
# Precision: 0.6495673934190891
# Recall: 0.6595883952761032
# F1-Score: 0.6545395412046451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6698529129182209
# Precision: 0.6625424743426875
# Recall: 0.6759348491573796
# F1-Score: 0.6691716618464759
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6273315628644486
# Precision: 0.6250801349173135
# Recall: 0.6185677153504793
# F1-Score: 0.6218068738405559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6674892784092321
# Precision: 0.6580162743370958
# Recall: 0.6488995264605387
# F1-Score: 0.6534261022172535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.655965400328415
# Precision: 0.6541913558784991
# Recall: 0.6535424008735324
# F1-Score: 0.6538667173560083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6553200910348741
# Precision: 0.6563825012897367
# Recall: 0.6554861622302938
# F1-Score: 0.655934025546546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6568110070363015
# Precision: 0.6635880731940726
# Recall: 0.6408992165305853
# F1-Score: 0.6520463320097044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6532122846495326
# Precision: 0.6538958987828977
# Recall: 0.6609599977584104
# F1-Score: 0.6574089722389584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6225975175579345
# Precision: 0.6207872693065543
# Recall: 0.6054161832624365
# F1-Score: 0.6130053840805648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6570066761731881
# Precision: 0.6482219313569092
# Recall: 0.663210306700867
# F1-Score: 0.6556304678648661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6546011770401449
# Precision: 0.6627964484739398
# Recall: 0.6429014483535755
# F1-Score: 0.6526973777362101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6691859677250647
# Precision: 0.6666369780515576
# Recall: 0.6584700238176578
# F1-Score: 0.6625283334796911
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6745903648447225
# Precision: 0.6795464870012926
# Recall: 0.6801083212002392
# F1-Score: 0.6798272880206898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6494898687834428
# Precision: 0.641644606428835
# Recall: 0.662400950149605
# F1-Score: 0.6518575901167357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6536507624894363
# Precision: 0.6490205487128968
# Recall: 0.6448204238711893
# F1-Score: 0.6469136689748227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.641316279787937
# Precision: 0.6505204076510325
# Recall: 0.6481980080616928
# F1-Score: 0.6493571313708878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6200073943502473
# Precision: 0.6206207570469536
# Recall: 0.6008549520774471
# F1-Score: 0.6105779303642919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6201867967746695
# Precision: 0.625929856133388
# Recall: 0.6354436560483725
# F1-Score: 0.6306508775870319
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6574042828063543
# Precision: 0.6655643838023747
# Recall: 0.6464742598661091
# F1-Score: 0.6558804414614494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6346859559633979
# Precision: 0.6442242574480789
# Recall: 0.6296483091347347
# F1-Score: 0.6368528925838877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6576156490548792
# Precision: 0.6566995698302391
# Recall: 0.6701581427866735
# F1-Score: 0.6633605998615513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6583547613739412
# Precision: 0.6565721347072702
# Recall: 0.6456494351114168
# F1-Score: 0.6510649765118993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6757332704276671
# Precision: 0.6687335337999699
# Recall: 0.6563884668355484
# F1-Score: 0.6625034959225854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6463453135734246
# Precision: 0.6415954983438686
# Recall: 0.6578645348833861
# F1-Score: 0.6496281737161329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6407174128173337
# Precision: 0.6388696800253828
# Recall: 0.6576694921452692
# F1-Score: 0.648133287490062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6498721704287193
# Precision: 0.6565788527141186
# Recall: 0.6484546753618391
# F1-Score: 0.6524914764663451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6467305322415526
# Precision: 0.6533677655094341
# Recall: 0.6508191191912922
# F1-Score: 0.6520909520638363
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6558295029276315
# Precision: 0.6496015037532108
# Recall: 0.6602809512622719
# F1-Score: 0.6548976928384044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6373314819181473
# Precision: 0.6320750406080111
# Recall: 0.6512222292177099
# F1-Score: 0.6415057939514264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6373899699907729
# Precision: 0.6460004143116289
# Recall: 0.6484556335201576
# F1-Score: 0.6472256954855954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6595284095541684
# Precision: 0.6675815389562294
# Recall: 0.668331397406955
# F1-Score: 0.6679562577308658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6564365841860447
# Precision: 0.6576831699285519
# Recall: 0.64091406324016
# F1-Score: 0.6491903447769225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6567171225241231
# Precision: 0.6500610723263547
# Recall: 0.664211305831317
# F1-Score: 0.657060014188618
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.640316579237023
# Precision: 0.6483257610193239
# Recall: 0.6257097595006316
# F1-Score: 0.6368170266397389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6427652671107345
# Precision: 0.6463709765348659
# Recall: 0.65429793880233
# F1-Score: 0.6503103021244588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6224435262953029
# Precision: 0.6157664811815348
# Recall: 0.6207384299218621
# F1-Score: 0.6182424595241638
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6430859905412389
# Precision: 0.6494292581537982
# Recall: 0.6313620977717821
# F1-Score: 0.6402682480411407
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6347055614365644
# Precision: 0.6301776471085917
# Recall: 0.6423702402939641
# F1-Score: 0.6362155335895424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6707758745420563
# Precision: 0.6707303370620376
# Recall: 0.6695890238745802
# F1-Score: 0.6701591945409135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6594572203580922
# Precision: 0.6562141475088973
# Recall: 0.6614754947063475
# F1-Score: 0.6588343172023609
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6712748307802991
# Precision: 0.6785832277362043
# Recall: 0.6638948228714069
# F1-Score: 0.6711586704565234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6769041246310693
# Precision: 0.6735085233560825
# Recall: 0.6923812064768015
# F1-Score: 0.6828144817089268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6491335123837447
# Precision: 0.650909210666584
# Recall: 0.6401708769659697
# F1-Score: 0.6454953867064004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6491625552696165
# Precision: 0.644283336286868
# Recall: 0.6329068774070352
# F1-Score: 0.6385444394462556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6565660500798787
# Precision: 0.6596499674287704
# Recall: 0.6750924559825017
# F1-Score: 0.6672818796935004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6695878517108508
# Precision: 0.6765426451372558
# Recall: 0.6555803126080973
# F1-Score: 0.6658965468810356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6439608190577598
# Precision: 0.6406038914203496
# Recall: 0.6560117536719303
# F1-Score: 0.6482162756717589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6723367380590443
# Precision: 0.6723079438927102
# Recall: 0.6917499322239403
# F1-Score: 0.6818903842194852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.648283100123145
# Precision: 0.6485043623149004
# Recall: 0.6488355552755332
# F1-Score: 0.6486699165207228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6624269494487307
# Precision: 0.6635762199697437
# Recall: 0.6750336679445094
# F1-Score: 0.6692559105847902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6338494677461481
# Precision: 0.6281776090399678
# Recall: 0.6244812438682231
# F1-Score: 0.6263239728082559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6621714127200777
# Precision: 0.6612891630491412
# Recall: 0.6605282756057013
# F1-Score: 0.6609085003298182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6714777009889331
# Precision: 0.6809051121071578
# Recall: 0.6902819473600259
# F1-Score: 0.6855614680835229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6494114633059063
# Precision: 0.6557637273474345
# Recall: 0.6361180596538599
# F1-Score: 0.6457915175039385
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6293538894157897
# Precision: 0.6277878302324689
# Recall: 0.6200072644701652
# F1-Score: 0.623873289681192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6696075187868114
# Precision: 0.6741666402205505
# Recall: 0.6859260890416761
# F1-Score: 0.6799955281573931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.6633134036874798
# Precision: 0.6720397715097033
# Recall: 0.6547271625255009
# F1-Score: 0.6632705133321616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6522840831810809
# Precision: 0.6583501890459653
# Recall: 0.6612124881238225
# F1-Score: 0.6597782342397375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6331985950959209
# Precision: 0.6396060688741231
# Recall: 0.63343527851575
# F1-Score: 0.636505717914543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6670928743273308
# Precision: 0.6602755463092244
# Recall: 0.6484536955779872
# F1-Score: 0.654311227105431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6642811671906101
# Precision: 0.6619802986587252
# Recall: 0.6455709034070181
# F1-Score: 0.6536726344140112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6231911953918906
# Precision: 0.6328039048781113
# Recall: 0.6375032721795845
# F1-Score: 0.6351448961222265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6766640686224027
# Precision: 0.6857554168935917
# Recall: 0.679555044041433
# F1-Score: 0.6826411513900402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6203815403703037
# Precision: 0.6149509329090249
# Recall: 0.6208681421484914
# F1-Score: 0.6178953714724598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6244119536027463
# Precision: 0.6306766910837
# Recall: 0.6259335529343965
# F1-Score: 0.6282961704030866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6765943566146886
# Precision: 0.682935897636438
# Recall: 0.6718844570766387
# F1-Score: 0.677365103359081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6289905710263122
# Precision: 0.6324629686554255
# Recall: 0.6216309141438953
# F1-Score: 0.6270001612476518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6631861263711853
# Precision: 0.6574470090283213
# Recall: 0.6584046722104335
# F1-Score: 0.6579254921307205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6626764337447624
# Precision: 0.6559802796375064
# Recall: 0.6756623132566035
# F1-Score: 0.6656758435870119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.67262579198672
# Precision: 0.6757160093925763
# Recall: 0.6914690556213328
# F1-Score: 0.6835017772493688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.656406804964495
# Precision: 0.6533904568432691
# Recall: 0.6469112497864254
# F1-Score: 0.6501347108596497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6242064342763706
# Precision: 0.619220612908482
# Recall: 0.6060460883479026
# F1-Score: 0.6125625219272983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6280599659890361
# Precision: 0.63244557477872
# Recall: 0.6157359088923343
# F1-Score: 0.6239788939441399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6289810484199099
# Precision: 0.6254739254599737
# Recall: 0.6105508948120316
# F1-Score: 0.617922324225078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6398335615734093
# Precision: 0.6383926753407169
# Recall: 0.6580914191953928
# F1-Score: 0.6480923961805145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.6413635831162008
# Precision: 0.6450648862142151
# Recall: 0.659784595727514
# F1-Score: 0.6523417161273273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6407374290510005
# Precision: 0.6407962876558585
# Recall: 0.6221093375023172
# F1-Score: 0.6313145591343788
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6549783633100658
# Precision: 0.6613823864670539
# Recall: 0.6367415147923876
# F1-Score: 0.6488280852196862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6688659179731288
# Precision: 0.6645361486195183
# Recall: 0.6655713483057748
# F1-Score: 0.6650533456236306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6620855514699671
# Precision: 0.6664923399329178
# Recall: 0.654108723506915
# F1-Score: 0.6602424695389777
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6544669469980848
# Precision: 0.6589920210862102
# Recall: 0.6442428188910533
# F1-Score: 0.6515339588353843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.679239777658559
# Precision: 0.6731874882334
# Recall: 0.6792366952377297
# F1-Score: 0.6761985631008995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6352022658275024
# Precision: 0.639964323361911
# Recall: 0.6179899299095102
# F1-Score: 0.628785198365527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6396462110897917
# Precision: 0.6305803304887894
# Recall: 0.652227714380215
# F1-Score: 0.6412213726486604
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.643051048483035
# Precision: 0.6520580071701145
# Recall: 0.6481096091707516
# F1-Score: 0.6500778128485356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6653499643645675
# Precision: 0.6689292655252668
# Recall: 0.6853444339366619
# F1-Score: 0.6770373655003832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6669498571373409
# Precision: 0.6689673897698922
# Recall: 0.6477147375384562
# F1-Score: 0.6581695434301572

# %%
#FFNN-B
import random#FFNN-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-FFNN-Dataset-B-80-20.h5')
    with open('Scaler-Original-FFNN-Dataset-B-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-FFNN-Dataset-B-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder
    

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    prediction = model.predict(features_df)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label


def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        
    }

    return features, None 
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection" 
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.5918010169520547
# Precision: 0.5943404157110855
# Recall: 0.6094437341138746
# F1-Score: 0.6017973277658221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.5973148843089255
# Precision: 0.5942835718859204
# Recall: 0.5862234113326167
# F1-Score: 0.5902259753857017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5945303872252653
# Precision: 0.5863452133062654
# Recall: 0.6115000874516839
# F1-Score: 0.5986585229107317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.5919116615132295
# Precision: 0.5918666254199303
# Recall: 0.5950627059949327
# F1-Score: 0.5934603626159283
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.590549210432513
# Precision: 0.5943957771073652
# Recall: 0.5930336788924189
# F1-Score: 0.5937139467696735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6019390320708011
# Precision: 0.5938223363729589
# Recall: 0.6082419936643644
# F1-Score: 0.6009456777520462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.6017422493073622
# Precision: 0.606252447417964
# Recall: 0.6207216636050273
# F1-Score: 0.6134017406645127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6103891577194281
# Precision: 0.6092302210713451
# Recall: 0.6266500064485794
# F1-Score: 0.617817347444978
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.5919498282918205
# Precision: 0.6018123710026553
# Recall: 0.576988605350466
# F1-Score: 0.5891391126969351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6072810372961895
# Precision: 0.6161475917982873
# Recall: 0.6255319225228747
# F1-Score: 0.6208042948443662
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5950044303842508
# Precision: 0.5957467268754937
# Recall: 0.5928378487595115
# F1-Score: 0.5942887283013911
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6139146584876989
# Precision: 0.6150456382801741
# Recall: 0.6023510250123283
# F1-Score: 0.6086321440137074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6015131750745081
# Precision: 0.5918911380056323
# Recall: 0.5887658619043372
# F1-Score: 0.590324363550123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.607611328800911
# Precision: 0.6131585550105636
# Recall: 0.6107013953759982
# F1-Score: 0.6119275085575078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6175223971143396
# Precision: 0.6111949980063545
# Recall: 0.6079754650833984
# F1-Score: 0.6095809805428403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6171159705286918
# Precision: 0.6136829021050154
# Recall: 0.5993143677538411
# F1-Score: 0.6064135338395368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5993047757856204
# Precision: 0.5995212507705288
# Recall: 0.5939446296004153
# F1-Score: 0.596719911449508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6089581964212882
# Precision: 0.6006936499779041
# Recall: 0.5942750638524221
# F1-Score: 0.5974671187032445
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.5921795187791447
# Precision: 0.5990299832598492
# Recall: 0.5783707117067801
# F1-Score: 0.5885190984391584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6178753115942746
# Precision: 0.6110433976393025
# Recall: 0.6161631127597667
# F1-Score: 0.6135925758710383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6164020392473609
# Precision: 0.6174141691688176
# Recall: 0.6344459054572593
# F1-Score: 0.625814177702656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6021174368739238
# Precision: 0.5923993992184494
# Recall: 0.5893312184783952
# F1-Score: 0.5908613258200939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6127432098026193
# Precision: 0.6139844573604799
# Recall: 0.6111514978247209
# F1-Score: 0.6125647021766364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6154175202169261
# Precision: 0.6211569137975906
# Recall: 0.6143324060102439
# F1-Score: 0.6177258115392278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6181138018214127
# Precision: 0.6267421312298997
# Recall: 0.6347795168283743
# F1-Score: 0.6307352202008721
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6056399883565553
# Precision: 0.5962266620209511
# Recall: 0.5882333449265383
# F1-Score: 0.5922030320615412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6191342525405127
# Precision: 0.6126249930242318
# Recall: 0.6341258493660094
# F1-Score: 0.623190024559437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.5962587011746592
# Precision: 0.5917942021060495
# Recall: 0.5997527403173016
# F1-Score: 0.5957468930181505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6100907075243929
# Precision: 0.6103274008752976
# Recall: 0.6012540387123806
# F1-Score: 0.6057567452304092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.5917284163741594
# Precision: 0.5937915508290488
# Recall: 0.5869321903078759
# F1-Score: 0.5903419459979976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.5993905934622245
# Precision: 0.6001457525310293
# Recall: 0.6154289157479835
# F1-Score: 0.6076912581500954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6175392938832633
# Precision: 0.624572604114422
# Recall: 0.6104066027423412
# F1-Score: 0.6174083568803589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.5953686502467737
# Precision: 0.6019359341226479
# Recall: 0.5778881219788444
# F1-Score: 0.5896669502927903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6034936138205406
# Precision: 0.5962695556700212
# Recall: 0.6192948470936418
# F1-Score: 0.6075641281789895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6110395467816181
# Precision: 0.618246731320988
# Recall: 0.6101368075527462
# F1-Score: 0.6141649981307379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6061609328177874
# Precision: 0.6123587466913665
# Recall: 0.607167849537916
# F1-Score: 0.6097522506256644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6165084768010548
# Precision: 0.6119443734549925
# Recall: 0.6006629138235474
# F1-Score: 0.6062511652595213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6163834475266914
# Precision: 0.6186474289923076
# Recall: 0.6249036258708286
# F1-Score: 0.621759790241193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6053497901686973
# Precision: 0.6013735608147883
# Recall: 0.5887384433494307
# F1-Score: 0.5949889301624899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6092686113061595
# Precision: 0.6143367035603355
# Recall: 0.6045614223359821
# F1-Score: 0.6094098652002153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6008110891455701
# Precision: 0.5962408945817586
# Recall: 0.5969020247746671
# F1-Score: 0.5965712765094051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.602768252977762
# Precision: 0.5966124236788213
# Recall: 0.5924688288760633
# F1-Score: 0.59453340667918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6170311784735408
# Precision: 0.6124909004463417
# Recall: 0.604865768850072
# F1-Score: 0.6086544539592819
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.602092443413478
# Precision: 0.6102406333084854
# Recall: 0.5878973260527414
# F1-Score: 0.5988606466688662
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.5987066729602383
# Precision: 0.5968283885779486
# Recall: 0.6009898430632945
# F1-Score: 0.5989018869677889
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.595699131156572
# Precision: 0.5895125811237228
# Recall: 0.5926224901298451
# F1-Score: 0.5910634449207971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6177409258716662
# Precision: 0.620256427831582
# Recall: 0.6352136199497423
# F1-Score: 0.6276459267447546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6123082872190342
# Precision: 0.6046003626031136
# Recall: 0.6273340051885433
# F1-Score: 0.6157574249513935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.5986377147174963
# Precision: 0.5974857446541464
# Recall: 0.6117479073497595
# F1-Score: 0.6045327193099093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6156444219396192
# Precision: 0.6081754118223921
# Recall: 0.6119202730036238
# F1-Score: 0.6100420953288075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6168486046476094
# Precision: 0.6251975230622866
# Recall: 0.6049390005675633
# F1-Score: 0.6149014479183429
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6022717160366016
# Precision: 0.606995702436259
# Recall: 0.6024424546767984
# F1-Score: 0.6047105076076807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6177713032171889
# Precision: 0.6251474578216584
# Recall: 0.6038530074955848
# F1-Score: 0.6143157520064632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6193048993593331
# Precision: 0.6213032883175413
# Recall: 0.6016760181818845
# F1-Score: 0.6113321568264576
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6121466544999175
# Precision: 0.6174589624442307
# Recall: 0.599667531952231
# F1-Score: 0.6084332134669757
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6092835345811358
# Precision: 0.6092679510369101
# Recall: 0.6206951146916494
# F1-Score: 0.6149284499413731
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6147757162718436
# Precision: 0.6064291625080382
# Recall: 0.6288456947500363
# F1-Score: 0.6174340322291171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6091254856062405
# Precision: 0.6067319593986046
# Recall: 0.6006496933025899
# F1-Score: 0.6036755064387948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6078895263815868
# Precision: 0.6034959811925005
# Recall: 0.6095996495755632
# F1-Score: 0.6065324601363559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.5901303291208603
# Precision: 0.5919562550644544
# Recall: 0.5921372257780176
# F1-Score: 0.5920467265919229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.5953191253568535
# Precision: 0.5899027610030911
# Recall: 0.5892115506691832
# F1-Score: 0.5895569532384242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.5931056624457183
# Precision: 0.5966774581306613
# Recall: 0.5821952989638954
# F1-Score: 0.5893474236821883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5920597838314292
# Precision: 0.6014945082567993
# Recall: 0.5998589076309032
# F1-Score: 0.6006755945373499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6173591651235582
# Precision: 0.6094507813911131
# Recall: 0.6309126398699891
# F1-Score: 0.6199960346578998
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6003467375753239
# Precision: 0.5908055771529979
# Recall: 0.6126774719678196
# F1-Score: 0.6015427765252204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.5902721985932909
# Precision: 0.5966984360205864
# Recall: 0.5948583864656133
# F1-Score: 0.5957769905041553
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6011735077443398
# Precision: 0.6070891345393603
# Recall: 0.5930020605173707
# F1-Score: 0.5999629181222844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.5953242592674998
# Precision: 0.5896501759622861
# Recall: 0.6059710236481086
# F1-Score: 0.5976992057996082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6033432819589886
# Precision: 0.6132687909182706
# Recall: 0.6164106680455687
# F1-Score: 0.6148357156749835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6025838470294674
# Precision: 0.6081618840823938
# Recall: 0.5905783935822048
# F1-Score: 0.5992411788132146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.5947204993478232
# Precision: 0.5968724783110788
# Recall: 0.5757265167643366
# F1-Score: 0.586108830612521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6001647741550602
# Precision: 0.5961476921294419
# Recall: 0.615501085596194
# F1-Score: 0.6056698251618657
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.6060999260755082
# Precision: 0.613711228773032
# Recall: 0.6078090034084985
# F1-Score: 0.610745856701794
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6067388134080555
# Precision: 0.6057574906662321
# Recall: 0.622317554152866
# F1-Score: 0.6139258697447391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.6108038138444283
# Precision: 0.6195778218470782
# Recall: 0.6124998749864974
# F1-Score: 0.6160185179896199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.6130164245550819
# Precision: 0.6059847219117321
# Recall: 0.6114519562461256
# F1-Score: 0.6087060630189894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.5979441624004986
# Precision: 0.5983628855962667
# Recall: 0.5797063523860988
# F1-Score: 0.588886891582555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6097850462335408
# Precision: 0.609853399625107
# Recall: 0.5931967205905544
# F1-Score: 0.601409751131173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.5984534787342037
# Precision: 0.6076352073754855
# Recall: 0.6166494960427497
# F1-Score: 0.6121091660457053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6144866139372934
# Precision: 0.6088110901287034
# Recall: 0.6331839041107897
# F1-Score: 0.6207583520087918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6053579475746466
# Precision: 0.5968513528865828
# Recall: 0.5872455620175153
# F1-Score: 0.5920094947552212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5942405862458283
# Precision: 0.592616279472475
# Recall: 0.587804313092643
# F1-Score: 0.5902004883291115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5978029441051824
# Precision: 0.5949280065042992
# Recall: 0.5882893142094436
# F1-Score: 0.5915900364597165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.6170709034422162
# Precision: 0.6192755055006525
# Recall: 0.6336540703443414
# F1-Score: 0.626382284032833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.5921552678183429
# Precision: 0.5938259927489967
# Recall: 0.6010392764266319
# F1-Score: 0.5974108616470668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6018250217334273
# Precision: 0.6079219767413947
# Recall: 0.6111613213052065
# F1-Score: 0.6095373452348639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.5994650699484727
# Precision: 0.5965394528151451
# Recall: 0.588303917806403
# F1-Score: 0.5923930637905961
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.603148769514949
# Precision: 0.6124357805413212
# Recall: 0.5856854881218663
# F1-Score: 0.5987620092411116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6197131620597134
# Precision: 0.6104138504876336
# Recall: 0.6059902113083893
# F1-Score: 0.6081939872782134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5901243883678113
# Precision: 0.597782160118463
# Recall: 0.5809149586400494
# F1-Score: 0.5892278742256295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.6186013694570063
# Precision: 0.6132750146451157
# Recall: 0.6018615500766296
# F1-Score: 0.6075146804953547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6120069548314191
# Precision: 0.603090252116797
# Recall: 0.6010000967290837
# F1-Score: 0.6020433602943125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6083047602671139
# Precision: 0.6008495095876555
# Recall: 0.6190040960679878
# F1-Score: 0.6097917091539808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.6110623749483091
# Precision: 0.6109194450626679
# Recall: 0.5937817770763724
# F1-Score: 0.602228713764773
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6071149246993943
# Precision: 0.6069363489790421
# Recall: 0.6159688442728652
# F1-Score: 0.6114192391867659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.5994944639392266
# Precision: 0.6082060220196621
# Recall: 0.6083793487864608
# F1-Score: 0.60829267305614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.5931087597919972
# Precision: 0.5919698245216382
# Recall: 0.5751221899575011
# F1-Score: 0.5834244046637292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6046850895760745
# Precision: 0.6089742686731037
# Recall: 0.5942383073141041
# F1-Score: 0.6015160510057649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5989783185218374
# Precision: 0.6068492742275572
# Recall: 0.6147783875324857
# F1-Score: 0.6107880984740803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.5918735283066964
# Precision: 0.5907784781151227
# Recall: 0.5916374920184118
# F1-Score: 0.5912076730340712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6198819149908521
# Precision: 0.6254012772261012
# Recall: 0.6229134372341223
# F1-Score: 0.6241548781486133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6004875171173899
# Precision: 0.6030481123132698
# Recall: 0.6042090080600866
# F1-Score: 0.6036280020293013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.6063163521382997
# Precision: 0.6048476793798876
# Recall: 0.6210439647241165
# F1-Score: 0.6128388306795535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.614292324330906
# Precision: 0.6101019859732433
# Recall: 0.6266755652974194
# F1-Score: 0.6182777275607069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.5970776502614873
# Precision: 0.5958092539238163
# Recall: 0.6148995497824336
# F1-Score: 0.6052038952264059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6008512835942308
# Precision: 0.608659357641961
# Recall: 0.6098864268168366
# F1-Score: 0.6092722744033067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.5989371094477094
# Precision: 0.604399933390901
# Recall: 0.6189026262379456
# F1-Score: 0.6115653124884498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.59184439116451
# Precision: 0.5875904368618556
# Recall: 0.607045071833207
# F1-Score: 0.59715934501719
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: TiSpy
# Accuracy: 0.6168636523585387
# Precision: 0.623768195535418
# Recall: 0.6150862465863103
# F1-Score: 0.6193967993119515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.6019826006137518
# Precision: 0.6047244004384922
# Recall: 0.6015387099589176
# F1-Score: 0.6031273485609722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Eyezy
# Accuracy: 0.5947144845482648
# Precision: 0.5882831183992363
# Recall: 0.585971638007418
# F1-Score: 0.5871251031682155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Qustodio
# Accuracy: 0.6158549933544485
# Precision: 0.6094837949772707
# Recall: 0.5995505435621532
# F1-Score: 0.6044763641905959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.614368946004894
# Precision: 0.6146299992771161
# Recall: 0.6280351619557942
# F1-Score: 0.6212602769935455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.5910768550585549
# Precision: 0.5941379532315137
# Recall: 0.5913649337796464
# F1-Score: 0.5927482003093952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.6146120724339581
# Precision: 0.6080829580617492
# Recall: 0.5991135920264489
# F1-Score: 0.6035649542368662
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: mLite
# Accuracy: 0.6171472068841641
# Precision: 0.6255681011846507
# Recall: 0.6121243323982877
# F1-Score: 0.6187732039353357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.5911744829123248
# Precision: 0.5844884145347236
# Recall: 0.599397007573216
# F1-Score: 0.5918488395769516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.593279185686387
# Precision: 0.594348876841395
# Recall: 0.6066549811437955
# F1-Score: 0.600438881650118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.6112529753067034
# Precision: 0.6153306565448832
# Recall: 0.6266035417306922
# F1-Score: 0.6209159378360903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted Label: kids-360
# Accuracy: 0.596228313472091
# Precision: 0.5916965020774335
# Recall: 0.6121311931167811
# F1-Score: 0.601740410568062

# %%
#CNN-LSTM-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-CNN-LSTM-Dataset-A-1-80-20.h5')
    with open('Scaler-Original-CNN-LSTM-Dataset-A-1-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-CNN-LSTM-Dataset-A-1-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    # Reshape the input to match the expected shape for the LSTM model
    features_reshaped = features_df.values.reshape((features_df.shape[0], features_df.shape[1], 1))
    
    prediction = model.predict(features_reshaped)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
       
     }

    return features, None 
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len    

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.771328141419613
# Precision: 0.7754110955331441
# Recall: 0.7699391667391711
# F1-Score: 0.7726654433632761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7628138449511462
# Precision: 0.7726350939627513
# Recall: 0.7734503919460491
# F1-Score: 0.7730425279886666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7775935661374572
# Precision: 0.7689771034393622
# Recall: 0.7831648739907939
# F1-Score: 0.7760061451517485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7841073661505945
# Precision: 0.7815616355207321
# Recall: 0.7900600518952378
# F1-Score: 0.7857878664605173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7828534027111262
# Precision: 0.788560254217444
# Recall: 0.7960097130166907
# F1-Score: 0.7922674727347621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7512114345386836
# Precision: 0.7542193100734629
# Recall: 0.7376903548134881
# F1-Score: 0.7458632698078762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7701318064284819
# Precision: 0.7654494930100669
# Recall: 0.7776591812297305
# F1-Score: 0.7715060331705691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7598517784687893
# Precision: 0.7567772570572141
# Recall: 0.7546767626109492
# F1-Score: 0.7557255502868968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.761936320256576
# Precision: 0.7605864613546834
# Recall: 0.7628968511784608
# F1-Score: 0.7617399043927269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7672344625152256
# Precision: 0.7703012386331969
# Recall: 0.7701323715965213
# F1-Score: 0.7702167958589989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7708122681826722
# Precision: 0.7616655143364593
# Recall: 0.7838456618544564
# F1-Score: 0.7725964307397885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7585829470596612
# Precision: 0.7591351491842933
# Recall: 0.7649736405151174
# F1-Score: 0.7620432119271835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7789251873549082
# Precision: 0.7713530177958173
# Recall: 0.7637062697023487
# F1-Score: 0.7675105979842447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7564348637397535
# Precision: 0.7647093944716684
# Recall: 0.7739429831670529
# F1-Score: 0.7692984830290748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7612456668902512
# Precision: 0.7592022157875803
# Recall: 0.7609760556562855
# F1-Score: 0.7600881008078249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7774582283036015
# Precision: 0.7749195478550384
# Recall: 0.7713634608142801
# F1-Score: 0.7731374152529806
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7583041827523808
# Precision: 0.7571959106209712
# Recall: 0.7461269116202897
# F1-Score: 0.7516206604790967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7872345876647233
# Precision: 0.7785357881299309
# Recall: 0.7992672942545426
# F1-Score: 0.7887653406260846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7640427465534526
# Precision: 0.7582959948117755
# Recall: 0.7599653604240548
# F1-Score: 0.7591297598636899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7680213540237801
# Precision: 0.7700023124671949
# Recall: 0.7754884096728368
# F1-Score: 0.7727356239482981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7724690752978977
# Precision: 0.762685115501616
# Recall: 0.7773358307842914
# F1-Score: 0.7699407846563094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7885525151373527
# Precision: 0.7931224889333023
# Recall: 0.7805672861117621
# F1-Score: 0.7867948035986261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.76092361184391
# Precision: 0.7607737992689161
# Recall: 0.7663146333385624
# F1-Score: 0.7635341642198089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.782040495389953
# Precision: 0.7884870107164411
# Recall: 0.7790496484804779
# F1-Score: 0.7837399207553712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7797930079865797
# Precision: 0.7805248455251267
# Recall: 0.7934551943319028
# F1-Score: 0.7869369080986214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7720523265126387
# Precision: 0.7714363613106674
# Recall: 0.7709950584930585
# F1-Score: 0.7712156467716081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7585565247875736
# Precision: 0.7508273965046127
# Recall: 0.7741378183573131
# F1-Score: 0.762304447377981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7658900552564168
# Precision: 0.7637579748582491
# Recall: 0.7642360883795123
# F1-Score: 0.7639969568173666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7592824865020883
# Precision: 0.7642191833355818
# Recall: 0.7403186437720608
# F1-Score: 0.7520790759235751
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7778510305166171
# Precision: 0.7710793517985192
# Recall: 0.7949172709407077
# F1-Score: 0.7828168785424993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7812826143200506
# Precision: 0.7894875740804177
# Recall: 0.7923509188688009
# F1-Score: 0.7909166549510709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7559747325373667
# Precision: 0.7605489414364686
# Recall: 0.7642002156925807
# F1-Score: 0.7623702067622412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7583978207287216
# Precision: 0.7532922333616859
# Recall: 0.7531291344682005
# F1-Score: 0.7532106750856575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7887259213950059
# Precision: 0.7811815052546435
# Recall: 0.7726747666188598
# F1-Score: 0.77690485044905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7703192213881523
# Precision: 0.7618984271935226
# Recall: 0.7867487483323021
# F1-Score: 0.7741242077910053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7547844084703605
# Precision: 0.7570802473508481
# Recall: 0.7531245876333268
# F1-Score: 0.7550972369882781
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.751168083238396
# Precision: 0.7435994006099285
# Recall: 0.7684921317696028
# F1-Score: 0.7558408685194464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7784600778274885
# Precision: 0.782704908679392
# Recall: 0.7883483408636546
# F1-Score: 0.7855164887921007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7794426637765974
# Precision: 0.775168095823718
# Recall: 0.7897614780620087
# F1-Score: 0.7823967433680257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7738228511835183
# Precision: 0.7755789118664733
# Recall: 0.7782973401037574
# F1-Score: 0.7769357481084757
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7512488967405759
# Precision: 0.7450699170705446
# Recall: 0.7537041544654574
# F1-Score: 0.7493621654233613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7682693152144225
# Precision: 0.7625946846750927
# Recall: 0.7723038462198107
# F1-Score: 0.7674185572879207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7790846794989433
# Precision: 0.7739161936520439
# Recall: 0.7611290134342209
# F1-Score: 0.767469343881082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7846382288287086
# Precision: 0.78746536904806
# Recall: 0.7875001408919262
# F1-Score: 0.7874827545861495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7554999577237825
# Precision: 0.7500973430467711
# Recall: 0.756785597873978
# F1-Score: 0.7534266276509503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7700641637857524
# Precision: 0.7629999573411417
# Recall: 0.7695696963869951
# F1-Score: 0.7662707454580372
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7815533527601725
# Precision: 0.7884400209097915
# Recall: 0.7794845827041621
# F1-Score: 0.7839367266379699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7640885280093004
# Precision: 0.7678771715270721
# Recall: 0.7818702539211744
# F1-Score: 0.7748105390896095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7600625455842732
# Precision: 0.76170185692395
# Recall: 0.7774439311749781
# F1-Score: 0.7694923906612727
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7843859809288245
# Precision: 0.7765370967722535
# Recall: 0.7806786497783689
# F1-Score: 0.7786023658620511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.775303458335953
# Precision: 0.7819001003808136
# Recall: 0.7766786210601215
# F1-Score: 0.7792806143395753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7856155503229616
# Precision: 0.7891406695274205
# Recall: 0.7943691614836864
# F1-Score: 0.7917462836904546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7737747204964387
# Precision: 0.7714640331645123
# Recall: 0.7889304990042604
# F1-Score: 0.7800995095802966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7886863045750251
# Precision: 0.7970593084412451
# Recall: 0.8084470818450044
# F1-Score: 0.8027128087006042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7718718478320911
# Precision: 0.7776522626357883
# Recall: 0.7869604740833513
# F1-Score: 0.7822786801021758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7789326637970821
# Precision: 0.7861534955854114
# Recall: 0.789094166001978
# F1-Score: 0.7876210859737183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7898798446769972
# Precision: 0.7949889514132117
# Recall: 0.8029058217032103
# F1-Score: 0.7989277742419798
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7599316770409568
# Precision: 0.759388590411903
# Recall: 0.7602007485795952
# F1-Score: 0.7597944524631361
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7669800350692088
# Precision: 0.774425196411378
# Recall: 0.7593859892335574
# F1-Score: 0.766831862185133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7750706666692846
# Precision: 0.772847607404895
# Recall: 0.7851395245691055
# F1-Score: 0.7789450767458278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7869427756435906
# Precision: 0.7915512096945918
# Recall: 0.7709868970868411
# F1-Score: 0.7811337315860213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7578053968320767
# Precision: 0.755540500866228
# Recall: 0.7388056475673832
# F1-Score: 0.7470793692491756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7674182369736421
# Precision: 0.763680316615698
# Recall: 0.7660046500165831
# F1-Score: 0.7648407174212418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7875828032571175
# Precision: 0.7965475743375215
# Recall: 0.776198364175555
# F1-Score: 0.7862413235965255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7739529908976815
# Precision: 0.774860983441281
# Recall: 0.7877170959380777
# F1-Score: 0.7812361528513474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7588546931331527
# Precision: 0.7617263630837913
# Recall: 0.7611838878695437
# F1-Score: 0.7614550288592346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7874913340233785
# Precision: 0.7922893886339151
# Recall: 0.7754467777580633
# F1-Score: 0.7837776108489206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7574639492771218
# Precision: 0.752591744933216
# Recall: 0.7682769871040712
# F1-Score: 0.7603534823707733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7695811116091109
# Precision: 0.762846610592073
# Recall: 0.7608332341011793
# F1-Score: 0.7618385921180654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7872171666263338
# Precision: 0.7861648390945314
# Recall: 0.7847633236260131
# F1-Score: 0.7854634561739476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7887772922774566
# Precision: 0.7817177996640693
# Recall: 0.783377095914947
# F1-Score: 0.7825465682057665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7722083436423524
# Precision: 0.7722522704337087
# Recall: 0.7851353360769224
# F1-Score: 0.7786405174259968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7533782652750963
# Precision: 0.7449588834570928
# Recall: 0.7352662925759709
# F1-Score: 0.7400808542237585
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7521933174682259
# Precision: 0.7481599081134277
# Recall: 0.7587439302010498
# F1-Score: 0.7534147497238937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7733325244030945
# Precision: 0.769900636901016
# Recall: 0.7877148897301599
# F1-Score: 0.7787058936313062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7856740764010026
# Precision: 0.7787141167940479
# Recall: 0.7873249469836627
# F1-Score: 0.7829958586618365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7628246313873958
# Precision: 0.7634194079951198
# Recall: 0.768532923562222
# F1-Score: 0.7659676315570386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.778304103747516
# Precision: 0.7713889913085882
# Recall: 0.771380335392643
# F1-Score: 0.7713846633263329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7572148953391915
# Precision: 0.7563769955947182
# Recall: 0.7393459193720603
# F1-Score: 0.7477644951535353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7885226375805594
# Precision: 0.7833429484212628
# Recall: 0.7727972806495222
# F1-Score: 0.7780343815382389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7772497462141883
# Precision: 0.7864623147420863
# Recall: 0.7703202067682557
# F1-Score: 0.7783075728776934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.752569887152242
# Precision: 0.7506209281358973
# Recall: 0.7660706894440305
# F1-Score: 0.7582671193841176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7574139966098887
# Precision: 0.7667064932180928
# Recall: 0.7597485783188442
# F1-Score: 0.7632116779221919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7731941203960416
# Precision: 0.7808366827525796
# Recall: 0.7748785880208122
# F1-Score: 0.777846226199713
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.788883079567578
# Precision: 0.797909060172487
# Recall: 0.7833691387580178
# F1-Score: 0.7905722518621926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7829180915625645
# Precision: 0.7848707822333107
# Recall: 0.7857086385117735
# F1-Score: 0.7852894868871412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7605579294426925
# Precision: 0.7556582650889125
# Recall: 0.7669670171807449
# F1-Score: 0.7612706452887845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7838827081454823
# Precision: 0.784047561713446
# Recall: 0.7732268710939952
# F1-Score: 0.7785996227262624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7629899877177293
# Precision: 0.7668389026710987
# Recall: 0.7682224710818264
# F1-Score: 0.7675300633634292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7877289643219236
# Precision: 0.7883099721784363
# Recall: 0.8036874106132369
# F1-Score: 0.7959244244355477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7773446602194648
# Precision: 0.7865481619439877
# Recall: 0.7788738759883913
# F1-Score: 0.7826922078521573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7618806314359556
# Precision: 0.7539880476132395
# Recall: 0.7503784237500188
# F1-Score: 0.7521789051595517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7507071052068968
# Precision: 0.7506799757100919
# Recall: 0.7432678475889832
# F1-Score: 0.7469555242458991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7705514384065475
# Precision: 0.7703886171987764
# Recall: 0.7785035262340254
# F1-Score: 0.7744248140229812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7521626537639815
# Precision: 0.746044443177252
# Recall: 0.7552346980658158
# F1-Score: 0.7506114410143888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7685294940439784
# Precision: 0.774191952712148
# Recall: 0.7674519229426202
# F1-Score: 0.7708072042037465
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7755119096244413
# Precision: 0.7748111904051665
# Recall: 0.7613304813808889
# F1-Score: 0.7680116846053779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7620479132586198
# Precision: 0.7610788628773248
# Recall: 0.7669313859864323
# F1-Score: 0.7639939163831209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7595933418664637
# Precision: 0.753637071733425
# Recall: 0.764780595081923
# F1-Score: 0.7591679427768112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7535843920663303
# Precision: 0.7469607050219655
# Recall: 0.7734491718173667
# F1-Score: 0.7599741983791484
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7598810817994943
# Precision: 0.7674206308829779
# Recall: 0.7623890705155488
# F1-Score: 0.7648965762715003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7725638965874396
# Precision: 0.7701921016441532
# Recall: 0.7758374206455781
# F1-Score: 0.7730044542179382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7681512766561153
# Precision: 0.771019152278983
# Recall: 0.7621399766080188
# F1-Score: 0.7665538529047863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7809270991416483
# Precision: 0.7883601753063753
# Recall: 0.763745388341856
# F1-Score: 0.7758575993083451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7671751847287677
# Precision: 0.7690413619891047
# Recall: 0.7543004923611716
# F1-Score: 0.7615996059425575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7718629000370409
# Precision: 0.7716002385872494
# Recall: 0.7874587614015188
# F1-Score: 0.7794488446933813
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.751179227744672
# Precision: 0.7412838598527025
# Recall: 0.7385517852330832
# F1-Score: 0.7399153005629175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.789543276011524
# Precision: 0.791232146718341
# Recall: 0.7723784605325213
# F1-Score: 0.7816916367440655
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.781374243924987
# Precision: 0.7813768882939421
# Recall: 0.7762293123274816
# F1-Score: 0.7787945944578462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.775691236129882
# Precision: 0.7800662519401514
# Recall: 0.7723494905245267
# F1-Score: 0.7761886919606026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7589592996949152
# Precision: 0.7654651588058826
# Recall: 0.7561731124979437
# F1-Score: 0.7607907642162648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7700818325018778
# Precision: 0.7621250036670965
# Recall: 0.7840756267345346
# F1-Score: 0.7729445042912948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7886198064349496
# Precision: 0.7889063427302536
# Recall: 0.79024154897025
# F1-Score: 0.7895733813762995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7707211398933572
# Precision: 0.7788199581558903
# Recall: 0.7577935125204861
# F1-Score: 0.7681628763181758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.773231488016556
# Precision: 0.7740519836537846
# Recall: 0.7770336074415619
# F1-Score: 0.7755399297869239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7588484711409933
# Precision: 0.7525205746319613
# Recall: 0.7519326719559846
# F1-Score: 0.7522265084251469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7787692681632242
# Precision: 0.7731057742096838
# Recall: 0.7935098115432029
# F1-Score: 0.7831749189463951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7755655373043456
# Precision: 0.7709046753497938
# Recall: 0.7790279953176967
# F1-Score: 0.7749450478518598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7866706539191214
# Precision: 0.7956905240160778
# Recall: 0.79303759720254
# F1-Score: 0.7943618456234394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7647899575439051
# Precision: 0.7622424852244428
# Recall: 0.7795552579974486
# F1-Score: 0.7708016694641637

# %%
#CNN-LSTM-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    model = tf.keras.models.load_model('Original-CNN-LSTM-Dataset-B-1-80-20.h5')
    with open('Scaler-Original-CNN-LSTM-Dataset-B-1-80-20.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    with open('Label-Encoder-Original-CNN-LSTM-Dataset-B-1-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, scaler, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    
    # Reshape the input to match the expected shape for the LSTM model
    features_reshaped = features_df.values.reshape((features_df.shape[0], features_df.shape[1], 1))
    
    prediction = model.predict(features_reshaped)
    
    # Check if the prediction is a probability distribution
    if prediction.shape[1] > 1:
        predicted_class = prediction.argmax(axis=1)[0]  # Get the class with the highest probability
    else:
        predicted_class = prediction[0][0]  # Single output class case
    
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]
    
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
       
     }

    return features, None 
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len    

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    model, scaler, label_encoder = load_pretrained_model()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150)
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.784964180347035
# Precision: 0.7817353735187051
# Recall: 0.7924797767172215
# F1-Score: 0.7870709085288776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7857359829176463
# Precision: 0.7842307132042883
# Recall: 0.7883961499530016
# F1-Score: 0.786307915056031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7893813942543304
# Precision: 0.7887255697430121
# Recall: 0.7785305741188356
# F1-Score: 0.783594912725843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7860010057416557
# Precision: 0.794530422561461
# Recall: 0.7926696452945751
# F1-Score: 0.7935989431732647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7742038795209222
# Precision: 0.7814413132617519
# Recall: 0.7667378518733768
# F1-Score: 0.7740197612633936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7779968347315772
# Precision: 0.7795957218530846
# Recall: 0.792525250347409
# F1-Score: 0.7860073182111207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7727099612602698
# Precision: 0.7815560998997834
# Recall: 0.7741821472348549
# F1-Score: 0.7778516478839884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7670034695636777
# Precision: 0.7748560182270026
# Recall: 0.7561385964437333
# F1-Score: 0.7653828909047496
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.778354694992281
# Precision: 0.7770770958649302
# Recall: 0.775468640828754
# F1-Score: 0.776272035157989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7860654195229582
# Precision: 0.7956389297961165
# Recall: 0.7968712632944741
# F1-Score: 0.7962546197364632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7716532777204427
# Precision: 0.7804587440945976
# Recall: 0.7782781979002203
# F1-Score: 0.7793669457940288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7819758046181612
# Precision: 0.786604506586565
# Recall: 0.7958648681881719
# F1-Score: 0.791207592298402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7773967892182221
# Precision: 0.7759395256859726
# Recall: 0.7871991401834226
# F1-Score: 0.7815287802564871
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.785979934355004
# Precision: 0.7869565481964403
# Recall: 0.8039856347516303
# F1-Score: 0.7953799537218241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7883793812770094
# Precision: 0.7971153157829268
# Recall: 0.7691212928010441
# F1-Score: 0.7828681296637029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.784246972012
# Precision: 0.7790854439429639
# Recall: 0.7760945643933317
# F1-Score: 0.777587128179377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7708741445796293
# Precision: 0.7739002645433651
# Recall: 0.752655388808116
# F1-Score: 0.7631299955947003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.777094714883497
# Precision: 0.7717584476470021
# Recall: 0.7672583991444211
# F1-Score: 0.7695018443785397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7696980162205761
# Precision: 0.7727984722158756
# Recall: 0.7787814460293104
# F1-Score: 0.7757784237916598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7893505827478335
# Precision: 0.7932412180626794
# Recall: 0.8027705873223419
# F1-Score: 0.7979774540061725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.782656299600182
# Precision: 0.7784413593081188
# Recall: 0.7855518004609997
# F1-Score: 0.7819804166510206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7890947872165863
# Precision: 0.7866543151503662
# Recall: 0.7973285977021112
# F1-Score: 0.7919554900319455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7780338498607798
# Precision: 0.7731684126244732
# Recall: 0.7832514881789434
# F1-Score: 0.7781772894171679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.785354890318255
# Precision: 0.7942713641629029
# Recall: 0.7839004816386846
# F1-Score: 0.7890518470158965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7723738622606283
# Precision: 0.7704366291125129
# Recall: 0.7588252675686235
# F1-Score: 0.7645868670366412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.766392721789491
# Precision: 0.7679775703378601
# Recall: 0.7655485187037896
# F1-Score: 0.7667611207544528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7832723063783841
# Precision: 0.7741903400453021
# Recall: 0.7849868865131038
# F1-Score: 0.7795512328539229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.781894273031107
# Precision: 0.7819155751922743
# Recall: 0.7688853735037848
# F1-Score: 0.7753457329074257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.784303103893992
# Precision: 0.7799232766176666
# Recall: 0.7972413205611432
# F1-Score: 0.7884872182640651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7793914013029378
# Precision: 0.7817046142428464
# Recall: 0.7926380857144206
# F1-Score: 0.7871333846746299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7852168666206916
# Precision: 0.7853245907746449
# Recall: 0.8010204549832264
# F1-Score: 0.7930948726369806
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7804286398304008
# Precision: 0.780841577326318
# Recall: 0.7680262656022708
# F1-Score: 0.7743809046057761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7672760254250572
# Precision: 0.7610334337412841
# Recall: 0.7483591745120481
# F1-Score: 0.7546430917132319
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7808186772577187
# Precision: 0.7856633087357648
# Recall: 0.796815125106256
# F1-Score: 0.7911999231759262
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7691838866850913
# Precision: 0.7789798981975571
# Recall: 0.7675632455161436
# F1-Score: 0.7732294327290227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7826133992337239
# Precision: 0.7817576434907613
# Recall: 0.7845814366649231
# F1-Score: 0.7831669947133065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7820162051306222
# Precision: 0.7753406886242483
# Recall: 0.7939270013481792
# F1-Score: 0.7845237773977203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7819608027920227
# Precision: 0.7910836611328544
# Recall: 0.769775021377415
# F1-Score: 0.78028388986568
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7858938317065587
# Precision: 0.7819149338241917
# Recall: 0.7874185085474301
# F1-Score: 0.7846570708037072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7828787420942277
# Precision: 0.7776099717409435
# Recall: 0.7996838946256167
# F1-Score: 0.788492473040529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7681496571151165
# Precision: 0.7617197147542266
# Recall: 0.7872917533118028
# F1-Score: 0.7742946545253832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.767211738586846
# Precision: 0.7616143282580052
# Recall: 0.7522785962356708
# F1-Score: 0.7569176768912218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7722900382440224
# Precision: 0.7724958388451405
# Recall: 0.7750546515820891
# F1-Score: 0.7737731297664409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7796494231996663
# Precision: 0.7791431586531055
# Recall: 0.764634305370503
# F1-Score: 0.7718205528770256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7706005667414283
# Precision: 0.774069226176391
# Recall: 0.7815077356942158
# F1-Score: 0.7777706960795223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7858254210586207
# Precision: 0.7819916701849026
# Recall: 0.767411667747487
# F1-Score: 0.7746330695041082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7678382866599947
# Precision: 0.7684636131915579
# Recall: 0.7692961378748526
# F1-Score: 0.7688796501737666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7838040332679025
# Precision: 0.7777772036302375
# Recall: 0.7910581755433105
# F1-Score: 0.7843614745697947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7770320113817152
# Precision: 0.7817213558694666
# Recall: 0.7646648567976851
# F1-Score: 0.7730990405179979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7820189929409667
# Precision: 0.7888062668376541
# Recall: 0.7945168152063758
# F1-Score: 0.7916512429460754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7885501771694527
# Precision: 0.7954385495633108
# Recall: 0.7792054281405796
# F1-Score: 0.787238314626261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7690413090627303
# Precision: 0.77731589844678
# Recall: 0.7729425281119996
# F1-Score: 0.7751230445117323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7697151349275537
# Precision: 0.7681400077080269
# Recall: 0.765154323544571
# F1-Score: 0.7666442587121657
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7767042566719334
# Precision: 0.770910761402558
# Recall: 0.7877652091963016
# F1-Score: 0.7792468591077805
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7742999769707719
# Precision: 0.7655636616206166
# Recall: 0.7562446206124804
# F1-Score: 0.7608756077834326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7664366315693545
# Precision: 0.7575224781693963
# Recall: 0.752412350790584
# F1-Score: 0.7549587672849832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7755911804746215
# Precision: 0.7810292036765766
# Recall: 0.7575450689002496
# F1-Score: 0.7691079104310651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7740503537009216
# Precision: 0.7747070510634606
# Recall: 0.7693886489972102
# F1-Score: 0.7720386908180737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7838051940815305
# Precision: 0.7838209749671753
# Recall: 0.7968555808065106
# F1-Score: 0.7902845347764114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.765571081553923
# Precision: 0.7664267214968541
# Recall: 0.7730931583573231
# F1-Score: 0.7697455064075881
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7807128773006476
# Precision: 0.7852262385960292
# Recall: 0.7757089691482449
# F1-Score: 0.7804385897217444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7677017169330291
# Precision: 0.77456300374326
# Recall: 0.7770638346735999
# F1-Score: 0.7758114038542264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7797234816546468
# Precision: 0.7776656093993277
# Recall: 0.7948239026937475
# F1-Score: 0.7861511442842609
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7858272560559606
# Precision: 0.778994788805842
# Recall: 0.8046505495997375
# F1-Score: 0.7916148518190768
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7792577981706894
# Precision: 0.7723373629434701
# Recall: 0.7827139848354185
# F1-Score: 0.7774910530770698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7832802715418
# Precision: 0.7886685537588606
# Recall: 0.8017698736148567
# F1-Score: 0.7951652522825644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7786403823739599
# Precision: 0.7840757557056629
# Recall: 0.7709887517021072
# F1-Score: 0.777477185353674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7873974986713911
# Precision: 0.7787692845470449
# Recall: 0.7841950370587627
# F1-Score: 0.781472743188595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7712624334011916
# Precision: 0.7796151444733069
# Recall: 0.7670948225125495
# F1-Score: 0.7733043086846749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7663307633006015
# Precision: 0.7629718029379631
# Recall: 0.7502637629710991
# F1-Score: 0.7565644223663194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7691114177525052
# Precision: 0.7787126767524452
# Recall: 0.7559469008478983
# F1-Score: 0.7671609303249435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7721772253840752
# Precision: 0.7664946124081256
# Recall: 0.7637368808949635
# F1-Score: 0.7651132617062496
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7726922726380749
# Precision: 0.7659183248823721
# Recall: 0.7724298430166325
# F1-Score: 0.7691603029767364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7761798980933009
# Precision: 0.7703763149773221
# Recall: 0.7635188492228793
# F1-Score: 0.7669322535308247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7657095327355876
# Precision: 0.764917339110749
# Recall: 0.7656836203088132
# F1-Score: 0.7653002878939879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7796797255843841
# Precision: 0.7740460151611691
# Recall: 0.7730267506718244
# F1-Score: 0.7735360471533309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7682229292797026
# Precision: 0.7711416552225061
# Recall: 0.7699003759175935
# F1-Score: 0.7705205156569126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.766864183492544
# Precision: 0.7626785278558443
# Recall: 0.7529793462473843
# F1-Score: 0.7577979029622327
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7774017051980152
# Precision: 0.7688130095120519
# Recall: 0.7797481336791885
# F1-Score: 0.7742419625484164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7742769404195115
# Precision: 0.7678443333402155
# Recall: 0.7766572849835748
# F1-Score: 0.772225665738364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7832342487541579
# Precision: 0.7783358575234106
# Recall: 0.7941024224299544
# F1-Score: 0.7861400956758279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7760411996232681
# Precision: 0.7677750307429965
# Recall: 0.7704531019471805
# F1-Score: 0.7691117350701553
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7864797838536656
# Precision: 0.7779555049353759
# Recall: 0.8058842511277106
# F1-Score: 0.7916736363076282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7706842997356284
# Precision: 0.7647212762176898
# Recall: 0.7651660140823148
# F1-Score: 0.7649435805074076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7861433136823097
# Precision: 0.7765230129840155
# Recall: 0.7893734894254869
# F1-Score: 0.7828955227056075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7873593822682292
# Precision: 0.784867192820214
# Recall: 0.7715483494983217
# F1-Score: 0.778150783940042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7769866409173278
# Precision: 0.7846794391282488
# Recall: 0.7618639154004091
# F1-Score: 0.7731033832034314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7833801444510428
# Precision: 0.79055388315997
# Recall: 0.7736389208958272
# F1-Score: 0.7820049440095341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7790757888433063
# Precision: 0.7694959716963758
# Recall: 0.7868563503301409
# F1-Score: 0.7780793375813007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7744819022978386
# Precision: 0.7702269753751622
# Recall: 0.7618058350995937
# F1-Score: 0.7659932609538299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7721978079696779
# Precision: 0.7809861967261583
# Recall: 0.7760953213361059
# F1-Score: 0.778533077782012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7821290231449516
# Precision: 0.7815165797671564
# Recall: 0.7784778578713545
# F1-Score: 0.7799942592475616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7716710170064488
# Precision: 0.7779804870955647
# Recall: 0.7652509669131881
# F1-Score: 0.7715632265568081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7853759078637486
# Precision: 0.7808182730286123
# Recall: 0.7942581240587231
# F1-Score: 0.7874808585962069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7716327163324718
# Precision: 0.771369113737696
# Recall: 0.7825900777003345
# F1-Score: 0.7769390830617509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7743448417235259
# Precision: 0.7729756557563462
# Recall: 0.760332485017476
# F1-Score: 0.7666019446066841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7785873869364861
# Precision: 0.7857231995636094
# Recall: 0.7599352720720602
# F1-Score: 0.7726141115790354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7888369427766226
# Precision: 0.7835368921328847
# Recall: 0.8080033406652476
# F1-Score: 0.7955820573442428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7752077612479216
# Precision: 0.7660024050459527
# Recall: 0.7923443228628106
# F1-Score: 0.778950725236745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7727242911090055
# Precision: 0.7696863515268291
# Recall: 0.7668052673736291
# F1-Score: 0.768243108281607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7808050063360173
# Precision: 0.7715053872996368
# Recall: 0.7757071453447385
# F1-Score: 0.7736005609745715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.7846361839111895
# Precision: 0.788835211995285
# Recall: 0.8026967735891979
# F1-Score: 0.7957056286614661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.78513585278703
# Precision: 0.7774734853910835
# Recall: 0.7664113522016706
# F1-Score: 0.7719027879937029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.771451433586736
# Precision: 0.7762763693530713
# Recall: 0.7558184625280893
# F1-Score: 0.7659108297636182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7840911234773789
# Precision: 0.7794732367252754
# Recall: 0.7807889028655078
# F1-Score: 0.7801305150881573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7717634699433582
# Precision: 0.7763020022776467
# Recall: 0.7737007654851135
# F1-Score: 0.7749992011650032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7707468141557995
# Precision: 0.7705808685586567
# Recall: 0.7849853953667324
# F1-Score: 0.7777164390813379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7777878896920848
# Precision: 0.7802664931141146
# Recall: 0.7834749930168514
# F1-Score: 0.7818674514499195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7707969696296886
# Precision: 0.7667548892909214
# Recall: 0.751857661295473
# F1-Score: 0.7592332061611587
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7823808553322306
# Precision: 0.7897580206813283
# Recall: 0.7950120722050692
# F1-Score: 0.7923763369598681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7873665425687097
# Precision: 0.7787051378955963
# Recall: 0.7763826271791582
# F1-Score: 0.7775421482121033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7836759118997945
# Precision: 0.775787012783264
# Recall: 0.7830253872936909
# F1-Score: 0.7793893942748236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7702146320207423
# Precision: 0.7783992460310384
# Recall: 0.7761181730860173
# F1-Score: 0.7772570359543223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7867704832069401
# Precision: 0.7839681770166659
# Recall: 0.7893062667261749
# F1-Score: 0.786628165853934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7687733967191872
# Precision: 0.7675702021831088
# Recall: 0.7661718168752099
# F1-Score: 0.7668703720420705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7820714683783976
# Precision: 0.7890458202292255
# Recall: 0.7959862060420837
# F1-Score: 0.7925008181886652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7847558968065885
# Precision: 0.7825604597542308
# Recall: 0.7853356981750901
# F1-Score: 0.7839456228235909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7727788015713111
# Precision: 0.7671852686005577
# Recall: 0.7876836043892829
# F1-Score: 0.7772993184224556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: mLite
# Accuracy: 0.781160946909044
# Precision: 0.7832516081938654
# Recall: 0.775639981718358
# F1-Score: 0.7794272122470965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Predicted Label: kids-360
# Accuracy: 0.7772550356625048
# Precision: 0.7806882777432693
# Recall: 0.7700747362927554
# F1-Score: 0.7753451870706374

# %%
#FFNN-XGB-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""

def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_models():
    ffnn_model = keras.models.load_model('Original-FFNN-XGB-Dataset-A-80-20-FFNN-Model.h5')
    with open('Original-FFNN-XGB-Dataset-A-80-20-xgb-model.pkl', 'rb') as f:
        xgb_model = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-A-80-20-scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-A-80-20-label_encoder.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-A-80-20-class_names.pkl', 'rb') as f:
        class_names = pickle.load(f)
    return ffnn_model, xgb_model, scaler, label_encoder, class_names

def predict_with_models(ffnn_model, xgb_model, scaler, label_encoder, class_names, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_scaled = scaler.transform(features_df)

    # Get intermediate output from FFNN
    intermediate_output = ffnn_model.predict(features_scaled)

    # Predict with XGBoost
    xgb_predictions = xgb_model.predict(intermediate_output)
    
    # Map predicted class indices to class names
    predicted_class_name = class_names[xgb_predictions[0]]
    
    return predicted_class_name

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tp, tn, fp, fn = 0, 0, 0, 0
    if cm.size == 4:
        tn, fp, fn, tp = cm.ravel()
    
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
       'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
    }

    return features, None

def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False
def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    # Corrected the function name to load_pretrained_models
    ffnn_model, xgb_model, scaler, label_encoder, class_names = load_pretrained_models()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_models(ffnn_model, xgb_model, scaler, label_encoder, class_names, features)
                
                
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
               
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.773428686984403
# Precision: 0.7658489786310106
# Recall: 0.7606961377662894
# F1-Score: 0.76326386151203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7875433508761842
# Precision: 0.7797011468148568
# Recall: 0.7792684371503996
# F1-Score: 0.7794847319308941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.767345046708465
# Precision: 0.7721571246917833
# Recall: 0.7692491645783955
# F1-Score: 0.7707004016100739
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.775164031441563
# Precision: 0.7832942080078499
# Recall: 0.7790009861969407
# F1-Score: 0.7811416981680626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7725215705876781
# Precision: 0.780516814314516
# Recall: 0.7758857609808303
# F1-Score: 0.7781943978315934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7979988606890569
# Precision: 0.7990691699810474
# Recall: 0.8057476586017243
# F1-Score: 0.802394517935907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7752323556222431
# Precision: 0.7693020071368649
# Recall: 0.7800455332477174
# F1-Score: 0.7746365211728535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7667079748921676
# Precision: 0.7625146577555394
# Recall: 0.7802385061781898
# F1-Score: 0.7712747721601332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7656575757374179
# Precision: 0.7628264168041822
# Recall: 0.7718097880343014
# F1-Score: 0.7672918092305357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7684186268008626
# Precision: 0.7684286636245934
# Recall: 0.7804336266564414
# F1-Score: 0.7743846209471464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7963558526720823
# Precision: 0.7986736144192983
# Recall: 0.7972751865332378
# F1-Score: 0.7979737877997988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7895896802393989
# Precision: 0.7869375728756002
# Recall: 0.790103027795768
# F1-Score: 0.7885171234660311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7940066107294419
# Precision: 0.793513588054495
# Recall: 0.8060455598406563
# F1-Score: 0.7997304821971843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7760003257669671
# Precision: 0.7704907231616209
# Recall: 0.7855795680461303
# F1-Score: 0.7779619891271935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.761354276507206
# Precision: 0.7622148768073597
# Recall: 0.7563278323968622
# F1-Score: 0.7592599432365691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.774023754808384
# Precision: 0.779731690937349
# Recall: 0.786673094772896
# F1-Score: 0.7831870127031823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.790977638033913
# Precision: 0.7898260655658379
# Recall: 0.7935818354314081
# F1-Score: 0.7916994962429401
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7606825751488995
# Precision: 0.7703477053482474
# Recall: 0.7484387538559468
# F1-Score: 0.7592352079945883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7942452569531945
# Precision: 0.7994319255557973
# Recall: 0.8061463529957174
# F1-Score: 0.8027750996190031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7740136891940891
# Precision: 0.7826002476511357
# Recall: 0.7638229493430038
# F1-Score: 0.7730975977072349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7666394970471406
# Precision: 0.776418442531521
# Recall: 0.7645289305875665
# F1-Score: 0.7704278185121557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7916495278458248
# Precision: 0.7904155351125484
# Recall: 0.7878029336696651
# F1-Score: 0.7891070719255057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7925621004010488
# Precision: 0.7854628900188378
# Recall: 0.7924980024021019
# F1-Score: 0.7889647636905535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7931037653163142
# Precision: 0.797645616117722
# Recall: 0.7801668282089562
# F1-Score: 0.7888094083665351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.773558464608887
# Precision: 0.7801060727321669
# Recall: 0.7692538992888006
# F1-Score: 0.7746419801014078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7806166230019954
# Precision: 0.7817502528174022
# Recall: 0.7756232271681557
# F1-Score: 0.7786746875070429
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7725440043279601
# Precision: 0.7705108117436473
# Recall: 0.7622763000108427
# F1-Score: 0.7663714369597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.792826767117599
# Precision: 0.7931609590877279
# Recall: 0.7910362381822199
# F1-Score: 0.7920971738000688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7650771374623271
# Precision: 0.7622954010019461
# Recall: 0.77193469968217
# F1-Score: 0.7670847693304271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7865894943946665
# Precision: 0.7870389651662842
# Recall: 0.791405938151753
# F1-Score: 0.789216410759835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7804234293102512
# Precision: 0.7809436700948094
# Recall: 0.7849118332932139
# F1-Score: 0.7829227236696712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7967634644542541
# Precision: 0.7971016479140502
# Recall: 0.8144891197232697
# F1-Score: 0.8057015869993968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7725610974259719
# Precision: 0.7655332529215515
# Recall: 0.7738743470895428
# F1-Score: 0.7696812023998453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7930960185471978
# Precision: 0.7889071279608888
# Recall: 0.789662120332226
# F1-Score: 0.7892844435990517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7935012109458794
# Precision: 0.7840412836366731
# Recall: 0.8120075967277331
# F1-Score: 0.7977794242940529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7825181728007498
# Precision: 0.791198163791607
# Recall: 0.7692440810079775
# F1-Score: 0.7800666848509253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.795654905618388
# Precision: 0.790713347131959
# Recall: 0.8063713668341544
# F1-Score: 0.7984656003843458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7964387771167973
# Precision: 0.790600095130702
# Recall: 0.8049584129268673
# F1-Score: 0.7977146492872804
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7639426960308914
# Precision: 0.7648161969425786
# Recall: 0.7484843890729135
# F1-Score: 0.7565621651266242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7657004241020575
# Precision: 0.7573410816288777
# Recall: 0.7490725930025466
# F1-Score: 0.7531841450415663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7641869307971452
# Precision: 0.7700391681355742
# Recall: 0.7695396531194293
# F1-Score: 0.7697893295938943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7668350958935186
# Precision: 0.7651456555932397
# Recall: 0.7667007511267084
# F1-Score: 0.7659224140112156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7814309655914025
# Precision: 0.7847370791738191
# Recall: 0.7834347119711994
# F1-Score: 0.7840853547643083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7764812763267012
# Precision: 0.7773397344486276
# Recall: 0.7761357012371236
# F1-Score: 0.7767372512452259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7771205917848996
# Precision: 0.7778725440091846
# Recall: 0.76798507061792
# F1-Score: 0.7728971866360921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7867794451422078
# Precision: 0.7839327177669569
# Recall: 0.790413463855885
# F1-Score: 0.7871597519186287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7862841740522166
# Precision: 0.7856655513123181
# Recall: 0.7910626010373515
# F1-Score: 0.7883548392795301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7901896100559054
# Precision: 0.787260473688788
# Recall: 0.8086107655464317
# F1-Score: 0.7977928026561909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7663563494565402
# Precision: 0.7667601901812847
# Recall: 0.7532064072081133
# F1-Score: 0.7599228680795791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7678593811454368
# Precision: 0.7660711865783191
# Recall: 0.77965880841039
# F1-Score: 0.7728052770167646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7748785511693841
# Precision: 0.7684950589413724
# Recall: 0.7658296965433382
# F1-Score: 0.7671600626663952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7932403379325784
# Precision: 0.7972049357537982
# Recall: 0.8119996475930306
# F1-Score: 0.8045342818315736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7670140947162669
# Precision: 0.7740668694233552
# Recall: 0.7780829868003265
# F1-Score: 0.7760697323510317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7681489944626736
# Precision: 0.7707515097530855
# Recall: 0.7850632363147082
# F1-Score: 0.7778415472285777
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7689330157930214
# Precision: 0.7692307106214036
# Recall: 0.78310777849576
# F1-Score: 0.7761072178117933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7633187171534019
# Precision: 0.7693595430951723
# Recall: 0.7622761504953972
# F1-Score: 0.7658014674268316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7857783179169554
# Precision: 0.7954311488856026
# Recall: 0.7843331889392607
# F1-Score: 0.7898431869225166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7864331029019761
# Precision: 0.7856399253815154
# Recall: 0.7750255925429042
# F1-Score: 0.7802966640846352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7700415879934737
# Precision: 0.7640071392014685
# Recall: 0.7590601246233315
# F1-Score: 0.7615255978111435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7667337260036892
# Precision: 0.7764751976457531
# Recall: 0.7635484383675606
# F1-Score: 0.7699575652336705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7600141772089807
# Precision: 0.7658009410152093
# Recall: 0.751585232244939
# F1-Score: 0.7586264963383599
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7934906574294798
# Precision: 0.7966415552873959
# Recall: 0.8084912352922188
# F1-Score: 0.8025226559440533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7645028539569497
# Precision: 0.7578124175263828
# Recall: 0.7572570941580865
# F1-Score: 0.7575346540699922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7769169801520881
# Precision: 0.7700106223946775
# Recall: 0.7571302962648061
# F1-Score: 0.7635161412248489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7827033581494165
# Precision: 0.7760417636807366
# Recall: 0.7953575705197674
# F1-Score: 0.7855809511298038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7726406574020719
# Precision: 0.7711416501734081
# Recall: 0.7725830254009664
# F1-Score: 0.7718616648813966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7796617744408435
# Precision: 0.7880021804235344
# Recall: 0.7706553435177543
# F1-Score: 0.7792322325066622
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7752396466569789
# Precision: 0.7653171728425762
# Recall: 0.7936089048897178
# F1-Score: 0.7792063165899402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7910710971718626
# Precision: 0.7878327278807152
# Recall: 0.7797414852973907
# F1-Score: 0.7837662245772186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7625396846069843
# Precision: 0.7587738286271798
# Recall: 0.7450326275067966
# F1-Score: 0.7518404471793744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7901656231150368
# Precision: 0.7998926642867334
# Recall: 0.7859252818488088
# F1-Score: 0.7928474629263823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7720955603505768
# Precision: 0.763033421969042
# Recall: 0.7776664201291695
# F1-Score: 0.7702804316426348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7602821681966231
# Precision: 0.7698030520710173
# Recall: 0.7602773339024611
# F1-Score: 0.7650105411764623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7976383316535052
# Precision: 0.8005209829353526
# Recall: 0.7777662680141963
# F1-Score: 0.7889795941646212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7942506825655611
# Precision: 0.8009358282671829
# Recall: 0.7971021852155672
# F1-Score: 0.79901440834668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7910944612770708
# Precision: 0.7875713814447601
# Recall: 0.7831623738496752
# F1-Score: 0.7853606896640831
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.784216916335071
# Precision: 0.7910488482412488
# Recall: 0.7888597756461375
# F1-Score: 0.789952795388003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7719019370331376
# Precision: 0.7651397954659039
# Recall: 0.7878479934269229
# F1-Score: 0.7763278718098141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7984482560417706
# Precision: 0.7977009179061617
# Recall: 0.7967423228995519
# F1-Score: 0.7972213322444693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7963981024332445
# Precision: 0.7910738852153484
# Recall: 0.8140676264215496
# F1-Score: 0.8024060625092222
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7663172349380264
# Precision: 0.7747290936403657
# Recall: 0.7790250833677704
# F1-Score: 0.7768711494926044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7911982523267588
# Precision: 0.7824160345648229
# Recall: 0.8090446777497554
# F1-Score: 0.7955075782299474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.788382965096129
# Precision: 0.7961896740791695
# Recall: 0.8016860261223907
# F1-Score: 0.7989283969606581
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7936177407726117
# Precision: 0.7960219652420729
# Recall: 0.7985365328587789
# F1-Score: 0.7972772663541791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7714502297089046
# Precision: 0.7713575204739191
# Recall: 0.7804324661200865
# F1-Score: 0.775868457928431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7671197235816797
# Precision: 0.7654984441228884
# Recall: 0.783139283711606
# F1-Score: 0.7742183887655054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7664531052424148
# Precision: 0.7571941913667561
# Recall: 0.7511600696354529
# F1-Score: 0.7541650608481028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7971103212186437
# Precision: 0.8002838987840444
# Recall: 0.7925734937287816
# F1-Score: 0.7964100347157139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7728701305868165
# Precision: 0.7771510202870846
# Recall: 0.7926789634095457
# F1-Score: 0.784838194672787
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.78978104237748
# Precision: 0.7910141051338825
# Recall: 0.7724882016629374
# F1-Score: 0.7816413968927999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7769340635720036
# Precision: 0.7768418388179267
# Recall: 0.757300590438204
# F1-Score: 0.7669467606070578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7792666812762827
# Precision: 0.7802642204177096
# Recall: 0.7718417107852295
# F1-Score: 0.7760301132087678
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7784144990780726
# Precision: 0.7827304864759884
# Recall: 0.7813279067440279
# F1-Score: 0.7820285677236721
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7814510648005439
# Precision: 0.7718490313302433
# Recall: 0.7880568554882671
# F1-Score: 0.7798687416743438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7607968514327406
# Precision: 0.756298733102707
# Recall: 0.7434410088055925
# F1-Score: 0.7498147543664241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7984205766523911
# Precision: 0.7908174914381729
# Recall: 0.7954354032446487
# F1-Score: 0.7931197254909658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7915627685187369
# Precision: 0.7970262440401742
# Recall: 0.7906653909503619
# F1-Score: 0.793833075583949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.797568973785018
# Precision: 0.7993776392661578
# Recall: 0.7883425919176626
# F1-Score: 0.7938217674410232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7605089425406204
# Precision: 0.7656394832803701
# Recall: 0.7639284673760612
# F1-Score: 0.7647830183339795
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7704026935655898
# Precision: 0.7633811987125562
# Recall: 0.7546066213169282
# F1-Score: 0.758968549729417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7624928895629589
# Precision: 0.7708705300515274
# Recall: 0.7455296465900957
# F1-Score: 0.7579883498943402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7784878797891652
# Precision: 0.7722230049820604
# Recall: 0.7847288513068059
# F1-Score: 0.7784257030229349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7649283381107141
# Precision: 0.7594145653167484
# Recall: 0.7644023168553782
# F1-Score: 0.7619002781415186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7729726512123039
# Precision: 0.7690109239215203
# Recall: 0.766307508522323
# F1-Score: 0.7676568361114944
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7883811625112798
# Precision: 0.7850132174089296
# Recall: 0.7972427510856577
# F1-Score: 0.7910807221427644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7620374013403077
# Precision: 0.765074959763416
# Recall: 0.7626666320306532
# F1-Score: 0.7638688976563571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7613121196598843
# Precision: 0.7655369764262815
# Recall: 0.7433680075242368
# F1-Score: 0.754289637724194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7704004300408883
# Precision: 0.7767376535772713
# Recall: 0.7876860419246335
# F1-Score: 0.7821735374109373
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7891402415351192
# Precision: 0.7883982244975019
# Recall: 0.7905635051851048
# F1-Score: 0.7894793801819958
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7729156799100282
# Precision: 0.7646048581103911
# Recall: 0.7781806686753532
# F1-Score: 0.771333032915338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7625662864771827
# Precision: 0.758572247947741
# Recall: 0.781391313490252
# F1-Score: 0.7698127151107989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.780453720602467
# Precision: 0.7780894769831453
# Recall: 0.77561090671547
# F1-Score: 0.7768482148559839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7616252621958801
# Precision: 0.7641247236579526
# Recall: 0.7568792436355843
# F1-Score: 0.7604847263016584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7639075792592749
# Precision: 0.76436188004067
# Recall: 0.76272157993163
# F1-Score: 0.7635408490308786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7979100367043864
# Precision: 0.8065375677008776
# Recall: 0.8124753940150674
# F1-Score: 0.809495592192418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7872481624456985
# Precision: 0.7826109513027907
# Recall: 0.7990463569925248
# F1-Score: 0.7907432618952497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7903184442067421
# Precision: 0.7811055946690638
# Recall: 0.8042405529562534
# F1-Score: 0.7925042695752523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7855571272578936
# Precision: 0.7799343668631648
# Recall: 0.7983950330572452
# F1-Score: 0.7890567389108999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7849151905766768
# Precision: 0.7829729589945619
# Recall: 0.8015620281918493
# F1-Score: 0.7921584541916096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7914558933293157
# Precision: 0.7914276809432612
# Recall: 0.7802843541762452
# F1-Score: 0.7858165148618474

# %%
#FFNN-XGB-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""

def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_models():
    ffnn_model = keras.models.load_model('Original-FFNN-XGB-Dataset-B-1-80-20-FFNN-Model.h5')
    with open('Original-FFNN-XGB-Dataset-B-1-80-20-xgb-model.pkl', 'rb') as f:
        xgb_model = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-B-1-80-20-scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-B-1-80-20-label_encoder.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    with open('Original-FFNN-XGB-Dataset-B-1-80-20-class_names.pkl', 'rb') as f:
        class_names = pickle.load(f)
    return ffnn_model, xgb_model, scaler, label_encoder, class_names

def predict_with_models(ffnn_model, xgb_model, scaler, label_encoder, class_names, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_scaled = scaler.transform(features_df)

    # Get intermediate output from FFNN
    intermediate_output = ffnn_model.predict(features_scaled)

    # Predict with XGBoost
    xgb_predictions = xgb_model.predict(intermediate_output)
    
    # Map predicted class indices to class names
    predicted_class_name = class_names[xgb_predictions[0]]
    
    return predicted_class_name

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tp, tn, fp, fn = 0, 0, 0, 0
    if cm.size == 4:
        tn, fp, fn, tp = cm.ravel()
    
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
       'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
    }

    return features, None

def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False
def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    # Corrected the function name to load_pretrained_models
    ffnn_model, xgb_model, scaler, label_encoder, class_names = load_pretrained_models()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_models(ffnn_model, xgb_model, scaler, label_encoder, class_names, features)
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")     
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
          0)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7762060961374001
# Precision: 0.776081859745392
# Recall: 0.7922490182143886
# F1-Score: 0.7840821093022582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7685471257076635
# Precision: 0.7598157775648778
# Recall: 0.7630363947945014
# F1-Score: 0.7614226806044382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7627580860988271
# Precision: 0.7607339989730519
# Recall: 0.7637240134745168
# F1-Score: 0.7622260739728971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7704146100462959
# Precision: 0.7781416450996043
# Recall: 0.76245108114949
# F1-Score: 0.7702164608269191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7618548330270711
# Precision: 0.7555363799806474
# Recall: 0.7564293858339339
# F1-Score: 0.7559826191911828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.762254285637481
# Precision: 0.7560608128163803
# Recall: 0.7720433687314728
# F1-Score: 0.7639685094001355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7754574581432645
# Precision: 0.775417891349172
# Recall: 0.7914146902326115
# F1-Score: 0.7833346300003501
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.762090355131058
# Precision: 0.7697572481307796
# Recall: 0.7693341330930904
# F1-Score: 0.7695456324521865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7625772114152592
# Precision: 0.756633953176475
# Recall: 0.7640411616956593
# F1-Score: 0.7603195171796343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.763012718493604
# Precision: 0.7614648698728799
# Recall: 0.7749460551065636
# F1-Score: 0.7681463173898172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7798262620701379
# Precision: 0.7788735844221777
# Recall: 0.7670909827108707
# F1-Score: 0.7729373828922013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7713712375945796
# Precision: 0.7729754897906647
# Recall: 0.7731453525244011
# F1-Score: 0.7730604118266488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7703039265899005
# Precision: 0.7628867312918144
# Recall: 0.75230841723144
# F1-Score: 0.7575606480846694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7632312291295826
# Precision: 0.7562909019977292
# Recall: 0.779275389107377
# F1-Score: 0.76761112867163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7633087230723796
# Precision: 0.7618185269309146
# Recall: 0.7787910690342662
# F1-Score: 0.7702113066833657
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7658526877308854
# Precision: 0.7582049877920074
# Recall: 0.7520043253421834
# F1-Score: 0.7550919271346644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7659428457019184
# Precision: 0.7690941221246939
# Recall: 0.7745304234645704
# F1-Score: 0.7718027000742634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7678257425101885
# Precision: 0.7608881165971866
# Recall: 0.7829282639073307
# F1-Score: 0.7717508632217946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7632747270466393
# Precision: 0.7653132014398722
# Recall: 0.7709535204520991
# F1-Score: 0.7681230068850317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7693987362910261
# Precision: 0.7608825601877883
# Recall: 0.7679843198262122
# F1-Score: 0.7644169457684823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7719258878166385
# Precision: 0.7804415498555825
# Recall: 0.7666882621234085
# F1-Score: 0.7735037757204064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7676256672771457
# Precision: 0.7720417604521305
# Recall: 0.7599412989329766
# F1-Score: 0.765943741576334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.765966037582424
# Precision: 0.7745469175486505
# Recall: 0.764270185028614
# F1-Score: 0.7693742355693984
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7748973258799422
# Precision: 0.767746432193889
# Recall: 0.7692288231139303
# F1-Score: 0.7684869127813597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7742667905781001
# Precision: 0.7832534903910736
# Recall: 0.7791530216384441
# F1-Score: 0.7811978752627389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7620428571951868
# Precision: 0.7626111365346196
# Recall: 0.7595303174470371
# F1-Score: 0.7610676091970697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.771052528314337
# Precision: 0.7761985514742349
# Recall: 0.7602269645153563
# F1-Score: 0.7681297433652772
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7674952453917089
# Precision: 0.7666906347481465
# Recall: 0.7779921863510946
# F1-Score: 0.7723000670883969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7713043290306189
# Precision: 0.7635149039992164
# Recall: 0.7850858427808775
# F1-Score: 0.7741501392509735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7679580813820802
# Precision: 0.7631462165110672
# Recall: 0.7689712273325473
# F1-Score: 0.766047648765762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7650278105786673
# Precision: 0.7574757853941058
# Recall: 0.7781471468849811
# F1-Score: 0.7676723352445481
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7685141813454995
# Precision: 0.7728177132863364
# Recall: 0.7760572826908327
# F1-Score: 0.7744341101070725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7702486116769262
# Precision: 0.7661382802599156
# Recall: 0.7802660373501368
# F1-Score: 0.773137624091133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.77309092760158
# Precision: 0.7782313823276215
# Recall: 0.7848495362518922
# F1-Score: 0.7815264485111578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7705006282450818
# Precision: 0.7727574399588679
# Recall: 0.7868853319846988
# F1-Score: 0.7797573978147886
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7724023127519696
# Precision: 0.7795498652546127
# Recall: 0.7569398357291911
# F1-Score: 0.7680784929059015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7727283174079341
# Precision: 0.7676827923987691
# Recall: 0.7541917852632909
# F1-Score: 0.7608774917635841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7786346126611182
# Precision: 0.7852236279368491
# Recall: 0.7734583465472914
# F1-Score: 0.7792965837497474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7690992908694659
# Precision: 0.7617917610740323
# Recall: 0.7758600783027672
# F1-Score: 0.768761562613352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7641377550119584
# Precision: 0.7650160976922818
# Recall: 0.7476540971221712
# F1-Score: 0.7562354593417614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7643849600536518
# Precision: 0.7684305612907719
# Recall: 0.758625147530487
# F1-Score: 0.7634963735227827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7621620330047858
# Precision: 0.7717448927231101
# Recall: 0.7556807028258755
# F1-Score: 0.7636283228914587
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7620743694024961
# Precision: 0.7613272381663917
# Recall: 0.7450821639690208
# F1-Score: 0.7531171078691694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.773612949080635
# Precision: 0.7701302553843578
# Recall: 0.7731856267235744
# F1-Score: 0.7716549166264561
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7786634260056675
# Precision: 0.7736372963599284
# Recall: 0.7886388676503986
# F1-Score: 0.7810660566019834
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7720333915744507
# Precision: 0.7779185458745992
# Recall: 0.7619844012741885
# F1-Score: 0.7698690342996924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7764979400004395
# Precision: 0.7817543013854867
# Recall: 0.763856811104357
# F1-Score: 0.7727019337503064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7745272807842684
# Precision: 0.7733741193796028
# Recall: 0.7931613267935914
# F1-Score: 0.7831427550949054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7788937754757386
# Precision: 0.7820643393450689
# Recall: 0.7688587078719383
# F1-Score: 0.7754053026686841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7602165509261154
# Precision: 0.7680060938896962
# Recall: 0.7522108229138202
# F1-Score: 0.7600264008406156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7656737842948251
# Precision: 0.7619171606487427
# Recall: 0.7618079976893296
# F1-Score: 0.7618625752587012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7641915860143944
# Precision: 0.769588718389501
# Recall: 0.7496509729969996
# F1-Score: 0.7594890191707503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7789215702840179
# Precision: 0.7767304525799452
# Recall: 0.7721799275850595
# F1-Score: 0.7744485056164435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.761373508768069
# Precision: 0.753464646070654
# Recall: 0.7460507944458541
# F1-Score: 0.749739392605724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7786254736260835
# Precision: 0.7704074966366111
# Recall: 0.7756055786568287
# F1-Score: 0.7729977990218271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7671162865790304
# Precision: 0.760928221803139
# Recall: 0.7596509099186535
# F1-Score: 0.7602890293792308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7721533363296793
# Precision: 0.7776984387658555
# Recall: 0.7838849168526179
# F1-Score: 0.78077942341661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7649556777337012
# Precision: 0.7621317930854997
# Recall: 0.7679842146996693
# F1-Score: 0.7650468116566442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7664303462191908
# Precision: 0.759081521446978
# Recall: 0.7848407976169999
# F1-Score: 0.7717462716776552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7793102410111763
# Precision: 0.775869381822661
# Recall: 0.7938791168889711
# F1-Score: 0.784770936450142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7677453551798711
# Precision: 0.7705199377843679
# Recall: 0.7510651475701013
# F1-Score: 0.7606681694608025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7647536130451124
# Precision: 0.7643733671997932
# Recall: 0.7473656588604403
# F1-Score: 0.7557738410464047
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7628303191503473
# Precision: 0.7707516933894488
# Recall: 0.7774429653307598
# F1-Score: 0.7740828695762715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7744846537481985
# Precision: 0.7692354401630932
# Recall: 0.7613643464923927
# F1-Score: 0.7652796548185935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7647973705180563
# Precision: 0.7690785178700751
# Recall: 0.7630964127575202
# F1-Score: 0.7660757872798922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.778387904066838
# Precision: 0.7879256281772633
# Recall: 0.7810857642869873
# F1-Score: 0.7844907875647115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7658666671927964
# Precision: 0.7715043685762265
# Recall: 0.7544771854275373
# F1-Score: 0.7628957807795428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7674788191009223
# Precision: 0.7624875290310276
# Recall: 0.7859787394441297
# F1-Score: 0.7740549459948293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7775877358556623
# Precision: 0.7786267451321393
# Recall: 0.7865153560690549
# F1-Score: 0.7825511705582462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7725675579244806
# Precision: 0.7816880350924043
# Recall: 0.7625706333025902
# F1-Score: 0.7720110007023797
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7640167586082478
# Precision: 0.7650292985450403
# Recall: 0.7527193770282282
# F1-Score: 0.7588244170816489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.77504793201897
# Precision: 0.7762514399639932
# Recall: 0.7730753985711732
# F1-Score: 0.7746601639057453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7727154542894862
# Precision: 0.7749689876360476
# Recall: 0.7753457807125462
# F1-Score: 0.7751573383858462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7791628679748198
# Precision: 0.7845758370906859
# Recall: 0.7754793134258636
# F1-Score: 0.7800010548039314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7634938455132583
# Precision: 0.767674486812605
# Recall: 0.7707135499980439
# F1-Score: 0.7691910165927699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7741267935063589
# Precision: 0.7828477347181797
# Recall: 0.75761797256286
# F1-Score: 0.7700262469970206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7693945563864685
# Precision: 0.767028166638684
# Recall: 0.7826238011544673
# F1-Score: 0.7747475069801438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7647063013914766
# Precision: 0.7547177385114825
# Recall: 0.7633201684113723
# F1-Score: 0.7589945793005963
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7742441082917306
# Precision: 0.7694485914507402
# Recall: 0.7701335135614752
# F1-Score: 0.7697909001536296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7634449345578594
# Precision: 0.7604854908221262
# Recall: 0.7450369790278323
# F1-Score: 0.7526819745614053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7769608845113556
# Precision: 0.774355631268221
# Recall: 0.774195462373453
# F1-Score: 0.7742755385375859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7665094921648704
# Precision: 0.7650441029867874
# Recall: 0.7859638753308732
# F1-Score: 0.7753629077198415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7797979674519975
# Precision: 0.7889608732566977
# Recall: 0.7646100473838617
# F1-Score: 0.7765946216811126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7728109779612541
# Precision: 0.7733305595518677
# Recall: 0.7646967821011967
# F1-Score: 0.7689894378005485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7694629610734479
# Precision: 0.760990033899699
# Recall: 0.7825987059748377
# F1-Score: 0.7716431202239253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7648363617654256
# Precision: 0.7717711541937581
# Recall: 0.7684453533980657
# F1-Score: 0.7701046630828926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7646428355143062
# Precision: 0.769762814574577
# Recall: 0.7724690826264836
# F1-Score: 0.7711135741564593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7797824571637229
# Precision: 0.7838832401576746
# Recall: 0.7689650693737659
# F1-Score: 0.776352495538553
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7794649212705792
# Precision: 0.7872107301095822
# Recall: 0.7635017470174941
# F1-Score: 0.7751749941718303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7721234423574505
# Precision: 0.781720223429554
# Recall: 0.7905643901022957
# F1-Score: 0.7861174323623145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7656079881457205
# Precision: 0.7564578835697802
# Recall: 0.7720926929039442
# F1-Score: 0.7641953277610107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7621273659530604
# Precision: 0.756370390067712
# Recall: 0.7631696290943735
# F1-Score: 0.7597547978555341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7681843921623651
# Precision: 0.7779076414662892
# Recall: 0.7573606081502536
# F1-Score: 0.7674966307324981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7752796078612161
# Precision: 0.7850975755482104
# Recall: 0.7665166039383154
# F1-Score: 0.7756958338297335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7775874401441241
# Precision: 0.7771293945284755
# Recall: 0.7702723673802474
# F1-Score: 0.7736856881251722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7715591646516499
# Precision: 0.7756608825826538
# Recall: 0.7653824807772667
# F1-Score: 0.7704874044019209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7677250720861073
# Precision: 0.7583166930785047
# Recall: 0.7793850055170528
# F1-Score: 0.7687065190322228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7735709376322659
# Precision: 0.7784641951619601
# Recall: 0.7910307618166086
# F1-Score: 0.7846971697588283
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7608759923298388
# Precision: 0.766107824430184
# Recall: 0.7644378337068176
# F1-Score: 0.765271917998321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7713433100861661
# Precision: 0.7745876262207976
# Recall: 0.7880576815374014
# F1-Score: 0.7812645977132724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7714433104490651
# Precision: 0.7694161124692064
# Recall: 0.7841569575524588
# F1-Score: 0.7767166018618995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7675369345795333
# Precision: 0.763730453258445
# Recall: 0.7815775601306879
# F1-Score: 0.7725509465858537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7610305047349035
# Precision: 0.7588191275038478
# Recall: 0.7744818771086082
# F1-Score: 0.7665705044048233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.773911338533879
# Precision: 0.7832444960259825
# Recall: 0.7738880173165328
# F1-Score: 0.7785381461241172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7655789718160981
# Precision: 0.7625759286757955
# Recall: 0.7559066749453791
# F1-Score: 0.7592266559578082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7742038950229772
# Precision: 0.7741030624050478
# Recall: 0.7719731479096806
# F1-Score: 0.7730366380447706
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7660036447959714
# Precision: 0.7565175522426622
# Recall: 0.78039675467404
# F1-Score: 0.7682716465936571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7600137786037628
# Precision: 0.7587825369119626
# Recall: 0.7736972238922604
# F1-Score: 0.7661673026449985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7749575736737775
# Precision: 0.7734778337994175
# Recall: 0.7686516285100315
# F1-Score: 0.7710571791760922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7669487145695469
# Precision: 0.7571953856643278
# Recall: 0.7591813799176199
# F1-Score: 0.7581870822655161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7626854197850511
# Precision: 0.7672345102433854
# Recall: 0.7678150719352039
# F1-Score: 0.7675246813039555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7713451900184268
# Precision: 0.7723369260108846
# Recall: 0.7728431751619662
# F1-Score: 0.7725899676549267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7607250996307863
# Precision: 0.762843526337012
# Recall: 0.7702288038812545
# F1-Score: 0.7665183765406064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7707543875482035
# Precision: 0.762958532926352
# Recall: 0.7612164354662546
# F1-Score: 0.7620864886073377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7736295784530972
# Precision: 0.7642155712591455
# Recall: 0.7879385128576386
# F1-Score: 0.7758957527251216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7634562164577975
# Precision: 0.7674229223222141
# Recall: 0.7827116682363924
# F1-Score: 0.7749918999707114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7657982560457024
# Precision: 0.7673702741345763
# Recall: 0.7479304341548089
# F1-Score: 0.7575256569884212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7651305107510321
# Precision: 0.7652211774204253
# Recall: 0.7500978725978155
# F1-Score: 0.757584057618687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7612653334120842
# Precision: 0.7585928065877187
# Recall: 0.772416847409637
# F1-Score: 0.7654424158622923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7609030104650171
# Precision: 0.7584563585158234
# Recall: 0.7567199447526787
# F1-Score: 0.7575871566567192

# %%
#LSTM-XGB-A
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_models():
    lstm_model = keras.models.load_model('Original-LSTM-XGB-Dataset-A-1-80-20-LSTM-Model.h5')
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-XGB-model.pkl', 'rb') as f:
        xgb_model = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-label_encoder.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-class_names.pkl', 'rb') as f:
        class_names = pickle.load(f)
    return lstm_model, xgb_model, scaler, label_encoder, class_names
def predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_scaled = scaler.transform(features_df)
    features_scaled_reshaped = features_scaled.reshape((features_scaled.shape[0], 1, features_scaled.shape[1]))
    intermediate_output = lstm_model.predict(features_scaled_reshaped)
    xgb_predictions = xgb_model.predict(intermediate_output)
    
    # Map predicted class indices to class names
    predicted_class_name = class_names[xgb_predictions[0]]
    
    return predicted_class_name

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
       
    }

    return features, None  
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    lstm_model, xgb_model, scaler, label_encoder, class_names = load_pretrained_models()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1
        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features)
               
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
               
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
                
            
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.786784610833189
# Precision: 0.7828291100441318
# Recall: 0.7699146524838987
# F1-Score: 0.7763181752958768
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7966861679207604
# Precision: 0.7939348550388127
# Recall: 0.7898821989019214
# F1-Score: 0.7919033420212206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7858969215971522
# Precision: 0.7876719505142771
# Recall: 0.7884549574250924
# F1-Score: 0.7880632594739817
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.774301866636338
# Precision: 0.7659787240967231
# Recall: 0.7807263555302735
# F1-Score: 0.7732822314412803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7931291290498422
# Precision: 0.7935290876846371
# Recall: 0.7770001466268043
# F1-Score: 0.7851776382295967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7646704856097769
# Precision: 0.7636821467647839
# Recall: 0.7666159410074151
# F1-Score: 0.7651462316403264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.773610329956129
# Precision: 0.7749456526155557
# Recall: 0.7693942817685621
# F1-Score: 0.7721599895577328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7759127747391157
# Precision: 0.768198951486607
# Recall: 0.7689772884858094
# F1-Score: 0.7685879229338245
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7866501717919104
# Precision: 0.7776000760479098
# Recall: 0.7684913199351728
# F1-Score: 0.7730188659950187
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.795626401750402
# Precision: 0.7925753451830923
# Recall: 0.7966333190191265
# F1-Score: 0.7945991511730083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7655767726872963
# Precision: 0.7555866741448142
# Recall: 0.7504784073664429
# F1-Score: 0.7530238776540802
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7794971602171138
# Precision: 0.7848259280725389
# Recall: 0.7820863036808897
# F1-Score: 0.7834537208664338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7855318387261733
# Precision: 0.7912653117482475
# Recall: 0.7919870824045644
# F1-Score: 0.7916260325565598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7713971022563104
# Precision: 0.7726448594741361
# Recall: 0.7782660317134938
# F1-Score: 0.7754452588134125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7991675247358148
# Precision: 0.8073359427560431
# Recall: 0.8138346560620168
# F1-Score: 0.8105722738598793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7919039442316521
# Precision: 0.7972213922228746
# Recall: 0.7776339324221346
# F1-Score: 0.7873058515836254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7668683177463068
# Precision: 0.7571548673350016
# Recall: 0.7850294095853954
# F1-Score: 0.7708402262479883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7766617884076065
# Precision: 0.7797795294433378
# Recall: 0.7838689564179927
# F1-Score: 0.7818188953691346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7659072217653063
# Precision: 0.7693138980886821
# Recall: 0.774642574790883
# F1-Score: 0.7719690409747888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7735538665729965
# Precision: 0.7785455669419611
# Recall: 0.7803600448787577
# F1-Score: 0.7794517499355273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7818002117300128
# Precision: 0.7781382991319339
# Recall: 0.7885749248910161
# F1-Score: 0.7833218503347479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7990556485706568
# Precision: 0.798281255007506
# Recall: 0.810424373097247
# F1-Score: 0.8043069836299656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7922642833669272
# Precision: 0.7993814208708099
# Recall: 0.7900935464533069
# F1-Score: 0.7947103474652106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7621024773187436
# Precision: 0.756460896885864
# Recall: 0.7465771073022567
# F1-Score: 0.7514865048131332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7984768535026001
# Precision: 0.801747652188084
# Recall: 0.7902185336489403
# F1-Score: 0.7959413456202742
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.760068629675749
# Precision: 0.7643646612006076
# Recall: 0.7442278716129078
# F1-Score: 0.7541618728292743
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7723371073318888
# Precision: 0.7732922435120699
# Recall: 0.7600242629286585
# F1-Score: 0.7666008484679786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7734708630574072
# Precision: 0.7813819464853717
# Recall: 0.7753027430581639
# F1-Score: 0.7783304744442192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7718710313518472
# Precision: 0.7649998349248909
# Recall: 0.7670757876555941
# F1-Score: 0.7660364048388648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7863812538681725
# Precision: 0.7958160413284924
# Recall: 0.793768111717836
# F1-Score: 0.7947907573052787
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7951155426241202
# Precision: 0.8028716774825402
# Recall: 0.8017274764268859
# F1-Score: 0.8022991690035894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7600593403081143
# Precision: 0.7621912427535718
# Recall: 0.7438828856226859
# F1-Score: 0.7529257828326774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7811687727434554
# Precision: 0.7722561655540575
# Recall: 0.8004853403538124
# F1-Score: 0.7861174098880587
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7620495542585148
# Precision: 0.7695433655336245
# Recall: 0.7534771290155983
# F1-Score: 0.7614255064727715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.762066377264175
# Precision: 0.7632029089179141
# Recall: 0.7767248261524551
# F1-Score: 0.7699045003838783
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7719366429232297
# Precision: 0.7774538628657892
# Recall: 0.7707857387884641
# F1-Score: 0.7741054413317802
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7948069373947797
# Precision: 0.8042334695322076
# Recall: 0.7803718999708331
# F1-Score: 0.7921230266130052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7618628499991281
# Precision: 0.7609611434305984
# Recall: 0.7562091071378497
# F1-Score: 0.758577683189667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7613871182381178
# Precision: 0.7611444038084062
# Recall: 0.7555584547285223
# F1-Score: 0.7583411428676219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7965803468544059
# Precision: 0.798912918025744
# Recall: 0.7835513041569535
# F1-Score: 0.7911575504228212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.775872665176276
# Precision: 0.7827185433675865
# Recall: 0.7771515526914256
# F1-Score: 0.7799251140660092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7837027065698792
# Precision: 0.7762726384804701
# Recall: 0.7955955321807995
# F1-Score: 0.7858153176668056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7699838334805342
# Precision: 0.7724489586655798
# Recall: 0.7819953600410315
# F1-Score: 0.7771928454119426
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7604805913485835
# Precision: 0.7539454080322807
# Recall: 0.7579391146805312
# F1-Score: 0.7559369865842416
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7832318826112303
# Precision: 0.7785050063203545
# Recall: 0.7768442648472705
# F1-Score: 0.7776737489462285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7607653670676948
# Precision: 0.7536708616915411
# Recall: 0.7408534447749917
# F1-Score: 0.7472071905352019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7911908948538475
# Precision: 0.796353298468612
# Recall: 0.7901730254585163
# F1-Score: 0.7932511244152729
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7836559171268643
# Precision: 0.7858638773471202
# Recall: 0.8027475704201023
# F1-Score: 0.794216004307379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7680774543699388
# Precision: 0.7640637818399687
# Recall: 0.748500441234981
# F1-Score: 0.7562020430130805
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7830195581655427
# Precision: 0.7901537506789301
# Recall: 0.7645683166849032
# F1-Score: 0.7771505090980041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7699044882255635
# Precision: 0.7780404854771181
# Recall: 0.7676946500261528
# F1-Score: 0.772832944642954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7848938395704874
# Precision: 0.7858100099426101
# Recall: 0.7828245365846421
# F1-Score: 0.7843144322414164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7811180955348406
# Precision: 0.7834082031245843
# Recall: 0.7749226808172515
# F1-Score: 0.7791423390184029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7845320451454144
# Precision: 0.775875327340425
# Recall: 0.7783729514299226
# F1-Score: 0.7771221325867176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7708865386998993
# Precision: 0.764743947469181
# Recall: 0.7661863578212454
# F1-Score: 0.7654644731408569
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7604735119497584
# Precision: 0.7596074430920178
# Recall: 0.7724123428925326
# F1-Score: 0.7659563801524276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7979688761079444
# Precision: 0.7911888071444486
# Recall: 0.7878378234902681
# F1-Score: 0.789509759616893
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7703896079923658
# Precision: 0.7692941686686057
# Recall: 0.7538356685956296
# F1-Score: 0.761486473177679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7786663376626856
# Precision: 0.7687046943589436
# Recall: 0.790680649718286
# F1-Score: 0.7795378217266665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7961978031940626
# Precision: 0.7912595162168804
# Recall: 0.7938461573755222
# F1-Score: 0.7925507263020573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.787435559334515
# Precision: 0.7843079191449784
# Recall: 0.7708199166744835
# F1-Score: 0.7775054255445203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7922161688965894
# Precision: 0.787055398527427
# Recall: 0.7782408920667996
# F1-Score: 0.7826233271445977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.787911254682254
# Precision: 0.7915395155341739
# Recall: 0.8045140448062894
# F1-Score: 0.7979740443429336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7724446555152549
# Precision: 0.7680392178136609
# Recall: 0.7843800921341234
# F1-Score: 0.7761236523804415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7928301498244411
# Precision: 0.7874312878312143
# Recall: 0.8037732302369226
# F1-Score: 0.7955183417630455
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7820587622553149
# Precision: 0.7815525498663486
# Recall: 0.7660546234906728
# F1-Score: 0.7737259876191108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7745322300938962
# Precision: 0.7819640564655894
# Recall: 0.7888602812717318
# F1-Score: 0.7853970309835916
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.783276514647493
# Precision: 0.7891109172726363
# Recall: 0.7661963535781007
# F1-Score: 0.777484833658942
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7981763657357134
# Precision: 0.7919458842546139
# Recall: 0.7875923040514272
# F1-Score: 0.7897630944055228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7669359932325664
# Precision: 0.7618223177437193
# Recall: 0.7776265560993059
# F1-Score: 0.7696433124508517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7859674945722404
# Precision: 0.7808067789140098
# Recall: 0.778354330386974
# F1-Score: 0.7795786258877291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7847756628188041
# Precision: 0.7909078477640462
# Recall: 0.7691418324601745
# F1-Score: 0.7798729989790317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.788329220580674
# Precision: 0.7865912890990938
# Recall: 0.7742158114511818
# F1-Score: 0.7803544883356579
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7806236467944445
# Precision: 0.7899127127737235
# Recall: 0.796524060825332
# F1-Score: 0.7932046106680782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7960970643723139
# Precision: 0.803812613778736
# Recall: 0.7778891120493743
# F1-Score: 0.7906384246486925
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7971445380273684
# Precision: 0.8011318733054984
# Recall: 0.8160049072074277
# F1-Score: 0.8084999955665043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.789623965063516
# Precision: 0.784243018719278
# Recall: 0.7721463876953326
# F1-Score: 0.7781476942513441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7751873052758811
# Precision: 0.7788381432654499
# Recall: 0.7861946295736181
# F1-Score: 0.7824990967206403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7921541214115747
# Precision: 0.7993070608023733
# Recall: 0.8087251756829246
# F1-Score: 0.8039885376737118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7952370750397062
# Precision: 0.8040093368796118
# Recall: 0.7844105018923909
# F1-Score: 0.7940890085526434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7623130382296568
# Precision: 0.7623421411332345
# Recall: 0.746913986533471
# F1-Score: 0.7545492077830143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7747904063863421
# Precision: 0.7703021490569449
# Recall: 0.7880012085490593
# F1-Score: 0.7790511666962366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7735183468412943
# Precision: 0.7823417311840324
# Recall: 0.7653865617253552
# F1-Score: 0.7737712755765528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7685022436404508
# Precision: 0.7707050090715153
# Recall: 0.7718318914774621
# F1-Score: 0.771268038659066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7661223675553621
# Precision: 0.7582562294969749
# Recall: 0.7688361543366922
# F1-Score: 0.7635095422645927
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7970018636586107
# Precision: 0.7871404379360539
# Recall: 0.7776440989744522
# F1-Score: 0.7823634528414908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7648468947868313
# Precision: 0.7688247233822613
# Recall: 0.7694060863494212
# F1-Score: 0.7691152950049225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7837665485736156
# Precision: 0.7797166851380292
# Recall: 0.7650952220395705
# F1-Score: 0.7723367583741118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7635084495151128
# Precision: 0.7662236657315052
# Recall: 0.7607340545969266
# F1-Score: 0.7634689922320499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7991525977474371
# Precision: 0.8044781698007887
# Recall: 0.7818748816223261
# F1-Score: 0.7930154932616812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7767410099938801
# Precision: 0.7753853649004533
# Recall: 0.7669083343004323
# F1-Score: 0.7711235531142316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.785325229387512
# Precision: 0.7880237470227868
# Recall: 0.7839209809113118
# F1-Score: 0.7859670098698388
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7771144787886766
# Precision: 0.7687117613810276
# Recall: 0.7919988048248731
# F1-Score: 0.7801815524945668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7966944392551812
# Precision: 0.8020853946939537
# Recall: 0.8031179982410246
# F1-Score: 0.8026013643382118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7723988639014449
# Precision: 0.7816698434024525
# Recall: 0.7664595788464276
# F1-Score: 0.7739899912255286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7904918904286372
# Precision: 0.7973220417017101
# Recall: 0.7767059961385439
# F1-Score: 0.7868790081946365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7858141680695561
# Precision: 0.7834516294653676
# Recall: 0.8011688139315595
# F1-Score: 0.7922111763318848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7817505397618087
# Precision: 0.7803458426790272
# Recall: 0.7914518220820282
# F1-Score: 0.7858595961667119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7858054465376225
# Precision: 0.7782360684588793
# Recall: 0.7947337262567814
# F1-Score: 0.7863983818018002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.780179014966015
# Precision: 0.7818074918325025
# Recall: 0.7720922996082865
# F1-Score: 0.7769195253707513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7940608868061173
# Precision: 0.7976790435863288
# Recall: 0.8085385753831208
# F1-Score: 0.8030720991942097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7724355569730942
# Precision: 0.7680775505880949
# Recall: 0.775331969000384
# F1-Score: 0.7716877109857952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7710072100440374
# Precision: 0.7644480077651552
# Recall: 0.7547689006721907
# F1-Score: 0.7595776208618308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7716740513761093
# Precision: 0.7717760204611953
# Recall: 0.7555729901117687
# F1-Score: 0.7635885595757482
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7797960471139043
# Precision: 0.7743418116731078
# Recall: 0.793427620785069
# F1-Score: 0.7837685422235502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7836571049647483
# Precision: 0.7821786400322641
# Recall: 0.7924989252197518
# F1-Score: 0.7873049635481532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7662033779514019
# Precision: 0.7581652495632537
# Recall: 0.7519923095060942
# F1-Score: 0.7550661632388707
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7945570857837475
# Precision: 0.7982137334530841
# Recall: 0.776153406985705
# F1-Score: 0.7870290135117032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7853030893665492
# Precision: 0.7763932098874758
# Recall: 0.7920033807877933
# F1-Score: 0.7841206117220919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7635570599376247
# Precision: 0.7570991637750295
# Recall: 0.7788380175634364
# F1-Score: 0.7678147504699802
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7644537363876285
# Precision: 0.7640069522869043
# Recall: 0.7473404035784192
# F1-Score: 0.755581781835853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7893416150581971
# Precision: 0.7875075218230485
# Recall: 0.7952003183142697
# F1-Score: 0.7913352245405412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7906478122100387
# Precision: 0.7890380249679566
# Recall: 0.7904742881657097
# F1-Score: 0.7897555035640182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7957683111468078
# Precision: 0.7965903012181423
# Recall: 0.781411097357336
# F1-Score: 0.78892769294248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7649280844122589
# Precision: 0.7646203450946102
# Recall: 0.7574232859830011
# F1-Score: 0.7610047997125841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.762097131438227
# Precision: 0.7571613654973988
# Recall: 0.7643341707023079
# F1-Score: 0.7607308606777533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.7909674434201011
# Precision: 0.785353411665326
# Recall: 0.774203139067853
# F1-Score: 0.7797384151323006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7663060302883287
# Precision: 0.7574481255044592
# Recall: 0.7626222393490881
# F1-Score: 0.7600263764350589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: kids-360
# Accuracy: 0.7807671847465432
# Precision: 0.7903380149224355
# Recall: 0.7753069719189359
# F1-Score: 0.7827503403286143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7626176838510372
# Precision: 0.7598224750200055
# Recall: 0.763221424905787
# F1-Score: 0.7615181572750012

# %%
#LSTM-XGB-B
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_models():
    lstm_model = keras.models.load_model('Original-LSTM-XGB-Dataset-B-1-80-20-LSTM-Model.h5')
    with open('Original-LSTM-XGB-Dataset-B-1-80-20-XGB-model.pkl', 'rb') as f:
        xgb_model = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-B-1-80-20-scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-B-1-80-20-label_encoder.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-B-1-80-20-class_names.pkl', 'rb') as f:
        class_names = pickle.load(f)
    return lstm_model, xgb_model, scaler, label_encoder, class_names
def predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_scaled = scaler.transform(features_df)
    features_scaled_reshaped = features_scaled.reshape((features_scaled.shape[0], 1, features_scaled.shape[1]))
    intermediate_output = lstm_model.predict(features_scaled_reshaped)
    xgb_predictions = xgb_model.predict(intermediate_output)
    
    # Map predicted class indices to class names
    predicted_class_name = class_names[xgb_predictions[0]]
    
    return predicted_class_name

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
       
    }

    return features, None  
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    csv_files = ['1-Update-3-All_together-Bi.csv', '2-Update-3-All_together-Bi.csv','3-Update-3-All_together-Bi.csv']
    # Load the saved model and encoders
    with open('knn_model_with_encoders-A-11.pkl', 'rb') as file:
        data = pickle.load(file)
    
    knn = data['model']  # Loaded kNN model
    label_encoder = data['label_encoder']  # Loaded label encoder
    protocol_encoder = data['protocol_encoder']  # Loaded protocol encoder
    lstm_model, xgb_model, scaler, label_encoder, class_names = load_pretrained_models()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)
    interface_name = "Bluetooth Network Connection"  
    initial_packets = sniff(iface=interface_name, count=150) 
    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1
        if packet_count % 150 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                X_features = np.array([features[feature] for feature in features.keys()]).reshape(1, -1)
                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    # Use the saved kNN model for prediction
                    nearest_neighbor_label = knn.predict(X_features)[0]
                    label = label_encoder.inverse_transform([nearest_neighbor_label])[0]

                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        true_labels.append(label)
                    else:
                        label = 'Normal-Traffic'
                        true_labels.append(label)
                    predicted_label = predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features)
               
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
            captured_packets = []
            packet_count = 0
    scapy.sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
if __name__ == '__main__':
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7611886166100114
# Precision: 0.7659836583232709
# Recall: 0.7585476161205861
# F1-Score: 0.762247502230352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7718296715533906
# Precision: 0.7790807128796773
# Recall: 0.7562743573032304
# F1-Score: 0.7675081508673157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7599879923510788
# Precision: 0.7653136495433819
# Recall: 0.7492067507531636
# F1-Score: 0.7571745518504395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7760028647087723
# Precision: 0.7833061137302466
# Recall: 0.7754453556750833
# F1-Score: 0.7793559138657917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7873051544477305
# Precision: 0.7957921404844754
# Recall: 0.7800322765515318
# F1-Score: 0.7878334010986935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7618020793897877
# Precision: 0.756006841540854
# Recall: 0.7659439232009895
# F1-Score: 0.7609429419023441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7770925419371513
# Precision: 0.7755681035945161
# Recall: 0.7842367730724501
# F1-Score: 0.7798783501184627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7510452299524322
# Precision: 0.7544608059805448
# Recall: 0.7661175755628211
# F1-Score: 0.76024451031366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7560716126230842
# Precision: 0.7640546778349678
# Recall: 0.7741192655697156
# F1-Score: 0.7690540443709744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7687451925130155
# Precision: 0.7593610691298058
# Recall: 0.7715053061323236
# F1-Score: 0.7653850180145794
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7743716078048573
# Precision: 0.7741852684542868
# Recall: 0.7876232832058049
# F1-Score: 0.7808464645700581
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7689597079362597
# Precision: 0.7642969103238171
# Recall: 0.7855421273783444
# F1-Score: 0.7747739039721436
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7589901182208626
# Precision: 0.7591553762483648
# Recall: 0.7407826241211303
# F1-Score: 0.7498564761935408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7828438187155285
# Precision: 0.7828966606036893
# Recall: 0.7988688186024288
# F1-Score: 0.7908020987512733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7841326272021069
# Precision: 0.7855810030437917
# Recall: 0.7769921070655716
# F1-Score: 0.7812629500362517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7589139405232732
# Precision: 0.7567304878348191
# Recall: 0.7672402441425915
# F1-Score: 0.7619491267830136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7875398330509418
# Precision: 0.7887635630445906
# Recall: 0.7854818319418594
# F1-Score: 0.787119276883241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.773950730376803
# Precision: 0.7713918216173196
# Recall: 0.775064537995926
# F1-Score: 0.7732238185954209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7862002108089446
# Precision: 0.7830405351909286
# Recall: 0.767889583883423
# F1-Score: 0.7753910551308202
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7871769546686966
# Precision: 0.7801412414968292
# Recall: 0.7953059348085356
# F1-Score: 0.7876506031847644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7691394556471992
# Precision: 0.7696648903672275
# Recall: 0.7774833703761946
# F1-Score: 0.773554375112567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7533615484512078
# Precision: 0.7464941225831812
# Recall: 0.7689155501719082
# F1-Score: 0.7575389669020639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7684114295024576
# Precision: 0.7653079690719587
# Recall: 0.7580100495239371
# F1-Score: 0.7616415278432946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7815314017276686
# Precision: 0.7873405581404774
# Recall: 0.7773619733325527
# F1-Score: 0.7823194474986181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7827169228860555
# Precision: 0.789265104737913
# Recall: 0.7753879886490174
# F1-Score: 0.7822650077006499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7828510442050772
# Precision: 0.7805920573921128
# Recall: 0.7693811171869578
# F1-Score: 0.774946042981303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7873405897401835
# Precision: 0.7927990005422957
# Recall: 0.7806417202033747
# F1-Score: 0.7866733934095138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7619545531546354
# Precision: 0.7545106641423718
# Recall: 0.7525434927569424
# F1-Score: 0.75352579456638
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7576625291613701
# Precision: 0.7555395522940687
# Recall: 0.768691821592643
# F1-Score: 0.7620589428719944
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7646173720232307
# Precision: 0.7640285885049674
# Recall: 0.7808681719101187
# F1-Score: 0.7723566033404653
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7585427864398022
# Precision: 0.7609942252752743
# Recall: 0.770841596980235
# F1-Score: 0.7658862593253595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7699007956227737
# Precision: 0.7731002212692236
# Recall: 0.7730960605908588
# F1-Score: 0.7730981409244431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7601593323626694
# Precision: 0.7582111640997274
# Recall: 0.7603672616717971
# F1-Score: 0.7592876822579524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7527831517915142
# Precision: 0.7430371540941547
# Recall: 0.7652053298154637
# F1-Score: 0.7539583278279186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7573140564816518
# Precision: 0.7512313217068646
# Recall: 0.7725201333838349
# F1-Score: 0.7617270111975807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.783123523531944
# Precision: 0.784465445275379
# Recall: 0.7780236732818594
# F1-Score: 0.7812312803296896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7752920589005157
# Precision: 0.7708511321223688
# Recall: 0.7914747249303713
# F1-Score: 0.7810268069297165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.762028749692351
# Precision: 0.7619024272541373
# Recall: 0.7599431960766173
# F1-Score: 0.7609215505036838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7675855638007186
# Precision: 0.7736164052645321
# Recall: 0.7485296537420632
# F1-Score: 0.7608662999656733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7730066915348868
# Precision: 0.7746286536231032
# Recall: 0.7741438975806999
# F1-Score: 0.7743861997391094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7521667136581311
# Precision: 0.7518645471699048
# Recall: 0.7405361207482183
# F1-Score: 0.7461573383855704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7743968781148299
# Precision: 0.7676555989234319
# Recall: 0.7931571211970783
# F1-Score: 0.7801980302491606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.78883377449186
# Precision: 0.7789443338831478
# Recall: 0.7801431333672605
# F1-Score: 0.7795432727401566
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7576592252305933
# Precision: 0.7504324004973713
# Recall: 0.7690558264578686
# F1-Score: 0.7596299855797023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.766642867691721
# Precision: 0.7610133080179508
# Recall: 0.7534877409842511
# F1-Score: 0.7572318272016781
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7695797341247504
# Precision: 0.7716866844437922
# Recall: 0.7813570079461849
# F1-Score: 0.7764917391358314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7597914514134055
# Precision: 0.7647313807689474
# Recall: 0.7677457038199459
# F1-Score: 0.7662355777661196
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7709528292495226
# Precision: 0.7734507452120478
# Recall: 0.7778402390466613
# F1-Score: 0.7756392819288443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7688912663426438
# Precision: 0.7667753093096399
# Recall: 0.7684636389461154
# F1-Score: 0.76761854578478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.7691975781642042
# Precision: 0.7751315885833739
# Recall: 0.7869002540921959
# F1-Score: 0.7809715875783587
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7769104779733697
# Precision: 0.7844249142952057
# Recall: 0.7932349223456092
# F1-Score: 0.7888053197852715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7770187735072059
# Precision: 0.7798334306779918
# Recall: 0.7967000082953073
# F1-Score: 0.7881764957611362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7871714371750588
# Precision: 0.7945673416293207
# Recall: 0.804116225241771
# F1-Score: 0.7993132658539138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7717780656517385
# Precision: 0.7779031675487371
# Recall: 0.7794357849294792
# F1-Score: 0.7786687220949856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7692081993425965
# Precision: 0.7607613400400037
# Recall: 0.7567877413051668
# F1-Score: 0.758769338373991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7782673133012374
# Precision: 0.7692766929407423
# Recall: 0.7892310111095271
# F1-Score: 0.7791261096942671
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7769852107579938
# Precision: 0.781787632278814
# Recall: 0.7615933513632622
# F1-Score: 0.7715583763595875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7884951375064082
# Precision: 0.7846898137500808
# Recall: 0.802044655118718
# F1-Score: 0.7932723255114386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7684292065825032
# Precision: 0.7646317743848092
# Recall: 0.749470239444531
# F1-Score: 0.7569750965269797
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7891607016626092
# Precision: 0.7798571328445814
# Recall: 0.7943452519703316
# F1-Score: 0.7870345219469659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7695587739344734
# Precision: 0.7754983707317482
# Recall: 0.754721830569819
# F1-Score: 0.7649690540809065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7615032831088928
# Precision: 0.7589216568193966
# Recall: 0.7463577177187858
# F1-Score: 0.7525872542894084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7831450780956779
# Precision: 0.7768858358786063
# Recall: 0.8002475488114964
# F1-Score: 0.7883936665133567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7881469111792258
# Precision: 0.7803113635014507
# Recall: 0.7959991300572958
# F1-Score: 0.7880771828381268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7652869955128759
# Precision: 0.7740033560896399
# Recall: 0.7510041180583098
# F1-Score: 0.762330306792816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7816878155466193
# Precision: 0.7859750561289583
# Recall: 0.7755403303956632
# F1-Score: 0.7807228285718733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7594882241837752
# Precision: 0.7567060609554712
# Recall: 0.749770759206153
# F1-Score: 0.753222446207452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.752855750615858
# Precision: 0.755048436106441
# Recall: 0.7344283638184613
# F1-Score: 0.7445956695146917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7592951666893946
# Precision: 0.7560919505048254
# Recall: 0.7484330276656075
# F1-Score: 0.7522429948594946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.770254835383311
# Precision: 0.7616510904856582
# Recall: 0.7767770975351748
# F1-Score: 0.7691397336694388
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7539133955816189
# Precision: 0.7575366307531166
# Recall: 0.7448942969661587
# F1-Score: 0.7511622738591418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7644688377109328
# Precision: 0.7641854179475138
# Recall: 0.7843559932529923
# F1-Score: 0.7741393393658045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7747717753661133
# Precision: 0.7732973939739232
# Recall: 0.7750773456237311
# F1-Score: 0.7741863467170775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7732300842386517
# Precision: 0.7648710153602363
# Recall: 0.7745733347655616
# F1-Score: 0.7696916007190341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.763447888678808
# Precision: 0.76256963481215
# Recall: 0.7646210795392323
# F1-Score: 0.7635939793433651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.778398802272288
# Precision: 0.7861777354887266
# Recall: 0.7854557377674836
# F1-Score: 0.7858165707876855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7685069858854299
# Precision: 0.772419282313201
# Recall: 0.7863330318306025
# F1-Score: 0.7793140585512208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7890479943585383
# Precision: 0.7911629386394645
# Recall: 0.7697275993518912
# F1-Score: 0.7802980857822526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7768978917691336
# Precision: 0.780004538145173
# Recall: 0.779029714384623
# F1-Score: 0.7795168214988665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7697733516045145
# Precision: 0.7775867993206672
# Recall: 0.7591974952093765
# F1-Score: 0.7682821232014947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7573960165809014
# Precision: 0.7532046971000688
# Recall: 0.7720824204318616
# F1-Score: 0.7625267386492488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7671534633844751
# Precision: 0.7656696575458636
# Recall: 0.7653561843226029
# F1-Score: 0.765512888842854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7725472400779709
# Precision: 0.764238377574783
# Recall: 0.7708459361848817
# F1-Score: 0.7675279362176854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7773095405305228
# Precision: 0.7689765465780241
# Recall: 0.7907606224563493
# F1-Score: 0.7797164608224726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7842735240390484
# Precision: 0.7882629722383443
# Recall: 0.7747846395621599
# F1-Score: 0.781465693322504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7790346101153973
# Precision: 0.773098787386272
# Recall: 0.7831895526738913
# F1-Score: 0.7781114564443441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7535292445082388
# Precision: 0.762773697002726
# Recall: 0.7623114632896895
# F1-Score: 0.7625425100976586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7876783181456738
# Precision: 0.7798721836273044
# Recall: 0.8062434631905016
# F1-Score: 0.7928385946322386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7754926981898841
# Precision: 0.7768249659846433
# Recall: 0.790392772670592
# F1-Score: 0.7835501393331419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7815349343002399
# Precision: 0.7804429291278473
# Recall: 0.7690414058756536
# F1-Score: 0.7747002197616107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7502386926544071
# Precision: 0.7522591843697657
# Recall: 0.7486674500904837
# F1-Score: 0.7504590196999067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7670961418850325
# Precision: 0.7747619935102293
# Recall: 0.7527345197535547
# F1-Score: 0.7635894315230004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7629273162622623
# Precision: 0.7662588329266998
# Recall: 0.776799424997187
# F1-Score: 0.7714931277025528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7709672433317568
# Precision: 0.761855777812765
# Recall: 0.7876518073795411
# F1-Score: 0.7745390678836801
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Qustodio
# Accuracy: 0.767864332785324
# Precision: 0.7760556887077992
# Recall: 0.7494793903742745
# F1-Score: 0.7625360471149375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7503575213364827
# Precision: 0.7481780266267363
# Recall: 0.7428512263917043
# F1-Score: 0.7455051113368364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7593529665698676
# Precision: 0.767825723586173
# Recall: 0.7725236558403263
# F1-Score: 0.7701675255699197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7734871030725669
# Precision: 0.7640011828206987
# Recall: 0.7890139652849278
# F1-Score: 0.77630614675593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7553375477759923
# Precision: 0.7637017870570431
# Recall: 0.7400912525105784
# F1-Score: 0.7517111693642708
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7650857812412808
# Precision: 0.7609750548758757
# Recall: 0.7598457040927395
# F1-Score: 0.7604099601603395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7792296596134702
# Precision: 0.7866342498854823
# Recall: 0.7969118848631228
# F1-Score: 0.791739715084017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7743952285620888
# Precision: 0.7702644808112865
# Recall: 0.7908785892493623
# F1-Score: 0.7804354355674225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.7885311027677102
# Precision: 0.7887896923314953
# Recall: 0.7790435768228469
# F1-Score: 0.7838863422082768
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7651076461523459
# Precision: 0.7615249754879387
# Recall: 0.7777505574793233
# F1-Score: 0.7695522491394907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.7773137091494179
# Precision: 0.7825631920767604
# Recall: 0.7938112513591195
# F1-Score: 0.7881470920272606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7546937787183261
# Precision: 0.7515042296954018
# Recall: 0.7735462125495672
# F1-Score: 0.7623659316345159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7631990580671768
# Precision: 0.7584334350260696
# Recall: 0.7566074007638323
# F1-Score: 0.7575193174621941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.7524161621542036
# Precision: 0.7503502471551265
# Recall: 0.74826253353549
# F1-Score: 0.7493049361510649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7655308909613356
# Precision: 0.7655814350864001
# Recall: 0.7526762832054116
# F1-Score: 0.7590740124149904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7539259371144633
# Precision: 0.75039893063946
# Recall: 0.7449557938542598
# F1-Score: 0.7476674556549399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Air-Droid
# Accuracy: 0.7694691992584001
# Precision: 0.7676055829492869
# Recall: 0.7773058463613393
# F1-Score: 0.7724252614175164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: FamiSafe
# Accuracy: 0.7604681465740223
# Precision: 0.7643681613813111
# Recall: 0.7741380424779907
# F1-Score: 0.7692220813928458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7545648272289747
# Precision: 0.7532056862901937
# Recall: 0.7659405889072372
# F1-Score: 0.759519759676091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.7821329785035057
# Precision: 0.7842181434493734
# Recall: 0.7865406613393862
# F1-Score: 0.7853776853613976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7672349965918641
# Precision: 0.7688978335750962
# Recall: 0.7485116249528732
# F1-Score: 0.7585677861667696
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.7638071685344562
# Precision: 0.7633006608949652
# Recall: 0.7673346571368186
# F1-Score: 0.7653123432083029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: kids-360
# Accuracy: 0.773531190600569
# Precision: 0.7656288698864193
# Recall: 0.7582683167268828
# F1-Score: 0.7619308172574234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.7541343807359592
# Precision: 0.7485057219122391
# Recall: 0.7543587488959881
# F1-Score: 0.7514208378611088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.7565004695970282
# Precision: 0.7609603487800877
# Recall: 0.7570038269672873
# F1-Score: 0.7589769316041571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: TiSpy
# Accuracy: 0.7785913188635679
# Precision: 0.7864975347591152
# Recall: 0.7819428850108021
# F1-Score: 0.7842135966805077
